# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/capstone2/notebooks'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2015.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1019442, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1831435403                                   GRUNWALDT
# 1                    1831374784                                     JOHNSON
# 2                    1831377340                                       WOLFF
# 3                    1831389816                                        ROSS
# 4                    1720466840                                      BETTIS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                  CHRISTINA                              A
# 1                       RYAN                              J
# 2                   PATRICIA                              A
# 3                    CYNTHIA                              A
# 4                    KRISTEN                              M
#
#   Credentials of the Provider Gender of the Provider  \
# 0                      FNP-BC                      F
# 1                        CRNA                      M
# 2                        D.C.                      F
# 3                        M.D.                      F
# 4                        CRNA                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                 540 N SCHMALE RD
# 1                           I                   5656 KELLEY ST
# 2                           I                  5332 46TH AVE S
# 3                           I                8755 S HARLEM AVE
# 4                           I                145 KIMEL PARK DR
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN         CAROL STREAM  ...
# 1                              NaN              HOUSTON  ...
# 2                              NaN          MINNEAPOLIS  ...
# 3                              NaN           BRIDGEVIEW  ...
# 4                        SUITE 120        WINSTON SALEM  ...
#
#   Percent (%) of Beneficiaries Identified With Depression   \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#   Percent (%) of Beneficiaries Identified With Diabetes   \
# 0                                                   34.0
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia   \
# 0                                                         57.0
# 1                                                         48.0
# 2                                                          NaN
# 3                                                          NaN
# 4                                                         58.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension   \
# 0                                                       57.0
# 1                                                       75.0
# 2                                                        NaN
# 3                                                        NaN
# 4                                                       75.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease   \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis   \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         0.0
# 3                                                         0.0
# 4                                                         NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis   \
# 0                                                                                  NaN
# 1                                                                                  NaN
# 2                                                                                  NaN
# 3                                                                                  NaN
# 4                                                                                 58.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   \
# 0                                                                                      NaN
# 1                                                                                      NaN
# 2                                                                                      NaN
# 3                                                                                      0.0
# 4                                                                                      0.0
#
#    Percent (%) of Beneficiaries Identified With Stroke   \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                    0.8336
# 1                                    2.4573
# 2                                    1.3695
# 3                                    1.0083
# 4                                    1.7666
#
# [5 rows x 70 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount ',
#        'Total Drug Medicare Payment Amount ',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#        'Percent (%) of Beneficiaries Identified With Asthma ',
#        'Percent (%) of Beneficiaries Identified With Cancer ',
#        'Percent (%) of Beneficiaries Identified With Heart Failure ',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Diabetes ',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#        'Percent (%) of Beneficiaries Identified With Hypertension ',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Percent (%) of Beneficiaries Identified With Stroke ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
list(med['Provider Type of the Provider'].unique())
# Out:
# ['Nurse Practitioner',
#  'CRNA',
#  'Chiropractic',
#  'Preventive Medicine',
#  'Emergency Medicine',
#  'Physician Assistant',
#  'Family Practice',
#  'Internal Medicine',
#  'Dermatology',
#  'Clinical Psychologist',
#  'Registered Dietician/Nutrition Professional',
#  'Licensed Clinical Social Worker',
#  'Physical Therapist',
#  'Neurology',
#  'Radiation Oncology',
#  'Obstetrics/Gynecology',
#  'Mass Immunization Roster Biller',
#  'Psychiatry',
#  'Psychologist (billing independently)',
#  'Podiatry',
#  'Osteopathic Manipulative Medicine',
#  'Certified Nurse Midwife',
#  'Pulmonary Disease',
#  'Hematology',
#  'General Practice',
#  'Ophthalmology',
#  'Hematology/Oncology',
#  'Orthopedic Surgery',
#  'Anesthesiology',
#  'Nephrology',
#  'Optometry',
#  'Addiction Medicine',
#  'Gastroenterology',
#  'Pediatric Medicine',
#  'Urology',
#  'Allergy/Immunology',
#  'Geriatric Medicine',
#  'General Surgery',
#  'Otolaryngology',
#  'Cardiology',
#  'Ambulance Service Supplier',
#  'Oral Surgery (dentists only)',
#  'Speech Language Pathologist',
#  'Endocrinology',
#  'Hand Surgery',
#  'Plastic and Reconstructive Surgery',
#  'Independent Diagnostic Testing Facility',
#  'Rheumatology',
#  'Gynecological/Oncology',
#  'Neurosurgery',
#  'Sports Medicine',
#  'Pathology',
#  'Interventional Pain Management',
#  'Maxillofacial Surgery',
#  'Colorectal Surgery (formerly proctology)',
#  'Infectious Disease',
#  'All Other Suppliers',
#  'Certified Clinical Nurse Specialist',
#  'Pain Management',
#  'Occupational therapist',
#  'Physical Medicine and Rehabilitation',
#  'Centralized Flu',
#  'Multispecialty Clinic/Group Practice',
#  'Cardiac Surgery',
#  'Diagnostic Radiology',
#  'Nuclear Medicine',
#  'Clinical Laboratory',
#  'Public Health Welfare Agency',
#  'Audiologist (billing independently)',
#  'Medical Oncology',
#  'Hospice and Palliative Care',
#  'Anesthesiologist Assistants',
#  'Critical Care (Intensivists)',
#  'Cardiac Electrophysiology',
#  'Thoracic Surgery',
#  'Interventional Radiology',
#  'Ambulatory Surgical Center',
#  'Interventional Cardiology',
#  'Vascular Surgery',
#  'Unknown Physician Specialty Code',
#  'Neuropsychiatry',
#  'Radiation Therapy',
#  'Surgical Oncology',
#  'Sleep Medicine',
#  'Geriatric Psychiatry',
#  'Portable X-ray',
#  'Peripheral Vascular Disease',
#  'Slide Preparation Facility',
#  'Mammographic Screening Center',
#  'Unknown Supplier/Provider',
#  'Pharmacy']

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',
                         'Multispecialty Clinic/Group Practice',
                           'Public Health Welfare Agency', 'Preventive Medicine']

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry','Clinical Psychologist','Psychologist (billing independently)',
                       ]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type of the Provider"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 55775

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
# Number of Beneficiaries With Race Not Elsewhere Classified                                float64
# Number of Hispanic Beneficiaries                                                          float64
# Number of Asian Pacific Islander Beneficiaries                                            float64
# Number of Beneficiaries Age 75 to 84                                                      float64
# Number of Black or African American Beneficiaries                                         float64
# Number of American Indian/Alaska Native Beneficiaries                                     float64
# Number of Beneficiaries Age Greater 84                                                    float64
# Number of Beneficiaries Age 65 to 74                                                      float64
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Number of Non-Hispanic White Beneficiaries                                                float64
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Number of Beneficiaries Age Less 65                                                       float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Number of Male Beneficiaries                                                              float64
# Number of Female Beneficiaries                                                            float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Submitted Charge Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Total Medical Medicare Payment Amount                                                     float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Gender of the Provider                                                                     object
# First Name of the Provider                                                                 object
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Medical Suppress Indicator                                                                           771
# Drug Suppress Indicator                                                                              771
# Number of Beneficiaries With Race Not Elsewhere Classified                                         10029
# Number of Hispanic Beneficiaries                                                                   10698
# Number of Asian Pacific Islander Beneficiaries                                                     11565
# Number of Beneficiaries Age 75 to 84                                                               12520
# Number of Black or African American Beneficiaries                                                  12734
# Number of American Indian/Alaska Native Beneficiaries                                              15378
# Number of Beneficiaries Age Greater 84                                                             17762
# Number of Beneficiaries Age 65 to 74                                                               17934
# Percent (%) of Beneficiaries Identified With Cancer                                                18970
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          19731
# Percent (%) of Beneficiaries Identified With Asthma                                                22019
# Percent (%) of Beneficiaries Identified With Heart Failure                                         22372
# Number of Non-Hispanic White Beneficiaries                                                         22801
# Street Address 2 of the Provider                                                                   22824
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 23046
# Percent (%) of Beneficiaries Identified With Stroke                                                23479
# Number of Beneficiaries Age Less 65                                                                23520
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   23575
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                23636
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                25419
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       25877
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       27395
# Number of Beneficiaries With Medicare Only Entitlement                                             27395
# Percent (%) of Beneficiaries Identified With Diabetes                                              28472
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             30305
# Number of Male Beneficiaries                                                                       31197
# Number of Female Beneficiaries                                                                     31197
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 32402
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        36102
# Percent (%) of Beneficiaries Identified With Hypertension                                          39426
# Middle Initial of the Provider                                                                     39570
# Percent (%) of Beneficiaries Identified With Depression                                            47787
# Credentials of the Provider                                                                        53477
# Total Medical Medicare Standardized Payment Amount                                                 55004
# Total Medical Submitted Charge Amount                                                              55004
# Total Medical Medicare Allowed Amount                                                              55004
# Number of Medicare Beneficiaries With Medical Services                                             55004
# Number of Medical Services                                                                         55004
# Number of HCPCS Associated With Medical Services                                                   55004
# Total Drug Medicare Standardized Payment Amount                                                    55004
# Total Drug Medicare Payment Amount                                                                 55004
# Total Drug Medicare Allowed Amount                                                                 55004
# Total Drug Submitted Charge Amount                                                                 55004
# Number of Drug Services                                                                            55004
# Number of HCPCS Associated With Drug Services                                                      55004
# Total Medical Medicare Payment Amount                                                              55004
# Number of Medicare Beneficiaries With Drug Services                                                55004
# Gender of the Provider                                                                             55774
# First Name of the Provider                                                                         55774
# National Provider Identifier                                                                       55775
# Total Medicare Standardized Payment Amount                                                         55775
# Last Name/Organization Name of the Provider                                                        55775
# Entity Type of the Provider                                                                        55775
# Street Address 1 of the Provider                                                                   55775
# City of the Provider                                                                               55775
# Zip Code of the Provider                                                                           55775
# State Code of the Provider                                                                         55775
# Country Code of the Provider                                                                       55775
# Provider Type of the Provider                                                                      55775
# Medicare Participation Indicator                                                                   55775
# Number of HCPCS                                                                                    55775
# Number of Services                                                                                 55775
# Number of Medicare Beneficiaries                                                                   55775
# Total Submitted Charge Amount                                                                      55775
# Total Medicare Allowed Amount                                                                      55775
# Total Medicare Payment Amount                                                                      55775
# Average Age of Beneficiaries                                                                       55775
# Average HCC Risk Score of Beneficiaries                                                            55775
#
#                                                                                          unique values  \
# Medical Suppress Indicator                                                                           2
# Drug Suppress Indicator                                                                              2
# Number of Beneficiaries With Race Not Elsewhere Classified                                          41
# Number of Hispanic Beneficiaries                                                                   270
# Number of Asian Pacific Islander Beneficiaries                                                     106
# Number of Beneficiaries Age 75 to 84                                                               352
# Number of Black or African American Beneficiaries                                                  331
# Number of American Indian/Alaska Native Beneficiaries                                               56
# Number of Beneficiaries Age Greater 84                                                             400
# Number of Beneficiaries Age 65 to 74                                                               336
# Percent (%) of Beneficiaries Identified With Cancer                                                 72
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           56
# Percent (%) of Beneficiaries Identified With Asthma                                                 71
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Number of Non-Hispanic White Beneficiaries                                                         811
# Street Address 2 of the Provider                                                                  7730
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  74
# Percent (%) of Beneficiaries Identified With Stroke                                                 75
# Number of Beneficiaries Age Less 65                                                                540
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    56
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        74
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       719
# Number of Beneficiaries With Medicare Only Entitlement                                             551
# Percent (%) of Beneficiaries Identified With Diabetes                                               67
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Number of Male Beneficiaries                                                                       521
# Number of Female Beneficiaries                                                                     667
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  72
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         67
# Percent (%) of Beneficiaries Identified With Hypertension                                           63
# Middle Initial of the Provider                                                                      29
# Percent (%) of Beneficiaries Identified With Depression                                             65
# Credentials of the Provider                                                                       2244
# Total Medical Medicare Standardized Payment Amount                                               54670
# Total Medical Submitted Charge Amount                                                            41641
# Total Medical Medicare Allowed Amount                                                            54765
# Number of Medicare Beneficiaries With Medical Services                                             976
# Number of Medical Services                                                                        3664
# Number of HCPCS Associated With Medical Services                                                    59
# Total Drug Medicare Standardized Payment Amount                                                    213
# Total Drug Medicare Payment Amount                                                                 213
# Total Drug Medicare Allowed Amount                                                                 214
# Total Drug Submitted Charge Amount                                                                 214
# Number of Drug Services                                                                            195
# Number of HCPCS Associated With Drug Services                                                       13
# Total Medical Medicare Payment Amount                                                            54662
# Number of Medicare Beneficiaries With Drug Services                                                 67
# Gender of the Provider                                                                               2
# First Name of the Provider                                                                        9060
# National Provider Identifier                                                                     55775
# Total Medicare Standardized Payment Amount                                                       55433
# Last Name/Organization Name of the Provider                                                      29442
# Entity Type of the Provider                                                                          2
# Street Address 1 of the Provider                                                                 33069
# City of the Provider                                                                              4679
# Zip Code of the Provider                                                                         34859
# State Code of the Provider                                                                          57
# Country Code of the Provider                                                                         7
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     68
# Number of Services                                                                                3800
# Number of Medicare Beneficiaries                                                                   985
# Total Submitted Charge Amount                                                                    42354
# Total Medicare Allowed Amount                                                                    55528
# Total Medicare Payment Amount                                                                    55428
# Average Age of Beneficiaries                                                                        67
# Average HCC Risk Score of Beneficiaries                                                          18078
#
#                                                                                          null values
# Medical Suppress Indicator                                                                     55004
# Drug Suppress Indicator                                                                        55004
# Number of Beneficiaries With Race Not Elsewhere Classified                                     45746
# Number of Hispanic Beneficiaries                                                               45077
# Number of Asian Pacific Islander Beneficiaries                                                 44210
# Number of Beneficiaries Age 75 to 84                                                           43255
# Number of Black or African American Beneficiaries                                              43041
# Number of American Indian/Alaska Native Beneficiaries                                          40397
# Number of Beneficiaries Age Greater 84                                                         38013
# Number of Beneficiaries Age 65 to 74                                                           37841
# Percent (%) of Beneficiaries Identified With Cancer                                            36805
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      36044
# Percent (%) of Beneficiaries Identified With Asthma                                            33756
# Percent (%) of Beneficiaries Identified With Heart Failure                                     33403
# Number of Non-Hispanic White Beneficiaries                                                     32974
# Street Address 2 of the Provider                                                               32951
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             32729
# Percent (%) of Beneficiaries Identified With Stroke                                            32296
# Number of Beneficiaries Age Less 65                                                            32255
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               32200
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            32139
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            30356
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   29898
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   28380
# Number of Beneficiaries With Medicare Only Entitlement                                         28380
# Percent (%) of Beneficiaries Identified With Diabetes                                          27303
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         25470
# Number of Male Beneficiaries                                                                   24578
# Number of Female Beneficiaries                                                                 24578
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             23373
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    19673
# Percent (%) of Beneficiaries Identified With Hypertension                                      16349
# Middle Initial of the Provider                                                                 16205
# Percent (%) of Beneficiaries Identified With Depression                                         7988
# Credentials of the Provider                                                                     2298
# Total Medical Medicare Standardized Payment Amount                                               771
# Total Medical Submitted Charge Amount                                                            771
# Total Medical Medicare Allowed Amount                                                            771
# Number of Medicare Beneficiaries With Medical Services                                           771
# Number of Medical Services                                                                       771
# Number of HCPCS Associated With Medical Services                                                 771
# Total Drug Medicare Standardized Payment Amount                                                  771
# Total Drug Medicare Payment Amount                                                               771
# Total Drug Medicare Allowed Amount                                                               771
# Total Drug Submitted Charge Amount                                                               771
# Number of Drug Services                                                                          771
# Number of HCPCS Associated With Drug Services                                                    771
# Total Medical Medicare Payment Amount                                                            771
# Number of Medicare Beneficiaries With Drug Services                                              771
# Gender of the Provider                                                                             1
# First Name of the Provider                                                                         1
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
print(mental_med['Number of Black or African American Beneficiaries'].notnull().sum())
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]
# Out:
# 12734

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Medicare Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 12734

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 5628

# %% [markdown]
# For some years, some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Medicare Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 0

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Medicare Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 10045

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 5407

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 12734

# %%
black_medicare[age_cols[:-1]].isnull().any(axis=1).sum()
# Out:
# 10045

# %%
black_medicare[age_cols].head(3)
# Out:
#       Number of Beneficiaries Age Less 65  \
# 325                                   NaN
# 681                                   NaN
# 2666                                  NaN
#
#       Number of Beneficiaries Age 65 to 74  \
# 325                                    NaN
# 681                                    NaN
# 2666                                   NaN
#
#       Number of Beneficiaries Age 75 to 84  \
# 325                                    NaN
# 681                                    NaN
# 2666                                   NaN
#
#       Number of Beneficiaries Age Greater 84 Number of Medicare Beneficiaries
# 325                                      NaN                               11
# 681                                      NaN                               24
# 2666                                     NaN                               31

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (12734, 12734)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (5628, 5628)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Female Beneficiaries                                                            float64
# Number of Male Beneficiaries                                                              float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Total Medical Submitted Charge Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Drug Medicare Allowed Amount                                                        float64
# Number of Black or African American Beneficiaries                                         float64
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# First Name of the Provider                                                                 object
# Gender of the Provider                                                                     object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Medical Suppress Indicator                                                                           285
# Drug Suppress Indicator                                                                              285
# Street Address 2 of the Provider                                                                    5292
# Percent (%) of Beneficiaries Identified With Cancer                                                 5441
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           5484
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    6350
# Percent (%) of Beneficiaries Identified With Asthma                                                 6458
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 6483
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 6525
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  6611
# Percent (%) of Beneficiaries Identified With Heart Failure                                          6682
# Percent (%) of Beneficiaries Identified With Stroke                                                 6702
# Percent (%) of Beneficiaries Identified With Diabetes                                               6891
# Number of Beneficiaries With Medicare Only Entitlement                                              6920
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                        6920
# Number of Female Beneficiaries                                                                      6974
# Number of Male Beneficiaries                                                                        6974
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  7050
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        7245
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         7677
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              8162
# Percent (%) of Beneficiaries Identified With Hypertension                                           8174
# Middle Initial of the Provider                                                                      8869
# Percent (%) of Beneficiaries Identified With Depression                                             9796
# Credentials of the Provider                                                                        12243
# Total Medical Medicare Standardized Payment Amount                                                 12449
# Total Medical Medicare Payment Amount                                                              12449
# Total Medical Medicare Allowed Amount                                                              12449
# Total Medical Submitted Charge Amount                                                              12449
# Number of Medicare Beneficiaries With Medical Services                                             12449
# Number of Medical Services                                                                         12449
# Total Drug Medicare Standardized Payment Amount                                                    12449
# Total Drug Medicare Payment Amount                                                                 12449
# Total Drug Submitted Charge Amount                                                                 12449
# Number of Medicare Beneficiaries With Drug Services                                                12449
# Number of Drug Services                                                                            12449
# Number of HCPCS Associated With Drug Services                                                      12449
# Number of HCPCS Associated With Medical Services                                                   12449
# Total Drug Medicare Allowed Amount                                                                 12449
# Number of Black or African American Beneficiaries                                                  12734
# National Provider Identifier                                                                       12734
# Total Medicare Standardized Payment Amount                                                         12734
# Last Name/Organization Name of the Provider                                                        12734
# First Name of the Provider                                                                         12734
# Gender of the Provider                                                                             12734
# Entity Type of the Provider                                                                        12734
# Street Address 1 of the Provider                                                                   12734
# City of the Provider                                                                               12734
# Zip Code of the Provider                                                                           12734
# State Code of the Provider                                                                         12734
# Country Code of the Provider                                                                       12734
# Provider Type of the Provider                                                                      12734
# Medicare Participation Indicator                                                                   12734
# Number of HCPCS                                                                                    12734
# Number of Services                                                                                 12734
# Number of Medicare Beneficiaries                                                                   12734
# Total Submitted Charge Amount                                                                      12734
# Total Medicare Allowed Amount                                                                      12734
# Total Medicare Payment Amount                                                                      12734
# Average Age of Beneficiaries                                                                       12734
# Average HCC Risk Score of Beneficiaries                                                            12734
#
#                                                                                          unique values  \
# Medical Suppress Indicator                                                                           2
# Drug Suppress Indicator                                                                              1
# Street Address 2 of the Provider                                                                  2457
# Percent (%) of Beneficiaries Identified With Cancer                                                 33
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           42
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    43
# Percent (%) of Beneficiaries Identified With Asthma                                                 65
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 72
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  72
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Percent (%) of Beneficiaries Identified With Stroke                                                 68
# Percent (%) of Beneficiaries Identified With Diabetes                                               65
# Number of Beneficiaries With Medicare Only Entitlement                                             527
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       684
# Number of Female Beneficiaries                                                                     640
# Number of Male Beneficiaries                                                                       510
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  71
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         65
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Percent (%) of Beneficiaries Identified With Hypertension                                           60
# Middle Initial of the Provider                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                             63
# Credentials of the Provider                                                                        739
# Total Medical Medicare Standardized Payment Amount                                               12436
# Total Medical Medicare Payment Amount                                                            12436
# Total Medical Medicare Allowed Amount                                                            12437
# Total Medical Submitted Charge Amount                                                            11274
# Number of Medicare Beneficiaries With Medical Services                                             936
# Number of Medical Services                                                                        2734
# Total Drug Medicare Standardized Payment Amount                                                    129
# Total Drug Medicare Payment Amount                                                                 129
# Total Drug Submitted Charge Amount                                                                 129
# Number of Medicare Beneficiaries With Drug Services                                                 55
# Number of Drug Services                                                                            124
# Number of HCPCS Associated With Drug Services                                                       12
# Number of HCPCS Associated With Medical Services                                                    48
# Total Drug Medicare Allowed Amount                                                                 129
# Number of Black or African American Beneficiaries                                                  331
# National Provider Identifier                                                                     12734
# Total Medicare Standardized Payment Amount                                                       12721
# Last Name/Organization Name of the Provider                                                       8904
# First Name of the Provider                                                                        3694
# Gender of the Provider                                                                               2
# Entity Type of the Provider                                                                          1
# Street Address 1 of the Provider                                                                 10045
# City of the Provider                                                                              2786
# Zip Code of the Provider                                                                         10428
# State Code of the Provider                                                                          54
# Country Code of the Provider                                                                         1
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     56
# Number of Services                                                                                2843
# Number of Medicare Beneficiaries                                                                   946
# Total Submitted Charge Amount                                                                    11554
# Total Medicare Allowed Amount                                                                    12720
# Total Medicare Payment Amount                                                                    12721
# Average Age of Beneficiaries                                                                        60
# Average HCC Risk Score of Beneficiaries                                                           9026
#
#                                                                                          null values
# Medical Suppress Indicator                                                                     12449
# Drug Suppress Indicator                                                                        12449
# Street Address 2 of the Provider                                                                7442
# Percent (%) of Beneficiaries Identified With Cancer                                             7293
# Percent (%) of Beneficiaries Identified With Osteoporosis                                       7250
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                6384
# Percent (%) of Beneficiaries Identified With Asthma                                             6276
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                             6251
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                             6209
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease              6123
# Percent (%) of Beneficiaries Identified With Heart Failure                                      6052
# Percent (%) of Beneficiaries Identified With Stroke                                             6032
# Percent (%) of Beneficiaries Identified With Diabetes                                           5843
# Number of Beneficiaries With Medicare Only Entitlement                                          5814
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                    5814
# Number of Female Beneficiaries                                                                  5760
# Number of Male Beneficiaries                                                                    5760
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis              5684
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                    5489
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                     5057
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders          4572
# Percent (%) of Beneficiaries Identified With Hypertension                                       4560
# Middle Initial of the Provider                                                                  3865
# Percent (%) of Beneficiaries Identified With Depression                                         2938
# Credentials of the Provider                                                                      491
# Total Medical Medicare Standardized Payment Amount                                               285
# Total Medical Medicare Payment Amount                                                            285
# Total Medical Medicare Allowed Amount                                                            285
# Total Medical Submitted Charge Amount                                                            285
# Number of Medicare Beneficiaries With Medical Services                                           285
# Number of Medical Services                                                                       285
# Total Drug Medicare Standardized Payment Amount                                                  285
# Total Drug Medicare Payment Amount                                                               285
# Total Drug Submitted Charge Amount                                                               285
# Number of Medicare Beneficiaries With Drug Services                                              285
# Number of Drug Services                                                                          285
# Number of HCPCS Associated With Drug Services                                                    285
# Number of HCPCS Associated With Medical Services                                                 285
# Total Drug Medicare Allowed Amount                                                               285
# Number of Black or African American Beneficiaries                                                  0
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# First Name of the Provider                                                                         0
# Gender of the Provider                                                                             0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries','Number of Medicare Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 6974
# Has nulls: 5760

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Medicare Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 6974
# Don't sum 0

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Drug Suppress Indicator                                                                    object
# Medical Suppress Indicator                                                                 object
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Submitted Charge Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Medical Medicare Allowed Amount                                                     float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Medical Medicare Standardized Payment Amount                                        float64
# Number of Black or African American Beneficiaries                                         float64
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# First Name of the Provider                                                                 object
# Gender of the Provider                                                                     object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Drug Suppress Indicator                                                                              285
# Medical Suppress Indicator                                                                           285
# Street Address 2 of the Provider                                                                    5292
# Percent (%) of Beneficiaries Identified With Cancer                                                 5441
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           5484
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    6350
# Percent (%) of Beneficiaries Identified With Asthma                                                 6458
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 6483
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 6525
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  6611
# Percent (%) of Beneficiaries Identified With Heart Failure                                          6682
# Percent (%) of Beneficiaries Identified With Stroke                                                 6702
# Percent (%) of Beneficiaries Identified With Diabetes                                               6891
# Number of Beneficiaries With Medicare Only Entitlement                                              6920
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                        6920
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  7050
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        7245
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         7677
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              8162
# Percent (%) of Beneficiaries Identified With Hypertension                                           8174
# Middle Initial of the Provider                                                                      8869
# Percent (%) of Beneficiaries Identified With Depression                                             9796
# Credentials of the Provider                                                                        12243
# Total Medical Submitted Charge Amount                                                              12449
# Number of Medicare Beneficiaries With Medical Services                                             12449
# Number of Medical Services                                                                         12449
# Number of HCPCS Associated With Medical Services                                                   12449
# Total Medical Medicare Allowed Amount                                                              12449
# Total Drug Medicare Standardized Payment Amount                                                    12449
# Total Drug Medicare Allowed Amount                                                                 12449
# Total Drug Submitted Charge Amount                                                                 12449
# Number of Medicare Beneficiaries With Drug Services                                                12449
# Number of Drug Services                                                                            12449
# Number of HCPCS Associated With Drug Services                                                      12449
# Total Medical Medicare Payment Amount                                                              12449
# Total Drug Medicare Payment Amount                                                                 12449
# Total Medical Medicare Standardized Payment Amount                                                 12449
# Number of Black or African American Beneficiaries                                                  12734
# National Provider Identifier                                                                       12734
# Total Medicare Standardized Payment Amount                                                         12734
# Last Name/Organization Name of the Provider                                                        12734
# First Name of the Provider                                                                         12734
# Gender of the Provider                                                                             12734
# Entity Type of the Provider                                                                        12734
# Street Address 1 of the Provider                                                                   12734
# City of the Provider                                                                               12734
# Zip Code of the Provider                                                                           12734
# State Code of the Provider                                                                         12734
# Country Code of the Provider                                                                       12734
# Provider Type of the Provider                                                                      12734
# Medicare Participation Indicator                                                                   12734
# Number of HCPCS                                                                                    12734
# Number of Services                                                                                 12734
# Number of Medicare Beneficiaries                                                                   12734
# Total Submitted Charge Amount                                                                      12734
# Total Medicare Allowed Amount                                                                      12734
# Total Medicare Payment Amount                                                                      12734
# Average Age of Beneficiaries                                                                       12734
# Average HCC Risk Score of Beneficiaries                                                            12734
#
#                                                                                          unique values  \
# Drug Suppress Indicator                                                                              1
# Medical Suppress Indicator                                                                           2
# Street Address 2 of the Provider                                                                  2457
# Percent (%) of Beneficiaries Identified With Cancer                                                 33
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           42
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    43
# Percent (%) of Beneficiaries Identified With Asthma                                                 65
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 72
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  72
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Percent (%) of Beneficiaries Identified With Stroke                                                 68
# Percent (%) of Beneficiaries Identified With Diabetes                                               65
# Number of Beneficiaries With Medicare Only Entitlement                                             527
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       684
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  71
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         65
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Percent (%) of Beneficiaries Identified With Hypertension                                           60
# Middle Initial of the Provider                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                             63
# Credentials of the Provider                                                                        739
# Total Medical Submitted Charge Amount                                                            11274
# Number of Medicare Beneficiaries With Medical Services                                             936
# Number of Medical Services                                                                        2734
# Number of HCPCS Associated With Medical Services                                                    48
# Total Medical Medicare Allowed Amount                                                            12437
# Total Drug Medicare Standardized Payment Amount                                                    129
# Total Drug Medicare Allowed Amount                                                                 129
# Total Drug Submitted Charge Amount                                                                 129
# Number of Medicare Beneficiaries With Drug Services                                                 55
# Number of Drug Services                                                                            124
# Number of HCPCS Associated With Drug Services                                                       12
# Total Medical Medicare Payment Amount                                                            12436
# Total Drug Medicare Payment Amount                                                                 129
# Total Medical Medicare Standardized Payment Amount                                               12436
# Number of Black or African American Beneficiaries                                                  331
# National Provider Identifier                                                                     12734
# Total Medicare Standardized Payment Amount                                                       12721
# Last Name/Organization Name of the Provider                                                       8904
# First Name of the Provider                                                                        3694
# Gender of the Provider                                                                               2
# Entity Type of the Provider                                                                          1
# Street Address 1 of the Provider                                                                 10045
# City of the Provider                                                                              2786
# Zip Code of the Provider                                                                         10428
# State Code of the Provider                                                                          54
# Country Code of the Provider                                                                         1
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     56
# Number of Services                                                                                2843
# Number of Medicare Beneficiaries                                                                   946
# Total Submitted Charge Amount                                                                    11554
# Total Medicare Allowed Amount                                                                    12720
# Total Medicare Payment Amount                                                                    12721
# Average Age of Beneficiaries                                                                        60
# Average HCC Risk Score of Beneficiaries                                                           9026
#
#                                                                                          null values
# Drug Suppress Indicator                                                                        12449
# Medical Suppress Indicator                                                                     12449
# Street Address 2 of the Provider                                                                7442
# Percent (%) of Beneficiaries Identified With Cancer                                             7293
# Percent (%) of Beneficiaries Identified With Osteoporosis                                       7250
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                6384
# Percent (%) of Beneficiaries Identified With Asthma                                             6276
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                             6251
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                             6209
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease              6123
# Percent (%) of Beneficiaries Identified With Heart Failure                                      6052
# Percent (%) of Beneficiaries Identified With Stroke                                             6032
# Percent (%) of Beneficiaries Identified With Diabetes                                           5843
# Number of Beneficiaries With Medicare Only Entitlement                                          5814
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                    5814
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis              5684
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                    5489
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                     5057
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders          4572
# Percent (%) of Beneficiaries Identified With Hypertension                                       4560
# Middle Initial of the Provider                                                                  3865
# Percent (%) of Beneficiaries Identified With Depression                                         2938
# Credentials of the Provider                                                                      491
# Total Medical Submitted Charge Amount                                                            285
# Number of Medicare Beneficiaries With Medical Services                                           285
# Number of Medical Services                                                                       285
# Number of HCPCS Associated With Medical Services                                                 285
# Total Medical Medicare Allowed Amount                                                            285
# Total Drug Medicare Standardized Payment Amount                                                  285
# Total Drug Medicare Allowed Amount                                                               285
# Total Drug Submitted Charge Amount                                                               285
# Number of Medicare Beneficiaries With Drug Services                                              285
# Number of Drug Services                                                                          285
# Number of HCPCS Associated With Drug Services                                                    285
# Total Medical Medicare Payment Amount                                                            285
# Total Drug Medicare Payment Amount                                                               285
# Total Medical Medicare Standardized Payment Amount                                               285
# Number of Black or African American Beneficiaries                                                  0
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# First Name of the Provider                                                                         0
# Gender of the Provider                                                                             0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
     'National Provider Identifier', #keeping this as unique ID for each provider
    'Provider Type of the Provider',
     'Number of Medicare Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'City of the Provider', 
 'State Code of the Provider',
 'Zip Code of the Provider',
    'Average HCC Risk Score of Beneficiaries '
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression ', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
 'Country Code of the Provider',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Total Drug Medicare Allowed Amount ',
#  'Percent (%) of Beneficiaries Identified With Heart Failure ',
#  'Drug Suppress Indicator',
#  'Medicare Participation Indicator',
#  'Number of Beneficiaries With Medicare Only Entitlement',
#  'Percent (%) of Beneficiaries Identified With Asthma ',
#  'First Name of the Provider',
#  'Percent (%) of Beneficiaries Identified With Stroke ',
#  'Number of Services',
#  'Number of HCPCS Associated With Medical Services',
#  'Number of HCPCS Associated With Drug Services',
#  'Total Medical Medicare Standardized Payment Amount',
#  'Total Medical Medicare Allowed Amount',
#  'Total Medicare Allowed Amount',
#  'Entity Type of the Provider',
#  'Number of Medical Services',
#  'Total Drug Medicare Payment Amount ',
#  'Street Address 2 of the Provider',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#  'Medical Suppress Indicator',
#  'Number of Medicare Beneficiaries With Drug Services',
#  'Total Medicare Standardized Payment Amount',
#  'Middle Initial of the Provider',
#  'Total Drug Submitted Charge Amount',
#  'Number of Medicare Beneficiaries With Medical Services',
#  'Percent (%) of Beneficiaries Identified With Hypertension ',
#  'Number of Drug Services',
#  'Gender of the Provider',
#  'Last Name/Organization Name of the Provider',
#  'Total Medical Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Total Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#  'Street Address 1 of the Provider',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Credentials of the Provider',
#  'Number of HCPCS',
#  'Total Medical Submitted Charge Amount',
#  'Total Drug Medicare Standardized Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#  'Percent (%) of Beneficiaries Identified With Cancer ',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Percent (%) of Beneficiaries Identified With Diabetes ']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape, all_medicare.shape
# Out:
# ((12734, 13), (5628, 18))

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries ':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression ':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ':
                    'percent_with_psychosis'}

                
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %%
all_medicare.columns, black_medicare.columns
# Out:
# (Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_white', 'num_black', 'num_asian_pac_isl', 'num_hispanic',
#         'num_nat_amer', 'num_race_unknown', 'percent_with_depression',
#         'percent_with_psychosis', 'avg_hcc_risk_score'],
#        dtype='object'),
#  Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_black', 'percent_with_depression', 'percent_with_psychosis',
#         'avg_hcc_risk_score'],
#        dtype='object'))

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#Some years' DFs have country values that are not 'US' listed in Country

# %%
black_medicare.country.unique()
# Out:
# array(['US'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# Some zip codes are integers, others strings, others floats.

# %%
black_medicare.full_zip.apply(lambda x: type(x)).unique()
# Out:
# array([<class 'int'>, <class 'str'>], dtype=object)

# %% [markdown]
# Turning floats to integers and then to strings

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int').astype('str')

# %% [markdown]
# Next I have to convert the NPPES Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9408
# 8    1664
# 5    1224
# 4     314
# 3      68
# 7      56
# Name: full_zip, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 2674     5701
# 6350     7834
# 13297    6032
# 17095    7631
# 39332    4011
# Name: full_zip, dtype: object

# %%
#adding leading zeros to the five digit zip code
idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9790
# 8    1664
# 5    1224
# 7      56
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ].head()['full_zip']
# Out:
# 8122     49855
# 9700     87420
# 10563    98372
# 10732    12084
# 13355    51503
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# 469384    9797001
# 427297    9616910
# 16257     9182112
# 20212     7170722
# 37710     7171686
# Name: full_zip, dtype: object

# %%
#I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    12734
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 5002

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    12734
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.
idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    12734
# Name: full_zip, dtype: int64
# 5    12734
# Name: five_dig_zip, dtype: int64
# 9    5628
# Name: full_zip, dtype: int64
# 5    5628
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12734 entries, 325 to 1009169
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      12734 non-null  object
#  1   city                     12734 non-null  object
#  2   full_zip                 12734 non-null  object
#  3   state                    12734 non-null  object
#  4   country                  12734 non-null  object
#  5   provider_type            12734 non-null  object
#  6   total_beneficiaries      12734 non-null  object
#  7   total_medicare_payment   12734 non-null  float64
#  8   avg_beneficiary_age      12734 non-null  object
#  9   num_black                12734 non-null  float64
#  10  percent_with_depression  9796 non-null   float64
#  11  percent_with_psychosis   8162 non-null   float64
#  12  avg_hcc_risk_score       12734 non-null  float64
#  13  five_dig_zip             12734 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 2.1+ MB

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5628 entries, 681 to 1009169
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      5628 non-null   object
#  1   city                     5628 non-null   object
#  2   full_zip                 5628 non-null   object
#  3   state                    5628 non-null   object
#  4   country                  5628 non-null   object
#  5   provider_type            5628 non-null   object
#  6   total_beneficiaries      5628 non-null   object
#  7   total_medicare_payment   5628 non-null   float64
#  8   avg_beneficiary_age      5628 non-null   object
#  9   num_white                5628 non-null   float64
#  10  num_black                5628 non-null   float64
#  11  num_asian_pac_isl        5628 non-null   float64
#  12  num_hispanic             5628 non-null   float64
#  13  num_nat_amer             5628 non-null   float64
#  14  num_race_unknown         5628 non-null   float64
#  15  percent_with_depression  3709 non-null   float64
#  16  percent_with_psychosis   2067 non-null   float64
#  17  avg_hcc_risk_score       5628 non-null   float64
#  18  five_dig_zip             5628 non-null   object
# dtypes: float64(10), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../data/raw/2015acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   98304                   222                112
# 1   22714                    74                304
# 2   69128                    24                 74
# 3   97908                    13                 16
# 4   37228                   503                132
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1974.0                        18
# 1                       1978.0                         6
# 2                       1955.0                         0
# 3                       1939.0                         9
# 4                       2002.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                     0                      0                      0
# 1                     0                      0                      0
# 2                     0                      0                      0
# 3                     4                      0                      2
# 4                   265                     27                     98
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  commute_60_more_mins  \
# 0                      0                      0  ...                    90
# 1                      0                      0  ...                    86
# 2                      3                      0  ...                     2
# 3                      0                      0  ...                     3
# 4                     57                     33  ...                     0
#
#    commute_less_10_mins  commuters_16_over  hispanic_any_race  \
# 0                    42                347                  0
# 1                    77                562                 29
# 2                     9                 91                 12
# 3                     4                 19                  0
# 4                    71                381                  9
#
#    pop_5_years_over  speak_only_english_at_home  speak_spanish_at_home  \
# 0               636                         611                      0
# 1              1058                        1046                     12
# 2               183                         177                      6
# 3                50                          48                      0
# 4              1160                        1090                     26
#
#    speak_spanish_at_home_low_english   do_date  geoid
# 0                                  0  20112015    NaN
# 1                                  0  20112015    NaN
# 2                                  1  20112015    NaN
# 3                                  0  20112015    NaN
# 4                                  0  20112015    NaN
#
# [5 rows x 247 columns]

# %%
# dropping do_date columns, which gives info on how numbers for this year were calculated
# but isn't useful for my investigation.

census.drop(columns=['do_date'], inplace=True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# geoid                                                         float64
# aggregate_travel_time_to_work                                 float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# high_school_including_ged                                     float64
# less_than_high_school_graduate                                float64
# population_1_year_and_over                                    float64
# different_house_year_ago_same_city                            float64
# different_house_year_ago_different_city                       float64
# bachelors_degree_2                                            float64
# not_us_citizen_pop                                            float64
# some_college_and_associates_degree                            float64
# graduate_professional_degree                                  float64
# sales_office_employed                                           int64
# hispanic_male_45_54                                             int64
# hispanic_male_55_64                                             int64
# white_male_45_54                                                int64
# white_male_55_64                                                int64
# speak_spanish_at_home                                           int64
# bachelors_degree_or_higher_25_64                                int64
# children                                                        int64
#
#                                                              non-null values  \
# geoid                                                                      0
# aggregate_travel_time_to_work                                          20376
# median_rent                                                            27240
# renter_occupied_housing_units_paying_cash_median_gross_rent            27431
# percent_income_spent_on_rent                                           27822
# owner_occupied_housing_units_lower_value_quartile                      30241
# owner_occupied_housing_units_upper_value_quartile                      30764
# owner_occupied_housing_units_median_value                              30793
# median_income                                                          31067
# median_year_structure_built                                            32230
# gini_index                                                             32277
# income_per_capita                                                      32542
# median_age                                                             32615
# high_school_including_ged                                              32989
# less_than_high_school_graduate                                         32989
# population_1_year_and_over                                             32989
# different_house_year_ago_same_city                                     32989
# different_house_year_ago_different_city                                32989
# bachelors_degree_2                                                     32989
# not_us_citizen_pop                                                     32989
# some_college_and_associates_degree                                     32989
# graduate_professional_degree                                           32989
# sales_office_employed                                                  33120
# hispanic_male_45_54                                                    33120
# hispanic_male_55_64                                                    33120
# white_male_45_54                                                       33120
# white_male_55_64                                                       33120
# speak_spanish_at_home                                                  33120
# bachelors_degree_or_higher_25_64                                       33120
# children                                                               33120
#
#                                                              unique values  \
# geoid                                                                    0
# aggregate_travel_time_to_work                                        17111
# median_rent                                                           1867
# renter_occupied_housing_units_paying_cash_median_gross_rent           1905
# percent_income_spent_on_rent                                           397
# owner_occupied_housing_units_lower_value_quartile                     4136
# owner_occupied_housing_units_upper_value_quartile                     6151
# owner_occupied_housing_units_median_value                             5119
# median_income                                                        19382
# median_year_structure_built                                             73
# gini_index                                                            4125
# income_per_capita                                                    20437
# median_age                                                             654
# high_school_including_ged                                             7200
# less_than_high_school_graduate                                        4588
# population_1_year_and_over                                           15307
# different_house_year_ago_same_city                                    3617
# different_house_year_ago_different_city                               4848
# bachelors_degree_2                                                    5961
# not_us_citizen_pop                                                    4190
# some_college_and_associates_degree                                    7568
# graduate_professional_degree                                          4479
# sales_office_employed                                                 5492
# hispanic_male_45_54                                                   1553
# hispanic_male_55_64                                                   1182
# white_male_45_54                                                      2753
# white_male_55_64                                                      2587
# speak_spanish_at_home                                                 5074
# bachelors_degree_or_higher_25_64                                      6960
# children                                                              8263
#
#                                                              null values
# geoid                                                              33120
# aggregate_travel_time_to_work                                      12744
# median_rent                                                         5880
# renter_occupied_housing_units_paying_cash_median_gross_rent         5689
# percent_income_spent_on_rent                                        5298
# owner_occupied_housing_units_lower_value_quartile                   2879
# owner_occupied_housing_units_upper_value_quartile                   2356
# owner_occupied_housing_units_median_value                           2327
# median_income                                                       2053
# median_year_structure_built                                          890
# gini_index                                                           843
# income_per_capita                                                    578
# median_age                                                           505
# high_school_including_ged                                            131
# less_than_high_school_graduate                                       131
# population_1_year_and_over                                           131
# different_house_year_ago_same_city                                   131
# different_house_year_ago_different_city                              131
# bachelors_degree_2                                                   131
# not_us_citizen_pop                                                   131
# some_college_and_associates_degree                                   131
# graduate_professional_degree                                         131
# sales_office_employed                                                  0
# hispanic_male_45_54                                                    0
# hispanic_male_55_64                                                    0
# white_male_45_54                                                       0
# white_male_55_64                                                       0
# speak_spanish_at_home                                                  0
# bachelors_degree_or_higher_25_64                                       0
# children                                                               0

# %% [markdown]
# Deleting columns with ZERO nonnull values. Weirdly these columns have info for all rows in the previous years.

# %%
allnull = list(info[info['non-null values']==0].index)
allnull
# Out:
# ['geoid']

# %%
census.drop(columns = allnull, inplace = True)

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['40536', '30639', '02065', '38157', '32163', '09126', '94141', '60567',
#        '33199', '23298', '77555', '92415', '45408', '94143', '03247', '92357',
#        '37044', '00801', '61637', '06030', '27710', '03756', '84132', '06904',
#        '19849', '48337', '32610', '06102', '00908', '66160', '00802', '54221',
#        '84603', '28286', '90509', '29151', '29425', '68198', '71130', '55903',
#        '08754', '95617', '85220', '23249', '87131', '20042', '14642', '98431',
#        '20060', '11242', '84068', '77805', '44195', '11571', '53102', '22908',
#        '27157', '00726', '10982', '48824', '12141', '61636', '21287', '02178',
#        '04333', '00919', '00963', '05302', '27599', '65212', '35249', '65211',
#        '29240', '92093', '37232', '85228', '49685', '18934', '84143', '20453',
#        '29220', '37684', '00977', '00792', '65102'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi              city   full_zip state country  \
# five_dig_zip
# 40536         1538217906         LEXINGTON  405361217    KY      US
# 30639         1972621472  FRANKLIN SPRINGS  306390000    GA      US
# 02065         1588768980       OCEAN BLUFF  020652480    MA      US
# 38157         1326048703           MEMPHIS  381570101    TN      US
# 38157         1407912926           MEMPHIS  381571610    TN      US
# ...                  ...               ...        ...   ...     ...
# 37684         1609017961     MOUNTAIN HOME  376840699    TN      US
# 37684         1417138512     MOUNTAIN HOME  376840699    TN      US
# 00977         1316063290     TRUJILLO ALTO  009770000    PR      US
# 00792         1588704720           HUMACAO  007920000    PR      US
# 65102         1639287915    JEFFERSON CITY  651021128    MO      US
#
#                                 provider_type total_beneficiaries  \
# five_dig_zip
# 40536                   Clinical Psychologist                  15
# 30639                   Clinical Psychologist                  35
# 02065                   Clinical Psychologist                  20
# 38157                   Clinical Psychologist                 124
# 38157                   Clinical Psychologist                  36
# ...                                       ...                 ...
# 37684         Licensed Clinical Social Worker                  11
# 37684                              Psychiatry                  52
# 00977                   Clinical Psychologist                  33
# 00792                              Psychiatry                  32
# 65102         Licensed Clinical Social Worker                  18
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 40536                        7550.30                  54        0.0
# 30639                       17512.85                  64        0.0
# 02065                       19016.69                  57        0.0
# 38157                       47714.58                  62       12.0
# 38157                       42485.65                  52       19.0
# ...                              ...                 ...        ...
# 37684                        6830.03                  60        0.0
# 37684                       15136.74                  68        0.0
# 00977                       11029.79                  84        0.0
# 00792                        5205.28                  60        0.0
# 65102                        7235.05                  59        0.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 40536                     1.2043
# 30639                     1.0925
# 02065                     1.5034
# 38157                     1.4978
# 38157                     1.3864
# ...                          ...
# 37684                     1.3932
# 37684                     1.9651
# 00977                     1.9054
# 00792                     1.0670
# 65102                     1.3228
#
# [202 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 4917
# 4917

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# not_us_citizen_pop                                            float64
# bachelors_degree_2                                            float64
# different_house_year_ago_different_city                       float64
# less_than_high_school_graduate                                float64
# population_1_year_and_over                                    float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# different_house_year_ago_same_city                            float64
# some_college_and_associates_degree                            float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# armed_forces                                                    int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_drove_alone                                           int64
# amerindian_including_hispanic                                   int64
# black_including_hispanic                                        int64
# white_including_hispanic                                        int64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# female_85_and_over                                              int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           4682
# owner_occupied_housing_units_lower_value_quartile                       4849
# owner_occupied_housing_units_median_value                               4852
# owner_occupied_housing_units_upper_value_quartile                       4854
# median_rent                                                             4857
# renter_occupied_housing_units_paying_cash_median_gross_rent             4861
# percent_income_spent_on_rent                                            4864
# not_us_citizen_pop                                                      4870
# bachelors_degree_2                                                      4870
# different_house_year_ago_different_city                                 4870
# less_than_high_school_graduate                                          4870
# population_1_year_and_over                                              4870
# high_school_including_ged                                               4870
# graduate_professional_degree                                            4870
# different_house_year_ago_same_city                                      4870
# some_college_and_associates_degree                                      4870
# median_income                                                           4876
# median_year_structure_built                                             4881
# gini_index                                                              4882
# income_per_capita                                                       4904
# median_age                                                              4907
# armed_forces                                                            4917
# commuters_by_carpool                                                    4917
# commuters_by_subway_or_elevated                                         4917
# commuters_drove_alone                                                   4917
# amerindian_including_hispanic                                           4917
# black_including_hispanic                                                4917
# white_including_hispanic                                                4917
# employed_agriculture_forestry_fishing_hunting_mining                    4917
# female_85_and_over                                                      4917
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         4599
# owner_occupied_housing_units_lower_value_quartile                     2639
# owner_occupied_housing_units_median_value                             2988
# owner_occupied_housing_units_upper_value_quartile                     3229
# median_rent                                                           1374
# renter_occupied_housing_units_paying_cash_median_gross_rent           1375
# percent_income_spent_on_rent                                           314
# not_us_citizen_pop                                                    2759
# bachelors_degree_2                                                    3730
# different_house_year_ago_different_city                               3250
# less_than_high_school_graduate                                        3043
# population_1_year_and_over                                            4628
# high_school_including_ged                                             3839
# graduate_professional_degree                                          3274
# different_house_year_ago_same_city                                    2642
# some_college_and_associates_degree                                    3924
# median_income                                                         4696
# median_year_structure_built                                             69
# gini_index                                                            1891
# income_per_capita                                                     4619
# median_age                                                             406
# armed_forces                                                           392
# commuters_by_carpool                                                  2221
# commuters_by_subway_or_elevated                                        648
# commuters_drove_alone                                                 4339
# amerindian_including_hispanic                                          708
# black_including_hispanic                                              3076
# white_including_hispanic                                              4632
# employed_agriculture_forestry_fishing_hunting_mining                   635
# female_85_and_over                                                    1037
#
#                                                              null values
# aggregate_travel_time_to_work                                        235
# owner_occupied_housing_units_lower_value_quartile                     68
# owner_occupied_housing_units_median_value                             65
# owner_occupied_housing_units_upper_value_quartile                     63
# median_rent                                                           60
# renter_occupied_housing_units_paying_cash_median_gross_rent           56
# percent_income_spent_on_rent                                          53
# not_us_citizen_pop                                                    47
# bachelors_degree_2                                                    47
# different_house_year_ago_different_city                               47
# less_than_high_school_graduate                                        47
# population_1_year_and_over                                            47
# high_school_including_ged                                             47
# graduate_professional_degree                                          47
# different_house_year_ago_same_city                                    47
# some_college_and_associates_degree                                    47
# median_income                                                         41
# median_year_structure_built                                           36
# gini_index                                                            35
# income_per_capita                                                     13
# median_age                                                            10
# armed_forces                                                           0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# commuters_drove_alone                                                  0
# amerindian_including_hispanic                                          0
# black_including_hispanic                                               0
# white_including_hispanic                                               0
# employed_agriculture_forestry_fishing_hunting_mining                   0
# female_85_and_over                                                     0

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls. This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (60, 60)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 4857 4857
# 3086 4857
# 3097 4857

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(5)
# Out:
#                                         data type  non-null values  \
# bachelors_degree_2                        float64             4812
# less_than_high_school_graduate            float64             4812
# different_house_year_ago_different_city   float64             4812
# different_house_year_ago_same_city        float64             4812
# population_1_year_and_over                float64             4812
#
#                                          unique values  null values
# bachelors_degree_2                                3709           45
# less_than_high_school_graduate                    3031           45
# different_house_year_ago_different_city           3224           45
# different_house_year_ago_same_city                2641           45
# population_1_year_and_over                        4579           45

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (45, 45)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#               data type  non-null values  unique values  null values
# median_income   float64             4808           4632            4

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((12277, 12), (6732, 14), (5401, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    4812
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [4]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../data/processed/2015black_medicare_census')

#saving all races medicare df merged
disorders_merged.to_csv('../data/processed/2015black_medicare_with_disorders_census')

#saving black_medicare with disorder values merged
all_merged.to_csv('../data/processed/2015all_races_medicare_census')
