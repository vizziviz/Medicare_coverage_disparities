# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/capstone2/notebooks'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2013.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (956293, 67)

# %%
med.head()
# Out:
#           NPI NPPES Provider Last Name / Organization Name  \
# 0  1003183823                                     POPADIUK
# 1  1003813437                                       DONATO
# 2  1003814310                                      MURTAZA
# 3  1003828153                                       LEVINE
# 4  1003879693                                        ALLEY
#
#   NPPES Provider First Name NPPES Provider Middle Initial NPPES Credentials  \
# 0                     LILIA                           NaN              P.A.
# 1                   HEATHER                             O              M.D.
# 2                    GHULAM                           NaN              M.D.
# 3                   SEYMOUR                           NaN                MD
# 4                     CAROL                             L                MD
#
#   NPPES Provider Gender NPPES Entity Code NPPES Provider Street Address 1  \
# 0                     F                 I                 6071 W OUTER DR
# 1                     F                 I            7205 WOLF RIVER BLVD
# 2                     M                 I                4800 ALBERTA AVE
# 3                     M                 I        150 NORTH ROBERTSON BLVD
# 4                     F                 I           320 BAWDEN ST APT 313
#
#   NPPES Provider Street Address 2 NPPES Provider City  ...  \
# 0                             NaN             DETROIT  ...
# 1                       SUITE 150          GERMANTOWN  ...
# 2                             NaN             EL PASO  ...
# 3                            #350       BEVERLY HILLS  ...
# 4                             NaN           KETCHIKAN  ...
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                                NaN
# 1                                                NaN
# 2                                               35.0
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Heart Failure  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               42.0
# 1                                               44.0
# 2                                               53.0
# 3                                               60.0
# 4                                               28.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               73.0
# 1                                               44.0
# 2                                               74.0
# 3                                               60.0
# 4                                               40.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               42.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               46.0
# 1                                                NaN
# 2                                               53.0
# 3                                               68.0
# 4                                               33.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   1.3464
# 1                                   0.7268
# 2                                   1.3583
# 3                                   1.2108
# 4                                   0.9825
#
# [5 rows x 67 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Provider Last Name / Organization Name',
#        'NPPES Provider First Name', 'NPPES Provider Middle Initial',
#        'NPPES Credentials', 'NPPES Provider Gender', 'NPPES Entity Code',
#        'NPPES Provider Street Address 1', 'NPPES Provider Street Address 2',
#        'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Unique Beneficiaries With Drug Services',
#        'Total Drug Submitted Charges', 'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount', 'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Unique Beneficiaries With Medical Services',
#        'Total Medical Submitted Charges',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Number of Beneficiaries Age Less than 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
med['Provider Type'].unique()
# Out:
# array(['Physician Assistant', 'Obstetrics/Gynecology', 'Rheumatology',
#        'Family Practice', 'Internal Medicine', 'Nephrology',
#        'Pediatric Medicine', 'Chiropractic', 'Optometry',
#        'Nurse Practitioner', 'Physical Therapist', 'Ophthalmology',
#        'Infectious Disease', 'Emergency Medicine', 'General Practice',
#        'Psychiatry', 'Urology', 'Allergy/Immunology',
#        'Independent Diagnostic Testing Facility', 'Endocrinology', 'CRNA',
#        'Clinical Psychologist', 'Pulmonary Disease', 'Orthopedic Surgery',
#        'Otolaryngology', 'Licensed Clinical Social Worker', 'Dermatology',
#        'Cardiac Surgery', 'Occupational therapist', 'Pathology',
#        'Anesthesiology', 'Pain Management', 'Certified Nurse Midwife',
#        'Podiatry', 'Preventive Medicine', 'General Surgery', 'Cardiology',
#        'Physical Medicine and Rehabilitation', 'Neurosurgery',
#        'Mass Immunization Roster Biller', 'Geriatric Medicine',
#        'Neurology', 'Diagnostic Radiology', 'Maxillofacial Surgery',
#        'Nuclear Medicine', 'Plastic and Reconstructive Surgery',
#        'Gynecological/Oncology', 'Hand Surgery', 'Gastroenterology',
#        'Oral Surgery (dentists only)', 'Hematology',
#        'Osteopathic Manipulative Medicine',
#        'Interventional Pain Management', 'Clinical Laboratory',
#        'All Other Suppliers', 'Vascular Surgery', 'Radiation Oncology',
#        'Certified Clinical Nurse Specialist',
#        'Ambulatory Surgical Center', 'Centralized Flu',
#        'Ambulance Service Supplier',
#        'Audiologist (billing independently)', 'Thoracic Surgery',
#        'Hematology/Oncology', 'Medical Oncology', 'Surgical Oncology',
#        'Anesthesiologist Assistants', 'Critical Care (Intensivists)',
#        'Hospice and Palliative Care',
#        'Registered Dietician/Nutrition Professional',
#        'Cardiac Electrophysiology', 'Interventional Radiology',
#        'Portable X-ray', 'Mammographic Screening Center',
#        'Sports Medicine', 'Multispecialty Clinic/Group Practice',
#        'Public Health Welfare Agency', 'Sleep Medicine',
#        'Slide Preparation Facility', 'Geriatric Psychiatry',
#        'Colorectal Surgery (formerly proctology)', 'Addiction Medicine',
#        'Neuropsychiatry', 'Peripheral Vascular Disease',
#        'Speech Language Pathologist',
#        'Psychologist (billing independently)',
#        'Unknown Physician Specialty Code', 'Radiation Therapy',
#        'Unknown Supplier/Provider', 'Pharmacy'], dtype=object)

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',
                         'Multispecialty Clinic/Group Practice',
                           'Public Health Welfare Agency', ]

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry','Clinical Psychologist','Psychologist (billing independently)',
                       ]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 52863

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age Less than 65                                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Payment Amount                                                    float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# NPI                                                                                       object
# Total Medicare Payment Amount                                                            float64
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Country                                                                    object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Provider Type                                                                             object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Drug Suppress Indicator                                                                             822
# Medical Suppress Indicator                                                                          822
# Number of Beneficiaries With Race Not Elsewhere Classified                                        10109
# Number of Hispanic Beneficiaries                                                                  10644
# Number of Asian Pacific Islander Beneficiaries                                                    11152
# Number of Beneficiaries Age 75 to 84                                                              12613
# Number of Black or African American Beneficiaries                                                 12634
# Number of American Indian/Alaska Native Beneficiaries                                             14529
# Number of Beneficiaries Age 65 to 74                                                              17096
# Number of Beneficiaries Age Greater 84                                                            17126
# Percent (%) of Beneficiaries Identified With Cancer                                               18562
# Percent (%) of Beneficiaries Identified With Asthma                                               18910
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         19604
# NPPES Provider Street Address 2                                                                   21772
# Percent (%) of Beneficiaries Identified With Heart Failure                                        22039
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               22093
# Number of Non-Hispanic White Beneficiaries                                                        22538
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                22746
# Number of Beneficiaries Age Less than 65                                                          23198
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  23334
# Percent (%) of Beneficiaries Identified With Stroke                                               24067
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               25338
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      25376
# Number of Beneficiaries With Medicare Only Entitlement                                            26708
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      26708
# Percent (%) of Beneficiaries Identified With Diabetes                                             28130
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            29615
# Number of Male Beneficiaries                                                                      30629
# Number of Female Beneficiaries                                                                    30629
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                30781
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       35290
# Percent (%) of Beneficiaries Identified With Hypertension                                         37964
# NPPES Provider Middle Initial                                                                     38179
# Percent (%) of Beneficiaries Identified With Depression                                           45050
# NPPES Credentials                                                                                 50974
# Total Medical Medicare Allowed Amount                                                             52041
# Total Medical Submitted Charges                                                                   52041
# Number of Unique Beneficiaries With Medical Services                                              52041
# Number of Medical Services                                                                        52041
# Number of HCPCS Associated With Medical Services                                                  52041
# Total Drug Medicare Payment Amount                                                                52041
# Total Drug Medicare Allowed Amount                                                                52041
# Total Drug Submitted Charges                                                                      52041
# Number of Drug Services                                                                           52041
# Number of HCPCS Associated With Drug Services                                                     52041
# Total Medical Medicare Payment Amount                                                             52041
# Number of Unique Beneficiaries With Drug Services                                                 52041
# NPPES Provider Gender                                                                             52859
# NPPES Provider First Name                                                                         52859
# NPI                                                                                               52863
# Total Medicare Payment Amount                                                                     52863
# NPPES Provider Last Name / Organization Name                                                      52863
# NPPES Entity Code                                                                                 52863
# NPPES Provider Street Address 1                                                                   52863
# NPPES Provider City                                                                               52863
# NPPES Provider Zip Code                                                                           52863
# NPPES Provider State                                                                              52863
# Average Age of Beneficiaries                                                                      52863
# NPPES Provider Country                                                                            52863
# Medicare Participation Indicator                                                                  52863
# Number of HCPCS                                                                                   52863
# Number of Services                                                                                52863
# Number of Unique Beneficiaries                                                                    52863
# Total Submitted Charges                                                                           52863
# Total Medicare Allowed Amount                                                                     52863
# Provider Type                                                                                     52863
# Average HCC Risk Score of Beneficiaries                                                           52863
#
#                                                                                         unique values  \
# Drug Suppress Indicator                                                                             2
# Medical Suppress Indicator                                                                          2
# Number of Beneficiaries With Race Not Elsewhere Classified                                         36
# Number of Hispanic Beneficiaries                                                                  289
# Number of Asian Pacific Islander Beneficiaries                                                     99
# Number of Beneficiaries Age 75 to 84                                                              374
# Number of Black or African American Beneficiaries                                                 338
# Number of American Indian/Alaska Native Beneficiaries                                              54
# Number of Beneficiaries Age 65 to 74                                                              333
# Number of Beneficiaries Age Greater 84                                                            419
# Percent (%) of Beneficiaries Identified With Cancer                                                71
# Percent (%) of Beneficiaries Identified With Asthma                                                52
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          54
# NPPES Provider Street Address 2                                                                  7414
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                72
# Number of Non-Hispanic White Beneficiaries                                                        868
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Number of Beneficiaries Age Less than 65                                                          579
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   56
# Percent (%) of Beneficiaries Identified With Stroke                                                75
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Number of Beneficiaries With Medicare Only Entitlement                                            577
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      771
# Percent (%) of Beneficiaries Identified With Diabetes                                              69
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# Number of Male Beneficiaries                                                                      533
# Number of Female Beneficiaries                                                                    705
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 71
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        63
# Percent (%) of Beneficiaries Identified With Hypertension                                          65
# NPPES Provider Middle Initial                                                                      29
# Percent (%) of Beneficiaries Identified With Depression                                            65
# NPPES Credentials                                                                                2073
# Total Medical Medicare Allowed Amount                                                           51746
# Total Medical Submitted Charges                                                                 40165
# Number of Unique Beneficiaries With Medical Services                                             1014
# Number of Medical Services                                                                       3610
# Number of HCPCS Associated With Medical Services                                                   65
# Total Drug Medicare Payment Amount                                                                300
# Total Drug Medicare Allowed Amount                                                                300
# Total Drug Submitted Charges                                                                      300
# Number of Drug Services                                                                           278
# Number of HCPCS Associated With Drug Services                                                      15
# Total Medical Medicare Payment Amount                                                           51697
# Number of Unique Beneficiaries With Drug Services                                                  74
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                        8642
# NPI                                                                                             52863
# Total Medicare Payment Amount                                                                   52513
# NPPES Provider Last Name / Organization Name                                                    28054
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                 30911
# NPPES Provider City                                                                              4536
# NPPES Provider Zip Code                                                                         32620
# NPPES Provider State                                                                               56
# Average Age of Beneficiaries                                                                       68
# NPPES Provider Country                                                                              3
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    71
# Number of Services                                                                               3788
# Number of Unique Beneficiaries                                                                   1029
# Total Submitted Charges                                                                         40941
# Total Medicare Allowed Amount                                                                   52562
# Provider Type                                                                                       6
# Average HCC Risk Score of Beneficiaries                                                         17212
#
#                                                                                         null values
# Drug Suppress Indicator                                                                       52041
# Medical Suppress Indicator                                                                    52041
# Number of Beneficiaries With Race Not Elsewhere Classified                                    42754
# Number of Hispanic Beneficiaries                                                              42219
# Number of Asian Pacific Islander Beneficiaries                                                41711
# Number of Beneficiaries Age 75 to 84                                                          40250
# Number of Black or African American Beneficiaries                                             40229
# Number of American Indian/Alaska Native Beneficiaries                                         38334
# Number of Beneficiaries Age 65 to 74                                                          35767
# Number of Beneficiaries Age Greater 84                                                        35737
# Percent (%) of Beneficiaries Identified With Cancer                                           34301
# Percent (%) of Beneficiaries Identified With Asthma                                           33953
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     33259
# NPPES Provider Street Address 2                                                               31091
# Percent (%) of Beneficiaries Identified With Heart Failure                                    30824
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           30770
# Number of Non-Hispanic White Beneficiaries                                                    30325
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            30117
# Number of Beneficiaries Age Less than 65                                                      29665
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              29529
# Percent (%) of Beneficiaries Identified With Stroke                                           28796
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           27525
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  27487
# Number of Beneficiaries With Medicare Only Entitlement                                        26155
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  26155
# Percent (%) of Beneficiaries Identified With Diabetes                                         24733
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        23248
# Number of Male Beneficiaries                                                                  22234
# Number of Female Beneficiaries                                                                22234
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            22082
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   17573
# Percent (%) of Beneficiaries Identified With Hypertension                                     14899
# NPPES Provider Middle Initial                                                                 14684
# Percent (%) of Beneficiaries Identified With Depression                                        7813
# NPPES Credentials                                                                              1889
# Total Medical Medicare Allowed Amount                                                           822
# Total Medical Submitted Charges                                                                 822
# Number of Unique Beneficiaries With Medical Services                                            822
# Number of Medical Services                                                                      822
# Number of HCPCS Associated With Medical Services                                                822
# Total Drug Medicare Payment Amount                                                              822
# Total Drug Medicare Allowed Amount                                                              822
# Total Drug Submitted Charges                                                                    822
# Number of Drug Services                                                                         822
# Number of HCPCS Associated With Drug Services                                                   822
# Total Medical Medicare Payment Amount                                                           822
# Number of Unique Beneficiaries With Drug Services                                               822
# NPPES Provider Gender                                                                             4
# NPPES Provider First Name                                                                         4
# NPI                                                                                               0
# Total Medicare Payment Amount                                                                     0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Country                                                                            0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Provider Type                                                                                     0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Unique Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 12634

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 5809

# %% [markdown]
# Some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Unique Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 10

# %%
#Let's look at rows where all info is present but not all bins equal the total.

mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']
][race_cols]
# Out:
#         Number of American Indian/Alaska Native Beneficiaries  \
# 322224                                                    0.0
# 847486                                                    0.0
# 355322                                                    0.0
# 679009                                                    0.0
# 702992                                                    0.0
# 897069                                                    0.0
# 65051                                                     0.0
# 244999                                                    0.0
# 650157                                                    0.0
# 794515                                                    0.0
#
#         Number of Asian Pacific Islander Beneficiaries  \
# 322224                                             0.0
# 847486                                             0.0
# 355322                                             0.0
# 679009                                            30.0
# 702992                                             0.0
# 897069                                            12.0
# 65051                                              0.0
# 244999                                             0.0
# 650157                                             0.0
# 794515                                             0.0
#
#         Number of Non-Hispanic White Beneficiaries  \
# 322224                                        15.0
# 847486                                        12.0
# 355322                                         0.0
# 679009                                        52.0
# 702992                                        44.0
# 897069                                        81.0
# 65051                                         25.0
# 244999                                        29.0
# 650157                                        47.0
# 794515                                        21.0
#
#         Number of Hispanic Beneficiaries  \
# 322224                               0.0
# 847486                               0.0
# 355322                              52.0
# 679009                              11.0
# 702992                              18.0
# 897069                              32.0
# 65051                                0.0
# 244999                               0.0
# 650157                               0.0
# 794515                               0.0
#
#         Number of Beneficiaries With Race Not Elsewhere Classified  \
# 322224                                                         0.0
# 847486                                                         0.0
# 355322                                                         0.0
# 679009                                                        21.0
# 702992                                                         0.0
# 897069                                                         0.0
# 65051                                                          0.0
# 244999                                                         0.0
# 650157                                                         0.0
# 794515                                                         0.0
#
#         Number of Black or African American Beneficiaries  \
# 322224                                                0.0
# 847486                                                0.0
# 355322                                                0.0
# 679009                                                0.0
# 702992                                               61.0
# 897069                                               25.0
# 65051                                                 0.0
# 244999                                                0.0
# 650157                                                0.0
# 794515                                                0.0
#
#        Number of Unique Beneficiaries
# 322224                             16
# 847486                             13
# 355322                             53
# 679009                            115
# 702992                            124
# 897069                            151
# 65051                              26
# 244999                             30
# 650157                             48
# 794515                             22

# %%
#index of rows where sums don't equal total
idx = mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']
].index

#sums of races that are off
sums_of_races = mental_med.loc[idx][race_cols[:-1]].sum(axis=1)

#values to replace 'Number with Race Not Classified' (Total+'Number Not Classfd'-sums)
new_values = mental_med.loc[idx, 
        'Number of Beneficiaries With Race Not Elsewhere Classified'] + \
        mental_med.loc[idx]['Number of Unique Beneficiaries'] - \
        sums_of_races

#actually replacing those values
mental_med.loc[idx, 
            'Number of Beneficiaries With Race Not Elsewhere Classified'] = new_values

# %%
#checking my work
(mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']).sum()
# Out:
# 0

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less than 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Unique Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Unique Beneficiaries']).sum()
# Out:
# 9910

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Unique Beneficiaries']).sum()
# Out:
# 5574

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 12634

# %%
black_medicare[age_cols[:-1]].isnull().any(axis=1).sum()
# Out:
# 9838

# %%
black_medicare[age_cols].head(3)
# Out:
#       Number of Beneficiaries Age Less than 65  \
# 1658                                       NaN
# 2885                                       NaN
# 2967                                       NaN
#
#       Number of Beneficiaries Age 65 to 74  \
# 1658                                   NaN
# 2885                                  12.0
# 2967                                   NaN
#
#       Number of Beneficiaries Age 75 to 84  \
# 1658                                   NaN
# 2885                                   NaN
# 2967                                  12.0
#
#       Number of Beneficiaries Age Greater 84 Number of Unique Beneficiaries
# 1658                                     NaN                             20
# 2885                                     NaN                             26
# 2967                                     NaN                             30

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (12634, 12634)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (5809, 5809)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries                                                             float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Drug Medicare Payment Amount                                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of Drug Services                                                                  float64
# Number of Medical Services                                                               float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# NPI                                                                                       object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# NPPES Provider Country                                                                    object
# Provider Type                                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          267
# Drug Suppress Indicator                                                                             267
# NPPES Provider Street Address 2                                                                    5298
# Percent (%) of Beneficiaries Identified With Cancer                                                5478
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5644
# Percent (%) of Beneficiaries Identified With Asthma                                                6410
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6429
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6487
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6494
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6684
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6708
# Number of Beneficiaries With Medicare Only Entitlement                                             6816
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       6816
# Percent (%) of Beneficiaries Identified With Diabetes                                              6876
# Number of Female Beneficiaries                                                                     6965
# Number of Male Beneficiaries                                                                       6965
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 6995
# Percent (%) of Beneficiaries Identified With Stroke                                                7033
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7268
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7760
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8153
# Percent (%) of Beneficiaries Identified With Hypertension                                          8171
# NPPES Provider Middle Initial                                                                      8962
# Percent (%) of Beneficiaries Identified With Depression                                            9659
# NPPES Credentials                                                                                 12190
# Total Drug Medicare Payment Amount                                                                12367
# Total Medical Medicare Payment Amount                                                             12367
# Total Medical Medicare Allowed Amount                                                             12367
# Total Medical Submitted Charges                                                                   12367
# Number of Unique Beneficiaries With Medical Services                                              12367
# Number of HCPCS Associated With Drug Services                                                     12367
# Number of HCPCS Associated With Medical Services                                                  12367
# Total Drug Medicare Allowed Amount                                                                12367
# Total Drug Submitted Charges                                                                      12367
# Number of Unique Beneficiaries With Drug Services                                                 12367
# Number of Drug Services                                                                           12367
# Number of Medical Services                                                                        12367
# NPPES Provider Gender                                                                             12631
# NPPES Provider First Name                                                                         12631
# NPI                                                                                               12634
# Average Age of Beneficiaries                                                                      12634
# NPPES Provider Last Name / Organization Name                                                      12634
# NPPES Entity Code                                                                                 12634
# NPPES Provider Street Address 1                                                                   12634
# NPPES Provider City                                                                               12634
# NPPES Provider Zip Code                                                                           12634
# NPPES Provider State                                                                              12634
# NPPES Provider Country                                                                            12634
# Provider Type                                                                                     12634
# Medicare Participation Indicator                                                                  12634
# Number of HCPCS                                                                                   12634
# Number of Services                                                                                12634
# Number of Unique Beneficiaries                                                                    12634
# Total Submitted Charges                                                                           12634
# Total Medicare Allowed Amount                                                                     12634
# Total Medicare Payment Amount                                                                     12634
# Number of Black or African American Beneficiaries                                                 12634
# Average HCC Risk Score of Beneficiaries                                                           12634
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# NPPES Provider Street Address 2                                                                  2428
# Percent (%) of Beneficiaries Identified With Cancer                                                44
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          43
# Percent (%) of Beneficiaries Identified With Asthma                                                44
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   46
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 70
# Number of Beneficiaries With Medicare Only Entitlement                                            534
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      743
# Percent (%) of Beneficiaries Identified With Diabetes                                              68
# Number of Female Beneficiaries                                                                    682
# Number of Male Beneficiaries                                                                      526
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 71
# Percent (%) of Beneficiaries Identified With Stroke                                                63
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        63
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Percent (%) of Beneficiaries Identified With Hypertension                                          61
# NPPES Provider Middle Initial                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                            64
# NPPES Credentials                                                                                 721
# Total Drug Medicare Payment Amount                                                                177
# Total Medical Medicare Payment Amount                                                           12357
# Total Medical Medicare Allowed Amount                                                           12359
# Total Medical Submitted Charges                                                                 11209
# Number of Unique Beneficiaries With Medical Services                                              970
# Number of HCPCS Associated With Drug Services                                                      13
# Number of HCPCS Associated With Medical Services                                                   55
# Total Drug Medicare Allowed Amount                                                                177
# Total Drug Submitted Charges                                                                      177
# Number of Unique Beneficiaries With Drug Services                                                  62
# Number of Drug Services                                                                           164
# Number of Medical Services                                                                       2847
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                        3582
# NPI                                                                                             12634
# Average Age of Beneficiaries                                                                       62
# NPPES Provider Last Name / Organization Name                                                     8744
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                  9937
# NPPES Provider City                                                                              2728
# NPPES Provider Zip Code                                                                         10269
# NPPES Provider State                                                                               53
# NPPES Provider Country                                                                              1
# Provider Type                                                                                       6
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    61
# Number of Services                                                                               2960
# Number of Unique Beneficiaries                                                                    983
# Total Submitted Charges                                                                         11473
# Total Medicare Allowed Amount                                                                   12626
# Total Medicare Payment Amount                                                                   12625
# Number of Black or African American Beneficiaries                                                 338
# Average HCC Risk Score of Beneficiaries                                                          8890
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    12367
# Drug Suppress Indicator                                                                       12367
# NPPES Provider Street Address 2                                                                7336
# Percent (%) of Beneficiaries Identified With Cancer                                            7156
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      6990
# Percent (%) of Beneficiaries Identified With Asthma                                            6224
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6205
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6147
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6140
# Percent (%) of Beneficiaries Identified With Heart Failure                                     5950
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             5926
# Number of Beneficiaries With Medicare Only Entitlement                                         5818
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   5818
# Percent (%) of Beneficiaries Identified With Diabetes                                          5758
# Number of Female Beneficiaries                                                                 5669
# Number of Male Beneficiaries                                                                   5669
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5639
# Percent (%) of Beneficiaries Identified With Stroke                                            5601
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5366
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    4874
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4481
# Percent (%) of Beneficiaries Identified With Hypertension                                      4463
# NPPES Provider Middle Initial                                                                  3672
# Percent (%) of Beneficiaries Identified With Depression                                        2975
# NPPES Credentials                                                                               444
# Total Drug Medicare Payment Amount                                                              267
# Total Medical Medicare Payment Amount                                                           267
# Total Medical Medicare Allowed Amount                                                           267
# Total Medical Submitted Charges                                                                 267
# Number of Unique Beneficiaries With Medical Services                                            267
# Number of HCPCS Associated With Drug Services                                                   267
# Number of HCPCS Associated With Medical Services                                                267
# Total Drug Medicare Allowed Amount                                                              267
# Total Drug Submitted Charges                                                                    267
# Number of Unique Beneficiaries With Drug Services                                               267
# Number of Drug Services                                                                         267
# Number of Medical Services                                                                      267
# NPPES Provider Gender                                                                             3
# NPPES Provider First Name                                                                         3
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# NPPES Provider Country                                                                            0
# Provider Type                                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Number of Black or African American Beneficiaries                                                 0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries','Number of Unique Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 6965
# Has nulls: 5669

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Unique Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 6822
# Don't sum 143

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Total Drug Submitted Charges                                                             float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Medicare Payment Amount                                                       float64
# NPPES Provider First Name                                                                 object
# NPPES Provider Gender                                                                     object
# NPI                                                                                       object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# NPPES Provider Country                                                                    object
# Provider Type                                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          267
# Drug Suppress Indicator                                                                             267
# NPPES Provider Street Address 2                                                                    5298
# Percent (%) of Beneficiaries Identified With Cancer                                                5478
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5644
# Percent (%) of Beneficiaries Identified With Asthma                                                6410
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6429
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6487
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6494
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6684
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6708
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       6816
# Number of Beneficiaries With Medicare Only Entitlement                                             6816
# Percent (%) of Beneficiaries Identified With Diabetes                                              6876
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 6995
# Percent (%) of Beneficiaries Identified With Stroke                                                7033
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7268
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7760
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8153
# Percent (%) of Beneficiaries Identified With Hypertension                                          8171
# NPPES Provider Middle Initial                                                                      8962
# Percent (%) of Beneficiaries Identified With Depression                                            9659
# NPPES Credentials                                                                                 12190
# Total Medical Medicare Payment Amount                                                             12367
# Total Medical Medicare Allowed Amount                                                             12367
# Total Medical Submitted Charges                                                                   12367
# Number of Unique Beneficiaries With Medical Services                                              12367
# Number of Medical Services                                                                        12367
# Number of HCPCS Associated With Medical Services                                                  12367
# Number of Unique Beneficiaries With Drug Services                                                 12367
# Total Drug Submitted Charges                                                                      12367
# Number of Drug Services                                                                           12367
# Number of HCPCS Associated With Drug Services                                                     12367
# Total Drug Medicare Allowed Amount                                                                12367
# Total Drug Medicare Payment Amount                                                                12367
# NPPES Provider First Name                                                                         12631
# NPPES Provider Gender                                                                             12631
# NPI                                                                                               12634
# Average Age of Beneficiaries                                                                      12634
# NPPES Provider Last Name / Organization Name                                                      12634
# NPPES Entity Code                                                                                 12634
# NPPES Provider Street Address 1                                                                   12634
# NPPES Provider City                                                                               12634
# NPPES Provider Zip Code                                                                           12634
# NPPES Provider State                                                                              12634
# NPPES Provider Country                                                                            12634
# Provider Type                                                                                     12634
# Medicare Participation Indicator                                                                  12634
# Number of HCPCS                                                                                   12634
# Number of Services                                                                                12634
# Number of Unique Beneficiaries                                                                    12634
# Total Submitted Charges                                                                           12634
# Total Medicare Allowed Amount                                                                     12634
# Total Medicare Payment Amount                                                                     12634
# Number of Black or African American Beneficiaries                                                 12634
# Average HCC Risk Score of Beneficiaries                                                           12634
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# NPPES Provider Street Address 2                                                                  2428
# Percent (%) of Beneficiaries Identified With Cancer                                                44
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          43
# Percent (%) of Beneficiaries Identified With Asthma                                                44
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   46
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 70
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      743
# Number of Beneficiaries With Medicare Only Entitlement                                            534
# Percent (%) of Beneficiaries Identified With Diabetes                                              68
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 71
# Percent (%) of Beneficiaries Identified With Stroke                                                63
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        63
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Percent (%) of Beneficiaries Identified With Hypertension                                          61
# NPPES Provider Middle Initial                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                            64
# NPPES Credentials                                                                                 721
# Total Medical Medicare Payment Amount                                                           12357
# Total Medical Medicare Allowed Amount                                                           12359
# Total Medical Submitted Charges                                                                 11209
# Number of Unique Beneficiaries With Medical Services                                              970
# Number of Medical Services                                                                       2847
# Number of HCPCS Associated With Medical Services                                                   55
# Number of Unique Beneficiaries With Drug Services                                                  62
# Total Drug Submitted Charges                                                                      177
# Number of Drug Services                                                                           164
# Number of HCPCS Associated With Drug Services                                                      13
# Total Drug Medicare Allowed Amount                                                                177
# Total Drug Medicare Payment Amount                                                                177
# NPPES Provider First Name                                                                        3582
# NPPES Provider Gender                                                                               2
# NPI                                                                                             12634
# Average Age of Beneficiaries                                                                       62
# NPPES Provider Last Name / Organization Name                                                     8744
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                  9937
# NPPES Provider City                                                                              2728
# NPPES Provider Zip Code                                                                         10269
# NPPES Provider State                                                                               53
# NPPES Provider Country                                                                              1
# Provider Type                                                                                       6
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    61
# Number of Services                                                                               2960
# Number of Unique Beneficiaries                                                                    983
# Total Submitted Charges                                                                         11473
# Total Medicare Allowed Amount                                                                   12626
# Total Medicare Payment Amount                                                                   12625
# Number of Black or African American Beneficiaries                                                 338
# Average HCC Risk Score of Beneficiaries                                                          8890
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    12367
# Drug Suppress Indicator                                                                       12367
# NPPES Provider Street Address 2                                                                7336
# Percent (%) of Beneficiaries Identified With Cancer                                            7156
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      6990
# Percent (%) of Beneficiaries Identified With Asthma                                            6224
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6205
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6147
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6140
# Percent (%) of Beneficiaries Identified With Heart Failure                                     5950
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             5926
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   5818
# Number of Beneficiaries With Medicare Only Entitlement                                         5818
# Percent (%) of Beneficiaries Identified With Diabetes                                          5758
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5639
# Percent (%) of Beneficiaries Identified With Stroke                                            5601
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5366
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    4874
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4481
# Percent (%) of Beneficiaries Identified With Hypertension                                      4463
# NPPES Provider Middle Initial                                                                  3672
# Percent (%) of Beneficiaries Identified With Depression                                        2975
# NPPES Credentials                                                                               444
# Total Medical Medicare Payment Amount                                                           267
# Total Medical Medicare Allowed Amount                                                           267
# Total Medical Submitted Charges                                                                 267
# Number of Unique Beneficiaries With Medical Services                                            267
# Number of Medical Services                                                                      267
# Number of HCPCS Associated With Medical Services                                                267
# Number of Unique Beneficiaries With Drug Services                                               267
# Total Drug Submitted Charges                                                                    267
# Number of Drug Services                                                                         267
# Number of HCPCS Associated With Drug Services                                                   267
# Total Drug Medicare Allowed Amount                                                              267
# Total Drug Medicare Payment Amount                                                              267
# NPPES Provider First Name                                                                         3
# NPPES Provider Gender                                                                             3
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# NPPES Provider Country                                                                            0
# Provider Type                                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Number of Black or African American Beneficiaries                                                 0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
    'NPI', #keeping this as unique ID for each provider
    'Provider Type',
     'Number of Unique Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'NPPES Provider City', 
    'NPPES Provider State',
    'NPPES Provider Zip Code', 
    'Average HCC Risk Score of Beneficiaries'
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
     'NPPES Provider Country',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Medicare Participation Indicator',
#  'Number of Medical Services',
#  'Total Drug Medicare Payment Amount',
#  'Total Submitted Charges',
#  'Number of Beneficiaries With Medicare Only Entitlement',
#  'NPPES Provider Street Address 2',
#  'Number of HCPCS Associated With Drug Services',
#  'Total Medicare Allowed Amount',
#  'Total Drug Submitted Charges',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'Number of Services',
#  'Total Medical Submitted Charges',
#  'Number of Drug Services',
#  'Percent (%) of Beneficiaries Identified With Hypertension',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#  'NPPES Provider Middle Initial',
#  'Drug Suppress Indicator',
#  'Medical Suppress Indicator',
#  'Number of HCPCS Associated With Medical Services',
#  'NPPES Provider First Name',
#  'NPPES Credentials',
#  'NPPES Provider Street Address 1',
#  'Total Medical Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Asthma',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Number of Unique Beneficiaries With Medical Services',
#  'Percent (%) of Beneficiaries Identified With Cancer',
#  'Number of HCPCS',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#  'Number of Unique Beneficiaries With Drug Services',
#  'NPPES Provider Gender',
#  'NPPES Entity Code',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#  'Percent (%) of Beneficiaries Identified With Heart Failure',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Total Medical Medicare Allowed Amount',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis',
#  'Percent (%) of Beneficiaries Identified With Diabetes',
#  'NPPES Provider Last Name / Organization Name',
#  'Percent (%) of Beneficiaries Identified With Stroke',
#  'Total Drug Medicare Allowed Amount']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['NPI', 'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Number of Unique Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['NPI', 'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Number of Unique Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape, all_medicare.shape
# Out:
# ((12634, 13), (5809, 18))

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'NPI':'npi',
                 'NPPES Provider City':'city', 'NPPES Provider Zip Code':'full_zip',
                'NPPES Provider State':'state','NPPES Provider Country':'country',
                'Provider Type':'provider_type',
                 'Number of Unique Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders':
                    'percent_with_psychosis'}
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#Some years' DFs have country values that are not 'US' listed in Country

# %%
black_medicare.country.unique()
# Out:
# array(['US'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# How many unique 5-digit zip codes are there in this df? There are 33,000 zip codes on Census df.

# %% [markdown]
# First I have to convert the NPPES Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9580
# 5    1346
# 8    1322
# 4     264
# 3      66
# 7      56
# Name: full_zip, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 5363     4002
# 5705     4901
# 7576     6032
# 26387    6069
# 47570    8850
# Name: full_zip, dtype: object

# %%
#adding leading zeros to the five digit zip code
idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9910
# 5    1346
# 8    1322
# 7      56
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ].head()['full_zip']
# Out:
# 5462     97058
# 12151    92591
# 12396    49007
# 22080    71655
# 26388    11777
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# 42484     9261739
# 204663    6789805
# 376347    9616910
# 25886     7256314
# 28013     9183014
# Name: full_zip, dtype: object

# %%
#I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    12634
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 4887

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    12634
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.
idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    12634
# Name: full_zip, dtype: int64
# 5    12634
# Name: five_dig_zip, dtype: int64
# 9    5809
# Name: full_zip, dtype: int64
# 5    5809
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12634 entries, 1658 to 941828
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      12634 non-null  object
#  1   city                     12634 non-null  object
#  2   full_zip                 12634 non-null  object
#  3   state                    12634 non-null  object
#  4   country                  12634 non-null  object
#  5   provider_type            12634 non-null  object
#  6   total_beneficiaries      12634 non-null  object
#  7   total_medicare_payment   12634 non-null  float64
#  8   avg_beneficiary_age      12634 non-null  object
#  9   num_black                12634 non-null  float64
#  10  percent_with_depression  9659 non-null   float64
#  11  percent_with_psychosis   8153 non-null   float64
#  12  avg_hcc_risk_score       12634 non-null  float64
#  13  five_dig_zip             12634 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 2.1+ MB

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5809 entries, 1658 to 941828
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      5809 non-null   object
#  1   city                     5809 non-null   object
#  2   full_zip                 5809 non-null   object
#  3   state                    5809 non-null   object
#  4   country                  5809 non-null   object
#  5   provider_type            5809 non-null   object
#  6   total_beneficiaries      5809 non-null   object
#  7   total_medicare_payment   5809 non-null   float64
#  8   avg_beneficiary_age      5809 non-null   object
#  9   num_white                5809 non-null   float64
#  10  num_black                5809 non-null   float64
#  11  num_asian_pac_isl        5809 non-null   float64
#  12  num_hispanic             5809 non-null   float64
#  13  num_nat_amer             5809 non-null   float64
#  14  num_race_unknown         5809 non-null   object
#  15  percent_with_depression  3734 non-null   float64
#  16  percent_with_psychosis   2179 non-null   float64
#  17  avg_hcc_risk_score       5809 non-null   float64
#  18  five_dig_zip             5809 non-null   object
# dtypes: float64(9), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../data/raw/2013acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   91046                   118                 29
# 1   79916                     0                 62
# 2   14881                    71                  0
# 3   20317                   246                  0
# 4   28424                    10                 21
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1987.0                         0
# 1                       1998.0                        41
# 2                       1987.0                         0
# 3                       1951.0                         0
# 4                       2002.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                   135                      0                     12
# 1                     0                     21                      0
# 2                     0                     18                      0
# 3                   117                     33                     20
# 4                    13                      0                      6
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                      0  ...
# 1                      0                      0  ...
# 2                      0                     19  ...
# 3                      0                     11  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          23                      0
# 1                        2201                    445
# 2                          71                      0
# 3                         355                      0
# 4                          55                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              176                 10
# 1                                 97             2850               2081
# 2                                  0               71                 18
# 3                                  0              355                 54
# 4                                  0               51                 21
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0               58              0           13             0  20092013
# 1              643             13            0           113  20092013
# 2                0              0           36            17  20092013
# 3               80             13           94            91  20092013
# 4               10              6            9             5  20092013
#
# [5 rows x 252 columns]

# %%
# dropping do_date columns, which gives info on how numbers for this year were calculated
# but isn't useful for my investigation.

census.drop(columns=['do_date'], inplace=True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# bachelors_degree_2                                            float64
# different_house_year_ago_same_city                            float64
# different_house_year_ago_different_city                       float64
# population_1_year_and_over                                    float64
# not_us_citizen_pop                                            float64
# less_than_high_school_graduate                                float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# some_college_and_associates_degree                            float64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_by_carpool                                            int64
# commuters_drove_alone                                           int64
# employed_finance_insurance_real_estate                          int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# female_75_to_79                                                 int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          19753
# percent_income_spent_on_rent                                           27449
# median_rent                                                            27491
# renter_occupied_housing_units_paying_cash_median_gross_rent            27503
# owner_occupied_housing_units_median_value                              31573
# owner_occupied_housing_units_upper_value_quartile                      31573
# owner_occupied_housing_units_lower_value_quartile                      31573
# median_income                                                          31985
# median_year_structure_built                                            32172
# gini_index                                                             32242
# income_per_capita                                                      32546
# median_age                                                             32589
# bachelors_degree_2                                                     32989
# different_house_year_ago_same_city                                     32989
# different_house_year_ago_different_city                                32989
# population_1_year_and_over                                             32989
# not_us_citizen_pop                                                     32989
# less_than_high_school_graduate                                         32989
# high_school_including_ged                                              32989
# graduate_professional_degree                                           32989
# some_college_and_associates_degree                                     32989
# employed_agriculture_forestry_fishing_hunting_mining                   33120
# commuters_by_subway_or_elevated                                        33120
# commuters_by_carpool                                                   33120
# commuters_drove_alone                                                  33120
# employed_finance_insurance_real_estate                                 33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# female_75_to_79                                                        33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16691
# percent_income_spent_on_rent                                           400
# median_rent                                                           1695
# renter_occupied_housing_units_paying_cash_median_gross_rent           1686
# owner_occupied_housing_units_median_value                             5011
# owner_occupied_housing_units_upper_value_quartile                     5923
# owner_occupied_housing_units_lower_value_quartile                     4094
# median_income                                                        19918
# median_year_structure_built                                             70
# gini_index                                                            4143
# income_per_capita                                                    20158
# median_age                                                             665
# bachelors_degree_2                                                    5797
# different_house_year_ago_same_city                                    3689
# different_house_year_ago_different_city                               4809
# population_1_year_and_over                                           15236
# not_us_citizen_pop                                                    4223
# less_than_high_school_graduate                                        4657
# high_school_including_ged                                             7096
# graduate_professional_degree                                          4310
# some_college_and_associates_degree                                    7383
# employed_agriculture_forestry_fishing_hunting_mining                   979
# commuters_by_subway_or_elevated                                        874
# commuters_by_carpool                                                  2846
# commuters_drove_alone                                                10035
# employed_finance_insurance_real_estate                                2361
# employed_construction                                                 2049
# employed_education_health_social                                      5174
# commuters_by_car_truck_van                                           10583
# female_75_to_79                                                       1069
#
#                                                              null values
# aggregate_travel_time_to_work                                      13367
# percent_income_spent_on_rent                                        5671
# median_rent                                                         5629
# renter_occupied_housing_units_paying_cash_median_gross_rent         5617
# owner_occupied_housing_units_median_value                           1547
# owner_occupied_housing_units_upper_value_quartile                   1547
# owner_occupied_housing_units_lower_value_quartile                   1547
# median_income                                                       1135
# median_year_structure_built                                          948
# gini_index                                                           878
# income_per_capita                                                    574
# median_age                                                           531
# bachelors_degree_2                                                   131
# different_house_year_ago_same_city                                   131
# different_house_year_ago_different_city                              131
# population_1_year_and_over                                           131
# not_us_citizen_pop                                                   131
# less_than_high_school_graduate                                       131
# high_school_including_ged                                            131
# graduate_professional_degree                                         131
# some_college_and_associates_degree                                   131
# employed_agriculture_forestry_fishing_hunting_mining                   0
# commuters_by_subway_or_elevated                                        0
# commuters_by_carpool                                                   0
# commuters_drove_alone                                                  0
# employed_finance_insurance_real_estate                                 0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# female_75_to_79                                                        0

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['68198', '80262', '46904', '02178', '00801', '71130', '40536', '85378',
#        '21287', '14642', '11571', '37684', '21302', '38163', '12402', '26507',
#        '87131', '01655', '03247', '65212', '94143', '45408', '08754', '01202',
#        '22908', '92161', '04333', '79430', '10155', '13925', '20042', '23298',
#        '53547', '35249', '29151', '00919', '85220', '28286', '45267', '27710',
#        '05047', '29220', '03756', '00792', '33421', '06030', '85247', '06102',
#        '19718', '00963', '27599', '44195', '29425', '36209', '65402', '32610',
#        '07962', '84143', '77555', '48824', '01805', '18341', '98378', '29240',
#        '00820', '66160', '92357', '53102', '48859', '32163', '77805', '84602',
#        '92415', '90509', '00726', '60674'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi            city   full_zip state country  \
# five_dig_zip
# 68198         1225089170           OMAHA  681988102    NE      US
# 68198         1588616700           OMAHA  681988102    NE      US
# 68198         1962452391           OMAHA  681988102    NE      US
# 68198         1255381158           OMAHA  681988095    NE      US
# 68198         1568410322           OMAHA  681988102    NE      US
# ...                  ...             ...        ...   ...     ...
# 92415         1649310335  SAN BERNARDINO  924150001    CA      US
# 92415         1750426862  SAN BERNARDINO  924150001    CA      US
# 90509         1659448645        TORRANCE  905090000    CA      US
# 00726         1376524181          CAGUAS  007261209    PR      US
# 60674         1073508537         CHICAGO  606740035    IL      US
#
#                      provider_type total_beneficiaries  \
# five_dig_zip
# 68198         Geriatric Psychiatry                 284
# 68198         Geriatric Psychiatry                 287
# 68198         Geriatric Psychiatry                 615
# 68198                   Psychiatry                  14
# 68198                   Psychiatry                 310
# ...                            ...                 ...
# 92415                   Psychiatry                  90
# 92415                   Psychiatry                  68
# 90509                   Psychiatry                  56
# 00726                   Psychiatry                  37
# 60674                   Psychiatry                  39
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 68198                       36270.51                  76       21.0
# 68198                       34849.88                  75       20.0
# 68198                       66742.31                  74       36.0
# 68198                         971.96                  56        0.0
# 68198                       30691.59                  50       39.0
# ...                              ...                 ...        ...
# 92415                       10876.35                  52       30.0
# 92415                        9622.61                  54       21.0
# 90509                        5743.61                  48       11.0
# 00726                        6581.76                  64        0.0
# 60674                        3325.54                  51       21.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 68198                     1.6756
# 68198                     1.6629
# 68198                     1.5242
# 68198                     0.8541
# 68198                     1.0669
# ...                          ...
# 92415                     1.3314
# 92415                     1.3561
# 90509                     1.3597
# 00726                     1.2169
# 60674                     1.1126
#
# [201 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 4811
# 4811

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# bachelors_degree_2                                            float64
# some_college_and_associates_degree                            float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# not_us_citizen_pop                                            float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# median_age                                                    float64
# income_per_capita                                             float64
# commuters_drove_alone                                           int64
# commuters_by_subway_or_elevated                                 int64
# employed_education_health_social                                int64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# amerindian_including_hispanic                                   int64
# commuters_by_carpool                                            int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           4539
# owner_occupied_housing_units_median_value                               4752
# owner_occupied_housing_units_upper_value_quartile                       4752
# owner_occupied_housing_units_lower_value_quartile                       4752
# percent_income_spent_on_rent                                            4759
# median_rent                                                             4759
# renter_occupied_housing_units_paying_cash_median_gross_rent             4759
# different_house_year_ago_same_city                                      4766
# population_1_year_and_over                                              4766
# less_than_high_school_graduate                                          4766
# different_house_year_ago_different_city                                 4766
# bachelors_degree_2                                                      4766
# some_college_and_associates_degree                                      4766
# high_school_including_ged                                               4766
# graduate_professional_degree                                            4766
# not_us_citizen_pop                                                      4766
# median_income                                                           4776
# median_year_structure_built                                             4777
# gini_index                                                              4778
# median_age                                                              4800
# income_per_capita                                                       4800
# commuters_drove_alone                                                   4811
# commuters_by_subway_or_elevated                                         4811
# employed_education_health_social                                        4811
# employed_agriculture_forestry_fishing_hunting_mining                    4811
# employed_arts_entertainment_recreation_accommodation_food               4811
# employed_construction                                                   4811
# amerindian_including_hispanic                                           4811
# commuters_by_carpool                                                    4811
# employed_information                                                    4811
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         4479
# owner_occupied_housing_units_median_value                             2862
# owner_occupied_housing_units_upper_value_quartile                     3091
# owner_occupied_housing_units_lower_value_quartile                     2607
# percent_income_spent_on_rent                                           314
# median_rent                                                           1289
# renter_occupied_housing_units_paying_cash_median_gross_rent           1260
# different_house_year_ago_same_city                                    2635
# population_1_year_and_over                                            4537
# less_than_high_school_graduate                                        2998
# different_house_year_ago_different_city                               3171
# bachelors_degree_2                                                    3617
# some_college_and_associates_degree                                    3820
# high_school_including_ged                                             3770
# graduate_professional_degree                                          3171
# not_us_citizen_pop                                                    2706
# median_income                                                         4629
# median_year_structure_built                                             68
# gini_index                                                            1883
# median_age                                                             395
# income_per_capita                                                     4507
# commuters_drove_alone                                                 4257
# commuters_by_subway_or_elevated                                        610
# employed_education_health_social                                      3375
# employed_agriculture_forestry_fishing_hunting_mining                   593
# employed_arts_entertainment_recreation_accommodation_food             2319
# employed_construction                                                 1649
# amerindian_including_hispanic                                          673
# commuters_by_carpool                                                  2210
# employed_information                                                   936
#
#                                                              null values
# aggregate_travel_time_to_work                                        272
# owner_occupied_housing_units_median_value                             59
# owner_occupied_housing_units_upper_value_quartile                     59
# owner_occupied_housing_units_lower_value_quartile                     59
# percent_income_spent_on_rent                                          52
# median_rent                                                           52
# renter_occupied_housing_units_paying_cash_median_gross_rent           52
# different_house_year_ago_same_city                                    45
# population_1_year_and_over                                            45
# less_than_high_school_graduate                                        45
# different_house_year_ago_different_city                               45
# bachelors_degree_2                                                    45
# some_college_and_associates_degree                                    45
# high_school_including_ged                                             45
# graduate_professional_degree                                          45
# not_us_citizen_pop                                                    45
# median_income                                                         35
# median_year_structure_built                                           34
# gini_index                                                            33
# median_age                                                            11
# income_per_capita                                                     11
# commuters_drove_alone                                                  0
# commuters_by_subway_or_elevated                                        0
# employed_education_health_social                                       0
# employed_agriculture_forestry_fishing_hunting_mining                   0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# amerindian_including_hispanic                                          0
# commuters_by_carpool                                                   0
# employed_information                                                   0

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls. This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (52, 52)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 4759 4759
# 3020 4759
# 3081 4759

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(5)
# Out:
#                                         data type  non-null values  \
# graduate_professional_degree              float64             4715
# not_us_citizen_pop                        float64             4715
# less_than_high_school_graduate            float64             4715
# different_house_year_ago_different_city   float64             4715
# some_college_and_associates_degree        float64             4715
#
#                                          unique values  null values
# graduate_professional_degree                      3163           44
# not_us_citizen_pop                                2706           44
# less_than_high_school_graduate                    2991           44
# different_house_year_ago_different_city           3154           44
# some_college_and_associates_degree                3792           44

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (44, 44)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#        data type  non-null values  unique values  null values
# geo_id    object             4715           4715            0

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((12167, 12), (6650, 14), (5571, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    4715
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [279]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'num_race_unknown',
#        'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../data/processed/2013black_medicare_census')

#saving all races medicare df merged
disorders_merged.to_csv('../data/processed/2013black_medicare_with_disorders_census')

#saving black_medicare with disorder values merged
all_merged.to_csv('../data/processed/2013all_races_medicare_census')
