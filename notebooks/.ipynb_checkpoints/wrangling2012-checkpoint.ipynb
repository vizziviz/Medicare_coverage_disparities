# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/capstone2/notebooks'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2012.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (925328, 67)

# %%
med.head()
# Out:
#           NPI NPPES Provider Last Name / Organization Name  \
# 0  1003000126                                    ENKESHAFI
# 1  1003000134                                       CIBULL
# 2  1003000142                                       KHALIL
# 3  1003000381                                     BRAGANZA
# 4  1003000407                                      GIRARDI
#
#   NPPES Provider First Name NPPES Provider Middle Initial NPPES Credentials  \
# 0                   ARDALAN                           NaN              M.D.
# 1                    THOMAS                             L              M.D.
# 2                    RASHID                           NaN              M.D.
# 3                    LUTHER                             Q                PT
# 4                     DAVID                             J              D.O.
#
#   NPPES Provider Gender NPPES Entity Code NPPES Provider Street Address 1  \
# 0                     M                 I                    900 SETON DR
# 1                     M                 I                  2650 RIDGE AVE
# 2                     M                 I      4126 N HOLLAND SYLVANIA RD
# 3                     M                 I             134 N OLD DIXIE HWY
# 4                     M                 I                   456 MAGEE AVE
#
#   NPPES Provider Street Address 2 NPPES Provider City  ...  \
# 0                             NaN          CUMBERLAND  ...
# 1               EVANSTON HOSPITAL            EVANSTON  ...
# 2                       SUITE 220              TOLEDO  ...
# 3                             NaN           LADY LAKE  ...
# 4                             NaN              PATTON  ...
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                                  51.0
# 1                                                  21.0
# 2                                                  50.0
# 3                                                  35.0
# 4                                                  39.0
#
#   Percent (%) of Beneficiaries Identified With Heart Failure  \
# 0                                                       53.0
# 1                                                       13.0
# 2                                                       31.0
# 3                                                        NaN
# 4                                                       51.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                                        65.0
# 1                                                        55.0
# 2                                                        63.0
# 3                                                        75.0
# 4                                                        65.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                                      75.0
# 1                                                      59.0
# 2                                                      75.0
# 3                                                      75.0
# 4                                                      75.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                                                66.0
# 1                                                                31.0
# 2                                                                47.0
# 3                                                                52.0
# 4                                                                65.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                                       14.0
# 1                                                        8.0
# 2                                                       13.0
# 3                                                        NaN
# 4                                                       20.0
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                                                                47.0
# 1                                                                                36.0
# 2                                                                                75.0
# 3                                                                                58.0
# 4                                                                                41.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                                                    14.0
# 1                                                                                     2.0
# 2                                                                                     NaN
# 3                                                                                     0.0
# 4                                                                                    21.0
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                                 19.0
# 1                                                  4.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                 12.0
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.2264
# 1                                   1.0703
# 2                                   1.8967
# 3                                   1.2687
# 4                                   1.8170
#
# [5 rows x 67 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Provider Last Name / Organization Name',
#        'NPPES Provider First Name', 'NPPES Provider Middle Initial',
#        'NPPES Credentials', 'NPPES Provider Gender', 'NPPES Entity Code',
#        'NPPES Provider Street Address 1', 'NPPES Provider Street Address 2',
#        'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Unique Beneficiaries With Drug Services',
#        'Total Drug Submitted Charges', 'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount', 'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Unique Beneficiaries With Medical Services',
#        'Total Medical Submitted Charges',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Number of Beneficiaries Age Less than 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
med['Provider Type'].unique()
# Out:
# array(['Internal Medicine', 'Pathology', 'Anesthesiology',
#        'Physical Therapist', 'Family Practice', 'Obstetrics/Gynecology',
#        'Clinical Psychologist', 'General Surgery',
#        'Occupational therapist', 'Chiropractic', 'Cardiac Surgery',
#        'Nurse Practitioner', 'Physician Assistant', 'Cardiology',
#        'Dermatology', 'CRNA', 'Mass Immunization Roster Biller',
#        'Physical Medicine and Rehabilitation',
#        'Registered Dietician/Nutrition Professional',
#        'Radiation Oncology', 'Infectious Disease', 'Orthopedic Surgery',
#        'Ambulatory Surgical Center', 'Endocrinology', 'Urology',
#        'Diagnostic Radiology', 'Neurology', 'Emergency Medicine',
#        'Nephrology', 'Licensed Clinical Social Worker', 'Psychiatry',
#        'Preventive Medicine', 'Pulmonary Disease', 'Otolaryngology',
#        'Plastic and Reconstructive Surgery', 'General Practice',
#        'Ambulance Service Supplier', 'Osteopathic Manipulative Medicine',
#        'Allergy/Immunology', 'Ophthalmology',
#        'Audiologist (billing independently)', 'Geriatric Medicine',
#        'Gastroenterology', 'Thoracic Surgery', 'Pain Management',
#        'Podiatry', 'Hematology/Oncology', 'Optometry',
#        'All Other Suppliers', 'Oral Surgery (dentists only)',
#        'Neurosurgery', 'Clinical Laboratory',
#        'Critical Care (Intensivists)', 'Surgical Oncology',
#        'Pediatric Medicine', 'Anesthesiologist Assistants',
#        'Hand Surgery', 'Certified Clinical Nurse Specialist',
#        'Hospice and Palliative Care',
#        'Independent Diagnostic Testing Facility', 'Rheumatology',
#        'Vascular Surgery', 'Interventional Pain Management',
#        'Maxillofacial Surgery', 'Medical Oncology', 'Portable X-ray',
#        'Nuclear Medicine', 'Certified Nurse Midwife',
#        'Mammographic Screening Center',
#        'Multispecialty Clinic/Group Practice',
#        'Cardiac Electrophysiology', 'Sports Medicine',
#        'Public Health Welfare Agency', 'Slide Preparation Facility',
#        'Interventional Radiology',
#        'Colorectal Surgery (formerly proctology)', 'Geriatric Psychiatry',
#        'Speech Language Pathologist', 'Hematology', 'Addiction Medicine',
#        'Gynecological/Oncology', 'Neuropsychiatry',
#        'Peripheral Vascular Disease',
#        'Psychologist (billing independently)',
#        'Unknown Physician Specialty Code', 'Radiation Therapy',
#        'Unknown Supplier/Provider', 'Sleep Medicine', 'Pharmacy'],
#       dtype=object)

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',]

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry',]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 37866

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Beneficiaries Age Less than 65                                                 float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Payment Amount                                                    float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# NPI                                                                                       object
# Total Medicare Payment Amount                                                            float64
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Country                                                                    object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Provider Type                                                                             object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Drug Suppress Indicator                                                                             874
# Medical Suppress Indicator                                                                          874
# Number of Beneficiaries With Race Not Elsewhere Classified                                         7128
# Number of Hispanic Beneficiaries                                                                   7668
# Number of Asian Pacific Islander Beneficiaries                                                     7731
# Number of Beneficiaries Age 75 to 84                                                               8548
# Number of Black or African American Beneficiaries                                                  9294
# Number of American Indian/Alaska Native Beneficiaries                                             10180
# Number of Beneficiaries Age Greater 84                                                            11386
# Number of Beneficiaries Age 65 to 74                                                              12182
# Percent (%) of Beneficiaries Identified With Cancer                                               13738
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         14451
# NPPES Provider Street Address 2                                                                   14748
# Percent (%) of Beneficiaries Identified With Asthma                                               14883
# Percent (%) of Beneficiaries Identified With Heart Failure                                        15897
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               16258
# Percent (%) of Beneficiaries Identified With Stroke                                               16721
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  16927
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                17056
# Number of Non-Hispanic White Beneficiaries                                                        17525
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      17865
# Number of Beneficiaries Age Less than 65                                                          18362
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               19088
# Number of Beneficiaries With Medicare Only Entitlement                                            20249
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      20249
# Percent (%) of Beneficiaries Identified With Diabetes                                             21464
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                22522
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            23331
# Number of Male Beneficiaries                                                                      23680
# Number of Female Beneficiaries                                                                    23680
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       26140
# NPPES Provider Middle Initial                                                                     26784
# Percent (%) of Beneficiaries Identified With Hypertension                                         27983
# Percent (%) of Beneficiaries Identified With Depression                                           32977
# NPPES Credentials                                                                                 36531
# Total Medical Medicare Allowed Amount                                                             36992
# Total Medical Submitted Charges                                                                   36992
# Number of Unique Beneficiaries With Medical Services                                              36992
# Number of Medical Services                                                                        36992
# Number of HCPCS Associated With Medical Services                                                  36992
# Total Drug Medicare Payment Amount                                                                36992
# Total Drug Medicare Allowed Amount                                                                36992
# Total Drug Submitted Charges                                                                      36992
# Number of Drug Services                                                                           36992
# Number of HCPCS Associated With Drug Services                                                     36992
# Total Medical Medicare Payment Amount                                                             36992
# Number of Unique Beneficiaries With Drug Services                                                 36992
# NPPES Provider Gender                                                                             37863
# NPPES Provider First Name                                                                         37863
# NPI                                                                                               37866
# Total Medicare Payment Amount                                                                     37866
# NPPES Provider Last Name / Organization Name                                                      37866
# NPPES Entity Code                                                                                 37866
# NPPES Provider Street Address 1                                                                   37866
# NPPES Provider City                                                                               37866
# NPPES Provider Zip Code                                                                           37866
# NPPES Provider State                                                                              37866
# Average Age of Beneficiaries                                                                      37866
# NPPES Provider Country                                                                            37866
# Medicare Participation Indicator                                                                  37866
# Number of HCPCS                                                                                   37866
# Number of Services                                                                                37866
# Number of Unique Beneficiaries                                                                    37866
# Total Submitted Charges                                                                           37866
# Total Medicare Allowed Amount                                                                     37866
# Provider Type                                                                                     37866
# Average HCC Risk Score of Beneficiaries                                                           37866
#
#                                                                                         unique values  \
# Drug Suppress Indicator                                                                             1
# Medical Suppress Indicator                                                                          2
# Number of Beneficiaries With Race Not Elsewhere Classified                                         33
# Number of Hispanic Beneficiaries                                                                  274
# Number of Asian Pacific Islander Beneficiaries                                                    103
# Number of Beneficiaries Age 75 to 84                                                              382
# Number of Black or African American Beneficiaries                                                 345
# Number of American Indian/Alaska Native Beneficiaries                                              53
# Number of Beneficiaries Age Greater 84                                                            417
# Number of Beneficiaries Age 65 to 74                                                              324
# Percent (%) of Beneficiaries Identified With Cancer                                                66
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          51
# NPPES Provider Street Address 2                                                                  5652
# Percent (%) of Beneficiaries Identified With Asthma                                                50
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                72
# Percent (%) of Beneficiaries Identified With Stroke                                                54
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   45
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Number of Non-Hispanic White Beneficiaries                                                        844
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Number of Beneficiaries Age Less than 65                                                          578
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Number of Beneficiaries With Medicare Only Entitlement                                            550
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      761
# Percent (%) of Beneficiaries Identified With Diabetes                                              68
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 71
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# Number of Male Beneficiaries                                                                      528
# Number of Female Beneficiaries                                                                    705
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        65
# NPPES Provider Middle Initial                                                                      29
# Percent (%) of Beneficiaries Identified With Hypertension                                          63
# Percent (%) of Beneficiaries Identified With Depression                                            65
# NPPES Credentials                                                                                1523
# Total Medical Medicare Allowed Amount                                                           36839
# Total Medical Submitted Charges                                                                 30388
# Number of Unique Beneficiaries With Medical Services                                             1011
# Number of Medical Services                                                                       3219
# Number of HCPCS Associated With Medical Services                                                   61
# Total Drug Medicare Payment Amount                                                                285
# Total Drug Medicare Allowed Amount                                                                284
# Total Drug Submitted Charges                                                                      284
# Number of Drug Services                                                                           262
# Number of HCPCS Associated With Drug Services                                                      15
# Total Medical Medicare Payment Amount                                                           36747
# Number of Unique Beneficiaries With Drug Services                                                  72
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                        7533
# NPI                                                                                             37866
# Total Medicare Payment Amount                                                                   37615
# NPPES Provider Last Name / Organization Name                                                    21586
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                 22304
# NPPES Provider City                                                                              3985
# NPPES Provider Zip Code                                                                         23269
# NPPES Provider State                                                                               55
# Average Age of Beneficiaries                                                                       65
# NPPES Provider Country                                                                              4
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    69
# Number of Services                                                                               3417
# Number of Unique Beneficiaries                                                                   1023
# Total Submitted Charges                                                                         31223
# Total Medicare Allowed Amount                                                                   37706
# Provider Type                                                                                       4
# Average HCC Risk Score of Beneficiaries                                                         14121
#
#                                                                                         null values
# Drug Suppress Indicator                                                                       36992
# Medical Suppress Indicator                                                                    36992
# Number of Beneficiaries With Race Not Elsewhere Classified                                    30738
# Number of Hispanic Beneficiaries                                                              30198
# Number of Asian Pacific Islander Beneficiaries                                                30135
# Number of Beneficiaries Age 75 to 84                                                          29318
# Number of Black or African American Beneficiaries                                             28572
# Number of American Indian/Alaska Native Beneficiaries                                         27686
# Number of Beneficiaries Age Greater 84                                                        26480
# Number of Beneficiaries Age 65 to 74                                                          25684
# Percent (%) of Beneficiaries Identified With Cancer                                           24128
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     23415
# NPPES Provider Street Address 2                                                               23118
# Percent (%) of Beneficiaries Identified With Asthma                                           22983
# Percent (%) of Beneficiaries Identified With Heart Failure                                    21969
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           21608
# Percent (%) of Beneficiaries Identified With Stroke                                           21145
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              20939
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            20810
# Number of Non-Hispanic White Beneficiaries                                                    20341
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  20001
# Number of Beneficiaries Age Less than 65                                                      19504
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           18778
# Number of Beneficiaries With Medicare Only Entitlement                                        17617
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  17617
# Percent (%) of Beneficiaries Identified With Diabetes                                         16402
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            15344
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        14535
# Number of Male Beneficiaries                                                                  14186
# Number of Female Beneficiaries                                                                14186
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   11726
# NPPES Provider Middle Initial                                                                 11082
# Percent (%) of Beneficiaries Identified With Hypertension                                      9883
# Percent (%) of Beneficiaries Identified With Depression                                        4889
# NPPES Credentials                                                                              1335
# Total Medical Medicare Allowed Amount                                                           874
# Total Medical Submitted Charges                                                                 874
# Number of Unique Beneficiaries With Medical Services                                            874
# Number of Medical Services                                                                      874
# Number of HCPCS Associated With Medical Services                                                874
# Total Drug Medicare Payment Amount                                                              874
# Total Drug Medicare Allowed Amount                                                              874
# Total Drug Submitted Charges                                                                    874
# Number of Drug Services                                                                         874
# Number of HCPCS Associated With Drug Services                                                   874
# Total Medical Medicare Payment Amount                                                           874
# Number of Unique Beneficiaries With Drug Services                                               874
# NPPES Provider Gender                                                                             3
# NPPES Provider First Name                                                                         3
# NPI                                                                                               0
# Total Medicare Payment Amount                                                                     0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Country                                                                            0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Provider Type                                                                                     0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Unique Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 9294

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 3942

# %% [markdown]
# Some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Unique Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 10

# %%
#Let's look at rows where all info is present but not all bins equal the total.

mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']
][race_cols]
# Out:
#         Number of American Indian/Alaska Native Beneficiaries  \
# 578632                                                    0.0
# 551725                                                    0.0
# 88526                                                     0.0
# 193759                                                    0.0
# 204627                                                    0.0
# 235717                                                    0.0
# 389762                                                    0.0
# 668003                                                    0.0
# 781800                                                    0.0
# 907273                                                    0.0
#
#         Number of Asian Pacific Islander Beneficiaries  \
# 578632                                             0.0
# 551725                                             0.0
# 88526                                              0.0
# 193759                                            20.0
# 204627                                             0.0
# 235717                                            18.0
# 389762                                             0.0
# 668003                                            19.0
# 781800                                             0.0
# 907273                                             0.0
#
#         Number of Non-Hispanic White Beneficiaries  \
# 578632                                        16.0
# 551725                                        19.0
# 88526                                        142.0
# 193759                                      1552.0
# 204627                                        13.0
# 235717                                      2555.0
# 389762                                        20.0
# 668003                                      1007.0
# 781800                                       258.0
# 907273                                        24.0
#
#         Number of Hispanic Beneficiaries  \
# 578632                               0.0
# 551725                               0.0
# 88526                                0.0
# 193759                             112.0
# 204627                               0.0
# 235717                             156.0
# 389762                               0.0
# 668003                             220.0
# 781800                               0.0
# 907273                              25.0
#
#         Number of Beneficiaries With Race Not Elsewhere Classified  \
# 578632                                                         0.0
# 551725                                                         0.0
# 88526                                                          0.0
# 193759                                                        13.0
# 204627                                                         0.0
# 235717                                                        27.0
# 389762                                                         0.0
# 668003                                                        12.0
# 781800                                                         0.0
# 907273                                                         0.0
#
#         Number of Black or African American Beneficiaries  \
# 578632                                               11.0
# 551725                                                0.0
# 88526                                                16.0
# 193759                                              113.0
# 204627                                                0.0
# 235717                                              234.0
# 389762                                               36.0
# 668003                                              210.0
# 781800                                               11.0
# 907273                                               20.0
#
#        Number of Unique Beneficiaries
# 578632                             28
# 551725                             20
# 88526                             159
# 193759                           1811
# 204627                             14
# 235717                           2991
# 389762                             57
# 668003                           1470
# 781800                            270
# 907273                             70

# %%
#index of rows where sums don't equal total
idx = mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']
].index

#sums of races that are off
sums_of_races = mental_med.loc[idx][race_cols[:-1]].sum(axis=1)

#values to replace 'Number with Race Not Classified' (Total+'Number Not Classfd'-sums)
new_values = mental_med.loc[idx, 
        'Number of Beneficiaries With Race Not Elsewhere Classified'] + \
        mental_med.loc[idx]['Number of Unique Beneficiaries'] - \
        sums_of_races

#actually replacing those values
mental_med.loc[idx, 
            'Number of Beneficiaries With Race Not Elsewhere Classified'] = new_values

# %%
#checking my work
(mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) == \
    mental_med.loc[all_races_idx]['Number of Unique Beneficiaries']).sum()
# Out:
# 3942

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less than 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Unique Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Unique Beneficiaries']).sum()
# Out:
# 7175

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Unique Beneficiaries']).sum()
# Out:
# 3734

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 9294

# %%
(black_medicare[age_cols[:-1]].sum(axis=1, skipna=False).isnull()).sum()
# Out:
# 7108

# %%
black_medicare[age_cols].head(3)
# Out:
#      Number of Beneficiaries Age Less than 65  \
# 180                                       NaN
# 212                                       NaN
# 235                                       0.0
#
#      Number of Beneficiaries Age 65 to 74  \
# 180                                   NaN
# 212                                   NaN
# 235                                   NaN
#
#      Number of Beneficiaries Age 75 to 84  \
# 180                                   NaN
# 212                                   NaN
# 235                                   NaN
#
#      Number of Beneficiaries Age Greater 84 Number of Unique Beneficiaries
# 180                                     0.0                             17
# 212                                     NaN                             21
# 235                                     NaN                             11

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (9294, 9294)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (3942, 3942)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries                                                             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of HCPCS Associated With Medical Services                                         float64
# Number of Drug Services                                                                  float64
# NPPES Provider First Name                                                                 object
# NPPES Provider Gender                                                                     object
# NPI                                                                                       object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# NPPES Provider Country                                                                    object
# Provider Type                                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          276
# Drug Suppress Indicator                                                                             276
# NPPES Provider Street Address 2                                                                    3705
# Percent (%) of Beneficiaries Identified With Cancer                                                4111
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          4326
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   4785
# Percent (%) of Beneficiaries Identified With Stroke                                                4996
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                5009
# Percent (%) of Beneficiaries Identified With Asthma                                                5033
# Percent (%) of Beneficiaries Identified With Heart Failure                                         5049
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 5085
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                5202
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       5370
# Number of Beneficiaries With Medicare Only Entitlement                                             5370
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       5398
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 5520
# Percent (%) of Beneficiaries Identified With Diabetes                                              5562
# Number of Female Beneficiaries                                                                     5741
# Number of Male Beneficiaries                                                                       5741
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        6155
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             6350
# NPPES Provider Middle Initial                                                                      6438
# Percent (%) of Beneficiaries Identified With Hypertension                                          6460
# Percent (%) of Beneficiaries Identified With Depression                                            7493
# NPPES Credentials                                                                                  8950
# Total Medical Medicare Payment Amount                                                              9018
# Total Medical Medicare Allowed Amount                                                              9018
# Total Medical Submitted Charges                                                                    9018
# Number of Unique Beneficiaries With Medical Services                                               9018
# Number of Medical Services                                                                         9018
# Total Drug Medicare Allowed Amount                                                                 9018
# Total Drug Medicare Payment Amount                                                                 9018
# Total Drug Submitted Charges                                                                       9018
# Number of Unique Beneficiaries With Drug Services                                                  9018
# Number of HCPCS Associated With Drug Services                                                      9018
# Number of HCPCS Associated With Medical Services                                                   9018
# Number of Drug Services                                                                            9018
# NPPES Provider First Name                                                                          9292
# NPPES Provider Gender                                                                              9292
# NPI                                                                                                9294
# Average Age of Beneficiaries                                                                       9294
# NPPES Provider Last Name / Organization Name                                                       9294
# NPPES Entity Code                                                                                  9294
# NPPES Provider Street Address 1                                                                    9294
# NPPES Provider City                                                                                9294
# NPPES Provider Zip Code                                                                            9294
# NPPES Provider State                                                                               9294
# NPPES Provider Country                                                                             9294
# Provider Type                                                                                      9294
# Medicare Participation Indicator                                                                   9294
# Number of HCPCS                                                                                    9294
# Number of Services                                                                                 9294
# Number of Unique Beneficiaries                                                                     9294
# Total Submitted Charges                                                                            9294
# Total Medicare Allowed Amount                                                                      9294
# Total Medicare Payment Amount                                                                      9294
# Number of Black or African American Beneficiaries                                                  9294
# Average HCC Risk Score of Beneficiaries                                                            9294
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# NPPES Provider Street Address 2                                                                  1936
# Percent (%) of Beneficiaries Identified With Cancer                                                37
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          40
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   41
# Percent (%) of Beneficiaries Identified With Stroke                                                44
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Percent (%) of Beneficiaries Identified With Asthma                                                42
# Percent (%) of Beneficiaries Identified With Heart Failure                                         73
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 66
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      717
# Number of Beneficiaries With Medicare Only Entitlement                                            500
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Number of Female Beneficiaries                                                                    668
# Number of Male Beneficiaries                                                                      515
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        63
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# NPPES Provider Middle Initial                                                                      28
# Percent (%) of Beneficiaries Identified With Hypertension                                          59
# Percent (%) of Beneficiaries Identified With Depression                                            64
# NPPES Credentials                                                                                 531
# Total Medical Medicare Payment Amount                                                            9004
# Total Medical Medicare Allowed Amount                                                            9010
# Total Medical Submitted Charges                                                                  8416
# Number of Unique Beneficiaries With Medical Services                                              953
# Number of Medical Services                                                                       2507
# Total Drug Medicare Allowed Amount                                                                156
# Total Drug Medicare Payment Amount                                                                156
# Total Drug Submitted Charges                                                                      156
# Number of Unique Beneficiaries With Drug Services                                                  58
# Number of HCPCS Associated With Drug Services                                                      11
# Number of HCPCS Associated With Medical Services                                                   47
# Number of Drug Services                                                                           147
# NPPES Provider First Name                                                                        3138
# NPPES Provider Gender                                                                               2
# NPI                                                                                              9294
# Average Age of Beneficiaries                                                                       61
# NPPES Provider Last Name / Organization Name                                                     6769
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                  7311
# NPPES Provider City                                                                              2349
# NPPES Provider Zip Code                                                                          7477
# NPPES Provider State                                                                               55
# NPPES Provider Country                                                                              2
# Provider Type                                                                                       4
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    52
# Number of Services                                                                               2626
# Number of Unique Beneficiaries                                                                    968
# Total Submitted Charges                                                                          8692
# Total Medicare Allowed Amount                                                                    9286
# Total Medicare Payment Amount                                                                    9279
# Number of Black or African American Beneficiaries                                                 345
# Average HCC Risk Score of Beneficiaries                                                          6990
#
#                                                                                         null values
# Medical Suppress Indicator                                                                     9018
# Drug Suppress Indicator                                                                        9018
# NPPES Provider Street Address 2                                                                5589
# Percent (%) of Beneficiaries Identified With Cancer                                            5183
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      4968
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               4509
# Percent (%) of Beneficiaries Identified With Stroke                                            4298
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            4285
# Percent (%) of Beneficiaries Identified With Asthma                                            4261
# Percent (%) of Beneficiaries Identified With Heart Failure                                     4245
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             4209
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            4092
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   3924
# Number of Beneficiaries With Medicare Only Entitlement                                         3924
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   3896
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             3774
# Percent (%) of Beneficiaries Identified With Diabetes                                          3732
# Number of Female Beneficiaries                                                                 3553
# Number of Male Beneficiaries                                                                   3553
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    3139
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         2944
# NPPES Provider Middle Initial                                                                  2856
# Percent (%) of Beneficiaries Identified With Hypertension                                      2834
# Percent (%) of Beneficiaries Identified With Depression                                        1801
# NPPES Credentials                                                                               344
# Total Medical Medicare Payment Amount                                                           276
# Total Medical Medicare Allowed Amount                                                           276
# Total Medical Submitted Charges                                                                 276
# Number of Unique Beneficiaries With Medical Services                                            276
# Number of Medical Services                                                                      276
# Total Drug Medicare Allowed Amount                                                              276
# Total Drug Medicare Payment Amount                                                              276
# Total Drug Submitted Charges                                                                    276
# Number of Unique Beneficiaries With Drug Services                                               276
# Number of HCPCS Associated With Drug Services                                                   276
# Number of HCPCS Associated With Medical Services                                                276
# Number of Drug Services                                                                         276
# NPPES Provider First Name                                                                         2
# NPPES Provider Gender                                                                             2
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# NPPES Provider Country                                                                            0
# Provider Type                                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Number of Black or African American Beneficiaries                                                 0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries','Number of Unique Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 5741
# Has nulls: 3553

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Unique Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 5609
# Don't sum 132

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# NPPES Provider Street Address 2                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# NPPES Provider Middle Initial                                                             object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Submitted Charges                                                             float64
# Total Drug Medicare Allowed Amount                                                       float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Drug Medicare Payment Amount                                                       float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# NPI                                                                                       object
# Average Age of Beneficiaries                                                              object
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Entity Code                                                                         object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider City                                                                       object
# NPPES Provider Zip Code                                                                   object
# NPPES Provider State                                                                      object
# NPPES Provider Country                                                                    object
# Provider Type                                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                        object
# Number of Unique Beneficiaries                                                            object
# Total Submitted Charges                                                                  float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          276
# Drug Suppress Indicator                                                                             276
# NPPES Provider Street Address 2                                                                    3705
# Percent (%) of Beneficiaries Identified With Cancer                                                4111
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          4326
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   4785
# Percent (%) of Beneficiaries Identified With Stroke                                                4996
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                5009
# Percent (%) of Beneficiaries Identified With Asthma                                                5033
# Percent (%) of Beneficiaries Identified With Heart Failure                                         5049
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 5085
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                5202
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       5370
# Number of Beneficiaries With Medicare Only Entitlement                                             5370
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       5398
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 5520
# Percent (%) of Beneficiaries Identified With Diabetes                                              5562
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        6155
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             6350
# NPPES Provider Middle Initial                                                                      6438
# Percent (%) of Beneficiaries Identified With Hypertension                                          6460
# Percent (%) of Beneficiaries Identified With Depression                                            7493
# NPPES Credentials                                                                                  8950
# Total Medical Medicare Payment Amount                                                              9018
# Total Medical Medicare Allowed Amount                                                              9018
# Total Medical Submitted Charges                                                                    9018
# Number of Unique Beneficiaries With Medical Services                                               9018
# Number of Medical Services                                                                         9018
# Number of HCPCS Associated With Medical Services                                                   9018
# Total Drug Submitted Charges                                                                       9018
# Total Drug Medicare Allowed Amount                                                                 9018
# Number of Unique Beneficiaries With Drug Services                                                  9018
# Number of Drug Services                                                                            9018
# Number of HCPCS Associated With Drug Services                                                      9018
# Total Drug Medicare Payment Amount                                                                 9018
# NPPES Provider Gender                                                                              9292
# NPPES Provider First Name                                                                          9292
# NPI                                                                                                9294
# Average Age of Beneficiaries                                                                       9294
# NPPES Provider Last Name / Organization Name                                                       9294
# NPPES Entity Code                                                                                  9294
# NPPES Provider Street Address 1                                                                    9294
# NPPES Provider City                                                                                9294
# NPPES Provider Zip Code                                                                            9294
# NPPES Provider State                                                                               9294
# NPPES Provider Country                                                                             9294
# Provider Type                                                                                      9294
# Medicare Participation Indicator                                                                   9294
# Number of HCPCS                                                                                    9294
# Number of Services                                                                                 9294
# Number of Unique Beneficiaries                                                                     9294
# Total Submitted Charges                                                                            9294
# Total Medicare Allowed Amount                                                                      9294
# Total Medicare Payment Amount                                                                      9294
# Number of Black or African American Beneficiaries                                                  9294
# Average HCC Risk Score of Beneficiaries                                                            9294
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# NPPES Provider Street Address 2                                                                  1936
# Percent (%) of Beneficiaries Identified With Cancer                                                37
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          40
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   41
# Percent (%) of Beneficiaries Identified With Stroke                                                44
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Percent (%) of Beneficiaries Identified With Asthma                                                42
# Percent (%) of Beneficiaries Identified With Heart Failure                                         73
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 66
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      717
# Number of Beneficiaries With Medicare Only Entitlement                                            500
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       75
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        63
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# NPPES Provider Middle Initial                                                                      28
# Percent (%) of Beneficiaries Identified With Hypertension                                          59
# Percent (%) of Beneficiaries Identified With Depression                                            64
# NPPES Credentials                                                                                 531
# Total Medical Medicare Payment Amount                                                            9004
# Total Medical Medicare Allowed Amount                                                            9010
# Total Medical Submitted Charges                                                                  8416
# Number of Unique Beneficiaries With Medical Services                                              953
# Number of Medical Services                                                                       2507
# Number of HCPCS Associated With Medical Services                                                   47
# Total Drug Submitted Charges                                                                      156
# Total Drug Medicare Allowed Amount                                                                156
# Number of Unique Beneficiaries With Drug Services                                                  58
# Number of Drug Services                                                                           147
# Number of HCPCS Associated With Drug Services                                                      11
# Total Drug Medicare Payment Amount                                                                156
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                        3138
# NPI                                                                                              9294
# Average Age of Beneficiaries                                                                       61
# NPPES Provider Last Name / Organization Name                                                     6769
# NPPES Entity Code                                                                                   2
# NPPES Provider Street Address 1                                                                  7311
# NPPES Provider City                                                                              2349
# NPPES Provider Zip Code                                                                          7477
# NPPES Provider State                                                                               55
# NPPES Provider Country                                                                              2
# Provider Type                                                                                       4
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    52
# Number of Services                                                                               2626
# Number of Unique Beneficiaries                                                                    968
# Total Submitted Charges                                                                          8692
# Total Medicare Allowed Amount                                                                    9286
# Total Medicare Payment Amount                                                                    9279
# Number of Black or African American Beneficiaries                                                 345
# Average HCC Risk Score of Beneficiaries                                                          6990
#
#                                                                                         null values
# Medical Suppress Indicator                                                                     9018
# Drug Suppress Indicator                                                                        9018
# NPPES Provider Street Address 2                                                                5589
# Percent (%) of Beneficiaries Identified With Cancer                                            5183
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      4968
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               4509
# Percent (%) of Beneficiaries Identified With Stroke                                            4298
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            4285
# Percent (%) of Beneficiaries Identified With Asthma                                            4261
# Percent (%) of Beneficiaries Identified With Heart Failure                                     4245
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             4209
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            4092
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   3924
# Number of Beneficiaries With Medicare Only Entitlement                                         3924
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   3896
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             3774
# Percent (%) of Beneficiaries Identified With Diabetes                                          3732
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    3139
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         2944
# NPPES Provider Middle Initial                                                                  2856
# Percent (%) of Beneficiaries Identified With Hypertension                                      2834
# Percent (%) of Beneficiaries Identified With Depression                                        1801
# NPPES Credentials                                                                               344
# Total Medical Medicare Payment Amount                                                           276
# Total Medical Medicare Allowed Amount                                                           276
# Total Medical Submitted Charges                                                                 276
# Number of Unique Beneficiaries With Medical Services                                            276
# Number of Medical Services                                                                      276
# Number of HCPCS Associated With Medical Services                                                276
# Total Drug Submitted Charges                                                                    276
# Total Drug Medicare Allowed Amount                                                              276
# Number of Unique Beneficiaries With Drug Services                                               276
# Number of Drug Services                                                                         276
# Number of HCPCS Associated With Drug Services                                                   276
# Total Drug Medicare Payment Amount                                                              276
# NPPES Provider Gender                                                                             2
# NPPES Provider First Name                                                                         2
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# NPPES Provider Last Name / Organization Name                                                      0
# NPPES Entity Code                                                                                 0
# NPPES Provider Street Address 1                                                                   0
# NPPES Provider City                                                                               0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider State                                                                              0
# NPPES Provider Country                                                                            0
# Provider Type                                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Unique Beneficiaries                                                                    0
# Total Submitted Charges                                                                           0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Number of Black or African American Beneficiaries                                                 0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
    'NPI', #keeping this as unique ID for each provider
    'Provider Type',
     'Number of Unique Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'NPPES Provider City', 
    'NPPES Provider State',
    'NPPES Provider Zip Code', 
    'Average HCC Risk Score of Beneficiaries'
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
     'NPPES Provider Country',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Percent (%) of Beneficiaries Identified With Cancer',
#  'Number of HCPCS',
#  'Total Drug Medicare Allowed Amount',
#  'NPPES Provider Street Address 1',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#  'Number of Beneficiaries With Medicare Only Entitlement',
#  'Total Medical Submitted Charges',
#  'Drug Suppress Indicator',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Total Drug Submitted Charges',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Percent (%) of Beneficiaries Identified With Asthma',
#  'Number of Medical Services',
#  'Total Medicare Allowed Amount',
#  'Total Medical Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#  'Medicare Participation Indicator',
#  'Percent (%) of Beneficiaries Identified With Stroke',
#  'Total Medical Medicare Allowed Amount',
#  'Number of Drug Services',
#  'Number of HCPCS Associated With Medical Services',
#  'Number of HCPCS Associated With Drug Services',
#  'NPPES Provider Gender',
#  'NPPES Provider Street Address 2',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#  'Number of Unique Beneficiaries With Drug Services',
#  'NPPES Provider Last Name / Organization Name',
#  'Percent (%) of Beneficiaries Identified With Hypertension',
#  'Number of Unique Beneficiaries With Medical Services',
#  'Number of Services',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'NPPES Entity Code',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#  'Total Drug Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Percent (%) of Beneficiaries Identified With Diabetes',
#  'NPPES Provider Middle Initial',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis',
#  'NPPES Provider First Name',
#  'Total Submitted Charges',
#  'Percent (%) of Beneficiaries Identified With Heart Failure',
#  'Medical Suppress Indicator',
#  'NPPES Credentials']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['NPI', 'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Number of Unique Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['NPI', 'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Number of Unique Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape
# Out:
# (9294, 13)

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'NPI':'npi',
                 'NPPES Provider City':'city', 'NPPES Provider Zip Code':'full_zip',
                'NPPES Provider State':'state','NPPES Provider Country':'country',
                'Provider Type':'provider_type',
                 'Number of Unique Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders':
                    'percent_with_psychosis'}
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#There are two countries values listed in my column info for Country

# %%
black_medicare.country.unique()
# Out:
# array(['US', 'DE'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# How many unique 5-digit zip codes are there in this df? There are 33,000 zip codes on Census df.

# %% [markdown]
# First I have to convert the NPPES Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    6850
# 8    1077
# 5    1024
# 4     237
# 3      59
# 7      46
# Name: full_zip, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 5765     6032
# 24474    6069
# 39197    4769
# 59668    4542
# 69946    4401
# Name: full_zip, dtype: object

# %%
#adding leading zeros to the five digit zip code
idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    7146
# 8    1077
# 5    1024
# 7      46
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ].head()['full_zip']
# Out:
# 1232     47904
# 1753     48848
# 7217     26807
# 10691    48755
# 10715    49007
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# 39871     9261739
# 363095    9616910
# 21729     9183014
# 23969     7256314
# 33809     9616910
# Name: full_zip, dtype: object

# %%
#I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9293
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 4111

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    9293
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.
idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    9293
# Name: full_zip, dtype: int64
# 5    9293
# Name: five_dig_zip, dtype: int64
# 9    3942
# Name: full_zip, dtype: int64
# 5    3942
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9293 entries, 180 to 924697
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      9293 non-null   object
#  1   city                     9293 non-null   object
#  2   full_zip                 9293 non-null   object
#  3   state                    9293 non-null   object
#  4   country                  9293 non-null   object
#  5   provider_type            9293 non-null   object
#  6   total_beneficiaries      9293 non-null   object
#  7   total_medicare_payment   9293 non-null   float64
#  8   avg_beneficiary_age      9293 non-null   object
#  9   num_black                9293 non-null   float64
#  10  percent_with_depression  7492 non-null   float64
#  11  percent_with_psychosis   6349 non-null   float64
#  12  avg_hcc_risk_score       9293 non-null   float64
#  13  five_dig_zip             9293 non-null   object
# dtypes: float64(5), object(9)
# memory usage: 1.4+ MB

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3942 entries, 180 to 924126
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      3942 non-null   object
#  1   city                     3942 non-null   object
#  2   full_zip                 3942 non-null   object
#  3   state                    3942 non-null   object
#  4   country                  3942 non-null   object
#  5   provider_type            3942 non-null   object
#  6   total_beneficiaries      3942 non-null   object
#  7   total_medicare_payment   3942 non-null   float64
#  8   avg_beneficiary_age      3942 non-null   object
#  9   num_white                3942 non-null   float64
#  10  num_black                3942 non-null   float64
#  11  num_asian_pac_isl        3942 non-null   float64
#  12  num_hispanic             3942 non-null   float64
#  13  num_nat_amer             3942 non-null   float64
#  14  num_race_unknown         3942 non-null   object
#  15  percent_with_depression  2633 non-null   float64
#  16  percent_with_psychosis   1500 non-null   float64
#  17  avg_hcc_risk_score       3942 non-null   float64
#  18  five_dig_zip             3942 non-null   object
# dtypes: float64(9), object(10)
# memory usage: 775.9+ KB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../data/raw/2012census.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   91046                   116                 13
# 1   20317                   232                  0
# 2   95915                    31                 17
# 3   14881                   100                  0
# 4   71345                    52                 26
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1987.0                         0
# 1                       1949.0                         0
# 2                       1939.0                         0
# 3                       1986.0                         0
# 4                       1970.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                   117                      0                     12
# 1                   139                     40                     24
# 2                    17                     20                      0
# 3                     0                     68                      0
# 4                    78                      0                      0
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                      0  ...
# 1                      0                     14  ...
# 2                      0                      0  ...
# 3                      0                     16  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          11                      0
# 1                         348                      0
# 2                          59                      0
# 3                         100                      0
# 4                         113                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              141                 11
# 1                                  0              348                 55
# 2                                  0               48                 17
# 3                                  0              100                 17
# 4                                  0              113                 28
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0               25              0            0             0  20082012
# 1               84             14           87            79  20082012
# 2                0              0            0            31  20082012
# 3                0              0           83             0  20082012
# 4                1             28           56             0  20082012
#
# [5 rows x 252 columns]

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# median_rent                                                   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# gini_index                                                    float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          19643
# renter_occupied_housing_units_paying_cash_median_gross_rent            28629
# median_rent                                                            28638
# percent_income_spent_on_rent                                           29152
# owner_occupied_housing_units_upper_value_quartile                      31921
# owner_occupied_housing_units_lower_value_quartile                      31921
# owner_occupied_housing_units_median_value                              31921
# gini_index                                                             32241
# median_income                                                          32251
# median_year_structure_built                                            32409
# income_per_capita                                                      32548
# median_age                                                             32721
# some_college_and_associates_degree                                     32989
# not_us_citizen_pop                                                     32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# less_than_high_school_graduate                                         32989
# different_house_year_ago_different_city                                32989
# graduate_professional_degree                                           32989
# bachelors_degree_2                                                     32989
# high_school_including_ged                                              32989
# commuters_drove_alone                                                  33120
# commuters_by_carpool                                                   33120
# commuters_by_subway_or_elevated                                        33120
# employed_finance_insurance_real_estate                                 33120
# employed_arts_entertainment_recreation_accommodation_food              33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# employed_information                                                   33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16605
# renter_occupied_housing_units_paying_cash_median_gross_rent           1657
# median_rent                                                           1669
# percent_income_spent_on_rent                                           401
# owner_occupied_housing_units_upper_value_quartile                     6057
# owner_occupied_housing_units_lower_value_quartile                     4215
# owner_occupied_housing_units_median_value                             5125
# gini_index                                                            4141
# median_income                                                        20047
# median_year_structure_built                                             69
# income_per_capita                                                    20115
# median_age                                                             676
# some_college_and_associates_degree                                    7360
# not_us_citizen_pop                                                    4159
# different_house_year_ago_same_city                                    3681
# population_1_year_and_over                                           15192
# less_than_high_school_graduate                                        4695
# different_house_year_ago_different_city                               4801
# graduate_professional_degree                                          4274
# bachelors_degree_2                                                    5711
# high_school_including_ged                                             7087
# commuters_drove_alone                                                 9950
# commuters_by_carpool                                                  2888
# commuters_by_subway_or_elevated                                        854
# employed_finance_insurance_real_estate                                2375
# employed_arts_entertainment_recreation_accommodation_food             2841
# employed_construction                                                 2092
# employed_education_health_social                                      5165
# commuters_by_car_truck_van                                           10544
# employed_information                                                  1083
#
#                                                              null values
# aggregate_travel_time_to_work                                      13477
# renter_occupied_housing_units_paying_cash_median_gross_rent         4491
# median_rent                                                         4482
# percent_income_spent_on_rent                                        3968
# owner_occupied_housing_units_upper_value_quartile                   1199
# owner_occupied_housing_units_lower_value_quartile                   1199
# owner_occupied_housing_units_median_value                           1199
# gini_index                                                           879
# median_income                                                        869
# median_year_structure_built                                          711
# income_per_capita                                                    572
# median_age                                                           399
# some_college_and_associates_degree                                   131
# not_us_citizen_pop                                                   131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# less_than_high_school_graduate                                       131
# different_house_year_ago_different_city                              131
# graduate_professional_degree                                         131
# bachelors_degree_2                                                   131
# high_school_including_ged                                            131
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['66160', '92161', '27710', '58206', '48824', '92369', '94143', '38157',
#        '32610', '14642', '20453', '11571', '41702', '46904', '65212', '92415',
#        '21041', '37232', '06504', '00919', '29425', '00732', '33421', '32163',
#        '27599', '00963', '01805', '02178', '68198', '00792', '04402', '01655',
#        '00820', '21287', '30031', '44195', '06102', '44636', '00908', '45408',
#        '12402', '20522', '23298', '06349', '60674', '29151', '20060', '18341',
#        '10155', '37684', '29240', '07962', '03247', '00801', '04333', '87131',
#        '84132', '05009', '45267', '00726', '22908', '04542', '61636', '54402',
#        '08754', '77805', '62781', '49685', '92357', '21285', '03756', '09180',
#        '29220', '77555', '06030', '85228', '47547', '05302', '28286', '35249',
#        '53547'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi         city   full_zip state country  \
# five_dig_zip
# 66160         1043305592  KANSAS CITY  661600000    KS      US
# 66160         1326157579  KANSAS CITY  661600001    KS      US
# 66160         1649205758  KANSAS CITY  661600001    KS      US
# 66160         1730270653  KANSAS CITY  661600001    KS      US
# 66160         1821217415  KANSAS CITY  661608500    KS      US
# ...                  ...          ...        ...   ...     ...
# 47547         1447341953       JASPER  475470769    IN      US
# 05302         1619018017  BRATTLEBORO  053020511    VT      US
# 28286         1457467516  WAYNESVILLE  282860000    NC      US
# 35249         1528226479   BIRMINGHAM  352491900    AL      US
# 53547         1518053552   JANESVILLE  535470351    WI      US
#
#                                 provider_type total_beneficiaries  \
# five_dig_zip
# 66160                              Psychiatry                 200
# 66160                              Psychiatry                 269
# 66160                              Psychiatry                 232
# 66160                              Psychiatry                 200
# 66160                              Psychiatry                 339
# ...                                       ...                 ...
# 47547         Licensed Clinical Social Worker                  77
# 05302         Licensed Clinical Social Worker                  15
# 28286         Licensed Clinical Social Worker                  11
# 35249                              Psychiatry                  92
# 53547                              Psychiatry                  63
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 66160                       24259.26                  54       34.0
# 66160                       20618.87                  56       43.0
# 66160                       19307.70                  57       44.0
# 66160                       13375.27                  54       29.0
# 66160                       32833.39                  56       62.0
# ...                              ...                 ...        ...
# 47547                       11464.96                  50        0.0
# 05302                        8855.83                  75        0.0
# 28286                        2301.12                  57        0.0
# 35249                        4468.40                  47       54.0
# 53547                        8963.86                  77        0.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 66160                     1.6524
# 66160                     2.3350
# 66160                     1.9529
# 66160                     1.6729
# 66160                     2.1212
# ...                          ...
# 47547                     0.9578
# 05302                     0.7822
# 28286                     0.6267
# 35249                     0.9872
# 53547                     1.7165
#
# [175 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 4030
# 4030

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# different_house_year_ago_same_city                            float64
# some_college_and_associates_degree                            float64
# graduate_professional_degree                                  float64
# not_us_citizen_pop                                            float64
# high_school_including_ged                                     float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# bachelors_degree_2                                            float64
# different_house_year_ago_different_city                       float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# median_rent                                                   float64
# percent_income_spent_on_rent                                  float64
# median_year_structure_built                                   float64
# median_income                                                 float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_drove_alone                                           int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           3830
# different_house_year_ago_same_city                                      3981
# some_college_and_associates_degree                                      3981
# graduate_professional_degree                                            3981
# not_us_citizen_pop                                                      3981
# high_school_including_ged                                               3981
# population_1_year_and_over                                              3981
# less_than_high_school_graduate                                          3981
# bachelors_degree_2                                                      3981
# different_house_year_ago_different_city                                 3981
# owner_occupied_housing_units_lower_value_quartile                       3984
# owner_occupied_housing_units_upper_value_quartile                       3984
# owner_occupied_housing_units_median_value                               3984
# renter_occupied_housing_units_paying_cash_median_gross_rent             3995
# median_rent                                                             3995
# percent_income_spent_on_rent                                            3997
# median_year_structure_built                                             4001
# median_income                                                           4001
# gini_index                                                              4001
# income_per_capita                                                       4019
# median_age                                                              4021
# commuters_by_carpool                                                    4030
# commuters_by_subway_or_elevated                                         4030
# commuters_drove_alone                                                   4030
# employed_finance_insurance_real_estate                                  4030
# employed_arts_entertainment_recreation_accommodation_food               4030
# employed_construction                                                   4030
# employed_education_health_social                                        4030
# commuters_by_car_truck_van                                              4030
# employed_information                                                    4030
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         3765
# different_house_year_ago_same_city                                    2361
# some_college_and_associates_degree                                    3319
# graduate_professional_degree                                          2793
# not_us_citizen_pop                                                    2469
# high_school_including_ged                                             3254
# population_1_year_and_over                                            3828
# less_than_high_school_graduate                                        2745
# bachelors_degree_2                                                    3129
# different_house_year_ago_different_city                               2842
# owner_occupied_housing_units_lower_value_quartile                     2353
# owner_occupied_housing_units_upper_value_quartile                     2738
# owner_occupied_housing_units_median_value                             2586
# renter_occupied_housing_units_paying_cash_median_gross_rent           1179
# median_rent                                                           1234
# percent_income_spent_on_rent                                           300
# median_year_structure_built                                             67
# median_income                                                         3893
# gini_index                                                            1797
# income_per_capita                                                     3814
# median_age                                                             383
# commuters_by_carpool                                                  2066
# commuters_by_subway_or_elevated                                        576
# commuters_drove_alone                                                 3592
# employed_finance_insurance_real_estate                                1875
# employed_arts_entertainment_recreation_accommodation_food             2122
# employed_construction                                                 1595
# employed_education_health_social                                      2965
# commuters_by_car_truck_van                                            3682
# employed_information                                                   901
#
#                                                              null values
# aggregate_travel_time_to_work                                        200
# different_house_year_ago_same_city                                    49
# some_college_and_associates_degree                                    49
# graduate_professional_degree                                          49
# not_us_citizen_pop                                                    49
# high_school_including_ged                                             49
# population_1_year_and_over                                            49
# less_than_high_school_graduate                                        49
# bachelors_degree_2                                                    49
# different_house_year_ago_different_city                               49
# owner_occupied_housing_units_lower_value_quartile                     46
# owner_occupied_housing_units_upper_value_quartile                     46
# owner_occupied_housing_units_median_value                             46
# renter_occupied_housing_units_paying_cash_median_gross_rent           35
# median_rent                                                           35
# percent_income_spent_on_rent                                          33
# median_year_structure_built                                           29
# median_income                                                         29
# gini_index                                                            29
# income_per_capita                                                     11
# median_age                                                             9
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# commuters_drove_alone                                                  0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls. This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (35, 35)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 3995 3995
# 2632 3995
# 2375 3995

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(5)
# Out:
#                                         data type  non-null values  \
# high_school_including_ged                 float64             3948
# less_than_high_school_graduate            float64             3948
# different_house_year_ago_same_city        float64             3948
# different_house_year_ago_different_city   float64             3948
# not_us_citizen_pop                        float64             3948
#
#                                          unique values  null values
# high_school_including_ged                         3240           47
# less_than_high_school_graduate                    2737           47
# different_house_year_ago_same_city                2360           47
# different_house_year_ago_different_city           2831           47
# not_us_citizen_pop                                2468           47

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (47, 47)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#        data type  non-null values  unique values  null values
# geo_id    object             3948           3948            0

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((8893, 12), (5450, 14), (3731, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    3948
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [481]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'num_race_unknown',
#        'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../data/processed/2012black_medicare_census')

#saving all races medicare df merged
disorders_merged.to_csv('../data/processed/2012black_medicare_with_disorders_census')

#saving black_medicare with disorder values merged
all_merged.to_csv('../data/processed/2012all_races_medicare_census')
