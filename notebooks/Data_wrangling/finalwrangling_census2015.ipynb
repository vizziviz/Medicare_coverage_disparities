# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/processed/final2015MEDICARE.csv", index_col=0)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1013166 entries, 0 to 1013165
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   npi                                  1013166 non-null  int64
#  1   entity_code                          1013166 non-null  object
#  2   full_zip                             1013166 non-null  int64
#  3   state                                1013166 non-null  object
#  4   country                              1013166 non-null  object
#  5   provider_type                        1013166 non-null  object
#  6   medicare_participation_indicator     1013166 non-null  object
#  7   number_of_hcpcs                      1013166 non-null  int64
#  8   number_of_services                   1013166 non-null  float64
#  9   total_beneficiaries                  1013166 non-null  int64
#  10  total_submitted_charges              1013166 non-null  float64
#  11  total_allowed_payment                1013166 non-null  float64
#  12  total_medicare_payment               1013166 non-null  float64
#  13  total_medicare_standardized_payment  1013166 non-null  float64
#  14  avg_beneficiary_age                  1013166 non-null  int64
#  15  avg_hcc_risk_score                   1013166 non-null  float64
#  16  services_per_capita                  1013166 non-null  float64
#  17  allowed_payment_per_capita           1013166 non-null  float64
#  18  medicare_payment_per_capita          1013166 non-null  float64
#  19  submitted_charges_per_capita         1013166 non-null  float64
#  20  region                               1013166 non-null  object
#  21  subregion                            1013166 non-null  object
# dtypes: float64(10), int64(5), object(7)
# memory usage: 177.8+ MB

# %%
med.full_zip = med.full_zip.apply(lambda x: str(x).zfill(5))
med.npi = med.npi.astype('str')

# %%
med.head()
# Out:
#           npi entity_code full_zip state country  \
# 0  1831435403           I    60188    IL      US
# 1  1831389816           I    60455    IL      US
# 2  1831455021           I    60050    IL      US
# 3  1831528231           I    60090    IL      US
# 4  1306967724           I    60131    IL      US
#
#                                  provider_type  \
# 0                           Nurse Practitioner
# 1                          Preventive Medicine
# 2                            Internal Medicine
# 3  Registered Dietician/Nutrition Professional
# 4                              Family Practice
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               12               106.0
# 1                                Y               16                26.0
# 2                                Y               28               143.0
# 3                                Y                2                66.0
# 4                                Y               16                36.0
#
#    total_beneficiaries  ...  total_medicare_payment  \
# 0                   35  ...                 2591.93
# 1                   11  ...                 1238.91
# 2                   42  ...                 6545.88
# 3                   12  ...                 1808.41
# 4                   14  ...                 1892.43
#
#    total_medicare_standardized_payment  avg_beneficiary_age  \
# 0                              2956.15                   72
# 1                              1184.70                   66
# 2                              6823.45                   68
# 3                               959.51                   72
# 4                              1817.65                   62
#
#    avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 0              0.8336                 3.03                      103.14
# 1              1.0083                 2.36                      189.88
# 2              0.9886                 3.40                      202.01
# 3              2.0698                 5.50                      153.78
# 4              1.3466                 2.57                      197.89
#
#    medicare_payment_per_capita  submitted_charges_per_capita   region  \
# 0                        74.06                        120.88  Midwest
# 1                       112.63                        373.91  Midwest
# 2                       155.85                        240.83  Midwest
# 3                       150.70                        174.17  Midwest
# 4                       135.17                        343.14  Midwest
#
#             subregion
# 0  East North Central
# 1  East North Central
# 2  East North Central
# 3  East North Central
# 4  East North Central
#
# [5 rows x 22 columns]

# %% [markdown]
# Checkpoint 1

# %%
checkpoint1 = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
census = pd.read_csv('../../data/raw/2015acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   98304                   222                112
# 1   22714                    74                304
# 2   69128                    24                 74
# 3   97908                    13                 16
# 4   37228                   503                132
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1974.0                        18
# 1                       1978.0                         6
# 2                       1955.0                         0
# 3                       1939.0                         9
# 4                       2002.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                     0                      0                      0
# 1                     0                      0                      0
# 2                     0                      0                      0
# 3                     4                      0                      2
# 4                   265                     27                     98
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  commute_60_more_mins  \
# 0                      0                      0  ...                    90
# 1                      0                      0  ...                    86
# 2                      3                      0  ...                     2
# 3                      0                      0  ...                     3
# 4                     57                     33  ...                     0
#
#    commute_less_10_mins  commuters_16_over  hispanic_any_race  \
# 0                    42                347                  0
# 1                    77                562                 29
# 2                     9                 91                 12
# 3                     4                 19                  0
# 4                    71                381                  9
#
#    pop_5_years_over  speak_only_english_at_home  speak_spanish_at_home  \
# 0               636                         611                      0
# 1              1058                        1046                     12
# 2               183                         177                      6
# 3                50                          48                      0
# 4              1160                        1090                     26
#
#    speak_spanish_at_home_low_english   do_date  geoid
# 0                                  0  20112015    NaN
# 1                                  0  20112015    NaN
# 2                                  1  20112015    NaN
# 3                                  0  20112015    NaN
# 4                                  0  20112015    NaN
#
# [5 rows x 247 columns]

# %% [markdown]
# checkpoint2

# %%
checkpoint2 = census.copy()

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# geoid                                                         float64
# aggregate_travel_time_to_work                                 float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# bachelors_degree_2                                            float64
# different_house_year_ago_different_city                       float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# some_college_and_associates_degree                            float64
# less_than_high_school_graduate                                float64
# not_us_citizen_pop                                            float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# children_in_single_female_hh                                    int64
# commuters_by_bus                                                int64
# commuters_by_car_truck_van                                      int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_drove_alone                                           int64
# female_75_to_79                                                 int64
# female_80_to_84                                                 int64
#
#                                                              non-null values  \
# geoid                                                                      0
# aggregate_travel_time_to_work                                          20376
# median_rent                                                            27240
# renter_occupied_housing_units_paying_cash_median_gross_rent            27431
# percent_income_spent_on_rent                                           27822
# owner_occupied_housing_units_lower_value_quartile                      30241
# owner_occupied_housing_units_upper_value_quartile                      30764
# owner_occupied_housing_units_median_value                              30793
# median_income                                                          31067
# median_year_structure_built                                            32230
# gini_index                                                             32277
# income_per_capita                                                      32542
# median_age                                                             32615
# bachelors_degree_2                                                     32989
# different_house_year_ago_different_city                                32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# some_college_and_associates_degree                                     32989
# less_than_high_school_graduate                                         32989
# not_us_citizen_pop                                                     32989
# high_school_including_ged                                              32989
# graduate_professional_degree                                           32989
# children_in_single_female_hh                                           33120
# commuters_by_bus                                                       33120
# commuters_by_car_truck_van                                             33120
# commuters_by_carpool                                                   33120
# commuters_by_subway_or_elevated                                        33120
# commuters_drove_alone                                                  33120
# female_75_to_79                                                        33120
# female_80_to_84                                                        33120
#
#                                                              unique values  \
# geoid                                                                    0
# aggregate_travel_time_to_work                                        17111
# median_rent                                                           1867
# renter_occupied_housing_units_paying_cash_median_gross_rent           1905
# percent_income_spent_on_rent                                           397
# owner_occupied_housing_units_lower_value_quartile                     4136
# owner_occupied_housing_units_upper_value_quartile                     6151
# owner_occupied_housing_units_median_value                             5119
# median_income                                                        19382
# median_year_structure_built                                             73
# gini_index                                                            4125
# income_per_capita                                                    20437
# median_age                                                             654
# bachelors_degree_2                                                    5961
# different_house_year_ago_different_city                               4848
# different_house_year_ago_same_city                                    3617
# population_1_year_and_over                                           15307
# some_college_and_associates_degree                                    7568
# less_than_high_school_graduate                                        4588
# not_us_citizen_pop                                                    4190
# high_school_including_ged                                             7200
# graduate_professional_degree                                          4479
# children_in_single_female_hh                                          3886
# commuters_by_bus                                                      1658
# commuters_by_car_truck_van                                           10645
# commuters_by_carpool                                                  2871
# commuters_by_subway_or_elevated                                        897
# commuters_drove_alone                                                10103
# female_75_to_79                                                       1077
# female_80_to_84                                                        941
#
#                                                              null values
# geoid                                                              33120
# aggregate_travel_time_to_work                                      12744
# median_rent                                                         5880
# renter_occupied_housing_units_paying_cash_median_gross_rent         5689
# percent_income_spent_on_rent                                        5298
# owner_occupied_housing_units_lower_value_quartile                   2879
# owner_occupied_housing_units_upper_value_quartile                   2356
# owner_occupied_housing_units_median_value                           2327
# median_income                                                       2053
# median_year_structure_built                                          890
# gini_index                                                           843
# income_per_capita                                                    578
# median_age                                                           505
# bachelors_degree_2                                                   131
# different_house_year_ago_different_city                              131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# some_college_and_associates_degree                                   131
# less_than_high_school_graduate                                       131
# not_us_citizen_pop                                                   131
# high_school_including_ged                                            131
# graduate_professional_degree                                         131
# children_in_single_female_hh                                           0
# commuters_by_bus                                                       0
# commuters_by_car_truck_van                                             0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# commuters_drove_alone                                                  0
# female_75_to_79                                                        0
# female_80_to_84                                                        0

# %% [markdown]
# This column shouldn't be here. There's a geo_id column with all the zips.

# %%
census.geoid
# Out:
# 4       NaN
# 7       NaN
# 10      NaN
# 11      NaN
# 17      NaN
#          ..
# 33114   NaN
# 33115   NaN
# 33117   NaN
# 33118   NaN
# 33119   NaN
# Name: geoid, Length: 19409, dtype: float64

# %%
census.drop(columns = ['geoid'], inplace =True)

# %% [markdown]
# Looking to see if any Medicare zip codes are missing from Census DF

# %%
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))

# %%
med[med.full_zip.isin(census.geo_id)].shape, med[~med.full_zip.isin(census.geo_id)].shape
# Out:
# ((984399, 22), (0, 22))

# %%
pd.options.display.max_rows = 120
med[
    ~med.full_zip.isin(census.geo_id)].head()
# Out:
# Empty DataFrame
# Columns: [npi, entity_code, full_zip, state, country, provider_type, medicare_participation_indicator, number_of_hcpcs, number_of_services, total_beneficiaries, total_submitted_charges, total_allowed_payment, total_medicare_payment, total_medicare_standardized_payment, avg_beneficiary_age, avg_hcc_risk_score, services_per_capita, allowed_payment_per_capita, medicare_payment_per_capita, submitted_charges_per_capita, region, subregion]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### Many are PO Boxes. Some are hospitals with their own zip codes. I want to drop these rows from Med, looking at how much of my data this will remove:

# %%
print(' Total providers in Med df:',med.shape[0],
     '\n Total beneficiaries in Med df:', med.total_beneficiaries.sum(),
     '\n Total providers whose zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].shape[0],
     '\n Total beneficiaries in Med in zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum(),
     '\n Percent providers with missing zips of all providers:',
                          round(med[~med.full_zip.isin(census.geo_id)].shape[0] \
                          / med.shape[0] * 100, 2),  '%',
     '\n Percent beneficiaries in missing zips of all beneficiaries:',
                          round(med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum() \
                          / med.total_beneficiaries.sum() * 100,2),  '%')
# Out:
#  Total providers in Med df: 984399
#  Total beneficiaries in Med df: 360839496
#  Total providers whose zips not in Census: 0
#  Total beneficiaries in Med in zips not in Census: 0
#  Percent providers with missing zips of all providers: 0.0 %
#  Percent beneficiaries in missing zips of all beneficiaries: 0.0 %

# %%
idx = med[~med['full_zip'].isin(census.geo_id)].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Dropping Rows from Census that don't appear in Medicare DF

# %%
print(census.shape)
idx = census[~census.geo_id.isin(med.full_zip)].index
census.drop(index = idx, inplace = True)
print(census.shape)
# Out:
# (19409, 246)
# (19409, 246)

# %%
med.full_zip.nunique()
# Out:
# 19409

# %% [markdown]
# Examining Nulls

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# different_house_year_ago_same_city                            float64
# bachelors_degree_2                                            float64
# different_house_year_ago_different_city                       float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# high_school_including_ged                                     float64
# not_us_citizen_pop                                            float64
# some_college_and_associates_degree                            float64
# graduate_professional_degree                                  float64
# armed_forces                                                    int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_drove_alone                                           int64
# amerindian_including_hispanic                                   int64
# black_including_hispanic                                        int64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# white_including_hispanic                                        int64
# female_85_and_over                                              int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          16400
# median_rent                                                            18701
# renter_occupied_housing_units_paying_cash_median_gross_rent            18730
# percent_income_spent_on_rent                                           18815
# owner_occupied_housing_units_lower_value_quartile                      18886
# owner_occupied_housing_units_median_value                              18968
# owner_occupied_housing_units_upper_value_quartile                      18979
# median_income                                                          19077
# median_year_structure_built                                            19166
# gini_index                                                             19185
# income_per_capita                                                      19333
# median_age                                                             19344
# different_house_year_ago_same_city                                     19406
# bachelors_degree_2                                                     19406
# different_house_year_ago_different_city                                19406
# population_1_year_and_over                                             19406
# less_than_high_school_graduate                                         19406
# high_school_including_ged                                              19406
# not_us_citizen_pop                                                     19406
# some_college_and_associates_degree                                     19406
# graduate_professional_degree                                           19406
# armed_forces                                                           19409
# commuters_by_carpool                                                   19409
# commuters_by_subway_or_elevated                                        19409
# commuters_drove_alone                                                  19409
# amerindian_including_hispanic                                          19409
# black_including_hispanic                                               19409
# employed_agriculture_forestry_fishing_hunting_mining                   19409
# white_including_hispanic                                               19409
# female_85_and_over                                                     19409
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        14783
# median_rent                                                           1796
# renter_occupied_housing_units_paying_cash_median_gross_rent           1812
# percent_income_spent_on_rent                                           388
# owner_occupied_housing_units_lower_value_quartile                     3906
# owner_occupied_housing_units_median_value                             4738
# owner_occupied_housing_units_upper_value_quartile                     5558
# median_income                                                        15423
# median_year_structure_built                                             71
# gini_index                                                            2834
# income_per_capita                                                    14494
# median_age                                                             518
# different_house_year_ago_same_city                                    3615
# bachelors_degree_2                                                    5959
# different_house_year_ago_different_city                               4842
# population_1_year_and_over                                           14321
# less_than_high_school_graduate                                        4578
# high_school_including_ged                                             7185
# not_us_citizen_pop                                                    4181
# some_college_and_associates_degree                                    7545
# graduate_professional_degree                                          4478
# armed_forces                                                           722
# commuters_by_carpool                                                  2865
# commuters_by_subway_or_elevated                                        895
# commuters_drove_alone                                                 9986
# amerindian_including_hispanic                                         1124
# black_including_hispanic                                              5313
# employed_agriculture_forestry_fishing_hunting_mining                  1008
# white_including_hispanic                                             13317
# female_85_and_over                                                    1105
#
#                                                              null values
# aggregate_travel_time_to_work                                       3009
# median_rent                                                          708
# renter_occupied_housing_units_paying_cash_median_gross_rent          679
# percent_income_spent_on_rent                                         594
# owner_occupied_housing_units_lower_value_quartile                    523
# owner_occupied_housing_units_median_value                            441
# owner_occupied_housing_units_upper_value_quartile                    430
# median_income                                                        332
# median_year_structure_built                                          243
# gini_index                                                           224
# income_per_capita                                                     76
# median_age                                                            65
# different_house_year_ago_same_city                                     3
# bachelors_degree_2                                                     3
# different_house_year_ago_different_city                                3
# population_1_year_and_over                                             3
# less_than_high_school_graduate                                         3
# high_school_including_ged                                              3
# not_us_citizen_pop                                                     3
# some_college_and_associates_degree                                     3
# graduate_professional_degree                                           3
# armed_forces                                                           0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# commuters_drove_alone                                                  0
# amerindian_including_hispanic                                          0
# black_including_hispanic                                               0
# employed_agriculture_forestry_fishing_hunting_mining                   0
# white_including_hispanic                                               0
# female_85_and_over                                                     0

# %%
census.columns
# Out:
# Index(['geo_id', 'nonfamily_households', 'family_households',
#        'median_year_structure_built', 'rent_burden_not_computed',
#        'rent_over_50_percent', 'rent_40_to_50_percent',
#        'rent_35_to_40_percent', 'rent_30_to_35_percent',
#        'rent_25_to_30_percent',
#        ...
#        'commute_35_44_mins', 'commute_60_more_mins', 'commute_less_10_mins',
#        'commuters_16_over', 'hispanic_any_race', 'pop_5_years_over',
#        'speak_only_english_at_home', 'speak_spanish_at_home',
#        'speak_spanish_at_home_low_english', 'do_date'],
#       dtype='object', length=246)

# %% [markdown]
# Some of these columns are irrelevant or are redundant.

# %%
#there are other cols that speak to Commute to work
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# median_rent                                                 float64
# percent_income_spent_on_rent                                float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# graduate_professional_degree                                float64
# high_school_including_ged                                   float64
# population_1_year_and_over                                  float64
# not_us_citizen_pop                                          float64
# bachelors_degree_2                                          float64
# some_college_and_associates_degree                          float64
# less_than_high_school_graduate                              float64
# different_house_year_ago_same_city                          float64
# different_house_year_ago_different_city                     float64
# children_in_single_female_hh                                  int64
# geo_id                                                       object
# bachelors_degree_or_higher_25_64                              int64
# white_male_55_64                                              int64
# white_male_45_54                                              int64
# children                                                      int64
# commuters_by_bus                                              int64
# commuters_drove_alone                                         int64
# commuters_by_carpool                                          int64
# commuters_by_subway_or_elevated                               int64
# employed_agriculture_forestry_fishing_hunting_mining          int64
# employed_arts_entertainment_recreation_accommodation_food     int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
#
#                                                            non-null values  \
# median_rent                                                          18701
# percent_income_spent_on_rent                                         18815
# median_income                                                        19077
# gini_index                                                           19185
# income_per_capita                                                    19333
# median_age                                                           19344
# graduate_professional_degree                                         19406
# high_school_including_ged                                            19406
# population_1_year_and_over                                           19406
# not_us_citizen_pop                                                   19406
# bachelors_degree_2                                                   19406
# some_college_and_associates_degree                                   19406
# less_than_high_school_graduate                                       19406
# different_house_year_ago_same_city                                   19406
# different_house_year_ago_different_city                              19406
# children_in_single_female_hh                                         19409
# geo_id                                                               19409
# bachelors_degree_or_higher_25_64                                     19409
# white_male_55_64                                                     19409
# white_male_45_54                                                     19409
# children                                                             19409
# commuters_by_bus                                                     19409
# commuters_drove_alone                                                19409
# commuters_by_carpool                                                 19409
# commuters_by_subway_or_elevated                                      19409
# employed_agriculture_forestry_fishing_hunting_mining                 19409
# employed_arts_entertainment_recreation_accommodation_food            19409
# employed_construction                                                19409
# employed_education_health_social                                     19409
# employed_finance_insurance_real_estate                               19409
#
#                                                            unique values  \
# median_rent                                                         1796
# percent_income_spent_on_rent                                         388
# median_income                                                      15423
# gini_index                                                          2834
# income_per_capita                                                  14494
# median_age                                                           518
# graduate_professional_degree                                        4478
# high_school_including_ged                                           7185
# population_1_year_and_over                                         14321
# not_us_citizen_pop                                                  4181
# bachelors_degree_2                                                  5959
# some_college_and_associates_degree                                  7545
# less_than_high_school_graduate                                      4578
# different_house_year_ago_same_city                                  3615
# different_house_year_ago_different_city                             4842
# children_in_single_female_hh                                        3838
# geo_id                                                             19409
# bachelors_degree_or_higher_25_64                                    6911
# white_male_55_64                                                    2587
# white_male_45_54                                                    2753
# children                                                            8189
# commuters_by_bus                                                    1656
# commuters_drove_alone                                               9986
# commuters_by_carpool                                                2865
# commuters_by_subway_or_elevated                                      895
# employed_agriculture_forestry_fishing_hunting_mining                1008
# employed_arts_entertainment_recreation_accommodation_food           3041
# employed_construction                                               2088
# employed_education_health_social                                    5272
# employed_finance_insurance_real_estate                              2395
#
#                                                            null values
# median_rent                                                        708
# percent_income_spent_on_rent                                       594
# median_income                                                      332
# gini_index                                                         224
# income_per_capita                                                   76
# median_age                                                          65
# graduate_professional_degree                                         3
# high_school_including_ged                                            3
# population_1_year_and_over                                           3
# not_us_citizen_pop                                                   3
# bachelors_degree_2                                                   3
# some_college_and_associates_degree                                   3
# less_than_high_school_graduate                                       3
# different_house_year_ago_same_city                                   3
# different_house_year_ago_different_city                              3
# children_in_single_female_hh                                         0
# geo_id                                                               0
# bachelors_degree_or_higher_25_64                                     0
# white_male_55_64                                                     0
# white_male_45_54                                                     0
# children                                                             0
# commuters_by_bus                                                     0
# commuters_drove_alone                                                0
# commuters_by_carpool                                                 0
# commuters_by_subway_or_elevated                                      0
# employed_agriculture_forestry_fishing_hunting_mining                 0
# employed_arts_entertainment_recreation_accommodation_food            0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0

# %%
# Let's look at rows in Medicare with zips that have nulls in Census.graduate_professional_degree
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
med[med.full_zip.isin(null_zips)]
# Out:
#                npi entity_code full_zip state country          provider_type  \
# 32364   1750491288           I    00617    IL      US               Podiatry
# 618724  1477551984           I    00960    OR      US  Obstetrics/Gynecology
# 684358  1205990884           I    00683    RI      US         Anesthesiology
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 32364                                 Y               39              1712.0
# 618724                                Y                5                33.0
# 684358                                Y               41               239.0
#
#         total_beneficiaries  ...  total_medicare_payment  \
# 32364                   887  ...                90877.94
# 618724                   18  ...                 1941.30
# 684358                  197  ...                70558.26
#
#         total_medicare_standardized_payment  avg_beneficiary_age  \
# 32364                              85903.74                   73
# 618724                              3781.86                   68
# 684358                             78809.03                   71
#
#         avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 32364               1.9325                 1.93                      137.35
# 618724              1.5393                 1.83                      151.15
# 684358              2.9318                 1.21                      459.67
#
#         medicare_payment_per_capita  submitted_charges_per_capita     region  \
# 32364                        102.46                        222.82    Midwest
# 618724                       107.85                        159.72       West
# 684358                       358.16                        459.81  Northeast
#
#                  subregion
# 32364   East North Central
# 618724             Pacific
# 684358         New England
#
# [3 rows x 22 columns]

# %%
# The second row has a typo in Full_zip, should be 60617
med.loc[
    med[med.npi == '1750491288'].index, 'full_zip'] = '60617'

#Droppping other two rows from DF
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
idx = med[med.full_zip.isin(null_zips)].index
med.drop(index = idx, inplace=True)

# %%
#Dropping these zips from Census 
census = census[census.graduate_professional_degree.notnull()]

# %% [markdown]
# ##### REEXAMINING CENSUS NULLS

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# median_rent                                                 float64
# percent_income_spent_on_rent                                float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# employed_retail_trade                                         int64
# white_male_45_54                                              int64
# employed_wholesale_trade                                      int64
# white_male_55_64                                              int64
# bachelors_degree_2                                          float64
# bachelors_degree_or_higher_25_64                              int64
# children                                                      int64
# children_in_single_female_hh                                  int64
# commuters_by_bus                                              int64
# commuters_by_car_truck_van                                    int64
# commuters_by_carpool                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# employed_transportation_warehousing_utilities                 int64
# different_house_year_ago_same_city                          float64
# employed_agriculture_forestry_fishing_hunting_mining          int64
# employed_arts_entertainment_recreation_accommodation_food     int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# employed_information                                          int64
# employed_manufacturing                                        int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
#
#                                                            non-null values  \
# median_rent                                                          18699
# percent_income_spent_on_rent                                         18813
# median_income                                                        19075
# gini_index                                                           19183
# income_per_capita                                                    19330
# median_age                                                           19341
# employed_retail_trade                                                19406
# white_male_45_54                                                     19406
# employed_wholesale_trade                                             19406
# white_male_55_64                                                     19406
# bachelors_degree_2                                                   19406
# bachelors_degree_or_higher_25_64                                     19406
# children                                                             19406
# children_in_single_female_hh                                         19406
# commuters_by_bus                                                     19406
# commuters_by_car_truck_van                                           19406
# commuters_by_carpool                                                 19406
# commuters_by_subway_or_elevated                                      19406
# commuters_drove_alone                                                19406
# employed_transportation_warehousing_utilities                        19406
# different_house_year_ago_same_city                                   19406
# employed_agriculture_forestry_fishing_hunting_mining                 19406
# employed_arts_entertainment_recreation_accommodation_food            19406
# employed_construction                                                19406
# employed_education_health_social                                     19406
# employed_finance_insurance_real_estate                               19406
# employed_information                                                 19406
# employed_manufacturing                                               19406
# employed_other_services_not_public_admin                             19406
# employed_public_administration                                       19406
#
#                                                            unique values  \
# median_rent                                                         1796
# percent_income_spent_on_rent                                         388
# median_income                                                      15421
# gini_index                                                          2833
# income_per_capita                                                  14492
# median_age                                                           518
# employed_retail_trade                                               3289
# white_male_45_54                                                    2753
# employed_wholesale_trade                                            1190
# white_male_55_64                                                    2587
# bachelors_degree_2                                                  5959
# bachelors_degree_or_higher_25_64                                    6910
# children                                                            8188
# children_in_single_female_hh                                        3838
# commuters_by_bus                                                    1656
# commuters_by_car_truck_van                                         10479
# commuters_by_carpool                                                2865
# commuters_by_subway_or_elevated                                      895
# commuters_drove_alone                                               9985
# employed_transportation_warehousing_utilities                       1847
# different_house_year_ago_same_city                                  3615
# employed_agriculture_forestry_fishing_hunting_mining                1008
# employed_arts_entertainment_recreation_accommodation_food           3041
# employed_construction                                               2088
# employed_education_health_social                                    5272
# employed_finance_insurance_real_estate                              2395
# employed_information                                                1109
# employed_manufacturing                                              3059
# employed_other_services_not_public_admin                            1765
# employed_public_administration                                      1853
#
#                                                            null values
# median_rent                                                        707
# percent_income_spent_on_rent                                       593
# median_income                                                      331
# gini_index                                                         223
# income_per_capita                                                   76
# median_age                                                          65
# employed_retail_trade                                                0
# white_male_45_54                                                     0
# employed_wholesale_trade                                             0
# white_male_55_64                                                     0
# bachelors_degree_2                                                   0
# bachelors_degree_or_higher_25_64                                     0
# children                                                             0
# children_in_single_female_hh                                         0
# commuters_by_bus                                                     0
# commuters_by_car_truck_van                                           0
# commuters_by_carpool                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# employed_transportation_warehousing_utilities                        0
# different_house_year_ago_same_city                                   0
# employed_agriculture_forestry_fishing_hunting_mining                 0
# employed_arts_entertainment_recreation_accommodation_food            0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# employed_information                                                 0
# employed_manufacturing                                               0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0

# %% [markdown]
# The remaining columns with nulls are important, but I know that other columns in the DF, have some information related to rent, income, and age.

# %%
census.columns[census.columns.str.contains('_rent$|^rent_|_rent_', regex=True)]
# Out:
# Index(['rent_burden_not_computed', 'rent_over_50_percent',
#        'rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'rent_under_10_percent',
#        'vacant_housing_units_for_rent', 'median_rent',
#        'percent_income_spent_on_rent'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('income')]
# Out:
# Index(['median_income', 'income_per_capita', 'percent_income_spent_on_rent',
#        'income_less_10000', 'income_10000_14999', 'income_15000_19999',
#        'income_20000_24999', 'income_25000_29999', 'income_30000_34999',
#        'income_35000_39999', 'income_40000_44999', 'income_45000_49999',
#        'income_50000_59999', 'income_60000_74999', 'income_75000_99999',
#        'income_100000_124999', 'income_125000_149999', 'income_150000_199999',
#        'income_200000_or_more', 'households_retirement_income'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('(?=.*male)(?=.*_to_)', regex=True)]
# Out:
# Index(['male_5_to_9', 'male_10_to_14', 'male_15_to_17', 'male_18_to_19',
#        'male_22_to_24', 'male_25_to_29', 'male_30_to_34', 'male_35_to_39',
#        'male_40_to_44', 'male_45_to_49', 'male_50_to_54', 'male_55_to_59',
#        'male_65_to_66', 'male_67_to_69', 'male_70_to_74', 'male_75_to_79',
#        'male_80_to_84', 'female_5_to_9', 'female_10_to_14', 'female_15_to_17',
#        'female_18_to_19', 'female_22_to_24', 'female_25_to_29',
#        'female_30_to_34', 'female_35_to_39', 'female_40_to_44',
#        'female_45_to_49', 'female_50_to_54', 'female_55_to_59',
#        'female_60_to_61', 'female_62_to_64', 'female_65_to_66',
#        'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
#        'female_80_to_84', 'male_45_to_64'],
#       dtype='object')

# %%
info[info['null values']>0].index
# Out:
# Index(['median_age', 'median_income', 'income_per_capita', 'median_rent',
#        'percent_income_spent_on_rent', 'gini_index'],
#       dtype='object')

# %% [markdown]
# While these factors are probably very relevant to the number of providers in a zip code, the health risk score, and the use of different providers, it seems there are other features in Census DF that may also address income, rent, and age.

# %%
#dropping these cols with nulls
cols = info[info['null values']>0].index
census.drop(columns = cols, inplace=True)

# %% [markdown]
# # Checking Data Types

# %% [markdown]
# All columns in Census besides Geo_id should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
#   geo_id
# 4  37228

# %% [markdown]
# There's a column called do_date that includes the years used to make the estimate Census measures. I'm going to keep that last four digits which represent the year being estimated.

# %%
census.do_date = census.do_date.apply(lambda x: str(x)[-4:])
census.do_date = pd.to_datetime(census.do_date, format='%Y')
census.do_date
# Out:
# 4       2015-01-01
# 7       2015-01-01
# 10      2015-01-01
# 11      2015-01-01
# 17      2015-01-01
#            ...
# 33114   2015-01-01
# 33115   2015-01-01
# 33117   2015-01-01
# 33118   2015-01-01
# 33119   2015-01-01
# Name: do_date, Length: 19406, dtype: datetime64[ns]

# %%
census.isnull().sum().sort_values()
# Out:
# geo_id                              0
# white_male_45_54                    0
# white_male_55_64                    0
# bachelors_degree_2                  0
# bachelors_degree_or_higher_25_64    0
#                                    ..
# male_18_to_19                       0
# male_20                             0
# male_21                             0
# dwellings_20_to_49_units            0
# do_date                             0
# Length: 234, dtype: int64

# %%
med.to_csv('../../data/processed/final2015MEDICARE.csv')
census.to_csv('../../data/processed/final2015CENSUS.csv')
