# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2015.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1019442, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1831435403                                   GRUNWALDT
# 1                    1831374784                                     JOHNSON
# 2                    1831377340                                       WOLFF
# 3                    1831389816                                        ROSS
# 4                    1720466840                                      BETTIS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                  CHRISTINA                              A
# 1                       RYAN                              J
# 2                   PATRICIA                              A
# 3                    CYNTHIA                              A
# 4                    KRISTEN                              M
#
#   Credentials of the Provider Gender of the Provider  \
# 0                      FNP-BC                      F
# 1                        CRNA                      M
# 2                        D.C.                      F
# 3                        M.D.                      F
# 4                        CRNA                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                 540 N SCHMALE RD
# 1                           I                   5656 KELLEY ST
# 2                           I                  5332 46TH AVE S
# 3                           I                8755 S HARLEM AVE
# 4                           I                145 KIMEL PARK DR
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN         CAROL STREAM  ...
# 1                              NaN              HOUSTON  ...
# 2                              NaN          MINNEAPOLIS  ...
# 3                              NaN           BRIDGEVIEW  ...
# 4                        SUITE 120        WINSTON SALEM  ...
#
#   Percent (%) of Beneficiaries Identified With Depression   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Diabetes   \
# 0                                               34.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia   \
# 0                                               57.0
# 1                                               48.0
# 2                                                NaN
# 3                                                NaN
# 4                                               58.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension   \
# 0                                               57.0
# 1                                               75.0
# 2                                                NaN
# 3                                                NaN
# 4                                               75.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis   \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                0.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               58.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    Percent (%) of Beneficiaries Identified With Stroke   \
# 0                                                0.0
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                    0.8336
# 1                                    2.4573
# 2                                    1.3695
# 3                                    1.0083
# 4                                    1.7666
#
# [5 rows x 70 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount ',
#        'Total Drug Medicare Payment Amount ',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#        'Percent (%) of Beneficiaries Identified With Asthma ',
#        'Percent (%) of Beneficiaries Identified With Cancer ',
#        'Percent (%) of Beneficiaries Identified With Heart Failure ',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Diabetes ',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#        'Percent (%) of Beneficiaries Identified With Hypertension ',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Percent (%) of Beneficiaries Identified With Stroke ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                         data type  \
# National Provider Identifier                                                                int64
# Average Age of Beneficiaries                                                                int64
# Total Medicare Standardized Payment Amount                                                float64
# Total Medicare Payment Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Submitted Charge Amount                                                             float64
# Number of Medicare Beneficiaries                                                            int64
# Number of Services                                                                        float64
# Number of HCPCS                                                                             int64
# Medicare Participation Indicator                                                           object
# Provider Type of the Provider                                                              object
# Country Code of the Provider                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
# Zip Code of the Provider                                                                   object
# Entity Type of the Provider                                                                object
# State Code of the Provider                                                                 object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Last Name/Organization Name of the Provider                                                object
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Gender of the Provider                                                                     object
# First Name of the Provider                                                                 object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Credentials of the Provider                                                                object
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Medical Submitted Charge Amount                                                     float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Number of Male Beneficiaries                                                              float64
# Number of Female Beneficiaries                                                            float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Number of Beneficiaries Age 65 to 74                                                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Number of Beneficiaries Age 75 to 84                                                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Number of Beneficiaries Age Less 65                                                       float64
# Number of Non-Hispanic White Beneficiaries                                                float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Number of Beneficiaries Age Greater 84                                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Street Address 2 of the Provider                                                           object
# Number of Black or African American Beneficiaries                                         float64
# Number of American Indian/Alaska Native Beneficiaries                                     float64
# Number of Hispanic Beneficiaries                                                          float64
# Number of Asian Pacific Islander Beneficiaries                                            float64
# Number of Beneficiaries With Race Not Elsewhere Classified                                float64
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
#
#                                                                                          non-null values  \
# National Provider Identifier                                                                     1019442
# Average Age of Beneficiaries                                                                     1019442
# Total Medicare Standardized Payment Amount                                                       1019442
# Total Medicare Payment Amount                                                                    1019442
# Total Medicare Allowed Amount                                                                    1019442
# Total Submitted Charge Amount                                                                    1019442
# Number of Medicare Beneficiaries                                                                 1019442
# Number of Services                                                                               1019442
# Number of HCPCS                                                                                  1019442
# Medicare Participation Indicator                                                                 1019442
# Provider Type of the Provider                                                                    1019442
# Country Code of the Provider                                                                     1019442
# Average HCC Risk Score of Beneficiaries                                                          1019442
# Zip Code of the Provider                                                                         1019442
# Entity Type of the Provider                                                                      1019442
# State Code of the Provider                                                                       1019442
# Street Address 1 of the Provider                                                                 1019441
# City of the Provider                                                                             1019440
# Last Name/Organization Name of the Provider                                                      1019425
# Percent (%) of Beneficiaries Identified With Hypertension                                         964948
# Gender of the Provider                                                                            956859
# First Name of the Provider                                                                        956849
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       942442
# Credentials of the Provider                                                                       922096
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                916919
# Total Medical Medicare Standardized Payment Amount                                                914316
# Total Medical Medicare Payment Amount                                                             914316
# Total Medical Medicare Allowed Amount                                                             914316
# Number of Medicare Beneficiaries With Medical Services                                            914316
# Number of Medical Services                                                                        914316
# Number of HCPCS Associated With Medical Services                                                  914316
# Total Medical Submitted Charge Amount                                                             914316
# Total Drug Medicare Standardized Payment Amount                                                   914316
# Total Drug Medicare Payment Amount                                                                914316
# Total Drug Medicare Allowed Amount                                                                914316
# Total Drug Submitted Charge Amount                                                                914316
# Number of Medicare Beneficiaries With Drug Services                                               914316
# Number of Drug Services                                                                           914316
# Number of HCPCS Associated With Drug Services                                                     914316
# Number of Male Beneficiaries                                                                      909095
# Number of Female Beneficiaries                                                                    909095
# Percent (%) of Beneficiaries Identified With Diabetes                                             874902
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               866770
# Percent (%) of Beneficiaries Identified With Depression                                           858769
# Number of Beneficiaries Age 65 to 74                                                              857666
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               821336
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      767632
# Number of Beneficiaries With Medicare Only Entitlement                                            767632
# Percent (%) of Beneficiaries Identified With Heart Failure                                        761070
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                743596
# Number of Beneficiaries Age 75 to 84                                                              728493
# Percent (%) of Beneficiaries Identified With Asthma                                               724995
# Middle Initial of the Provider                                                                    704144
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  692263
# Percent (%) of Beneficiaries Identified With Cancer                                               682670
# Number of Beneficiaries Age Less 65                                                               679050
# Number of Non-Hispanic White Beneficiaries                                                        678814
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      670015
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         637273
# Number of Beneficiaries Age Greater 84                                                            612832
# Percent (%) of Beneficiaries Identified With Stroke                                               575734
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            524584
# Street Address 2 of the Provider                                                                  412877
# Number of Black or African American Beneficiaries                                                 346436
# Number of American Indian/Alaska Native Beneficiaries                                             296721
# Number of Hispanic Beneficiaries                                                                  269761
# Number of Asian Pacific Islander Beneficiaries                                                    178127
# Number of Beneficiaries With Race Not Elsewhere Classified                                        147902
# Medical Suppress Indicator                                                                        105126
# Drug Suppress Indicator                                                                           105126
#
#                                                                                          unique values  \
# National Provider Identifier                                                                   1019442
# Average Age of Beneficiaries                                                                        85
# Total Medicare Standardized Payment Amount                                                      968511
# Total Medicare Payment Amount                                                                   966868
# Total Medicare Allowed Amount                                                                   978464
# Total Submitted Charge Amount                                                                   698982
# Number of Medicare Beneficiaries                                                                  6913
# Number of Services                                                                               40236
# Number of HCPCS                                                                                    487
# Medicare Participation Indicator                                                                     2
# Provider Type of the Provider                                                                       91
# Country Code of the Provider                                                                        22
# Average HCC Risk Score of Beneficiaries                                                          44246
# Zip Code of the Provider                                                                        340869
# Entity Type of the Provider                                                                          2
# State Code of the Provider                                                                          61
# Street Address 1 of the Provider                                                                347613
# City of the Provider                                                                             12988
# Last Name/Organization Name of the Provider                                                     253015
# Percent (%) of Beneficiaries Identified With Hypertension                                           67
# Gender of the Provider                                                                               2
# First Name of the Provider                                                                       63723
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         71
# Credentials of the Provider                                                                      15681
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  72
# Total Medical Medicare Standardized Payment Amount                                              847569
# Total Medical Medicare Payment Amount                                                           868254
# Total Medical Medicare Allowed Amount                                                           878087
# Number of Medicare Beneficiaries With Medical Services                                            6824
# Number of Medical Services                                                                       25908
# Number of HCPCS Associated With Medical Services                                                   488
# Total Medical Submitted Charge Amount                                                           621791
# Total Drug Medicare Standardized Payment Amount                                                 229564
# Total Drug Medicare Payment Amount                                                              229564
# Total Drug Medicare Allowed Amount                                                              231841
# Total Drug Submitted Charge Amount                                                              155588
# Number of Medicare Beneficiaries With Drug Services                                               1182
# Number of Drug Services                                                                          23553
# Number of HCPCS Associated With Drug Services                                                      113
# Number of Male Beneficiaries                                                                      3634
# Number of Female Beneficiaries                                                                    4781
# Percent (%) of Beneficiaries Identified With Diabetes                                               73
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Depression                                             75
# Number of Beneficiaries Age 65 to 74                                                              3446
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 73
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      3038
# Number of Beneficiaries With Medicare Only Entitlement                                            5577
# Percent (%) of Beneficiaries Identified With Heart Failure                                          76
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  76
# Number of Beneficiaries Age 75 to 84                                                              2887
# Percent (%) of Beneficiaries Identified With Asthma                                                 75
# Middle Initial of the Provider                                                                      33
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    75
# Percent (%) of Beneficiaries Identified With Cancer                                                 76
# Number of Beneficiaries Age Less 65                                                               2097
# Number of Non-Hispanic White Beneficiaries                                                        6069
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        76
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           76
# Number of Beneficiaries Age Greater 84                                                            2155
# Percent (%) of Beneficiaries Identified With Stroke                                                 76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              76
# Street Address 2 of the Provider                                                                 72911
# Number of Black or African American Beneficiaries                                                 2069
# Number of American Indian/Alaska Native Beneficiaries                                              529
# Number of Hispanic Beneficiaries                                                                  1643
# Number of Asian Pacific Islander Beneficiaries                                                    1087
# Number of Beneficiaries With Race Not Elsewhere Classified                                         522
# Medical Suppress Indicator                                                                           2
# Drug Suppress Indicator                                                                              2
#
#                                                                                          null values
# National Provider Identifier                                                                       0
# Average Age of Beneficiaries                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Total Medicare Payment Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Submitted Charge Amount                                                                      0
# Number of Medicare Beneficiaries                                                                   0
# Number of Services                                                                                 0
# Number of HCPCS                                                                                    0
# Medicare Participation Indicator                                                                   0
# Provider Type of the Provider                                                                      0
# Country Code of the Provider                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0
# Zip Code of the Provider                                                                           0
# Entity Type of the Provider                                                                        0
# State Code of the Provider                                                                         0
# Street Address 1 of the Provider                                                                   1
# City of the Provider                                                                               2
# Last Name/Organization Name of the Provider                                                       17
# Percent (%) of Beneficiaries Identified With Hypertension                                      54494
# Gender of the Provider                                                                         62583
# First Name of the Provider                                                                     62593
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    77000
# Credentials of the Provider                                                                    97346
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            102523
# Total Medical Medicare Standardized Payment Amount                                            105126
# Total Medical Medicare Payment Amount                                                         105126
# Total Medical Medicare Allowed Amount                                                         105126
# Number of Medicare Beneficiaries With Medical Services                                        105126
# Number of Medical Services                                                                    105126
# Number of HCPCS Associated With Medical Services                                              105126
# Total Medical Submitted Charge Amount                                                         105126
# Total Drug Medicare Standardized Payment Amount                                               105126
# Total Drug Medicare Payment Amount                                                            105126
# Total Drug Medicare Allowed Amount                                                            105126
# Total Drug Submitted Charge Amount                                                            105126
# Number of Medicare Beneficiaries With Drug Services                                           105126
# Number of Drug Services                                                                       105126
# Number of HCPCS Associated With Drug Services                                                 105126
# Number of Male Beneficiaries                                                                  110347
# Number of Female Beneficiaries                                                                110347
# Percent (%) of Beneficiaries Identified With Diabetes                                         144540
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           152672
# Percent (%) of Beneficiaries Identified With Depression                                       160673
# Number of Beneficiaries Age 65 to 74                                                          161776
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           198106
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  251810
# Number of Beneficiaries With Medicare Only Entitlement                                        251810
# Percent (%) of Beneficiaries Identified With Heart Failure                                    258372
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            275846
# Number of Beneficiaries Age 75 to 84                                                          290949
# Percent (%) of Beneficiaries Identified With Asthma                                           294447
# Middle Initial of the Provider                                                                315298
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              327179
# Percent (%) of Beneficiaries Identified With Cancer                                           336772
# Number of Beneficiaries Age Less 65                                                           340392
# Number of Non-Hispanic White Beneficiaries                                                    340628
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  349427
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     382169
# Number of Beneficiaries Age Greater 84                                                        406610
# Percent (%) of Beneficiaries Identified With Stroke                                           443708
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        494858
# Street Address 2 of the Provider                                                              606565
# Number of Black or African American Beneficiaries                                             673006
# Number of American Indian/Alaska Native Beneficiaries                                         722721
# Number of Hispanic Beneficiaries                                                              749681
# Number of Asian Pacific Islander Beneficiaries                                                841315
# Number of Beneficiaries With Race Not Elsewhere Classified                                    871540
# Medical Suppress Indicator                                                                    914316
# Drug Suppress Indicator                                                                       914316

# %% [markdown]
# Dropping Most of the Columns, since only 15 have no null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (1019442, 70)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (1019442, 16)

# %%
med.columns
# Out:
# Index(['National Provider Identifier', 'Entity Type of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                 'Total Medicare Standardized Payment Amount':'total_medicare_standardized_payment',
                'Average HCC Risk Score of Beneficiaries ':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charge Amount':'total_submitted_charges',
                 'Entity Type of the Provider':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['IL', 'TX', 'MN', 'NC', 'CA', 'VT', 'NM', 'IA', 'VA', 'CO', 'NE',
#        'ND', 'AL', 'OH', 'NJ', 'PA', 'ME', 'FL', 'KY', 'AR', 'NY', 'OR',
#        'MA', 'AZ', 'RI', 'WI', 'CT', 'WV', 'AK', 'MO', 'PR', 'MI', 'GA',
#        'WA', 'MD', 'OK', 'UT', 'HI', 'MT', 'DC', 'NH', 'KS', 'WY', 'SC',
#        'TN', 'MS', 'LA', 'NV', 'IN', 'SD', 'DE', 'ID', 'VI', 'AE', 'GU',
#        'AP', 'XX', 'MP', 'AA', 'AS'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country       provider_type  \
# 17712   1720142466           I  969503900    MP      US           Optometry
# 18833   1619955549           I  969502878    MP      US     Family Practice
# 105299  1023150414           I      21287    MP      US      Anesthesiology
# 136171  1063459428           I  969501908    MP      US   Internal Medicine
# 188724  1124064274           I      96950    MP      US  Emergency Medicine
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 17712                                 Y               16               599.0
# 18833                                 Y                7                28.0
# 105299                                Y               61               357.0
# 136171                                Y               15              1116.0
# 188724                                Y               10               281.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 17712                   295                 92734.52               65800.34
# 18833                    15                  1498.52                1476.46
# 105299                  215                448440.00               64237.07
# 136171                  236                 82464.35               80558.57
# 188724                  235                239922.00               36632.39
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 17712                 36855.05                             34542.19
# 18833                   873.00                              1058.47
# 105299                50491.98                             46900.14
# 136171                49471.17                             48033.66
# 188724                28068.15                             28653.88
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 17712                    70              1.3616
# 18833                    71              1.1734
# 105299                   68              1.7440
# 136171                   71              0.7859
# 188724                   64              1.7058

# %%
#this line was accidentally mislabeled with state "MP" instead of state "MD" in the Med DFs from most years
med.loc[med.npi == 1023150414, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     844438
# 5      88474
# 8      70815
# 4      10758
# 7       2637
# 3       2236
# 10         4
# 2          2
# 1          2
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code full_zip state country     provider_type  \
# 488228  1457431231           I       61    PR      US  General Practice
# 693494  1669551479           I       80    PR      US           Urology
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 488228                                Y                2                88.0
# 693494                                Y               18               225.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 488228                   24                 10531.08                9724.17
# 693494                   87                 21430.11               19511.23
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 488228                 7379.14                              8667.70
# 693494                13998.30                             16847.36
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 488228                   67              3.2514
# 693494                   76              1.2860

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country  \
# 0  1831435403           I    60188    IL      US
# 1  1831389816           I    60455    IL      US
# 2  1831455021           I    60050    IL      US
# 3  1831528231           I    60090    IL      US
# 4  1306967724           I    60131    IL      US
#
#                                  provider_type  \
# 0                           Nurse Practitioner
# 1                          Preventive Medicine
# 2                            Internal Medicine
# 3  Registered Dietician/Nutrition Professional
# 4                              Family Practice
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               12               106.0
# 1                                Y               16                26.0
# 2                                Y               28               143.0
# 3                                Y                2                66.0
# 4                                Y               16                36.0
#
#    total_beneficiaries  ...  total_medicare_standardized_payment  \
# 0                   35  ...                              2956.15
# 1                   11  ...                              1184.70
# 2                   42  ...                              6823.45
# 3                   12  ...                               959.51
# 4                   14  ...                              1817.65
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   72              0.8336                 3.03
# 1                   66              1.0083                 2.36
# 2                   68              0.9886                 3.40
# 3                   72              2.0698                 5.50
# 4                   62              1.3466                 2.57
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                      103.14                        74.06
# 1                      189.88                       112.63
# 2                      202.01                       155.85
# 3                      153.78                       150.70
# 4                      197.89                       135.17
#
#    submitted_charges_per_capita  State Code   Region            Division
# 0                        120.88          IL  Midwest  East North Central
# 1                        373.91          IL  Midwest  East North Central
# 2                        240.83          IL  Midwest  East North Central
# 3                        174.17          IL  Midwest  East North Central
# 4                        343.14          IL  Midwest  East North Central
#
# [5 rows x 23 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1013166 entries, 0 to 1013165
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   npi                                  1013166 non-null  int64
#  1   entity_code                          1013166 non-null  object
#  2   full_zip                             1013166 non-null  object
#  3   state                                1013166 non-null  object
#  4   country                              1013166 non-null  object
#  5   provider_type                        1013166 non-null  object
#  6   medicare_participation_indicator     1013166 non-null  object
#  7   number_of_hcpcs                      1013166 non-null  int64
#  8   number_of_services                   1013166 non-null  float64
#  9   total_beneficiaries                  1013166 non-null  int64
#  10  total_submitted_charges              1013166 non-null  float64
#  11  total_allowed_payment                1013166 non-null  float64
#  12  total_medicare_payment               1013166 non-null  float64
#  13  total_medicare_standardized_payment  1013166 non-null  float64
#  14  avg_beneficiary_age                  1013166 non-null  int64
#  15  avg_hcc_risk_score                   1013166 non-null  float64
#  16  services_per_capita                  1013166 non-null  float64
#  17  allowed_payment_per_capita           1013166 non-null  float64
#  18  medicare_payment_per_capita          1013166 non-null  float64
#  19  submitted_charges_per_capita         1013166 non-null  float64
#  20  region                               1013166 non-null  object
#  21  subregion                            1013166 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 177.8+ MB

# %%
med.to_csv('../../data/processed/final2015MEDICARE.csv')
