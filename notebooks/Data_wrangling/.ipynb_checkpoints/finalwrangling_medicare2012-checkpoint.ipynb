# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2012.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (925328, 67)

# %%
med.head()
# Out:
#           NPI NPPES Provider Last Name / Organization Name  \
# 0  1003000126                                    ENKESHAFI
# 1  1003000134                                       CIBULL
# 2  1003000142                                       KHALIL
# 3  1003000381                                     BRAGANZA
# 4  1003000407                                      GIRARDI
#
#   NPPES Provider First Name NPPES Provider Middle Initial NPPES Credentials  \
# 0                   ARDALAN                           NaN              M.D.
# 1                    THOMAS                             L              M.D.
# 2                    RASHID                           NaN              M.D.
# 3                    LUTHER                             Q                PT
# 4                     DAVID                             J              D.O.
#
#   NPPES Provider Gender NPPES Entity Code NPPES Provider Street Address 1  \
# 0                     M                 I                    900 SETON DR
# 1                     M                 I                  2650 RIDGE AVE
# 2                     M                 I      4126 N HOLLAND SYLVANIA RD
# 3                     M                 I             134 N OLD DIXIE HWY
# 4                     M                 I                   456 MAGEE AVE
#
#   NPPES Provider Street Address 2 NPPES Provider City  ...  \
# 0                             NaN          CUMBERLAND  ...
# 1               EVANSTON HOSPITAL            EVANSTON  ...
# 2                       SUITE 220              TOLEDO  ...
# 3                             NaN           LADY LAKE  ...
# 4                             NaN              PATTON  ...
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                               51.0
# 1                                               21.0
# 2                                               50.0
# 3                                               35.0
# 4                                               39.0
#
#   Percent (%) of Beneficiaries Identified With Heart Failure  \
# 0                                               53.0
# 1                                               13.0
# 2                                               31.0
# 3                                                NaN
# 4                                               51.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               65.0
# 1                                               55.0
# 2                                               63.0
# 3                                               75.0
# 4                                               65.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               59.0
# 2                                               75.0
# 3                                               75.0
# 4                                               75.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               66.0
# 1                                               31.0
# 2                                               47.0
# 3                                               52.0
# 4                                               65.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                               14.0
# 1                                                8.0
# 2                                               13.0
# 3                                                NaN
# 4                                               20.0
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               47.0
# 1                                               36.0
# 2                                               75.0
# 3                                               58.0
# 4                                               41.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                               14.0
# 1                                                2.0
# 2                                                NaN
# 3                                                0.0
# 4                                               21.0
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               19.0
# 1                                                4.0
# 2                                                NaN
# 3                                                NaN
# 4                                               12.0
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.2264
# 1                                   1.0703
# 2                                   1.8967
# 3                                   1.2687
# 4                                   1.8170
#
# [5 rows x 67 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Provider Last Name / Organization Name',
#        'NPPES Provider First Name', 'NPPES Provider Middle Initial',
#        'NPPES Credentials', 'NPPES Provider Gender', 'NPPES Entity Code',
#        'NPPES Provider Street Address 1', 'NPPES Provider Street Address 2',
#        'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Unique Beneficiaries With Drug Services',
#        'Total Drug Submitted Charges', 'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount', 'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Unique Beneficiaries With Medical Services',
#        'Total Medical Submitted Charges',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Number of Beneficiaries Age Less than 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# NPI                                                                                        int64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charges                                                                  float64
# Number of Unique Beneficiaries                                                             int64
# Number of Services                                                                         int64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type                                                                             object
# NPPES Provider Country                                                                    object
# Average HCC Risk Score of Beneficiaries                                                  float64
# NPPES Provider Zip Code                                                                   object
# NPPES Entity Code                                                                         object
# NPPES Provider State                                                                      object
# NPPES Provider City                                                                       object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider Last Name / Organization Name                                              object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# NPPES Credentials                                                                         object
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# NPPES Provider Middle Initial                                                             object
# Number of Beneficiaries Age Less than 65                                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# NPPES Provider Street Address 2                                                           object
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
#
#                                                                                         non-null values  \
# NPI                                                                                              925328
# Average Age of Beneficiaries                                                                     925328
# Total Medicare Payment Amount                                                                    925328
# Total Medicare Allowed Amount                                                                    925328
# Total Submitted Charges                                                                          925328
# Number of Unique Beneficiaries                                                                   925328
# Number of Services                                                                               925328
# Number of HCPCS                                                                                  925328
# Medicare Participation Indicator                                                                 925328
# Provider Type                                                                                    925328
# NPPES Provider Country                                                                           925328
# Average HCC Risk Score of Beneficiaries                                                          925328
# NPPES Provider Zip Code                                                                          925328
# NPPES Entity Code                                                                                925328
# NPPES Provider State                                                                             925328
# NPPES Provider City                                                                              925327
# NPPES Provider Street Address 1                                                                  925327
# NPPES Provider Last Name / Organization Name                                                     925310
# Percent (%) of Beneficiaries Identified With Hypertension                                        876503
# NPPES Provider Gender                                                                            869335
# NPPES Provider First Name                                                                        869331
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                      857254
# NPPES Credentials                                                                                846317
# Total Medical Medicare Payment Amount                                                            829296
# Total Medical Submitted Charges                                                                  829296
# Number of Unique Beneficiaries With Medical Services                                             829296
# Number of Medical Services                                                                       829296
# Number of HCPCS Associated With Medical Services                                                 829296
# Total Medical Medicare Allowed Amount                                                            829296
# Total Drug Medicare Payment Amount                                                               829296
# Total Drug Medicare Allowed Amount                                                               829296
# Total Drug Submitted Charges                                                                     829296
# Number of Unique Beneficiaries With Drug Services                                                829296
# Number of Drug Services                                                                          829296
# Number of HCPCS Associated With Drug Services                                                    829296
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis               827771
# Number of Male Beneficiaries                                                                     826398
# Number of Female Beneficiaries                                                                   826398
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              795221
# Percent (%) of Beneficiaries Identified With Diabetes                                            795173
# Number of Beneficiaries Age 65 to 74                                                             775739
# Percent (%) of Beneficiaries Identified With Depression                                          769966
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              721412
# Number of Beneficiaries With Medicare Only Entitlement                                           703924
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     703924
# Percent (%) of Beneficiaries Identified With Heart Failure                                       701244
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               677647
# Number of Beneficiaries Age 75 to 84                                                             675156
# NPPES Provider Middle Initial                                                                    659485
# Number of Beneficiaries Age Less than 65                                                         633435
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 628682
# Percent (%) of Beneficiaries Identified With Cancer                                              626860
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     616102
# Number of Non-Hispanic White Beneficiaries                                                       602970
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        593745
# Percent (%) of Beneficiaries Identified With Asthma                                              580327
# Number of Beneficiaries Age Greater 84                                                           573686
# Percent (%) of Beneficiaries Identified With Stroke                                              520956
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           491445
# NPPES Provider Street Address 2                                                                  381641
# Number of Black or African American Beneficiaries                                                305052
# Number of American Indian/Alaska Native Beneficiaries                                            246785
# Number of Hispanic Beneficiaries                                                                 240465
# Number of Asian Pacific Islander Beneficiaries                                                   159602
# Number of Beneficiaries With Race Not Elsewhere Classified                                       119593
# Drug Suppress Indicator                                                                           96032
# Medical Suppress Indicator                                                                        96032
#
#                                                                                         unique values  \
# NPI                                                                                            925328
# Average Age of Beneficiaries                                                                       88
# Total Medicare Payment Amount                                                                  879854
# Total Medicare Allowed Amount                                                                  889315
# Total Submitted Charges                                                                        643779
# Number of Unique Beneficiaries                                                                   6734
# Number of Services                                                                              29173
# Number of HCPCS                                                                                   505
# Medicare Participation Indicator                                                                    2
# Provider Type                                                                                      89
# NPPES Provider Country                                                                             25
# Average HCC Risk Score of Beneficiaries                                                         43776
# NPPES Provider Zip Code                                                                        312997
# NPPES Entity Code                                                                                   2
# NPPES Provider State                                                                               61
# NPPES Provider City                                                                             12888
# NPPES Provider Street Address 1                                                                325563
# NPPES Provider Last Name / Organization Name                                                   236675
# Percent (%) of Beneficiaries Identified With Hypertension                                          68
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                       56794
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        69
# NPPES Credentials                                                                               13975
# Total Medical Medicare Payment Amount                                                          787600
# Total Medical Submitted Charges                                                                575325
# Number of Unique Beneficiaries With Medical Services                                             6665
# Number of Medical Services                                                                      19326
# Number of HCPCS Associated With Medical Services                                                  499
# Total Medical Medicare Allowed Amount                                                          795341
# Total Drug Medicare Payment Amount                                                             196921
# Total Drug Medicare Allowed Amount                                                             199031
# Total Drug Submitted Charges                                                                   128820
# Number of Unique Beneficiaries With Drug Services                                                1174
# Number of Drug Services                                                                         18901
# Number of HCPCS Associated With Drug Services                                                     111
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 73
# Number of Male Beneficiaries                                                                     3521
# Number of Female Beneficiaries                                                                   4731
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Diabetes                                              73
# Number of Beneficiaries Age 65 to 74                                                             3236
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                74
# Number of Beneficiaries With Medicare Only Entitlement                                           5417
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     3109
# Percent (%) of Beneficiaries Identified With Heart Failure                                         75
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 76
# Number of Beneficiaries Age 75 to 84                                                             2917
# NPPES Provider Middle Initial                                                                      33
# Number of Beneficiaries Age Less than 65                                                         2031
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Number of Non-Hispanic White Beneficiaries                                                       5931
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          76
# Percent (%) of Beneficiaries Identified With Asthma                                                76
# Number of Beneficiaries Age Greater 84                                                           2187
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# NPPES Provider Street Address 2                                                                 66378
# Number of Black or African American Beneficiaries                                                2067
# Number of American Indian/Alaska Native Beneficiaries                                             478
# Number of Hispanic Beneficiaries                                                                 1772
# Number of Asian Pacific Islander Beneficiaries                                                   1106
# Number of Beneficiaries With Race Not Elsewhere Classified                                        434
# Drug Suppress Indicator                                                                             2
# Medical Suppress Indicator                                                                          2
#
#                                                                                         null values
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charges                                                                           0
# Number of Unique Beneficiaries                                                                    0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type                                                                                     0
# NPPES Provider Country                                                                            0
# Average HCC Risk Score of Beneficiaries                                                           0
# NPPES Provider Zip Code                                                                           0
# NPPES Entity Code                                                                                 0
# NPPES Provider State                                                                              0
# NPPES Provider City                                                                               1
# NPPES Provider Street Address 1                                                                   1
# NPPES Provider Last Name / Organization Name                                                     18
# Percent (%) of Beneficiaries Identified With Hypertension                                     48825
# NPPES Provider Gender                                                                         55993
# NPPES Provider First Name                                                                     55997
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   68074
# NPPES Credentials                                                                             79011
# Total Medical Medicare Payment Amount                                                         96032
# Total Medical Submitted Charges                                                               96032
# Number of Unique Beneficiaries With Medical Services                                          96032
# Number of Medical Services                                                                    96032
# Number of HCPCS Associated With Medical Services                                              96032
# Total Medical Medicare Allowed Amount                                                         96032
# Total Drug Medicare Payment Amount                                                            96032
# Total Drug Medicare Allowed Amount                                                            96032
# Total Drug Submitted Charges                                                                  96032
# Number of Unique Beneficiaries With Drug Services                                             96032
# Number of Drug Services                                                                       96032
# Number of HCPCS Associated With Drug Services                                                 96032
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            97557
# Number of Male Beneficiaries                                                                  98930
# Number of Female Beneficiaries                                                                98930
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                          130107
# Percent (%) of Beneficiaries Identified With Diabetes                                        130155
# Number of Beneficiaries Age 65 to 74                                                         149589
# Percent (%) of Beneficiaries Identified With Depression                                      155362
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                          203916
# Number of Beneficiaries With Medicare Only Entitlement                                       221404
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                 221404
# Percent (%) of Beneficiaries Identified With Heart Failure                                   224084
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease           247681
# Number of Beneficiaries Age 75 to 84                                                         250172
# NPPES Provider Middle Initial                                                                265843
# Number of Beneficiaries Age Less than 65                                                     291893
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                             296646
# Percent (%) of Beneficiaries Identified With Cancer                                          298468
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                 309226
# Number of Non-Hispanic White Beneficiaries                                                   322358
# Percent (%) of Beneficiaries Identified With Osteoporosis                                    331583
# Percent (%) of Beneficiaries Identified With Asthma                                          345001
# Number of Beneficiaries Age Greater 84                                                       351642
# Percent (%) of Beneficiaries Identified With Stroke                                          404372
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders       433883
# NPPES Provider Street Address 2                                                              543687
# Number of Black or African American Beneficiaries                                            620276
# Number of American Indian/Alaska Native Beneficiaries                                        678543
# Number of Hispanic Beneficiaries                                                             684863
# Number of Asian Pacific Islander Beneficiaries                                               765726
# Number of Beneficiaries With Race Not Elsewhere Classified                                   805735
# Drug Suppress Indicator                                                                      829296
# Medical Suppress Indicator                                                                   829296

# %% [markdown]
# Dropping Most of the Columns, since only 15 have no null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (925328, 67)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (925328, 15)

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Entity Code', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'NPI':'npi',
                 'NPPES Provider City':'city', 'NPPES Provider Zip Code':'full_zip',
                'NPPES Provider State':'state','NPPES Provider Country':'country',
                'Provider Type':'provider_type',
                 'Number of Unique Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charges':'total_submitted_charges',
                 'NPPES Entity Code':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'avg_beneficiary_age', 'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['MD', 'IL', 'OH', 'FL', 'PA', 'CT', 'CO', 'MI', 'VA', 'CA', 'TX',
#        'KY', 'SC', 'OR', 'NE', 'MO', 'NY', 'GA', 'NJ', 'TN', 'MA', 'IA',
#        'AZ', 'MN', 'IN', 'ME', 'DC', 'NC', 'OK', 'NV', 'MS', 'LA', 'ND',
#        'WA', 'AL', 'AR', 'HI', 'DE', 'KS', 'WV', 'WI', 'ID', 'SD', 'MT',
#        'VT', 'NH', 'PR', 'WY', 'UT', 'RI', 'NM', 'VI', 'AK', 'GU', 'AE',
#        'MP', 'AP', 'AS', 'XX', 'AA'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country        provider_type  \
# 24870   1023150414           I      21287    MP      US       Anesthesiology
# 58331   1063459428           I  969501908    MP      US    Internal Medicine
# 114446  1124064274           I      96950    MP      US   Emergency Medicine
# 146488  1154508067           I      96950    MP      US   Physical Therapist
# 155414  1164591574           I  969502878    MP      US  Physician Assistant
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 24870                                 Y               51                 333
# 58331                                 Y               18                1138
# 114446                                Y               16                 565
# 146488                                Y               10                 427
# 155414                                Y               27                 141
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 24870                   196                385456.80               60706.93
# 58331                   191                 78750.70               69037.99
# 114446                  490                535109.00               78470.42
# 146488                   23                 17220.59               14076.72
# 155414                   46                  5113.60                4584.76
#
#         total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score
# 24870                 48459.50                   68              1.7548
# 58331                 45685.83                   71              0.8108
# 114446                60547.06                   75              1.9376
# 146488                11262.00                   73              0.8520
# 155414                 2531.08                   68              1.2040

# %%
# This one was a typo. The others are Northern Mariana Islands, a US territory.
med.loc[24870, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     751328
# 5      91075
# 8      66419
# 4      11271
# 7       2843
# 3       2324
# 10         6
# 1          2
# 2          1
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code full_zip state country  \
# 103581  1114060506           I        0    MA      US
# 294814  1316958416           I        0    XX      US
# 617372  1669551479           I       80    PR      US
#
#                             provider_type medicare_participation_indicator  \
# 103581  Osteopathic Manipulative Medicine                                Y
# 294814                               CRNA                                Y
# 617372                            Urology                                Y
#
#         number_of_hcpcs  number_of_services  total_beneficiaries  \
# 103581               23                1347                 1060
# 294814               19                  46                   44
# 617372               17                 397                  115
#
#         total_submitted_charges  total_allowed_payment  \
# 103581                458969.00              163070.06
# 294814                 49840.00                9956.52
# 617372                 68901.34               40490.91
#
#         total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score
# 103581               126041.77                   72              1.9500
# 294814                 7965.21                   74              1.0228
# 617372                30173.08                   74              1.1614

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country               provider_type  \
# 0  1003000126           I    21502    MD      US           Internal Medicine
# 1  1003004482           O    21204    MD      US  Ambulatory Surgical Center
# 2  1003006586           I    20852    MD      US           Internal Medicine
# 3  1003006800           I    21202    MD      US         Physician Assistant
# 4  1003007816           I    20910    MD      US               Ophthalmology
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               16                1243
# 1                                Y               37                1054
# 2                                Y               30                1426
# 3                                Y               10                  88
# 4                                Y               29                1059
#
#    total_beneficiaries  ...  total_medicare_payment  avg_beneficiary_age  \
# 0                  581  ...                90965.51                   76
# 1                  610  ...               653050.74                   75
# 2                  390  ...               101517.88                   80
# 3                   82  ...                14493.58                   72
# 4                  419  ...                97218.06                   82
#
#    avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 0              2.2264                 2.14                      196.14
# 1              1.2309                 1.73                     1374.22
# 2              2.9636                 3.66                      327.00
# 3              0.9648                 1.07                      220.93
# 4              1.3969                 2.53                      299.55
#
#    medicare_payment_per_capita  submitted_charges_per_capita  State Code  \
# 0                       156.57                        288.37          MD
# 1                      1070.57                       3059.21          MD
# 2                       260.30                        408.53          MD
# 3                       176.75                       1494.89          MD
# 4                       232.02                        445.32          MD
#
#    Region        Division
# 0   South  South Atlantic
# 1   South  South Atlantic
# 2   South  South Atlantic
# 3   South  South Atlantic
# 4   South  South Atlantic
#
# [5 rows x 22 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %% [markdown]
# ##### Adding Types of Doctors

# %%
general_medicine_practitioners = ['Internal Medicine', 
'Family Practice', 
'Obstetrics/Gynecology' ,
       'Nurse Practitioner',
 'Physician Assistant', 
'General Practice', 
 'Geriatric Medicine', 
       'Pediatric Medicine', 
 'Certified Clinical Nurse Specialist',]

medical_specialists = ['Pathology', 
      'Occupational therapist', 
'Cardiology', 
       'Dermatology', 
       'Physical Medicine and Rehabilitation', 
      'Radiation Oncology', 
 'Infectious Disease', 
 'Endocrinology',
       'Nephrology',
 'Pulmonary Disease', 
'Otolaryngology', 
       'Allergy/Immunology',  
'Medical Oncology',
 'Hematology',  
       'Gynecological/Oncology',  
       'Peripheral Vascular Disease', 
  'Cardiac Electrophysiology', 
 'Sports Medicine', 
       'Gastroenterology', 
       'Podiatry', 
 'Hematology/Oncology', 
 'Rheumatology', ]


other_specialists = ['Anesthesiology',       
 'Physical Therapist',  
'Chiropractic',
 'CRNA', 
       'Diagnostic Radiology', 
 'Neurology', 
     'Preventive Medicine',
       'Audiologist (billing independently)', 
 'Pain Management', 
 'Anesthesiologist Assistants', 
 'Interventional Pain Management', 
 'Osteopathic Manipulative Medicine',  
    'Public Health Welfare Agency', 
       'Nuclear Medicine', 
       'Multispecialty Clinic/Group Practice', 
       'Interventional Radiology', 
'Addiction Medicine', 
 'Radiation Therapy', 
       'Unknown Physician Specialty Code', 
'Sleep Medicine' ]

mental_health_providers = ['Clinical Psychologist',  
 'Licensed Clinical Social Worker', 
 'Geriatric Psychiatry', 
'Psychiatry', 
       'Psychologist (billing independently)', 
'Neuropsychiatry', ]

surgery_specialists =['General Surgery', 
'Cardiac Surgery', 
'Orthopedic Surgery', 
       'Ambulatory Surgical Center', 
'Emergency Medicine' ,
       'Plastic and Reconstructive Surgery', 
'Thoracic Surgery', 
'Ophthalmology', 
 'Optometry', 
'Oral Surgery (dentists only)', 
       'Neurosurgery', 
       'Critical Care (Intensivists)', 
 'Surgical Oncology', 
       'Hand Surgery', 
       'Vascular Surgery', 
       'Maxillofacial Surgery', 
       'Colorectal Surgery (formerly proctology)',
'Urology',]


other_health_services = ['Portable X-ray', 
'Certified Nurse Midwife', 
'Slide Preparation Facility', 
       'Mammographic Screening Center',
       'Speech Language Pathologist', 
       'Unknown Supplier/Provider', 
'Pharmacy', 
 'Mass Immunization Roster Biller',  
       'Registered Dietician/Nutrition Professional',
       'Ambulance Service Supplier',
       'All Other Suppliers',  
'Clinical Laboratory',
       'Hospice and Palliative Care', 
       'Independent Diagnostic Testing Facility',]

# %%
med['doctor_category'] = '0'

for i in general_medicine_practitioners:
    med.loc[med.provider_type == i, 'doctor_category'] = 'General Medicine Pracitioner'

for i in medical_specialists:
    med.loc[med.provider_type == i, 'doctor_category'] = 'Medical Specialists'
    
for i in surgery_specialists:
    med.loc[med.provider_type == i, 'doctor_category'] = 'Surgery Specialists'
    
for i in other_specialists:
    med.loc[med.provider_type == i, 'doctor_category'] = 'Other Specialists'

for i in other_health_services:
    med.loc[med.provider_type == i, 'doctor_category'] = 'Other Health Services'

for i in mental_health_providers:
    med.loc[med.provider_type == i, 'doctor_category'] = 'Mental Health Providers'

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 919021 entries, 0 to 919020
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               919021 non-null  int64
#  1   entity_code                       919021 non-null  object
#  2   full_zip                          919021 non-null  object
#  3   state                             919021 non-null  object
#  4   country                           919021 non-null  object
#  5   provider_type                     919021 non-null  object
#  6   medicare_participation_indicator  919021 non-null  object
#  7   number_of_hcpcs                   919021 non-null  int64
#  8   number_of_services                919021 non-null  int64
#  9   total_beneficiaries               919021 non-null  int64
#  10  total_submitted_charges           919021 non-null  float64
#  11  total_allowed_payment             919021 non-null  float64
#  12  total_medicare_payment            919021 non-null  float64
#  13  avg_beneficiary_age               919021 non-null  int64
#  14  avg_hcc_risk_score                919021 non-null  float64
#  15  services_per_capita               919021 non-null  float64
#  16  allowed_payment_per_capita        919021 non-null  float64
#  17  medicare_payment_per_capita       919021 non-null  float64
#  18  submitted_charges_per_capita      919021 non-null  float64
#  19  region                            919021 non-null  object
#  20  subregion                         919021 non-null  object
#  21  doctor_category                   919021 non-null  object
# dtypes: float64(8), int64(5), object(9)
# memory usage: 161.3+ MB

# %%
med.to_csv('../../data/processed/final2012MEDICARE.csv')

# %% [markdown]
# MED is the df I will use to merge with Census and aggregate by zip code.
# But I want a DF of providers as well, so I can compare doctors with mostly Black patients to doctors with mostly non-Black patients.

# %% [markdown]
# # Making DF with zero nulls in 'Number of Black Beneficiaries'

# %%
med.shape
# Out:
# (919021, 22)

# %%
original_df[original_df['Number of Black or African American Beneficiaries'].notnull()].shape
# Out:
# (305052, 67)

# %%
idx = original_df[original_df['Number of Black or African American Beneficiaries'].notnull()].index
med_with_black_beneficiaries = original_df.loc[idx]
info = pd.DataFrame(index=med_with_black_beneficiaries.columns.values,
                    data={'data type': med_with_black_beneficiaries.dtypes, \
                          'non-null values': med_with_black_beneficiaries.notnull().sum(),
                          'unique values': med_with_black_beneficiaries.nunique(), \
                          'null values': med_with_black_beneficiaries.isnull().sum()})
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# NPI                                                                                        int64
# Number of Black or African American Beneficiaries                                        float64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charges                                                                  float64
# Number of Unique Beneficiaries                                                             int64
# Number of Services                                                                         int64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type                                                                             object
# NPPES Provider Country                                                                    object
# Average HCC Risk Score of Beneficiaries                                                  float64
# NPPES Provider Zip Code                                                                   object
# NPPES Provider City                                                                       object
# NPPES Provider Street Address 1                                                           object
# NPPES Entity Code                                                                         object
# NPPES Provider State                                                                      object
# NPPES Provider Last Name / Organization Name                                              object
# NPPES Provider First Name                                                                 object
# NPPES Provider Gender                                                                     object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# NPPES Credentials                                                                         object
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of Drug Services                                                                  float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age Less than 65                                                 float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# NPPES Provider Middle Initial                                                             object
# Number of Hispanic Beneficiaries                                                         float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# NPPES Provider Street Address 2                                                           object
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
#
#                                                                                         non-null values  \
# NPI                                                                                              305052
# Number of Black or African American Beneficiaries                                                305052
# Average Age of Beneficiaries                                                                     305052
# Total Medicare Payment Amount                                                                    305052
# Total Medicare Allowed Amount                                                                    305052
# Total Submitted Charges                                                                          305052
# Number of Unique Beneficiaries                                                                   305052
# Number of Services                                                                               305052
# Number of HCPCS                                                                                  305052
# Medicare Participation Indicator                                                                 305052
# Provider Type                                                                                    305052
# NPPES Provider Country                                                                           305052
# Average HCC Risk Score of Beneficiaries                                                          305052
# NPPES Provider Zip Code                                                                          305052
# NPPES Provider City                                                                              305052
# NPPES Provider Street Address 1                                                                  305052
# NPPES Entity Code                                                                                305052
# NPPES Provider State                                                                             305052
# NPPES Provider Last Name / Organization Name                                                     305042
# NPPES Provider First Name                                                                        290029
# NPPES Provider Gender                                                                            290029
# Percent (%) of Beneficiaries Identified With Hypertension                                        289514
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                      285390
# NPPES Credentials                                                                                282799
# Number of Non-Hispanic White Beneficiaries                                                       281458
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis               279659
# Number of Male Beneficiaries                                                                     278596
# Number of Female Beneficiaries                                                                   278596
# Percent (%) of Beneficiaries Identified With Diabetes                                            275464
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              274657
# Total Medical Medicare Payment Amount                                                            274003
# Total Medical Submitted Charges                                                                  274003
# Total Medical Medicare Allowed Amount                                                            274003
# Number of HCPCS Associated With Drug Services                                                    274003
# Number of Medical Services                                                                       274003
# Number of HCPCS Associated With Medical Services                                                 274003
# Number of Unique Beneficiaries With Medical Services                                             274003
# Total Drug Medicare Payment Amount                                                               274003
# Total Drug Medicare Allowed Amount                                                               274003
# Total Drug Submitted Charges                                                                     274003
# Number of Unique Beneficiaries With Drug Services                                                274003
# Number of Drug Services                                                                          274003
# Percent (%) of Beneficiaries Identified With Depression                                          270666
# Number of Beneficiaries Age 65 to 74                                                             268071
# Number of Beneficiaries With Medicare Only Entitlement                                           267779
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     267779
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              266057
# Percent (%) of Beneficiaries Identified With Heart Failure                                       264793
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               259853
# Number of Beneficiaries Age Less than 65                                                         254997
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     252937
# Percent (%) of Beneficiaries Identified With Asthma                                              249814
# Number of Beneficiaries Age 75 to 84                                                             247546
# Percent (%) of Beneficiaries Identified With Cancer                                              247472
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 247272
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        241594
# Number of Beneficiaries Age Greater 84                                                           238062
# Percent (%) of Beneficiaries Identified With Stroke                                              235540
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           221604
# NPPES Provider Middle Initial                                                                    212744
# Number of Hispanic Beneficiaries                                                                 155159
# Number of American Indian/Alaska Native Beneficiaries                                            136943
# NPPES Provider Street Address 2                                                                  136031
# Number of Asian Pacific Islander Beneficiaries                                                   102985
# Number of Beneficiaries With Race Not Elsewhere Classified                                        83294
# Drug Suppress Indicator                                                                           31049
# Medical Suppress Indicator                                                                        31049
#
#                                                                                         unique values  \
# NPI                                                                                            305052
# Number of Black or African American Beneficiaries                                                2067
# Average Age of Beneficiaries                                                                       85
# Total Medicare Payment Amount                                                                  302364
# Total Medicare Allowed Amount                                                                  302762
# Total Submitted Charges                                                                        272941
# Number of Unique Beneficiaries                                                                   6688
# Number of Services                                                                              23984
# Number of HCPCS                                                                                   505
# Medicare Participation Indicator                                                                    2
# Provider Type                                                                                      89
# NPPES Provider Country                                                                             14
# Average HCC Risk Score of Beneficiaries                                                         37323
# NPPES Provider Zip Code                                                                        123997
# NPPES Provider City                                                                              8942
# NPPES Provider Street Address 1                                                                124032
# NPPES Entity Code                                                                                   2
# NPPES Provider State                                                                               60
# NPPES Provider Last Name / Organization Name                                                   112103
# NPPES Provider First Name                                                                       30406
# NPPES Provider Gender                                                                               2
# Percent (%) of Beneficiaries Identified With Hypertension                                          65
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        68
# NPPES Credentials                                                                                4766
# Number of Non-Hispanic White Beneficiaries                                                       5885
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 72
# Number of Male Beneficiaries                                                                     3498
# Number of Female Beneficiaries                                                                   4703
# Percent (%) of Beneficiaries Identified With Diabetes                                              72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Total Medical Medicare Payment Amount                                                          271237
# Total Medical Submitted Charges                                                                245144
# Total Medical Medicare Allowed Amount                                                          271607
# Number of HCPCS Associated With Drug Services                                                     109
# Number of Medical Services                                                                      16718
# Number of HCPCS Associated With Medical Services                                                  496
# Number of Unique Beneficiaries With Medical Services                                             6618
# Total Drug Medicare Payment Amount                                                              79563
# Total Drug Medicare Allowed Amount                                                              79954
# Total Drug Submitted Charges                                                                    55937
# Number of Unique Beneficiaries With Drug Services                                                1053
# Number of Drug Services                                                                         14181
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Number of Beneficiaries Age 65 to 74                                                             3208
# Number of Beneficiaries With Medicare Only Entitlement                                           5379
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     3059
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                73
# Percent (%) of Beneficiaries Identified With Heart Failure                                         75
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 76
# Number of Beneficiaries Age Less than 65                                                         2028
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Percent (%) of Beneficiaries Identified With Asthma                                                71
# Number of Beneficiaries Age 75 to 84                                                             2890
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          74
# Number of Beneficiaries Age Greater 84                                                           2176
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# NPPES Provider Middle Initial                                                                      32
# Number of Hispanic Beneficiaries                                                                 1576
# Number of American Indian/Alaska Native Beneficiaries                                             438
# NPPES Provider Street Address 2                                                                 29920
# Number of Asian Pacific Islander Beneficiaries                                                    897
# Number of Beneficiaries With Race Not Elsewhere Classified                                        410
# Drug Suppress Indicator                                                                             2
# Medical Suppress Indicator                                                                          2
#
#                                                                                         null values
# NPI                                                                                               0
# Number of Black or African American Beneficiaries                                                 0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charges                                                                           0
# Number of Unique Beneficiaries                                                                    0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type                                                                                     0
# NPPES Provider Country                                                                            0
# Average HCC Risk Score of Beneficiaries                                                           0
# NPPES Provider Zip Code                                                                           0
# NPPES Provider City                                                                               0
# NPPES Provider Street Address 1                                                                   0
# NPPES Entity Code                                                                                 0
# NPPES Provider State                                                                              0
# NPPES Provider Last Name / Organization Name                                                     10
# NPPES Provider First Name                                                                     15023
# NPPES Provider Gender                                                                         15023
# Percent (%) of Beneficiaries Identified With Hypertension                                     15538
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   19662
# NPPES Credentials                                                                             22253
# Number of Non-Hispanic White Beneficiaries                                                    23594
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            25393
# Number of Male Beneficiaries                                                                  26456
# Number of Female Beneficiaries                                                                26456
# Percent (%) of Beneficiaries Identified With Diabetes                                         29588
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           30395
# Total Medical Medicare Payment Amount                                                         31049
# Total Medical Submitted Charges                                                               31049
# Total Medical Medicare Allowed Amount                                                         31049
# Number of HCPCS Associated With Drug Services                                                 31049
# Number of Medical Services                                                                    31049
# Number of HCPCS Associated With Medical Services                                              31049
# Number of Unique Beneficiaries With Medical Services                                          31049
# Total Drug Medicare Payment Amount                                                            31049
# Total Drug Medicare Allowed Amount                                                            31049
# Total Drug Submitted Charges                                                                  31049
# Number of Unique Beneficiaries With Drug Services                                             31049
# Number of Drug Services                                                                       31049
# Percent (%) of Beneficiaries Identified With Depression                                       34386
# Number of Beneficiaries Age 65 to 74                                                          36981
# Number of Beneficiaries With Medicare Only Entitlement                                        37273
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  37273
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           38995
# Percent (%) of Beneficiaries Identified With Heart Failure                                    40259
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            45199
# Number of Beneficiaries Age Less than 65                                                      50055
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  52115
# Percent (%) of Beneficiaries Identified With Asthma                                           55238
# Number of Beneficiaries Age 75 to 84                                                          57506
# Percent (%) of Beneficiaries Identified With Cancer                                           57580
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              57780
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     63458
# Number of Beneficiaries Age Greater 84                                                        66990
# Percent (%) of Beneficiaries Identified With Stroke                                           69512
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        83448
# NPPES Provider Middle Initial                                                                 92308
# Number of Hispanic Beneficiaries                                                             149893
# Number of American Indian/Alaska Native Beneficiaries                                        168109
# NPPES Provider Street Address 2                                                              169021
# Number of Asian Pacific Islander Beneficiaries                                               202067
# Number of Beneficiaries With Race Not Elsewhere Classified                                   221758
# Drug Suppress Indicator                                                                      274003
# Medical Suppress Indicator                                                                   274003

# %%
cols = info[info['null values']>0].index
med_with_black_beneficiaries.drop(columns = cols, inplace = True)
med_with_black_beneficiaries.columns
# Out:
# Index(['NPI', 'NPPES Entity Code', 'NPPES Provider Street Address 1',
#        'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'NPI':'npi',
                 'NPPES Provider City':'city', 'NPPES Provider Zip Code':'full_zip',
                'NPPES Provider State':'state','NPPES Provider Country':'country',
                'Provider Type':'provider_type',
                 'Number of Unique Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'number_black_beneficiaries',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charges':'total_submitted_charges',
                 'NPPES Entity Code':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med_with_black_beneficiaries.rename(columns = new_name_dict, inplace = True)

# %%
med_with_black_beneficiaries.columns
# Out:
# Index(['npi', 'entity_code', 'address', 'city', 'full_zip', 'state', 'country',
#        'provider_type', 'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'avg_beneficiary_age', 'number_black_beneficiaries',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med_with_black_beneficiaries[med_with_black_beneficiaries.country != 'US'].index
med_with_black_beneficiaries.drop(index = idx, inplace =True)

# %%
med_with_black_beneficiaries.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     246154
# 5      30288
# 8      22203
# 4       3863
# 7       1356
# 3       1167
# 10         3
# 1          1
# Name: full_zip, dtype: int64

# %%
med_with_black_beneficiaries[
    med_with_black_beneficiaries.full_zip.apply(lambda x: len(str(x))) == 1]
# Out:
#                npi entity_code                 address        city full_zip  \
# 103581  1114060506           I  CHARLTON MEMORIAL HOSP  FALL RIVER        0
#
#        state country                      provider_type  \
# 103581    MA      US  Osteopathic Manipulative Medicine
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 103581                                Y               23                1347
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 103581                 1060                 458969.0              163070.06
#
#         total_medicare_payment  avg_beneficiary_age  \
# 103581               126041.77                   72
#
#         number_black_beneficiaries  avg_hcc_risk_score
# 103581                        14.0                1.95

# %%
idx = med_with_black_beneficiaries[
    med_with_black_beneficiaries.full_zip.apply(lambda x: len(str(x))) == 1].index
med_with_black_beneficiaries.drop(index = idx, inplace = True)

# %%
med_with_black_beneficiaries[
    med_with_black_beneficiaries.full_zip.apply(lambda x: len(str(x))) == 10]
# Out:
#                npi entity_code                 address    city    full_zip  \
# 199931  1215919634           I        PSC 475 BOX 1740     FPO  96350-1740
# 502055  1548237472           I             OMEGA DRIVE  NEWARK  19713 6004
# 623515  1679557110           I  OPTOMETRY CLINIC/ SGPE     APO  96368-5267
#
#        state country         provider_type medicare_participation_indicator  \
# 199931    AP      US  Diagnostic Radiology                                Y
# 502055    DE      US            Cardiology                                Y
# 623515    AP      US             Optometry                                Y
#
#         number_of_hcpcs  number_of_services  total_beneficiaries  \
# 199931              264                4071                 2265
# 502055               50                4582                 1309
# 623515               19                 433                  325
#
#         total_submitted_charges  total_allowed_payment  \
# 199931                521454.07              134445.90
# 502055                688628.50              292007.59
# 623515                 39873.17               39141.38
#
#         total_medicare_payment  avg_beneficiary_age  \
# 199931               104206.25                   71
# 502055               221959.83                   76
# 623515                27192.82                   74
#
#         number_black_beneficiaries  avg_hcc_risk_score
# 199931                       135.0              1.7750
# 502055                       122.0              1.6333
# 623515                         0.0              1.0702

# %%
med_with_black_beneficiaries['full_zip'] = make_five_digit_zip(med_with_black_beneficiaries, 'full_zip')

# %%
med_with_black_beneficiaries['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med_with_black_beneficiaries['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med_with_black_beneficiaries['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med_with_black_beneficiaries['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)
med_with_black_beneficiaries['percent_black_patients'] = round(med_with_black_beneficiaries.number_black_beneficiaries/med_with_black_beneficiaries.total_beneficiaries, 2)

# %%
med_with_black_beneficiaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305034 entries, 1 to 925326
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               305034 non-null  int64
#  1   entity_code                       305034 non-null  object
#  2   address                           305034 non-null  object
#  3   city                              305034 non-null  object
#  4   full_zip                          305034 non-null  object
#  5   state                             305034 non-null  object
#  6   country                           305034 non-null  object
#  7   provider_type                     305034 non-null  object
#  8   medicare_participation_indicator  305034 non-null  object
#  9   number_of_hcpcs                   305034 non-null  int64
#  10  number_of_services                305034 non-null  int64
#  11  total_beneficiaries               305034 non-null  int64
#  12  total_submitted_charges           305034 non-null  float64
#  13  total_allowed_payment             305034 non-null  float64
#  14  total_medicare_payment            305034 non-null  float64
#  15  avg_beneficiary_age               305034 non-null  int64
#  16  number_black_beneficiaries        305034 non-null  float64
#  17  avg_hcc_risk_score                305034 non-null  float64
#  18  services_per_capita               302906 non-null  float64
#  19  allowed_payment_per_capita        302906 non-null  float64
#  20  medicare_payment_per_capita       302906 non-null  float64
#  21  submitted_charges_per_capita      302906 non-null  float64
#  22  percent_black_patients            305034 non-null  float64
# dtypes: float64(10), int64(5), object(8)
# memory usage: 65.9+ MB

# %%
med_with_black_beneficiaries.state.unique()
# Out:
# array(['IL', 'CO', 'FL', 'SC', 'NE', 'CA', 'PA', 'NY', 'TX', 'MI', 'MD',
#        'OH', 'ME', 'NV', 'IA', 'VA', 'ND', 'AZ', 'MN', 'MA', 'NC', 'HI',
#        'NJ', 'MO', 'WV', 'DC', 'OR', 'GA', 'KY', 'NH', 'WA', 'CT', 'IN',
#        'LA', 'TN', 'AR', 'AL', 'WI', 'MS', 'OK', 'ID', 'DE', 'SD', 'WY',
#        'PR', 'KS', 'VT', 'UT', 'NM', 'AK', 'MT', 'RI', 'GU', 'VI', 'MP',
#        'AE', 'AS', 'AP', 'AA'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med_with_black_beneficiaries[
    med_with_black_beneficiaries.state == 'MP'
].head()
# Out:
#                npi entity_code                      address       city  \
# 24870   1023150414           I       600 NORTH WOLFE STREET  BALTIMORE
# 146488  1154508067           I            1 LOWER NAVY HILL     SAIPAN
# 331190  1356484182           I  COMMON WEALTH HEALTH CENTER     SAIPAN
# 416572  1447579479           O            SUSUPE BEACH ROAD     SAIPAN
# 462793  1497994008           I              LOWER NAVY HILL     SAIPAN
#
#        full_zip state country               provider_type  \
# 24870     21287    MP      US              Anesthesiology
# 146488    96950    MP      US          Physical Therapist
# 331190    96960    MP      US           Internal Medicine
# 416572    96950    MP      US  Ambulance Service Supplier
# 462793    96950    MP      US       Obstetrics/Gynecology
#
#        medicare_participation_indicator  number_of_hcpcs  ...  \
# 24870                                 Y               51  ...
# 146488                                Y               10  ...
# 331190                                Y               55  ...
# 416572                                Y                2  ...
# 462793                                Y                5  ...
#
#         total_allowed_payment  total_medicare_payment  avg_beneficiary_age  \
# 24870                60706.93                48459.50                   68
# 146488               14076.72                11262.00                   73
# 331190               82241.18                57024.78                   72
# 416572              319288.49               255172.40                   65
# 462793                1591.91                 1206.36                   64
#
#         number_black_beneficiaries  avg_hcc_risk_score  services_per_capita  \
# 24870                         14.0              1.7548                 4.35
# 146488                         0.0              0.8520                 2.28
# 331190                         0.0              1.1649                 2.57
# 416572                         0.0              4.9771                 1.27
# 462793                         0.0              0.9359                 4.92
#
#         allowed_payment_per_capita  medicare_payment_per_capita  \
# 24870                       288.25                       195.81
# 146488                      206.11                       162.68
# 331190                      194.93                       155.70
# 416572                       74.28                        51.22
# 462793                      459.25                       308.32
#
#         submitted_charges_per_capita  percent_black_patients
# 24870                         560.62                    0.07
# 146488                        706.40                    0.00
# 331190                        206.89                    0.00
# 416572                         76.50                    0.00
# 462793                        546.20                    0.00
#
# [5 rows x 23 columns]

# %%
# This one was a typo. The others are Northern Mariana Islands, a US territory.
med_with_black_beneficiaries.loc[24870, 'state'] = 'MD'

# %%
med_with_black_beneficiaries.to_csv('../../data/processed/final2012MEDICARE_with_Black_beneficiaries.csv')

# %%
med_with_black_beneficiaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305034 entries, 1 to 925326
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               305034 non-null  int64
#  1   entity_code                       305034 non-null  object
#  2   address                           305034 non-null  object
#  3   city                              305034 non-null  object
#  4   full_zip                          305034 non-null  object
#  5   state                             305034 non-null  object
#  6   country                           305034 non-null  object
#  7   provider_type                     305034 non-null  object
#  8   medicare_participation_indicator  305034 non-null  object
#  9   number_of_hcpcs                   305034 non-null  int64
#  10  number_of_services                305034 non-null  int64
#  11  total_beneficiaries               305034 non-null  int64
#  12  total_submitted_charges           305034 non-null  float64
#  13  total_allowed_payment             305034 non-null  float64
#  14  total_medicare_payment            305034 non-null  float64
#  15  avg_beneficiary_age               305034 non-null  int64
#  16  number_black_beneficiaries        305034 non-null  float64
#  17  avg_hcc_risk_score                305034 non-null  float64
#  18  services_per_capita               302906 non-null  float64
#  19  allowed_payment_per_capita        302906 non-null  float64
#  20  medicare_payment_per_capita       302906 non-null  float64
#  21  submitted_charges_per_capita      302906 non-null  float64
#  22  percent_black_patients            305034 non-null  float64
# dtypes: float64(10), int64(5), object(8)
# memory usage: 65.9+ MB

# %% [markdown]
# Renamed Columns and Dropped Countries Checkpoint

# %%
checkpoint5 = med_with_black_beneficiaries.copy()

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med_with_black_beneficiaries = pd.merge(med_with_black_beneficiaries, regions, left_on='state',right_on='State Code')

# %%
checkpoint7 = med_with_black_beneficiaries.copy()

# %% [markdown]
# ##### Adding Types of Doctors

# %%
general_medicine_practitioners = ['Internal Medicine', 
'Family Practice', 
'Obstetrics/Gynecology' ,
       'Nurse Practitioner',
 'Physician Assistant', 
'General Practice', 
 'Geriatric Medicine', 
       'Pediatric Medicine', 
 'Certified Clinical Nurse Specialist',]

medical_specialists = ['Pathology', 
      'Occupational therapist', 
'Cardiology', 
       'Dermatology', 
       'Physical Medicine and Rehabilitation', 
      'Radiation Oncology', 
 'Infectious Disease', 
 'Endocrinology',
       'Nephrology',
 'Pulmonary Disease', 
'Otolaryngology', 
       'Allergy/Immunology',  
'Medical Oncology',
 'Hematology',  
       'Gynecological/Oncology',  
       'Peripheral Vascular Disease', 
  'Cardiac Electrophysiology', 
 'Sports Medicine', 
       'Gastroenterology', 
       'Podiatry', 
 'Hematology/Oncology', 
 'Rheumatology', ]


other_specialists = ['Anesthesiology',       
 'Physical Therapist',  
'Chiropractic',
 'CRNA', 
       'Diagnostic Radiology', 
 'Neurology', 
     'Preventive Medicine',
       'Audiologist (billing independently)', 
 'Pain Management', 
 'Anesthesiologist Assistants', 
 'Interventional Pain Management', 
 'Osteopathic Manipulative Medicine',  
    'Public Health Welfare Agency', 
       'Nuclear Medicine', 
       'Multispecialty Clinic/Group Practice', 
       'Interventional Radiology', 
'Addiction Medicine', 
 'Radiation Therapy', 
       'Unknown Physician Specialty Code', 
'Sleep Medicine' ]

mental_health_providers = ['Clinical Psychologist',  
 'Licensed Clinical Social Worker', 
 'Geriatric Psychiatry', 
'Psychiatry', 
       'Psychologist (billing independently)', 
'Neuropsychiatry', ]

surgery_specialists =['General Surgery', 
'Cardiac Surgery', 
'Orthopedic Surgery', 
       'Ambulatory Surgical Center', 
'Emergency Medicine' ,
       'Plastic and Reconstructive Surgery', 
'Thoracic Surgery', 
'Ophthalmology', 
 'Optometry', 
'Oral Surgery (dentists only)', 
       'Neurosurgery', 
       'Critical Care (Intensivists)', 
 'Surgical Oncology', 
       'Hand Surgery', 
       'Vascular Surgery', 
       'Maxillofacial Surgery', 
       'Colorectal Surgery (formerly proctology)',
'Urology',]


other_health_services = ['Portable X-ray', 
'Certified Nurse Midwife', 
'Slide Preparation Facility', 
       'Mammographic Screening Center',
       'Speech Language Pathologist', 
       'Unknown Supplier/Provider', 
'Pharmacy', 
 'Mass Immunization Roster Biller',  
       'Registered Dietician/Nutrition Professional',
       'Ambulance Service Supplier',
       'All Other Suppliers',  
'Clinical Laboratory',
       'Hospice and Palliative Care', 
       'Independent Diagnostic Testing Facility',]

# %%
med_with_black_beneficiaries['doctor_category'] = '0'

for i in general_medicine_practitioners:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'General Medicine Pracitioner'

for i in medical_specialists:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'Medical Specialists'
    
for i in surgery_specialists:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'Surgery Specialists'
    
for i in other_specialists:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'Other Specialists'

for i in other_health_services:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'Other Health Services'

for i in mental_health_providers:
    med_with_black_beneficiaries.loc[med_with_black_beneficiaries.provider_type == i, 'doctor_category'] = 'Mental Health Providers'

# %%
med_with_black_beneficiaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302011 entries, 0 to 302010
# Data columns (total 27 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               302011 non-null  int64
#  1   entity_code                       302011 non-null  object
#  2   address                           302011 non-null  object
#  3   city                              302011 non-null  object
#  4   full_zip                          302011 non-null  object
#  5   state                             302011 non-null  object
#  6   country                           302011 non-null  object
#  7   provider_type                     302011 non-null  object
#  8   medicare_participation_indicator  302011 non-null  object
#  9   number_of_hcpcs                   302011 non-null  int64
#  10  number_of_services                302011 non-null  int64
#  11  total_beneficiaries               302011 non-null  int64
#  12  total_submitted_charges           302011 non-null  float64
#  13  total_allowed_payment             302011 non-null  float64
#  14  total_medicare_payment            302011 non-null  float64
#  15  avg_beneficiary_age               302011 non-null  int64
#  16  number_black_beneficiaries        302011 non-null  float64
#  17  avg_hcc_risk_score                302011 non-null  float64
#  18  services_per_capita               299913 non-null  float64
#  19  allowed_payment_per_capita        299913 non-null  float64
#  20  medicare_payment_per_capita       299913 non-null  float64
#  21  submitted_charges_per_capita      299913 non-null  float64
#  22  percent_black_patients            302011 non-null  float64
#  23  State Code                        302011 non-null  object
#  24  Region                            302011 non-null  object
#  25  Division                          302011 non-null  object
#  26  doctor_category                   302011 non-null  object
# dtypes: float64(10), int64(5), object(12)
# memory usage: 64.5+ MB

# %% [markdown]
# # Saving Medicare DF to CSV

# %%
#saving black medicare merged
med_with_black_beneficiaries.to_csv('../../data/processed/final2012MEDICAREwithBlackben.csv')
