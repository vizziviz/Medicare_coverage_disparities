# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2017.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1088687, 71)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        D.O.                      M
# 4                        M.D.                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
# 2                           I       4126 N HOLLAND SYLVANIA RD
# 3                           I                  100 HOSPITAL RD
# 4                           I                 11100 EUCLID AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
# 2                        SUITE 220               TOLEDO  ...
# 3                              NaN           BROOKVILLE  ...
# 4                              NaN            CLEVELAND  ...
#
#   Percent (%) of Beneficiaries Identified With Depression  \
# 0                                               46.0
# 1                                               12.0
# 2                                               45.0
# 3                                               50.0
# 4                                               21.0
#
#    Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                               51.0
# 1                                               20.0
# 2                                               41.0
# 3                                               44.0
# 4                                               20.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               67.0
# 1                                               34.0
# 2                                               50.0
# 3                                               66.0
# 4                                               35.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               55.0
# 2                                               74.0
# 3                                               75.0
# 4                                               48.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               56.0
# 1                                               27.0
# 2                                               39.0
# 3                                               64.0
# 4                                               23.0
#
#   Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                                9.0
# 1                                                9.0
# 2                                               10.0
# 3                                               20.0
# 4                                               15.0
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               49.0
# 1                                               36.0
# 2                                               75.0
# 3                                               48.0
# 4                                               42.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                8.0
# 1                                                1.0
# 2                                                4.0
# 3                                               13.0
# 4                                                0.0
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               13.0
# 1                                                3.0
# 2                                                5.0
# 3                                               11.0
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.1178
# 1                                   1.1024
# 2                                   1.6807
# 3                                   2.1173
# 4                                   1.0032
#
# [5 rows x 71 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'Provider RUCA',
#        'State Code of the Provider', 'Country Code of the Provider',
#        'Provider Type of the Provider', 'Medicare Participation Indicator',
#        'Number of HCPCS', 'Number of Services',
#        'Number of Medicare Beneficiaries', 'Total Submitted Charge Amount',
#        'Total Medicare Allowed Amount', 'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries\t',
#        'Number of Non-Hispanic White Beneficiaries\t',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# National Provider Identifier                                                               int64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Standardized Payment Amount                                               float64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charge Amount                                                            float64
# Number of Medicare Beneficiaries                                                           int64
# Number of Services                                                                       float64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type of the Provider                                                             object
# Country Code of the Provider                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
# Entity Type of the Provider                                                               object
# State Code of the Provider                                                                object
# Zip Code of the Provider                                                                  object
# City of the Provider                                                                      object
# Street Address 1 of the Provider                                                          object
# Last Name/Organization Name of the Provider                                               object
# Provider RUCA                                                                            float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Gender of the Provider                                                                    object
# First Name of the Provider                                                                object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Submitted Charge Amount                                                    float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries\t                                                           float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Non-Hispanic White Beneficiaries\t                                             float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Middle Initial of the Provider                                                            object
# Number of Beneficiaries Age Less 65                                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Street Address 2 of the Provider                                                          object
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
#
#                                                                                         non-null values  \
# National Provider Identifier                                                                    1088687
# Average Age of Beneficiaries                                                                    1088687
# Total Medicare Standardized Payment Amount                                                      1088687
# Total Medicare Payment Amount                                                                   1088687
# Total Medicare Allowed Amount                                                                   1088687
# Total Submitted Charge Amount                                                                   1088687
# Number of Medicare Beneficiaries                                                                1088687
# Number of Services                                                                              1088687
# Number of HCPCS                                                                                 1088687
# Medicare Participation Indicator                                                                1088687
# Provider Type of the Provider                                                                   1088687
# Country Code of the Provider                                                                    1088687
# Average HCC Risk Score of Beneficiaries                                                         1088687
# Entity Type of the Provider                                                                     1088687
# State Code of the Provider                                                                      1088687
# Zip Code of the Provider                                                                        1088686
# City of the Provider                                                                            1088686
# Street Address 1 of the Provider                                                                1088685
# Last Name/Organization Name of the Provider                                                     1088664
# Provider RUCA                                                                                   1081476
# Percent (%) of Beneficiaries Identified With Hypertension                                       1031998
# Gender of the Provider                                                                          1026824
# First Name of the Provider                                                                      1026811
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                      992853
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis               986548
# Credentials of the Provider                                                                      977348
# Total Medical Medicare Standardized Payment Amount                                               974072
# Total Medical Medicare Payment Amount                                                            974072
# Total Medical Medicare Allowed Amount                                                            974072
# Number of Medicare Beneficiaries With Medical Services                                           974072
# Number of Medical Services                                                                       974072
# Number of HCPCS Associated With Medical Services                                                 974072
# Total Medical Submitted Charge Amount                                                            974072
# Total Drug Medicare Standardized Payment Amount                                                  974072
# Total Drug Medicare Payment Amount                                                               974072
# Total Drug Medicare Allowed Amount                                                               974072
# Total Drug Submitted Charge Amount                                                               974072
# Number of Medicare Beneficiaries With Drug Services                                              974072
# Number of Drug Services                                                                          974072
# Number of HCPCS Associated With Drug Services                                                    974072
# Number of Female Beneficiaries                                                                   969611
# Number of Male Beneficiaries\t                                                                   969611
# Percent (%) of Beneficiaries Identified With Diabetes                                            934900
# Percent (%) of Beneficiaries Identified With Depression                                          928809
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              927158
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              921763
# Number of Beneficiaries Age 65 to 74                                                             917912
# Percent (%) of Beneficiaries Identified With Heart Failure                                       817602
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     815560
# Number of Beneficiaries With Medicare Only Entitlement                                           815560
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               798311
# Number of Beneficiaries Age 75 to 84                                                             777508
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 741411
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     736259
# Number of Non-Hispanic White Beneficiaries\t                                                     735984
# Percent (%) of Beneficiaries Identified With Cancer                                              733004
# Middle Initial of the Provider                                                                   729423
# Number of Beneficiaries Age Less 65                                                              703800
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        681480
# Percent (%) of Beneficiaries Identified With Asthma                                              678916
# Number of Beneficiaries Age Greater 84                                                           640677
# Percent (%) of Beneficiaries Identified With Stroke                                              595309
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           501102
# Street Address 2 of the Provider                                                                 397704
# Number of Black or African American Beneficiaries                                                373993
# Number of American Indian/Alaska Native Beneficiaries                                            329303
# Number of Hispanic Beneficiaries                                                                 289083
# Number of Asian Pacific Islander Beneficiaries                                                   194174
# Number of Beneficiaries With Race Not Elsewhere Classified                                       175071
# Medical Suppress Indicator                                                                       114615
# Drug Suppress Indicator                                                                          114615
#
#                                                                                         unique values  \
# National Provider Identifier                                                                  1088687
# Average Age of Beneficiaries                                                                       86
# Total Medicare Standardized Payment Amount                                                    1027689
# Total Medicare Payment Amount                                                                 1026609
# Total Medicare Allowed Amount                                                                 1041228
# Total Submitted Charge Amount                                                                  736392
# Number of Medicare Beneficiaries                                                                 6970
# Number of Services                                                                              40322
# Number of HCPCS                                                                                   483
# Medicare Participation Indicator                                                                    2
# Provider Type of the Provider                                                                      95
# Country Code of the Provider                                                                       26
# Average HCC Risk Score of Beneficiaries                                                         46394
# Entity Type of the Provider                                                                         2
# State Code of the Provider                                                                         61
# Zip Code of the Provider                                                                       353453
# City of the Provider                                                                            13039
# Street Address 1 of the Provider                                                               373149
# Last Name/Organization Name of the Provider                                                    265231
# Provider RUCA                                                                                      21
# Percent (%) of Beneficiaries Identified With Hypertension                                          66
# Gender of the Provider                                                                              2
# First Name of the Provider                                                                      69081
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        72
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 71
# Credentials of the Provider                                                                     16879
# Total Medical Medicare Standardized Payment Amount                                             902843
# Total Medical Medicare Payment Amount                                                          916413
# Total Medical Medicare Allowed Amount                                                          928848
# Number of Medicare Beneficiaries With Medical Services                                           6867
# Number of Medical Services                                                                      25483
# Number of HCPCS Associated With Medical Services                                                  475
# Total Medical Submitted Charge Amount                                                          651401
# Total Drug Medicare Standardized Payment Amount                                                235537
# Total Drug Medicare Payment Amount                                                             235400
# Total Drug Medicare Allowed Amount                                                             238726
# Total Drug Submitted Charge Amount                                                             156919
# Number of Medicare Beneficiaries With Drug Services                                              1173
# Number of Drug Services                                                                         24241
# Number of HCPCS Associated With Drug Services                                                     117
# Number of Female Beneficiaries                                                                   4886
# Number of Male Beneficiaries\t                                                                   3725
# Percent (%) of Beneficiaries Identified With Diabetes                                              73
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                73
# Number of Beneficiaries Age 65 to 74                                                             3553
# Percent (%) of Beneficiaries Identified With Heart Failure                                         76
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     3023
# Number of Beneficiaries With Medicare Only Entitlement                                           5714
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 76
# Number of Beneficiaries Age 75 to 84                                                             2965
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Number of Non-Hispanic White Beneficiaries\t                                                     6177
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Middle Initial of the Provider                                                                     31
# Number of Beneficiaries Age Less 65                                                              2029
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          76
# Percent (%) of Beneficiaries Identified With Asthma                                                76
# Number of Beneficiaries Age Greater 84                                                           2144
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# Street Address 2 of the Provider                                                                72787
# Number of Black or African American Beneficiaries                                                2053
# Number of American Indian/Alaska Native Beneficiaries                                             531
# Number of Hispanic Beneficiaries                                                                 1564
# Number of Asian Pacific Islander Beneficiaries                                                   1093
# Number of Beneficiaries With Race Not Elsewhere Classified                                        602
# Medical Suppress Indicator                                                                          2
# Drug Suppress Indicator                                                                             2
#
#                                                                                         null values
# National Provider Identifier                                                                      0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charge Amount                                                                     0
# Number of Medicare Beneficiaries                                                                  0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type of the Provider                                                                     0
# Country Code of the Provider                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0
# Entity Type of the Provider                                                                       0
# State Code of the Provider                                                                        0
# Zip Code of the Provider                                                                          1
# City of the Provider                                                                              1
# Street Address 1 of the Provider                                                                  2
# Last Name/Organization Name of the Provider                                                      23
# Provider RUCA                                                                                  7211
# Percent (%) of Beneficiaries Identified With Hypertension                                     56689
# Gender of the Provider                                                                        61863
# First Name of the Provider                                                                    61876
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   95834
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis           102139
# Credentials of the Provider                                                                  111339
# Total Medical Medicare Standardized Payment Amount                                           114615
# Total Medical Medicare Payment Amount                                                        114615
# Total Medical Medicare Allowed Amount                                                        114615
# Number of Medicare Beneficiaries With Medical Services                                       114615
# Number of Medical Services                                                                   114615
# Number of HCPCS Associated With Medical Services                                             114615
# Total Medical Submitted Charge Amount                                                        114615
# Total Drug Medicare Standardized Payment Amount                                              114615
# Total Drug Medicare Payment Amount                                                           114615
# Total Drug Medicare Allowed Amount                                                           114615
# Total Drug Submitted Charge Amount                                                           114615
# Number of Medicare Beneficiaries With Drug Services                                          114615
# Number of Drug Services                                                                      114615
# Number of HCPCS Associated With Drug Services                                                114615
# Number of Female Beneficiaries                                                               119076
# Number of Male Beneficiaries\t                                                               119076
# Percent (%) of Beneficiaries Identified With Diabetes                                        153787
# Percent (%) of Beneficiaries Identified With Depression                                      159878
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                          161529
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                          166924
# Number of Beneficiaries Age 65 to 74                                                         170775
# Percent (%) of Beneficiaries Identified With Heart Failure                                   271085
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                 273127
# Number of Beneficiaries With Medicare Only Entitlement                                       273127
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease           290376
# Number of Beneficiaries Age 75 to 84                                                         311179
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                             347276
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                 352428
# Number of Non-Hispanic White Beneficiaries\t                                                 352703
# Percent (%) of Beneficiaries Identified With Cancer                                          355683
# Middle Initial of the Provider                                                               359264
# Number of Beneficiaries Age Less 65                                                          384887
# Percent (%) of Beneficiaries Identified With Osteoporosis                                    407207
# Percent (%) of Beneficiaries Identified With Asthma                                          409771
# Number of Beneficiaries Age Greater 84                                                       448010
# Percent (%) of Beneficiaries Identified With Stroke                                          493378
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders       587585
# Street Address 2 of the Provider                                                             690983
# Number of Black or African American Beneficiaries                                            714694
# Number of American Indian/Alaska Native Beneficiaries                                        759384
# Number of Hispanic Beneficiaries                                                             799604
# Number of Asian Pacific Islander Beneficiaries                                               894513
# Number of Beneficiaries With Race Not Elsewhere Classified                                   913616
# Medical Suppress Indicator                                                                   974072
# Drug Suppress Indicator                                                                      974072

# %% [markdown]
# Looking at Row where Zip Code is Null

# %%
med.loc[med['Zip Code of the Provider'].isnull()]
# Out:
#         National Provider Identifier  \
# 641125                    1588870349
#
#        Last Name/Organization Name of the Provider First Name of the Provider  \
# 641125                                      WIXSON                     SANDRA
#
#        Middle Initial of the Provider Credentials of the Provider  \
# 641125                              J                       PH.D.
#
#        Gender of the Provider Entity Type of the Provider  \
# 641125                      F                           I
#
#        Street Address 1 of the Provider Street Address 2 of the Provider  \
# 641125            ROTUNDA 8, CASA # 163                            ULLOA
#
#        City of the Provider  ...  \
# 641125                ULLOA  ...
#
#        Percent (%) of Beneficiaries Identified With Depression  \
# 641125                                                    75.0
#
#         Percent (%) of Beneficiaries Identified With Diabetes  \
# 641125                                                    NaN
#
#        Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 641125                                                         NaN
#
#        Percent (%) of Beneficiaries Identified With Hypertension  \
# 641125                                                      75.0
#
#        Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 641125                                                                 NaN
#
#        Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 641125                                                       NaN
#
#         Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 641125                                                                                54.0
#
#         Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 641125                                                                                     NaN
#
#         Percent (%) of Beneficiaries Identified With Stroke  \
# 641125                                                  NaN
#
#         Average HCC Risk Score of Beneficiaries
# 641125                                   0.8013
#
# [1 rows x 71 columns]

# %% [markdown]
# Dropping this Column

# %%
idx = med.loc[med['Zip Code of the Provider'].isnull()].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Looking at Nulls Again

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})
info[info['null values']==0]
# Out:
#                                            data type  non-null values  \
# National Provider Identifier                   int64          1088686
# Entity Type of the Provider                   object          1088686
# Zip Code of the Provider                      object          1088686
# State Code of the Provider                    object          1088686
# Country Code of the Provider                  object          1088686
# Provider Type of the Provider                 object          1088686
# Medicare Participation Indicator              object          1088686
# Number of HCPCS                                int64          1088686
# Number of Services                           float64          1088686
# Number of Medicare Beneficiaries               int64          1088686
# Total Submitted Charge Amount                float64          1088686
# Total Medicare Allowed Amount                float64          1088686
# Total Medicare Payment Amount                float64          1088686
# Total Medicare Standardized Payment Amount   float64          1088686
# Average Age of Beneficiaries                   int64          1088686
# Average HCC Risk Score of Beneficiaries      float64          1088686
#
#                                             unique values  null values
# National Provider Identifier                      1088686            0
# Entity Type of the Provider                             2            0
# Zip Code of the Provider                           353453            0
# State Code of the Provider                             61            0
# Country Code of the Provider                           25            0
# Provider Type of the Provider                          95            0
# Medicare Participation Indicator                        2            0
# Number of HCPCS                                       483            0
# Number of Services                                  40322            0
# Number of Medicare Beneficiaries                     6970            0
# Total Submitted Charge Amount                      736392            0
# Total Medicare Allowed Amount                     1041227            0
# Total Medicare Payment Amount                     1026608            0
# Total Medicare Standardized Payment Amount        1027688            0
# Average Age of Beneficiaries                           86            0
# Average HCC Risk Score of Beneficiaries             46394            0

# %% [markdown]
# Dropping Rest of Cols that have null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (1088686, 71)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (1088686, 16)

# %%
med.columns
# Out:
# Index(['National Provider Identifier', 'Entity Type of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                 'Total Medicare Standardized Payment Amount':'total_medicare_standardized_payment',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charge Amount':'total_submitted_charges',
                 'Entity Type of the Provider':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['MD', 'IL', 'OH', 'PA', 'CO', 'FL', 'OK', 'CA', 'TX', 'OR', 'MN',
#        'KY', 'SC', 'ME', 'MO', 'NY', 'CT', 'MI', 'GA', 'NJ', 'LA', 'TN',
#        'MA', 'WA', 'AR', 'NH', 'DC', 'NC', 'NV', 'HI', 'MS', 'IA', 'VA',
#        'ND', 'IN', 'NE', 'AZ', 'AL', 'PR', 'DE', 'KS', 'RI', 'WI', 'ID',
#        'NM', 'MT', 'WV', 'VT', 'AE', 'UT', 'WY', 'SD', 'AP', 'AK', 'VI',
#        'GU', 'MP', 'AA', 'XX', 'AS'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country  \
# 27342   1023150414           I      21287    MP      US
# 67712   1063459428           I  969501908    MP      US
# 169936  1154508067           I      96950    MP      US
# 199996  1184653172           I      96950    MP      US
# 219448  1205091535           I      96950    MP      US
#
#                                  provider_type  \
# 27342                           Anesthesiology
# 67712                        Internal Medicine
# 169936  Physical Therapist in Private Practice
# 199996                         Family Practice
# 219448                     Physician Assistant
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 27342                                 Y               69               228.0
# 67712                                 Y               17              1558.0
# 169936                                Y               13              1002.0
# 199996                                Y               28              2754.0
# 219448                                Y               13               157.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 27342                   162                290603.00               52167.04
# 67712                   304                159910.30              151149.72
# 169936                   38                 31678.13               25075.51
# 199996                  273                273133.36              260977.48
# 219448                  111                 20312.45                7961.17
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 27342                 40462.18                             37400.29
# 67712                 88114.54                             91554.49
# 169936                18422.33                             17580.01
# 199996               182653.97                            195194.94
# 219448                 5960.24                              5993.91
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 27342                    71              1.8860
# 67712                    72              0.8520
# 169936                   69              0.9602
# 199996                   67              2.5160
# 219448                   66              3.4465

# %%
#this line was accidentally mislabeled with state "MP" instead of state "MD" in the Med DFs from most years
med.loc[med.npi == 1023150414, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     875140
# 5     115109
# 8      73244
# 4      12375
# 11      6596
# 7       3310
# 3       2082
# 10       637
# 6        102
# 2          2
# 1          2
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code full_zip state country  \
# 121154  1114060506           I        0    MA      US
# 347525  1316958416           I        0    XX      US
# 400032  1366672248           I       96    PR      US
# 724662  1669551479           I       80    PR      US
#
#                                         provider_type  \
# 121154                             Emergency Medicine
# 347525  Certified Registered Nurse Anesthetist (CRNA)
# 400032                                      Neurology
# 724662                                        Urology
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 121154                                Y               30              1622.0
# 347525                                Y               39               126.0
# 400032                                Y                6                67.0
# 724662                                Y               12               195.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 121154                  946                663715.00              169038.47
# 347525                  125                161405.00               18216.05
# 400032                   27                 11719.90               11719.90
# 724662                   77                 14742.98               14616.36
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 121154               130261.86                            128373.65
# 347525                14048.27                             13955.07
# 400032                 8796.86                              9888.65
# 724662                 9455.60                             11451.76
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 121154                   71              2.0972
# 347525                   71              1.4817
# 400032                   68              1.4510
# 724662                   75              1.4308

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country        provider_type  \
# 0  1003000126           I    21502    MD      US    Internal Medicine
# 1  1003006586           I    20832    MD      US    Internal Medicine
# 2  1003006800           I    21202    MD      US  Physician Assistant
# 3  1003007816           I    20910    MD      US        Ophthalmology
# 4  1003007824           I    21201    MD      US    Internal Medicine
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               23              1670.0
# 1                                Y               14              1480.0
# 2                                Y                8                37.0
# 3                                Y               28              2845.0
# 4                                Y               38               836.0
#
#    total_beneficiaries  ...  total_medicare_standardized_payment  \
# 0                  578  ...                            138279.12
# 1                  575  ...                            105457.74
# 2                   16  ...                              2301.46
# 3                  709  ...                            199510.67
# 4                  232  ...                             42719.15
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   75              2.1178                 2.89
# 1                   80              2.1172                 2.57
# 2                   69              0.9604                 2.31
# 3                   79              1.2566                 4.01
# 4                   66              2.6638                 3.60
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                      306.54                       237.17
# 1                      264.33                       202.08
# 2                      200.84                       149.06
# 3                      448.53                       320.18
# 4                      259.29                       189.48
#
#    submitted_charges_per_capita  State Code  Region        Division
# 0                       1385.55          MD   South  South Atlantic
# 1                        484.78          MD   South  South Atlantic
# 2                        572.65          MD   South  South Atlantic
# 3                        830.84          MD   South  South Atlantic
# 4                        387.56          MD   South  South Atlantic
#
# [5 rows x 23 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1082693 entries, 0 to 1082692
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   npi                                  1082693 non-null  int64
#  1   entity_code                          1082693 non-null  object
#  2   full_zip                             1082693 non-null  object
#  3   state                                1082693 non-null  object
#  4   country                              1082693 non-null  object
#  5   provider_type                        1082693 non-null  object
#  6   medicare_participation_indicator     1082693 non-null  object
#  7   number_of_hcpcs                      1082693 non-null  int64
#  8   number_of_services                   1082693 non-null  float64
#  9   total_beneficiaries                  1082693 non-null  int64
#  10  total_submitted_charges              1082693 non-null  float64
#  11  total_allowed_payment                1082693 non-null  float64
#  12  total_medicare_payment               1082693 non-null  float64
#  13  total_medicare_standardized_payment  1082693 non-null  float64
#  14  avg_beneficiary_age                  1082693 non-null  int64
#  15  avg_hcc_risk_score                   1082693 non-null  float64
#  16  services_per_capita                  1082693 non-null  float64
#  17  allowed_payment_per_capita           1082693 non-null  float64
#  18  medicare_payment_per_capita          1082693 non-null  float64
#  19  submitted_charges_per_capita         1082693 non-null  float64
#  20  region                               1082693 non-null  object
#  21  subregion                            1082693 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 190.0+ MB

# %%
med.to_csv('../../data/processed/final2017MEDICARE.csv')
