# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/processed/final2014MEDICARE.csv", index_col=0)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980332 entries, 0 to 980331
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   npi                                  980332 non-null  int64
#  1   entity_code                          980332 non-null  object
#  2   full_zip                             980332 non-null  int64
#  3   state                                980332 non-null  object
#  4   country                              980332 non-null  object
#  5   provider_type                        980332 non-null  object
#  6   medicare_participation_indicator     980332 non-null  object
#  7   number_of_hcpcs                      980332 non-null  int64
#  8   number_of_services                   980332 non-null  float64
#  9   total_beneficiaries                  980332 non-null  int64
#  10  total_submitted_charges              980332 non-null  float64
#  11  total_allowed_payment                980332 non-null  float64
#  12  total_medicare_payment               980332 non-null  float64
#  13  total_medicare_standardized_payment  980332 non-null  float64
#  14  avg_beneficiary_age                  980332 non-null  int64
#  15  avg_hcc_risk_score                   980332 non-null  float64
#  16  services_per_capita                  980332 non-null  float64
#  17  allowed_payment_per_capita           980332 non-null  float64
#  18  medicare_payment_per_capita          980332 non-null  float64
#  19  submitted_charges_per_capita         980332 non-null  float64
#  20  region                               980332 non-null  object
#  21  subregion                            980332 non-null  object
# dtypes: float64(10), int64(5), object(7)
# memory usage: 172.0+ MB

# %%
med.full_zip = med.full_zip.apply(lambda x: str(x).zfill(5))
med.npi = med.npi.astype('str')

# %%
med.head()
# Out:
#           npi entity_code full_zip state country          provider_type  \
# 0  1659374411           I    54601    WI      US     Allergy/Immunology
# 1  1487623633           I    53717    WI      US     Nurse Practitioner
# 2  1598700387           I    53132    WI      US           Rheumatology
# 3  1346490323           I    54935    WI      US  Obstetrics/Gynecology
# 4  1861570996           I    54301    WI      US  Obstetrics/Gynecology
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y                8                42.0
# 1                                Y                7                38.0
# 2                                Y                8                89.0
# 3                                Y               19               801.0
# 4                                Y               32               542.0
#
#    total_beneficiaries  ...  total_medicare_payment  \
# 0                   14  ...                 1470.57
# 1                   26  ...                 1002.52
# 2                   13  ...                 2726.29
# 3                   22  ...                 2670.36
# 4                   35  ...                 1980.31
#
#    total_medicare_standardized_payment  avg_beneficiary_age  \
# 0                              1550.48                   59
# 1                              1266.85                   70
# 2                              2798.53                   69
# 3                              2698.17                   55
# 4                              2060.33                   64
#
#    avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 0              1.1238                 3.00                      154.31
# 1              1.0511                 1.46                       55.26
# 2              1.0231                 6.85                      274.97
# 3              1.1173                36.41                      163.36
# 4              0.4507                15.49                       73.11
#
#    medicare_payment_per_capita  submitted_charges_per_capita   region  \
# 0                       105.04                        348.93  Midwest
# 1                        38.56                        216.31  Midwest
# 2                       209.71                        719.36  Midwest
# 3                       121.38                        584.68  Midwest
# 4                        56.58                        208.86  Midwest
#
#             subregion
# 0  East North Central
# 1  East North Central
# 2  East North Central
# 3  East North Central
# 4  East North Central
#
# [5 rows x 22 columns]

# %% [markdown]
# Checkpoint 1

# %%
checkpoint1 = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
census = pd.read_csv('../../data/raw/2014acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   20899                   131                  0
# 1   70803                   102                  0
# 2   40041                   142                  0
# 3   95646                    23                  0
# 4   61112                   100                  0
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1985.0                         0
# 1                       1996.0                        27
# 2                       1939.0                         0
# 3                       1991.0                         5
# 4                       2001.0                         9
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                    39                      8                     41
# 1                    44                      0                      0
# 2                    44                     66                      0
# 3                    12                      0                      0
# 4                    56                      9                      0
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                     34  ...
# 1                      0                     11  ...
# 2                     11                     10  ...
# 3                      0                      0  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          32                      8
# 1                         955                     31
# 2                         277                      0
# 3                          77                     16
# 4                         100                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              131                 17
# 1                                  4             1010               1005
# 2                                  0              277                 40
# 3                                 10               98                 87
# 4                                  0              100                 10
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0                9             24            0            23  20102014
# 1                5              0            0             0  20102014
# 2               10              0          196            24  20102014
# 3                8              0            0             3  20102014
# 4                0              0           81             9  20102014
#
# [5 rows x 252 columns]

# %% [markdown]
# checkpoint2

# %%
checkpoint2 = census.copy()

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          20157
# percent_income_spent_on_rent                                           27690
# median_rent                                                            27725
# renter_occupied_housing_units_paying_cash_median_gross_rent            27738
# owner_occupied_housing_units_upper_value_quartile                      31607
# owner_occupied_housing_units_lower_value_quartile                      31607
# owner_occupied_housing_units_median_value                              31607
# median_income                                                          32008
# median_year_structure_built                                            32204
# gini_index                                                             32255
# income_per_capita                                                      32571
# median_age                                                             32614
# some_college_and_associates_degree                                     32989
# not_us_citizen_pop                                                     32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# less_than_high_school_graduate                                         32989
# different_house_year_ago_different_city                                32989
# graduate_professional_degree                                           32989
# bachelors_degree_2                                                     32989
# high_school_including_ged                                              32989
# commuters_drove_alone                                                  33120
# commuters_by_carpool                                                   33120
# commuters_by_subway_or_elevated                                        33120
# employed_finance_insurance_real_estate                                 33120
# employed_arts_entertainment_recreation_accommodation_food              33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# employed_information                                                   33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16959
# percent_income_spent_on_rent                                           399
# median_rent                                                           1703
# renter_occupied_housing_units_paying_cash_median_gross_rent           1678
# owner_occupied_housing_units_upper_value_quartile                     5870
# owner_occupied_housing_units_lower_value_quartile                     4091
# owner_occupied_housing_units_median_value                             4992
# median_income                                                        19805
# median_year_structure_built                                             71
# gini_index                                                            4097
# income_per_capita                                                    20265
# median_age                                                             652
# some_college_and_associates_degree                                    7440
# not_us_citizen_pop                                                    4186
# different_house_year_ago_same_city                                    3668
# population_1_year_and_over                                           15365
# less_than_high_school_graduate                                        4646
# different_house_year_ago_different_city                               4819
# graduate_professional_degree                                          4404
# bachelors_degree_2                                                    5885
# high_school_including_ged                                             7137
# commuters_drove_alone                                                10011
# commuters_by_carpool                                                  2874
# commuters_by_subway_or_elevated                                        880
# employed_finance_insurance_real_estate                                2361
# employed_arts_entertainment_recreation_accommodation_food             2944
# employed_construction                                                 2051
# employed_education_health_social                                      5226
# commuters_by_car_truck_van                                           10614
# employed_information                                                  1088
#
#                                                              null values
# aggregate_travel_time_to_work                                      12963
# percent_income_spent_on_rent                                        5430
# median_rent                                                         5395
# renter_occupied_housing_units_paying_cash_median_gross_rent         5382
# owner_occupied_housing_units_upper_value_quartile                   1513
# owner_occupied_housing_units_lower_value_quartile                   1513
# owner_occupied_housing_units_median_value                           1513
# median_income                                                       1112
# median_year_structure_built                                          916
# gini_index                                                           865
# income_per_capita                                                    549
# median_age                                                           506
# some_college_and_associates_degree                                   131
# not_us_citizen_pop                                                   131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# less_than_high_school_graduate                                       131
# different_house_year_ago_different_city                              131
# graduate_professional_degree                                         131
# bachelors_degree_2                                                   131
# high_school_including_ged                                            131
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Looking to see if any Medicare zip codes are missing from Census DF

# %%
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))

# %%
med[med.full_zip.isin(census.geo_id)].shape, med[~med.full_zip.isin(census.geo_id)].shape
# Out:
# ((952799, 22), (27533, 22))

# %%
pd.options.display.max_rows = 120
med[
    ~med.full_zip.isin(census.geo_id)].head()
# Out:
#              npi entity_code full_zip state country          provider_type  \
# 102   1457468068           I    54308    WI      US  Obstetrics/Gynecology
# 170   1952418824           I    54308    WI      US  Obstetrics/Gynecology
# 412   1881701316           I    54308    WI      US  Obstetrics/Gynecology
# 497   1588779581           I    54308    WI      US  Obstetrics/Gynecology
# 1024  1932118601           I    54308    WI      US  Obstetrics/Gynecology
#
#      medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 102                                 Y               27               216.0
# 170                                 Y               32               100.0
# 412                                 Y               29               669.0
# 497                                 Y               35               101.0
# 1024                                Y               24               807.0
#
#       total_beneficiaries  ...  total_medicare_payment  \
# 102                    22  ...                 6398.57
# 170                    37  ...                 7029.97
# 412                    21  ...                 2928.44
# 497                    46  ...                 7384.61
# 1024                   23  ...                 4811.65
#
#       total_medicare_standardized_payment  avg_beneficiary_age  \
# 102                               6913.09                   58
# 170                               7454.35                   53
# 412                               4234.50                   51
# 497                               7777.08                   56
# 1024                              5089.04                   57
#
#       avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 102               1.2939                 9.82                      389.51
# 170               0.8637                 2.70                      254.63
# 412               0.7052                31.86                      225.83
# 497               0.7763                 2.20                      207.06
# 1024              0.7138                35.09                      268.96
#
#       medicare_payment_per_capita  submitted_charges_per_capita   region  \
# 102                        290.84                       2204.18  Midwest
# 170                        190.00                       2230.47  Midwest
# 412                        139.45                       1000.14  Midwest
# 497                        160.54                       3457.57  Midwest
# 1024                       209.20                       1204.26  Midwest
#
#                subregion
# 102   East North Central
# 170   East North Central
# 412   East North Central
# 497   East North Central
# 1024  East North Central
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### Many are PO Boxes. Some are hospitals with their own zip codes. I want to drop these rows from Med, looking at how much of my data this will remove:

# %%
print(' Total providers in Med df:',med.shape[0],
     '\n Total beneficiaries in Med df:', med.total_beneficiaries.sum(),
     '\n Total providers whose zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].shape[0],
     '\n Total beneficiaries in Med in zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum(),
     '\n Percent providers with missing zips of all providers:',
                          round(med[~med.full_zip.isin(census.geo_id)].shape[0] \
                          / med.shape[0] * 100, 2),  '%',
     '\n Percent beneficiaries in missing zips of all beneficiaries:',
                          round(med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum() \
                          / med.total_beneficiaries.sum() * 100,2),  '%')
# Out:
#  Total providers in Med df: 980332
#  Total beneficiaries in Med df: 362857029
#  Total providers whose zips not in Census: 27533
#  Total beneficiaries in Med in zips not in Census: 9151786
#  Percent providers with missing zips of all providers: 2.81 %
#  Percent beneficiaries in missing zips of all beneficiaries: 2.52 %

# %%
idx = med[~med['full_zip'].isin(census.geo_id)].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Dropping Rows from Census that don't appear in Medicare DF

# %%
print(census.shape)
idx = census[~census.geo_id.isin(med.full_zip)].index
census.drop(index = idx, inplace = True)
print(census.shape)
# Out:
# (33120, 252)
# (19359, 252)

# %%
med.full_zip.nunique()
# Out:
# 19359

# %% [markdown]
# Examining Nulls

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_year_structure_built                                   float64
# median_income                                                 float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          16289
# percent_income_spent_on_rent                                           18769
# median_rent                                                            18770
# renter_occupied_housing_units_paying_cash_median_gross_rent            18771
# owner_occupied_housing_units_upper_value_quartile                      18995
# owner_occupied_housing_units_lower_value_quartile                      18995
# owner_occupied_housing_units_median_value                              18995
# median_year_structure_built                                            19125
# median_income                                                          19126
# gini_index                                                             19139
# income_per_capita                                                      19286
# median_age                                                             19288
# some_college_and_associates_degree                                     19356
# not_us_citizen_pop                                                     19356
# different_house_year_ago_same_city                                     19356
# population_1_year_and_over                                             19356
# less_than_high_school_graduate                                         19356
# different_house_year_ago_different_city                                19356
# graduate_professional_degree                                           19356
# bachelors_degree_2                                                     19356
# high_school_including_ged                                              19356
# commuters_drove_alone                                                  19359
# commuters_by_carpool                                                   19359
# commuters_by_subway_or_elevated                                        19359
# employed_finance_insurance_real_estate                                 19359
# employed_arts_entertainment_recreation_accommodation_food              19359
# employed_construction                                                  19359
# employed_education_health_social                                       19359
# commuters_by_car_truck_van                                             19359
# employed_information                                                   19359
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        14664
# percent_income_spent_on_rent                                           388
# median_rent                                                           1647
# renter_occupied_housing_units_paying_cash_median_gross_rent           1601
# owner_occupied_housing_units_upper_value_quartile                     5273
# owner_occupied_housing_units_lower_value_quartile                     3877
# owner_occupied_housing_units_median_value                             4577
# median_year_structure_built                                             70
# median_income                                                        15408
# gini_index                                                            2853
# income_per_capita                                                    14440
# median_age                                                             513
# some_college_and_associates_degree                                    7415
# not_us_citizen_pop                                                    4163
# different_house_year_ago_same_city                                    3664
# population_1_year_and_over                                           14367
# less_than_high_school_graduate                                        4635
# different_house_year_ago_different_city                               4812
# graduate_professional_degree                                          4403
# bachelors_degree_2                                                    5882
# high_school_including_ged                                             7117
# commuters_drove_alone                                                 9889
# commuters_by_carpool                                                  2868
# commuters_by_subway_or_elevated                                        875
# employed_finance_insurance_real_estate                                2356
# employed_arts_entertainment_recreation_accommodation_food             2941
# employed_construction                                                 2049
# employed_education_health_social                                      5203
# commuters_by_car_truck_van                                           10434
# employed_information                                                  1086
#
#                                                              null values
# aggregate_travel_time_to_work                                       3070
# percent_income_spent_on_rent                                         590
# median_rent                                                          589
# renter_occupied_housing_units_paying_cash_median_gross_rent          588
# owner_occupied_housing_units_upper_value_quartile                    364
# owner_occupied_housing_units_lower_value_quartile                    364
# owner_occupied_housing_units_median_value                            364
# median_year_structure_built                                          234
# median_income                                                        233
# gini_index                                                           220
# income_per_capita                                                     73
# median_age                                                            71
# some_college_and_associates_degree                                     3
# not_us_citizen_pop                                                     3
# different_house_year_ago_same_city                                     3
# population_1_year_and_over                                             3
# less_than_high_school_graduate                                         3
# different_house_year_ago_different_city                                3
# graduate_professional_degree                                           3
# bachelors_degree_2                                                     3
# high_school_including_ged                                              3
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Some of these columns are irrelevant or are redundant.

# %%
#there are other cols that speak to Commute to work
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# percent_income_spent_on_rent                                float64
# median_rent                                                 float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# less_than_high_school_graduate                              float64
# different_house_year_ago_same_city                          float64
# different_house_year_ago_different_city                     float64
# not_us_citizen_pop                                          float64
# bachelors_degree_2                                          float64
# high_school_including_ged                                   float64
# population_1_year_and_over                                  float64
# some_college_and_associates_degree                          float64
# graduate_professional_degree                                float64
# civilian_labor_force                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# black_including_hispanic                                      int64
# white_including_hispanic                                      int64
# female_85_and_over                                            int64
# employed_agriculture_forestry_fishing_hunting_mining          int64
# employed_arts_entertainment_recreation_accommodation_food     int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# commuters_by_carpool                                          int64
# employed_information                                          int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
#
#                                                            non-null values  \
# percent_income_spent_on_rent                                         18769
# median_rent                                                          18770
# median_income                                                        19126
# gini_index                                                           19139
# income_per_capita                                                    19286
# median_age                                                           19288
# less_than_high_school_graduate                                       19356
# different_house_year_ago_same_city                                   19356
# different_house_year_ago_different_city                              19356
# not_us_citizen_pop                                                   19356
# bachelors_degree_2                                                   19356
# high_school_including_ged                                            19356
# population_1_year_and_over                                           19356
# some_college_and_associates_degree                                   19356
# graduate_professional_degree                                         19356
# civilian_labor_force                                                 19359
# commuters_by_subway_or_elevated                                      19359
# commuters_drove_alone                                                19359
# black_including_hispanic                                             19359
# white_including_hispanic                                             19359
# female_85_and_over                                                   19359
# employed_agriculture_forestry_fishing_hunting_mining                 19359
# employed_arts_entertainment_recreation_accommodation_food            19359
# employed_construction                                                19359
# employed_education_health_social                                     19359
# employed_finance_insurance_real_estate                               19359
# commuters_by_carpool                                                 19359
# employed_information                                                 19359
# employed_other_services_not_public_admin                             19359
# employed_public_administration                                       19359
#
#                                                            unique values  \
# percent_income_spent_on_rent                                         388
# median_rent                                                         1647
# median_income                                                      15408
# gini_index                                                          2853
# income_per_capita                                                  14440
# median_age                                                           513
# less_than_high_school_graduate                                      4635
# different_house_year_ago_same_city                                  3664
# different_house_year_ago_different_city                             4812
# not_us_citizen_pop                                                  4163
# bachelors_degree_2                                                  5882
# high_school_including_ged                                           7117
# population_1_year_and_over                                         14367
# some_college_and_associates_degree                                  7415
# graduate_professional_degree                                        4403
# civilian_labor_force                                               11567
# commuters_by_subway_or_elevated                                      875
# commuters_drove_alone                                               9889
# black_including_hispanic                                            5296
# white_including_hispanic                                           13366
# female_85_and_over                                                  1089
# employed_agriculture_forestry_fishing_hunting_mining                 991
# employed_arts_entertainment_recreation_accommodation_food           2941
# employed_construction                                               2049
# employed_education_health_social                                    5203
# employed_finance_insurance_real_estate                              2356
# commuters_by_carpool                                                2868
# employed_information                                                1086
# employed_other_services_not_public_admin                            1742
# employed_public_administration                                      1848
#
#                                                            null values
# percent_income_spent_on_rent                                       590
# median_rent                                                        589
# median_income                                                      233
# gini_index                                                         220
# income_per_capita                                                   73
# median_age                                                          71
# less_than_high_school_graduate                                       3
# different_house_year_ago_same_city                                   3
# different_house_year_ago_different_city                              3
# not_us_citizen_pop                                                   3
# bachelors_degree_2                                                   3
# high_school_including_ged                                            3
# population_1_year_and_over                                           3
# some_college_and_associates_degree                                   3
# graduate_professional_degree                                         3
# civilian_labor_force                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# black_including_hispanic                                             0
# white_including_hispanic                                             0
# female_85_and_over                                                   0
# employed_agriculture_forestry_fishing_hunting_mining                 0
# employed_arts_entertainment_recreation_accommodation_food            0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# commuters_by_carpool                                                 0
# employed_information                                                 0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0

# %%
# Let's look at rows in Medicare with zips that have nulls in Census.graduate_professional_degree
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
med[med.full_zip.isin(null_zips)]
# Out:
# Empty DataFrame
# Columns: [npi, entity_code, full_zip, state, country, provider_type, medicare_participation_indicator, number_of_hcpcs, number_of_services, total_beneficiaries, total_submitted_charges, total_allowed_payment, total_medicare_payment, total_medicare_standardized_payment, avg_beneficiary_age, avg_hcc_risk_score, services_per_capita, allowed_payment_per_capita, medicare_payment_per_capita, submitted_charges_per_capita, region, subregion]
# Index: []
#
# [0 rows x 22 columns]

# %%
# The second row has a typo in Full_zip, should be 60617
med.loc[
    med[med.npi == '1750491288'].index, 'full_zip'] = '60617'

#Droppping other two rows from DF
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
idx = med[med.full_zip.isin(null_zips)].index
med.drop(index = idx, inplace=True)

# %%
#Dropping these zips from Census 
census = census[census.graduate_professional_degree.notnull()]

# %% [markdown]
# ##### REEXAMINING CENSUS NULLS

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# percent_income_spent_on_rent                                float64
# median_rent                                                 float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# employed_transportation_warehousing_utilities                 int64
# bachelors_degree_or_higher_25_64                              int64
# children                                                      int64
# graduate_professional_degree                                float64
# four_more_cars                                                int64
# children_in_single_female_hh                                  int64
# commuters_by_bus                                              int64
# commuters_by_car_truck_van                                    int64
# commuters_by_carpool                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# different_house_year_ago_different_city                     float64
# employed_wholesale_trade                                      int64
# different_house_year_ago_same_city                          float64
# employed_arts_entertainment_recreation_accommodation_food     int64
# female_female_households                                      int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# employed_information                                          int64
# employed_manufacturing                                        int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
# employed_retail_trade                                         int64
#
#                                                            non-null values  \
# percent_income_spent_on_rent                                         18767
# median_rent                                                          18768
# median_income                                                        19124
# gini_index                                                           19137
# income_per_capita                                                    19283
# median_age                                                           19285
# employed_transportation_warehousing_utilities                        19356
# bachelors_degree_or_higher_25_64                                     19356
# children                                                             19356
# graduate_professional_degree                                         19356
# four_more_cars                                                       19356
# children_in_single_female_hh                                         19356
# commuters_by_bus                                                     19356
# commuters_by_car_truck_van                                           19356
# commuters_by_carpool                                                 19356
# commuters_by_subway_or_elevated                                      19356
# commuters_drove_alone                                                19356
# different_house_year_ago_different_city                              19356
# employed_wholesale_trade                                             19356
# different_house_year_ago_same_city                                   19356
# employed_arts_entertainment_recreation_accommodation_food            19356
# female_female_households                                             19356
# employed_construction                                                19356
# employed_education_health_social                                     19356
# employed_finance_insurance_real_estate                               19356
# employed_information                                                 19356
# employed_manufacturing                                               19356
# employed_other_services_not_public_admin                             19356
# employed_public_administration                                       19356
# employed_retail_trade                                                19356
#
#                                                            unique values  \
# percent_income_spent_on_rent                                         388
# median_rent                                                         1647
# median_income                                                      15406
# gini_index                                                          2853
# income_per_capita                                                  14438
# median_age                                                           513
# employed_transportation_warehousing_utilities                       1803
# bachelors_degree_or_higher_25_64                                    6842
# children                                                            8166
# graduate_professional_degree                                        4403
# four_more_cars                                                      1577
# children_in_single_female_hh                                        3814
# commuters_by_bus                                                    1627
# commuters_by_car_truck_van                                         10434
# commuters_by_carpool                                                2868
# commuters_by_subway_or_elevated                                      875
# commuters_drove_alone                                               9888
# different_house_year_ago_different_city                             4812
# employed_wholesale_trade                                            1193
# different_house_year_ago_same_city                                  3664
# employed_arts_entertainment_recreation_accommodation_food           2941
# female_female_households                                             201
# employed_construction                                               2049
# employed_education_health_social                                    5203
# employed_finance_insurance_real_estate                              2356
# employed_information                                                1086
# employed_manufacturing                                              3025
# employed_other_services_not_public_admin                            1742
# employed_public_administration                                      1848
# employed_retail_trade                                               3222
#
#                                                            null values
# percent_income_spent_on_rent                                       589
# median_rent                                                        588
# median_income                                                      232
# gini_index                                                         219
# income_per_capita                                                   73
# median_age                                                          71
# employed_transportation_warehousing_utilities                        0
# bachelors_degree_or_higher_25_64                                     0
# children                                                             0
# graduate_professional_degree                                         0
# four_more_cars                                                       0
# children_in_single_female_hh                                         0
# commuters_by_bus                                                     0
# commuters_by_car_truck_van                                           0
# commuters_by_carpool                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# different_house_year_ago_different_city                              0
# employed_wholesale_trade                                             0
# different_house_year_ago_same_city                                   0
# employed_arts_entertainment_recreation_accommodation_food            0
# female_female_households                                             0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# employed_information                                                 0
# employed_manufacturing                                               0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0
# employed_retail_trade                                                0

# %% [markdown]
# The remaining columns with nulls are important, but I know that other columns in the DF, have some information related to rent, income, and age.

# %%
census.columns[census.columns.str.contains('_rent$|^rent_|_rent_', regex=True)]
# Out:
# Index(['rent_burden_not_computed', 'rent_over_50_percent',
#        'rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'rent_under_10_percent',
#        'vacant_housing_units_for_rent', 'median_rent',
#        'percent_income_spent_on_rent'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('income')]
# Out:
# Index(['median_income', 'income_per_capita', 'percent_income_spent_on_rent',
#        'income_less_10000', 'income_10000_14999', 'income_15000_19999',
#        'income_20000_24999', 'income_25000_29999', 'income_30000_34999',
#        'income_35000_39999', 'income_40000_44999', 'income_45000_49999',
#        'income_50000_59999', 'income_60000_74999', 'income_75000_99999',
#        'income_100000_124999', 'income_125000_149999', 'income_150000_199999',
#        'income_200000_or_more', 'households_retirement_income'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('(?=.*male)(?=.*_to_)', regex=True)]
# Out:
# Index(['male_5_to_9', 'male_10_to_14', 'male_15_to_17', 'male_18_to_19',
#        'male_22_to_24', 'male_25_to_29', 'male_30_to_34', 'male_35_to_39',
#        'male_40_to_44', 'male_45_to_49', 'male_50_to_54', 'male_55_to_59',
#        'male_65_to_66', 'male_67_to_69', 'male_70_to_74', 'male_75_to_79',
#        'male_80_to_84', 'female_5_to_9', 'female_10_to_14', 'female_15_to_17',
#        'female_18_to_19', 'female_22_to_24', 'female_25_to_29',
#        'female_30_to_34', 'female_35_to_39', 'female_40_to_44',
#        'female_45_to_49', 'female_50_to_54', 'female_55_to_59',
#        'female_60_to_61', 'female_62_to_64', 'female_65_to_66',
#        'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
#        'female_80_to_84', 'male_45_to_64'],
#       dtype='object')

# %%
info[info['null values']>0].index
# Out:
# Index(['median_age', 'median_income', 'income_per_capita', 'median_rent',
#        'percent_income_spent_on_rent', 'gini_index'],
#       dtype='object')

# %% [markdown]
# While these factors are probably very relevant to the number of providers in a zip code, the health risk score, and the use of different providers, it seems there are other features in Census DF that may also address income, rent, and age.

# %%
#dropping these cols with nulls
cols = info[info['null values']>0].index
census.drop(columns = cols, inplace=True)

# %% [markdown]
# # Checking Data Types

# %% [markdown]
# All columns in Census besides Geo_id should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
#   geo_id
# 1  70803

# %% [markdown]
# There's a column called do_date that includes the years used to make the estimate Census measures. I'm going to keep that last four digits which represent the year being estimated.

# %%
census.do_date = census.do_date.apply(lambda x: str(x)[-4:])
census.do_date = pd.to_datetime(census.do_date, format='%Y')
census.do_date
# Out:
# 1       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# 7       2014-01-01
# 8       2014-01-01
#            ...
# 33080   2014-01-01
# 33087   2014-01-01
# 33097   2014-01-01
# 33107   2014-01-01
# 33118   2014-01-01
# Name: do_date, Length: 19356, dtype: datetime64[ns]

# %%
census.isnull().sum().sort_values()
# Out:
# geo_id                          0
# children                        0
# children_in_single_female_hh    0
# commuters_by_bus                0
# commuters_by_car_truck_van      0
#                                ..
# male_21                         0
# male_22_to_24                   0
# male_25_to_29                   0
# pop_divorced                    0
# do_date                         0
# Length: 240, dtype: int64

# %%
med.to_csv('../../data/processed/final2014MEDICARE.csv')
census.to_csv('../../data/processed/final2014CENSUS.csv')
