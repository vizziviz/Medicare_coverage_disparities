# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2014.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (986677, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1659374411                                        MAHR
# 1                    1073738571                                        GIBB
# 2                    1619972387                                        DEEM
# 3                    1265649073                                      GAMBLE
# 4                    1366640377                                       DIRKS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                       TODD                              A
# 1                      JOYCE                              E
# 2                     ROBERT                              B
# 3                      SARAH                              M
# 4                    ZACHARY                              B
#
#   Credentials of the Provider Gender of the Provider  \
# 0                          MD                      M
# 1                        CRNP                      F
# 2                        M.D.                      M
# 3                          DO                      F
# 4                        O.D.                      M
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                   1836 SOUTH AVE
# 1                           I                215 ALLEGHENY AVE
# 2                           I                 1549 S JEFFERSON
# 3                           I                 222 RAILROAD AVE
# 4                           I                   320 SUNRISE DR
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN            LA CROSSE  ...
# 1                              NaN              OAKMONT  ...
# 2                              NaN           MONTICELLO  ...
# 3                          SUITE B            GREENWICH  ...
# 4                              NaN          SAINT PETER  ...
#
#   Percent (%) of Beneficiaries Identified With Depression   \
# 0                                                NaN
# 1                                               37.0
# 2                                                NaN
# 3                                                NaN
# 4                                               22.0
#
#   Percent (%) of Beneficiaries Identified With Diabetes   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               26.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               32.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension   \
# 0                                                NaN
# 1                                               57.0
# 2                                                NaN
# 3                                                NaN
# 4                                               34.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               12.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis   \
# 0                                                NaN
# 1                                               37.0
# 2                                                NaN
# 3                                                NaN
# 4                                               17.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.0
# 4                                               27.0
#
#    Percent (%) of Beneficiaries Identified With Stroke   \
# 0                                                0.0
# 1                                                NaN
# 2                                                0.0
# 3                                                0.0
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                    1.1238
# 1                                    0.9576
# 2                                    0.6467
# 3                                    0.9607
# 4                                    0.9950
#
# [5 rows x 70 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount ',
#        'Total Drug Medicare Payment Amount ',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#        'Percent (%) of Beneficiaries Identified With Asthma ',
#        'Percent (%) of Beneficiaries Identified With Cancer ',
#        'Percent (%) of Beneficiaries Identified With Heart Failure ',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Diabetes ',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#        'Percent (%) of Beneficiaries Identified With Hypertension ',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Percent (%) of Beneficiaries Identified With Stroke ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                         data type  \
# National Provider Identifier                                                                int64
# Average Age of Beneficiaries                                                                int64
# Total Medicare Standardized Payment Amount                                                float64
# Total Medicare Payment Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Submitted Charge Amount                                                             float64
# Number of Medicare Beneficiaries                                                            int64
# Number of Services                                                                        float64
# Number of HCPCS                                                                             int64
# Medicare Participation Indicator                                                           object
# Provider Type of the Provider                                                              object
# Country Code of the Provider                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
# Zip Code of the Provider                                                                   object
# Entity Type of the Provider                                                                object
# State Code of the Provider                                                                 object
# City of the Provider                                                                       object
# Street Address 1 of the Provider                                                           object
# Last Name/Organization Name of the Provider                                                object
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Gender of the Provider                                                                     object
# First Name of the Provider                                                                 object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Credentials of the Provider                                                                object
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Medical Submitted Charge Amount                                                     float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Number of Male Beneficiaries                                                              float64
# Number of Female Beneficiaries                                                            float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Number of Beneficiaries Age 65 to 74                                                      float64
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Number of Beneficiaries Age 75 to 84                                                      float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Number of Beneficiaries Age Less 65                                                       float64
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Number of Non-Hispanic White Beneficiaries                                                float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Number of Beneficiaries Age Greater 84                                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Street Address 2 of the Provider                                                           object
# Number of Black or African American Beneficiaries                                         float64
# Number of American Indian/Alaska Native Beneficiaries                                     float64
# Number of Hispanic Beneficiaries                                                          float64
# Number of Asian Pacific Islander Beneficiaries                                            float64
# Number of Beneficiaries With Race Not Elsewhere Classified                                float64
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
#
#                                                                                          non-null values  \
# National Provider Identifier                                                                      986677
# Average Age of Beneficiaries                                                                      986677
# Total Medicare Standardized Payment Amount                                                        986677
# Total Medicare Payment Amount                                                                     986677
# Total Medicare Allowed Amount                                                                     986677
# Total Submitted Charge Amount                                                                     986677
# Number of Medicare Beneficiaries                                                                  986677
# Number of Services                                                                                986677
# Number of HCPCS                                                                                   986677
# Medicare Participation Indicator                                                                  986677
# Provider Type of the Provider                                                                     986677
# Country Code of the Provider                                                                      986677
# Average HCC Risk Score of Beneficiaries                                                           986677
# Zip Code of the Provider                                                                          986677
# Entity Type of the Provider                                                                       986677
# State Code of the Provider                                                                        986677
# City of the Provider                                                                              986676
# Street Address 1 of the Provider                                                                  986676
# Last Name/Organization Name of the Provider                                                       986658
# Percent (%) of Beneficiaries Identified With Hypertension                                         934284
# Gender of the Provider                                                                            925347
# First Name of the Provider                                                                        925340
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       913013
# Credentials of the Provider                                                                       896152
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                884690
# Total Medical Medicare Standardized Payment Amount                                                883567
# Total Medical Medicare Payment Amount                                                             883567
# Total Medical Medicare Allowed Amount                                                             883567
# Number of Medicare Beneficiaries With Medical Services                                            883567
# Number of Medical Services                                                                        883567
# Number of HCPCS Associated With Medical Services                                                  883567
# Total Medical Submitted Charge Amount                                                             883567
# Total Drug Medicare Standardized Payment Amount                                                   883567
# Total Drug Medicare Payment Amount                                                                883567
# Total Drug Medicare Allowed Amount                                                                883567
# Total Drug Submitted Charge Amount                                                                883567
# Number of Medicare Beneficiaries With Drug Services                                               883567
# Number of Drug Services                                                                           883567
# Number of HCPCS Associated With Drug Services                                                     883567
# Number of Male Beneficiaries                                                                      880912
# Number of Female Beneficiaries                                                                    880912
# Percent (%) of Beneficiaries Identified With Diabetes                                             847364
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               841621
# Number of Beneficiaries Age 65 to 74                                                              829408
# Percent (%) of Beneficiaries Identified With Depression                                           827752
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               779805
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      746461
# Number of Beneficiaries With Medicare Only Entitlement                                            746461
# Percent (%) of Beneficiaries Identified With Heart Failure                                        738805
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                717417
# Number of Beneficiaries Age 75 to 84                                                              709781
# Middle Initial of the Provider                                                                    691434
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  669718
# Number of Beneficiaries Age Less 65                                                               666771
# Percent (%) of Beneficiaries Identified With Cancer                                               662693
# Number of Non-Hispanic White Beneficiaries                                                        652953
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      646699
# Percent (%) of Beneficiaries Identified With Asthma                                               622619
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         617374
# Number of Beneficiaries Age Greater 84                                                            600810
# Percent (%) of Beneficiaries Identified With Stroke                                               546038
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            516824
# Street Address 2 of the Provider                                                                  402131
# Number of Black or African American Beneficiaries                                                 332052
# Number of American Indian/Alaska Native Beneficiaries                                             280989
# Number of Hispanic Beneficiaries                                                                  259655
# Number of Asian Pacific Islander Beneficiaries                                                    170994
# Number of Beneficiaries With Race Not Elsewhere Classified                                        135926
# Medical Suppress Indicator                                                                        103110
# Drug Suppress Indicator                                                                           103110
#
#                                                                                          unique values  \
# National Provider Identifier                                                                    986677
# Average Age of Beneficiaries                                                                        86
# Total Medicare Standardized Payment Amount                                                      936734
# Total Medicare Payment Amount                                                                   935495
# Total Medicare Allowed Amount                                                                   947608
# Total Submitted Charge Amount                                                                   677764
# Number of Medicare Beneficiaries                                                                  6745
# Number of Services                                                                               38579
# Number of HCPCS                                                                                    494
# Medicare Participation Indicator                                                                     2
# Provider Type of the Provider                                                                       91
# Country Code of the Provider                                                                        25
# Average HCC Risk Score of Beneficiaries                                                          42203
# Zip Code of the Provider                                                                        333008
# Entity Type of the Provider                                                                          2
# State Code of the Provider                                                                          61
# City of the Provider                                                                             12974
# Street Address 1 of the Provider                                                                340123
# Last Name/Organization Name of the Provider                                                     247429
# Percent (%) of Beneficiaries Identified With Hypertension                                           66
# Gender of the Provider                                                                               2
# First Name of the Provider                                                                       61360
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         70
# Credentials of the Provider                                                                      15075
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  73
# Total Medical Medicare Standardized Payment Amount                                              821100
# Total Medical Medicare Payment Amount                                                           836480
# Total Medical Medicare Allowed Amount                                                           846167
# Number of Medicare Beneficiaries With Medical Services                                            6670
# Number of Medical Services                                                                       25708
# Number of HCPCS Associated With Medical Services                                                   487
# Total Medical Submitted Charge Amount                                                           602072
# Total Drug Medicare Standardized Payment Amount                                                 213459
# Total Drug Medicare Payment Amount                                                              213453
# Total Drug Medicare Allowed Amount                                                              216110
# Total Drug Submitted Charge Amount                                                              140684
# Number of Medicare Beneficiaries With Drug Services                                               1213
# Number of Drug Services                                                                          20893
# Number of HCPCS Associated With Drug Services                                                      112
# Number of Male Beneficiaries                                                                      3579
# Number of Female Beneficiaries                                                                    4732
# Percent (%) of Beneficiaries Identified With Diabetes                                               72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 74
# Number of Beneficiaries Age 65 to 74                                                              3324
# Percent (%) of Beneficiaries Identified With Depression                                             75
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 73
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      3074
# Number of Beneficiaries With Medicare Only Entitlement                                            5461
# Percent (%) of Beneficiaries Identified With Heart Failure                                          76
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  76
# Number of Beneficiaries Age 75 to 84                                                              2861
# Middle Initial of the Provider                                                                      32
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    76
# Number of Beneficiaries Age Less 65                                                               2093
# Percent (%) of Beneficiaries Identified With Cancer                                                 76
# Number of Non-Hispanic White Beneficiaries                                                        5963
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        76
# Percent (%) of Beneficiaries Identified With Asthma                                                 76
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           76
# Number of Beneficiaries Age Greater 84                                                            2161
# Percent (%) of Beneficiaries Identified With Stroke                                                 76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              76
# Street Address 2 of the Provider                                                                 70986
# Number of Black or African American Beneficiaries                                                 2050
# Number of American Indian/Alaska Native Beneficiaries                                              498
# Number of Hispanic Beneficiaries                                                                  1699
# Number of Asian Pacific Islander Beneficiaries                                                    1093
# Number of Beneficiaries With Race Not Elsewhere Classified                                         495
# Medical Suppress Indicator                                                                           2
# Drug Suppress Indicator                                                                              2
#
#                                                                                          null values
# National Provider Identifier                                                                       0
# Average Age of Beneficiaries                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Total Medicare Payment Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Submitted Charge Amount                                                                      0
# Number of Medicare Beneficiaries                                                                   0
# Number of Services                                                                                 0
# Number of HCPCS                                                                                    0
# Medicare Participation Indicator                                                                   0
# Provider Type of the Provider                                                                      0
# Country Code of the Provider                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0
# Zip Code of the Provider                                                                           0
# Entity Type of the Provider                                                                        0
# State Code of the Provider                                                                         0
# City of the Provider                                                                               1
# Street Address 1 of the Provider                                                                   1
# Last Name/Organization Name of the Provider                                                       19
# Percent (%) of Beneficiaries Identified With Hypertension                                      52393
# Gender of the Provider                                                                         61330
# First Name of the Provider                                                                     61337
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    73664
# Credentials of the Provider                                                                    90525
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            101987
# Total Medical Medicare Standardized Payment Amount                                            103110
# Total Medical Medicare Payment Amount                                                         103110
# Total Medical Medicare Allowed Amount                                                         103110
# Number of Medicare Beneficiaries With Medical Services                                        103110
# Number of Medical Services                                                                    103110
# Number of HCPCS Associated With Medical Services                                              103110
# Total Medical Submitted Charge Amount                                                         103110
# Total Drug Medicare Standardized Payment Amount                                               103110
# Total Drug Medicare Payment Amount                                                            103110
# Total Drug Medicare Allowed Amount                                                            103110
# Total Drug Submitted Charge Amount                                                            103110
# Number of Medicare Beneficiaries With Drug Services                                           103110
# Number of Drug Services                                                                       103110
# Number of HCPCS Associated With Drug Services                                                 103110
# Number of Male Beneficiaries                                                                  105765
# Number of Female Beneficiaries                                                                105765
# Percent (%) of Beneficiaries Identified With Diabetes                                         139313
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           145056
# Number of Beneficiaries Age 65 to 74                                                          157269
# Percent (%) of Beneficiaries Identified With Depression                                       158925
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           206872
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  240216
# Number of Beneficiaries With Medicare Only Entitlement                                        240216
# Percent (%) of Beneficiaries Identified With Heart Failure                                    247872
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            269260
# Number of Beneficiaries Age 75 to 84                                                          276896
# Middle Initial of the Provider                                                                295243
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              316959
# Number of Beneficiaries Age Less 65                                                           319906
# Percent (%) of Beneficiaries Identified With Cancer                                           323984
# Number of Non-Hispanic White Beneficiaries                                                    333724
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  339978
# Percent (%) of Beneficiaries Identified With Asthma                                           364058
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     369303
# Number of Beneficiaries Age Greater 84                                                        385867
# Percent (%) of Beneficiaries Identified With Stroke                                           440639
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        469853
# Street Address 2 of the Provider                                                              584546
# Number of Black or African American Beneficiaries                                             654625
# Number of American Indian/Alaska Native Beneficiaries                                         705688
# Number of Hispanic Beneficiaries                                                              727022
# Number of Asian Pacific Islander Beneficiaries                                                815683
# Number of Beneficiaries With Race Not Elsewhere Classified                                    850751
# Medical Suppress Indicator                                                                    883567
# Drug Suppress Indicator                                                                       883567

# %% [markdown]
# Dropping Most of the Columns, since only 15 have no null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (986677, 70)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (986677, 16)

# %%
med.columns
# Out:
# Index(['National Provider Identifier', 'Entity Type of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                 'Total Medicare Standardized Payment Amount':'total_medicare_standardized_payment',
                'Average HCC Risk Score of Beneficiaries ':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charge Amount':'total_submitted_charges',
                 'Entity Type of the Provider':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['WI', 'PA', 'FL', 'CT', 'MN', 'IA', 'TX', 'NM', 'MO', 'WA', 'OR',
#        'NY', 'GA', 'CA', 'IL', 'UT', 'MD', 'VA', 'KY', 'AK', 'AZ', 'NJ',
#        'ND', 'MI', 'IN', 'OK', 'OH', 'TN', 'AR', 'CO', 'RI', 'KS', 'MA',
#        'NC', 'NE', 'WV', 'HI', 'ID', 'PR', 'VT', 'LA', 'AL', 'SC', 'DC',
#        'WY', 'NV', 'MS', 'ME', 'VI', 'GU', 'DE', 'NH', 'SD', 'MT', 'AE',
#        'MP', 'AA', 'AP', 'AS', 'XX'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country        provider_type  \
# 11579   1366648800           I      96950    MP      US      Family Practice
# 53980   1164591574           I  969502878    MP      US  Physician Assistant
# 79569   1356484182           I      96960    MP      US    Internal Medicine
# 81241   1699709295           I      96950    MP      US    Internal Medicine
# 131982  1982739025           I      96950    MP      US   Emergency Medicine
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 11579                                 Y               23               197.0
# 53980                                 Y               27               161.0
# 79569                                 Y               59              1346.0
# 81241                                 Y               46               580.0
# 131982                                Y               12               182.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 11579                    57                 16471.30               12875.36
# 53980                    53                  6621.80                6043.16
# 79569                   148                 98568.57               97060.17
# 81241                   111                 29366.54               29254.69
# 131982                  136                 29298.15               13848.38
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 11579                  7179.75                              7442.89
# 53980                  3663.85                              4341.90
# 79569                 66534.99                             62843.91
# 81241                 18543.98                             17455.15
# 131982                10455.61                             10347.68
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 11579                    71              0.8959
# 53980                    69              1.8598
# 79569                    73              1.1022
# 81241                    73              0.9539
# 131982                   70              2.6430

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     811971
# 5      90514
# 8      68262
# 4      10903
# 7       2702
# 3       2241
# 10         8
# 1          2
# 2          1
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code full_zip state country  \
# 340305  1114060506           I        0    MA      US
# 583441  1669551479           I       80    PR      US
# 751979  1316958416           I        0    XX      US
#
#                             provider_type medicare_participation_indicator  \
# 340305  Osteopathic Manipulative Medicine                                Y
# 583441                            Urology                                Y
# 751979                               CRNA                                Y
#
#         number_of_hcpcs  number_of_services  total_beneficiaries  \
# 340305               31              1264.0                  985
# 583441               16               261.0                   93
# 751979               40               106.0                  102
#
#         total_submitted_charges  total_allowed_payment  \
# 340305                547170.25              160792.70
# 583441                 23135.86               23040.81
# 751979                113380.00               21707.78
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 340305               124194.84                            122847.19
# 583441                16887.96                             19583.47
# 751979                16613.13                             17185.36
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 340305                   71              1.9834
# 583441                   75              1.1289
# 751979                   69              1.4151

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country          provider_type  \
# 0  1659374411           I    54601    WI      US     Allergy/Immunology
# 1  1487623633           I    53717    WI      US     Nurse Practitioner
# 2  1598700387           I    53132    WI      US           Rheumatology
# 3  1346490323           I    54935    WI      US  Obstetrics/Gynecology
# 4  1861570996           I    54301    WI      US  Obstetrics/Gynecology
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y                8                42.0
# 1                                Y                7                38.0
# 2                                Y                8                89.0
# 3                                Y               19               801.0
# 4                                Y               32               542.0
#
#    total_beneficiaries  ...  total_medicare_standardized_payment  \
# 0                   14  ...                              1550.48
# 1                   26  ...                              1266.85
# 2                   13  ...                              2798.53
# 3                   22  ...                              2698.17
# 4                   35  ...                              2060.33
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   59              1.1238                 3.00
# 1                   70              1.0511                 1.46
# 2                   69              1.0231                 6.85
# 3                   55              1.1173                36.41
# 4                   64              0.4507                15.49
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                      154.31                       105.04
# 1                       55.26                        38.56
# 2                      274.97                       209.71
# 3                      163.36                       121.38
# 4                       73.11                        56.58
#
#    submitted_charges_per_capita  State Code   Region            Division
# 0                        348.93          WI  Midwest  East North Central
# 1                        216.31          WI  Midwest  East North Central
# 2                        719.36          WI  Midwest  East North Central
# 3                        584.68          WI  Midwest  East North Central
# 4                        208.86          WI  Midwest  East North Central
#
# [5 rows x 23 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980332 entries, 0 to 980331
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   npi                                  980332 non-null  int64
#  1   entity_code                          980332 non-null  object
#  2   full_zip                             980332 non-null  object
#  3   state                                980332 non-null  object
#  4   country                              980332 non-null  object
#  5   provider_type                        980332 non-null  object
#  6   medicare_participation_indicator     980332 non-null  object
#  7   number_of_hcpcs                      980332 non-null  int64
#  8   number_of_services                   980332 non-null  float64
#  9   total_beneficiaries                  980332 non-null  int64
#  10  total_submitted_charges              980332 non-null  float64
#  11  total_allowed_payment                980332 non-null  float64
#  12  total_medicare_payment               980332 non-null  float64
#  13  total_medicare_standardized_payment  980332 non-null  float64
#  14  avg_beneficiary_age                  980332 non-null  int64
#  15  avg_hcc_risk_score                   980332 non-null  float64
#  16  services_per_capita                  980332 non-null  float64
#  17  allowed_payment_per_capita           980332 non-null  float64
#  18  medicare_payment_per_capita          980332 non-null  float64
#  19  submitted_charges_per_capita         980332 non-null  float64
#  20  region                               980332 non-null  object
#  21  subregion                            980332 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 172.0+ MB

# %%
med.to_csv('../../data/processed/final2014MEDICARE.csv')
