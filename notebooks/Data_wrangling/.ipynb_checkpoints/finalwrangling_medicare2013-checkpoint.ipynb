# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2013.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (956293, 67)

# %%
med.head()
# Out:
#           NPI NPPES Provider Last Name / Organization Name  \
# 0  1003183823                                     POPADIUK
# 1  1003813437                                       DONATO
# 2  1003814310                                      MURTAZA
# 3  1003828153                                       LEVINE
# 4  1003879693                                        ALLEY
#
#   NPPES Provider First Name NPPES Provider Middle Initial NPPES Credentials  \
# 0                     LILIA                           NaN              P.A.
# 1                   HEATHER                             O              M.D.
# 2                    GHULAM                           NaN              M.D.
# 3                   SEYMOUR                           NaN                MD
# 4                     CAROL                             L                MD
#
#   NPPES Provider Gender NPPES Entity Code NPPES Provider Street Address 1  \
# 0                     F                 I                 6071 W OUTER DR
# 1                     F                 I            7205 WOLF RIVER BLVD
# 2                     M                 I                4800 ALBERTA AVE
# 3                     M                 I        150 NORTH ROBERTSON BLVD
# 4                     F                 I           320 BAWDEN ST APT 313
#
#   NPPES Provider Street Address 2 NPPES Provider City  ...  \
# 0                             NaN             DETROIT  ...
# 1                       SUITE 150          GERMANTOWN  ...
# 2                             NaN             EL PASO  ...
# 3                            #350       BEVERLY HILLS  ...
# 4                             NaN           KETCHIKAN  ...
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                                NaN
# 1                                                NaN
# 2                                               35.0
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Heart Failure  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               42.0
# 1                                               44.0
# 2                                               53.0
# 3                                               60.0
# 4                                               28.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               73.0
# 1                                               44.0
# 2                                               74.0
# 3                                               60.0
# 4                                               40.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               42.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               46.0
# 1                                                NaN
# 2                                               53.0
# 3                                               68.0
# 4                                               33.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   1.3464
# 1                                   0.7268
# 2                                   1.3583
# 3                                   1.2108
# 4                                   0.9825
#
# [5 rows x 67 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Provider Last Name / Organization Name',
#        'NPPES Provider First Name', 'NPPES Provider Middle Initial',
#        'NPPES Credentials', 'NPPES Provider Gender', 'NPPES Entity Code',
#        'NPPES Provider Street Address 1', 'NPPES Provider Street Address 2',
#        'NPPES Provider City', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Unique Beneficiaries With Drug Services',
#        'Total Drug Submitted Charges', 'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount', 'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Unique Beneficiaries With Medical Services',
#        'Total Medical Submitted Charges',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Number of Beneficiaries Age Less than 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# NPI                                                                                        int64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charges                                                                  float64
# Number of Unique Beneficiaries                                                             int64
# Number of Services                                                                         int64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type                                                                             object
# NPPES Provider Country                                                                    object
# Average HCC Risk Score of Beneficiaries                                                  float64
# NPPES Provider Zip Code                                                                   object
# NPPES Entity Code                                                                         object
# NPPES Provider State                                                                      object
# NPPES Provider City                                                                       object
# NPPES Provider Street Address 1                                                           object
# NPPES Provider Last Name / Organization Name                                              object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# NPPES Provider Gender                                                                     object
# NPPES Provider First Name                                                                 object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# NPPES Credentials                                                                         object
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Submitted Charges                                                          float64
# Number of Unique Beneficiaries With Medical Services                                     float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charges                                                             float64
# Number of Unique Beneficiaries With Drug Services                                        float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries                                                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# NPPES Provider Middle Initial                                                             object
# Number of Beneficiaries Age Less than 65                                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# NPPES Provider Street Address 2                                                           object
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
#
#                                                                                         non-null values  \
# NPI                                                                                              956293
# Average Age of Beneficiaries                                                                     956293
# Total Medicare Payment Amount                                                                    956293
# Total Medicare Allowed Amount                                                                    956293
# Total Submitted Charges                                                                          956293
# Number of Unique Beneficiaries                                                                   956293
# Number of Services                                                                               956293
# Number of HCPCS                                                                                  956293
# Medicare Participation Indicator                                                                 956293
# Provider Type                                                                                    956293
# NPPES Provider Country                                                                           956293
# Average HCC Risk Score of Beneficiaries                                                          956293
# NPPES Provider Zip Code                                                                          956293
# NPPES Entity Code                                                                                956293
# NPPES Provider State                                                                             956293
# NPPES Provider City                                                                              956291
# NPPES Provider Street Address 1                                                                  956291
# NPPES Provider Last Name / Organization Name                                                     956275
# Percent (%) of Beneficiaries Identified With Hypertension                                        906330
# NPPES Provider Gender                                                                            898293
# NPPES Provider First Name                                                                        898288
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                      886581
# NPPES Credentials                                                                                873126
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis               857849
# Total Medical Medicare Payment Amount                                                            855508
# Total Medical Submitted Charges                                                                  855508
# Number of Unique Beneficiaries With Medical Services                                             855508
# Number of Medical Services                                                                       855508
# Number of HCPCS Associated With Medical Services                                                 855508
# Total Medical Medicare Allowed Amount                                                            855508
# Total Drug Medicare Payment Amount                                                               855508
# Total Drug Medicare Allowed Amount                                                               855508
# Total Drug Submitted Charges                                                                     855508
# Number of Unique Beneficiaries With Drug Services                                                855508
# Number of Drug Services                                                                          855508
# Number of HCPCS Associated With Drug Services                                                    855508
# Number of Female Beneficiaries                                                                   854854
# Number of Male Beneficiaries                                                                     854854
# Percent (%) of Beneficiaries Identified With Diabetes                                            822613
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              819432
# Number of Beneficiaries Age 65 to 74                                                             803528
# Percent (%) of Beneficiaries Identified With Depression                                          800406
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              752279
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     726453
# Number of Beneficiaries With Medicare Only Entitlement                                           726453
# Percent (%) of Beneficiaries Identified With Heart Failure                                       721405
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               699972
# Number of Beneficiaries Age 75 to 84                                                             694141
# NPPES Provider Middle Initial                                                                    678408
# Number of Beneficiaries Age Less than 65                                                         652491
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 650309
# Percent (%) of Beneficiaries Identified With Cancer                                              646550
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     633056
# Number of Non-Hispanic White Beneficiaries                                                       629147
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        604753
# Percent (%) of Beneficiaries Identified With Asthma                                              603736
# Number of Beneficiaries Age Greater 84                                                           589192
# Percent (%) of Beneficiaries Identified With Stroke                                              533130
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           503777
# NPPES Provider Street Address 2                                                                  392669
# Number of Black or African American Beneficiaries                                                319244
# Number of American Indian/Alaska Native Beneficiaries                                            263435
# Number of Hispanic Beneficiaries                                                                 250582
# Number of Asian Pacific Islander Beneficiaries                                                   165528
# Number of Beneficiaries With Race Not Elsewhere Classified                                       126199
# Medical Suppress Indicator                                                                       100785
# Drug Suppress Indicator                                                                          100785
#
#                                                                                         unique values  \
# NPI                                                                                            956293
# Average Age of Beneficiaries                                                                       87
# Total Medicare Payment Amount                                                                  908630
# Total Medicare Allowed Amount                                                                  919237
# Total Submitted Charges                                                                        661025
# Number of Unique Beneficiaries                                                                   6717
# Number of Services                                                                              29162
# Number of HCPCS                                                                                   497
# Medicare Participation Indicator                                                                    2
# Provider Type                                                                                      90
# NPPES Provider Country                                                                             31
# Average HCC Risk Score of Beneficiaries                                                         41660
# NPPES Provider Zip Code                                                                        324831
# NPPES Entity Code                                                                                   2
# NPPES Provider State                                                                               61
# NPPES Provider City                                                                             12958
# NPPES Provider Street Address 1                                                                331389
# NPPES Provider Last Name / Organization Name                                                   242197
# Percent (%) of Beneficiaries Identified With Hypertension                                          69
# NPPES Provider Gender                                                                               2
# NPPES Provider First Name                                                                       59120
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        72
# NPPES Credentials                                                                               14402
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 73
# Total Medical Medicare Payment Amount                                                          816132
# Total Medical Submitted Charges                                                                592727
# Number of Unique Beneficiaries With Medical Services                                             6644
# Number of Medical Services                                                                      19182
# Number of HCPCS Associated With Medical Services                                                  490
# Total Medical Medicare Allowed Amount                                                          823218
# Total Drug Medicare Payment Amount                                                             204424
# Total Drug Medicare Allowed Amount                                                             207180
# Total Drug Submitted Charges                                                                   133724
# Number of Unique Beneficiaries With Drug Services                                                1209
# Number of Drug Services                                                                         18919
# Number of HCPCS Associated With Drug Services                                                     111
# Number of Female Beneficiaries                                                                   4731
# Number of Male Beneficiaries                                                                     3539
# Percent (%) of Beneficiaries Identified With Diabetes                                              72
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Number of Beneficiaries Age 65 to 74                                                             3266
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                74
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     3082
# Number of Beneficiaries With Medicare Only Entitlement                                           5443
# Percent (%) of Beneficiaries Identified With Heart Failure                                         75
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 76
# Number of Beneficiaries Age 75 to 84                                                             2880
# NPPES Provider Middle Initial                                                                      33
# Number of Beneficiaries Age Less than 65                                                         2050
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Number of Non-Hispanic White Beneficiaries                                                       5942
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          76
# Percent (%) of Beneficiaries Identified With Asthma                                                76
# Number of Beneficiaries Age Greater 84                                                           2175
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# NPPES Provider Street Address 2                                                                 68922
# Number of Black or African American Beneficiaries                                                2085
# Number of American Indian/Alaska Native Beneficiaries                                             491
# Number of Hispanic Beneficiaries                                                                 1707
# Number of Asian Pacific Islander Beneficiaries                                                   1103
# Number of Beneficiaries With Race Not Elsewhere Classified                                        468
# Medical Suppress Indicator                                                                          2
# Drug Suppress Indicator                                                                             2
#
#                                                                                         null values
# NPI                                                                                               0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charges                                                                           0
# Number of Unique Beneficiaries                                                                    0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type                                                                                     0
# NPPES Provider Country                                                                            0
# Average HCC Risk Score of Beneficiaries                                                           0
# NPPES Provider Zip Code                                                                           0
# NPPES Entity Code                                                                                 0
# NPPES Provider State                                                                              0
# NPPES Provider City                                                                               2
# NPPES Provider Street Address 1                                                                   2
# NPPES Provider Last Name / Organization Name                                                     18
# Percent (%) of Beneficiaries Identified With Hypertension                                     49963
# NPPES Provider Gender                                                                         58000
# NPPES Provider First Name                                                                     58005
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   69712
# NPPES Credentials                                                                             83167
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            98444
# Total Medical Medicare Payment Amount                                                        100785
# Total Medical Submitted Charges                                                              100785
# Number of Unique Beneficiaries With Medical Services                                         100785
# Number of Medical Services                                                                   100785
# Number of HCPCS Associated With Medical Services                                             100785
# Total Medical Medicare Allowed Amount                                                        100785
# Total Drug Medicare Payment Amount                                                           100785
# Total Drug Medicare Allowed Amount                                                           100785
# Total Drug Submitted Charges                                                                 100785
# Number of Unique Beneficiaries With Drug Services                                            100785
# Number of Drug Services                                                                      100785
# Number of HCPCS Associated With Drug Services                                                100785
# Number of Female Beneficiaries                                                               101439
# Number of Male Beneficiaries                                                                 101439
# Percent (%) of Beneficiaries Identified With Diabetes                                        133680
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                          136861
# Number of Beneficiaries Age 65 to 74                                                         152765
# Percent (%) of Beneficiaries Identified With Depression                                      155887
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                          204014
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                 229840
# Number of Beneficiaries With Medicare Only Entitlement                                       229840
# Percent (%) of Beneficiaries Identified With Heart Failure                                   234888
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease           256321
# Number of Beneficiaries Age 75 to 84                                                         262152
# NPPES Provider Middle Initial                                                                277885
# Number of Beneficiaries Age Less than 65                                                     303802
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                             305984
# Percent (%) of Beneficiaries Identified With Cancer                                          309743
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                 323237
# Number of Non-Hispanic White Beneficiaries                                                   327146
# Percent (%) of Beneficiaries Identified With Osteoporosis                                    351540
# Percent (%) of Beneficiaries Identified With Asthma                                          352557
# Number of Beneficiaries Age Greater 84                                                       367101
# Percent (%) of Beneficiaries Identified With Stroke                                          423163
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders       452516
# NPPES Provider Street Address 2                                                              563624
# Number of Black or African American Beneficiaries                                            637049
# Number of American Indian/Alaska Native Beneficiaries                                        692858
# Number of Hispanic Beneficiaries                                                             705711
# Number of Asian Pacific Islander Beneficiaries                                               790765
# Number of Beneficiaries With Race Not Elsewhere Classified                                   830094
# Medical Suppress Indicator                                                                   855508
# Drug Suppress Indicator                                                                      855508

# %% [markdown]
# Dropping Most of the Columns, since only 15 have no null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (956293, 67)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (956293, 15)

# %%
med.columns
# Out:
# Index(['NPI', 'NPPES Entity Code', 'NPPES Provider Zip Code',
#        'NPPES Provider State', 'NPPES Provider Country', 'Provider Type',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Unique Beneficiaries',
#        'Total Submitted Charges', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount', 'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'NPI':'npi',
                 'NPPES Provider City':'city', 'NPPES Provider Zip Code':'full_zip',
                'NPPES Provider State':'state','NPPES Provider Country':'country',
                'Provider Type':'provider_type',
                 'Number of Unique Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charges':'total_submitted_charges',
                 'NPPES Entity Code':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'avg_beneficiary_age', 'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['MI', 'TN', 'TX', 'CA', 'AK', 'PA', 'OH', 'WA', 'NC', 'MA', 'GA',
#        'NJ', 'MN', 'DC', 'MT', 'ND', 'WI', 'KY', 'IL', 'OK', 'FL', 'AZ',
#        'NE', 'VA', 'CO', 'DE', 'MO', 'LA', 'NY', 'KS', 'NM', 'NH', 'UT',
#        'IA', 'CT', 'IN', 'WY', 'ME', 'NV', 'AL', 'OR', 'SC', 'VT', 'HI',
#        'MS', 'WV', 'PR', 'MD', 'AR', 'RI', 'ID', 'SD', 'MP', 'AE', 'VI',
#        'GU', 'AP', 'AS', 'XX', 'AA'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country       provider_type  \
# 1043    1720126253           I      96950    MP      US     Family Practice
# 26778   1023150414           I      21287    MP      US      Anesthesiology
# 61494   1063459428           I  969501908    MP      US   Internal Medicine
# 66427   1063630606           I      96950    MP      US  Emergency Medicine
# 119329  1124064274           I      96950    MP      US  Emergency Medicine
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 1043                                  Y               30                 203
# 26778                                 Y               64                 358
# 61494                                 Y               18                1134
# 66427                                 Y               16                 450
# 119329                                Y               25                1030
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 1043                     55                 17485.69               17294.54
# 26778                   213                468250.90               71060.41
# 61494                   225                 75391.75               71190.07
# 66427                   390                240730.00               54422.46
# 119329                  763                742990.85              118501.76
#
#         total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score
# 1043                  10757.52                   71              0.6807
# 26778                 55813.64                   68              1.8067
# 61494                 43792.21                   71              0.7912
# 66427                 41584.96                   70              2.0703
# 119329                91676.51                   75              1.7536

# %%
# This one was a typo. The others are Northern Mariana Islands, a US territory.
med.loc[med.npi==1023150414, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9     782441
# 5      92213
# 8      65805
# 4      10814
# 7       2697
# 3       2240
# 10         6
# 1          2
# 2          1
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code full_zip state country  \
# 108153  1114060506           I        0    MA      US
# 305661  1316958416           I        0    XX      US
# 638147  1669551479           I       80    PR      US
#
#                             provider_type medicare_participation_indicator  \
# 108153  Osteopathic Manipulative Medicine                                Y
# 305661                               CRNA                                Y
# 638147                            Urology                                Y
#
#         number_of_hcpcs  number_of_services  total_beneficiaries  \
# 108153               26                1340                 1043
# 305661               36                  89                   87
# 638147               14                 284                  109
#
#         total_submitted_charges  total_allowed_payment  \
# 108153                510009.00              168269.57
# 305661                115570.00               19885.88
# 638147                 25448.29               22592.77
#
#         total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score
# 108153               129427.79                   72              1.9600
# 305661                15174.21                   72              1.4413
# 638147                15960.83                   73              0.9717

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country           provider_type  \
# 0  1003183823           I    48235    MI      US     Physician Assistant
# 1  1023192564           I    49770    MI      US        General Practice
# 2  1073556320           I    48503    MI      US  Occupational therapist
# 3  1083919666           I    48237    MI      US      Nurse Practitioner
# 4  1144322173           I    48439    MI      US     Physician Assistant
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               14                  46
# 1                                Y               18                 135
# 2                                Y                2                  13
# 3                                Y                9                  30
# 4                                Y                7                  36
#
#    total_beneficiaries  ...  total_medicare_payment  avg_beneficiary_age  \
# 0                   26  ...                 1721.94                   60
# 1                   41  ...                 3899.56                   74
# 2                   12  ...                  667.53                   61
# 3                   21  ...                 1231.86                   70
# 4                   26  ...                 1422.64                   68
#
#    avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 0              1.3464                 1.77                       89.24
# 1              1.0309                 3.29                      181.36
# 2              1.5304                 1.08                       70.56
# 3              0.8738                 1.43                       74.79
# 4              1.2295                 1.38                       69.71
#
#    medicare_payment_per_capita  submitted_charges_per_capita  State Code  \
# 0                        66.23                        155.46          MI
# 1                        95.11                        229.24          MI
# 2                        55.63                        325.86          MI
# 3                        58.66                         76.66          MI
# 4                        54.72                        145.00          MI
#
#     Region            Division
# 0  Midwest  East North Central
# 1  Midwest  East North Central
# 2  Midwest  East North Central
# 3  Midwest  East North Central
# 4  Midwest  East North Central
#
# [5 rows x 22 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949955 entries, 0 to 949954
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               949955 non-null  int64
#  1   entity_code                       949955 non-null  object
#  2   full_zip                          949955 non-null  object
#  3   state                             949955 non-null  object
#  4   country                           949955 non-null  object
#  5   provider_type                     949955 non-null  object
#  6   medicare_participation_indicator  949955 non-null  object
#  7   number_of_hcpcs                   949955 non-null  int64
#  8   number_of_services                949955 non-null  int64
#  9   total_beneficiaries               949955 non-null  int64
#  10  total_submitted_charges           949955 non-null  float64
#  11  total_allowed_payment             949955 non-null  float64
#  12  total_medicare_payment            949955 non-null  float64
#  13  avg_beneficiary_age               949955 non-null  int64
#  14  avg_hcc_risk_score                949955 non-null  float64
#  15  services_per_capita               949955 non-null  float64
#  16  allowed_payment_per_capita        949955 non-null  float64
#  17  medicare_payment_per_capita       949955 non-null  float64
#  18  submitted_charges_per_capita      949955 non-null  float64
#  19  region                            949955 non-null  object
#  20  subregion                         949955 non-null  object
# dtypes: float64(8), int64(5), object(8)
# memory usage: 159.4+ MB

# %%
med.to_csv('../../data/processed/final2013MEDICARE.csv')

# %% [markdown]
# MED is the df I will use to merge with Census and aggregate by zip code.
# But I want a DF of providers as well, so I can compare doctors with mostly Black patients to doctors with mostly non-Black patients.
