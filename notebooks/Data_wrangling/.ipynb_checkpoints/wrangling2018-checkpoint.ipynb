# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2018.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1121462, 71)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        D.O.                      M
# 4                        M.D.                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
# 2                           I       4126 N HOLLAND SYLVANIA RD
# 3                           I                  100 HOSPITAL RD
# 4                           I                 11100 EUCLID AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
# 2                        SUITE 220               TOLEDO  ...
# 3                              NaN           BROOKVILLE  ...
# 4                              NaN            CLEVELAND  ...
#
#   Percent (%) of Beneficiaries Identified With Depression  \
# 0                                               47.0
# 1                                               15.0
# 2                                               44.0
# 3                                               53.0
# 4                                               23.0
#
#    Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                               53.0
# 1                                               20.0
# 2                                               31.0
# 3                                               39.0
# 4                                               23.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               75.0
# 1                                               51.0
# 2                                               51.0
# 3                                               67.0
# 4                                               49.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               53.0
# 2                                               68.0
# 3                                               75.0
# 4                                               56.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               55.0
# 1                                               27.0
# 2                                               35.0
# 3                                               57.0
# 4                                               21.0
#
#   Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                               11.0
# 1                                               10.0
# 2                                                5.0
# 3                                               21.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               56.0
# 1                                               39.0
# 2                                               75.0
# 3                                               46.0
# 4                                               41.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                9.0
# 1                                                1.0
# 2                                                6.0
# 3                                               15.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               11.0
# 1                                                3.0
# 2                                                5.0
# 3                                                9.0
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.2948
# 1                                   1.0899
# 2                                   1.7085
# 3                                   2.1838
# 4                                   1.0221
#
# [5 rows x 71 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'Provider RUCA',
#        'State Code of the Provider', 'Country Code of the Provider',
#        'Provider Type of the Provider', 'Medicare Participation Indicator',
#        'Number of HCPCS', 'Number of Services',
#        'Number of Medicare Beneficiaries', 'Total Submitted Charge Amount',
#        'Total Medicare Allowed Amount', 'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
list(med['Provider Type of the Provider'].unique())
# Out:
# ['Internal Medicine',
#  'Pathology',
#  'Anesthesiology',
#  'Family Practice',
#  'Obstetrics & Gynecology',
#  'General Surgery',
#  'Urology',
#  'Cardiac Surgery',
#  'Physician Assistant',
#  'Licensed Clinical Social Worker',
#  'Physical Therapist in Private Practice',
#  'Certified Registered Nurse Anesthetist (CRNA)',
#  'Optometry',
#  'Mass Immunizer Roster Biller',
#  'Physical Medicine and Rehabilitation',
#  'Radiation Oncology',
#  'Infectious Disease',
#  'Nurse Practitioner',
#  'Orthopedic Surgery',
#  'Endocrinology',
#  'Chiropractic',
#  'Psychiatry',
#  'Diagnostic Radiology',
#  'Centralized Flu',
#  'Rheumatology',
#  'General Practice',
#  'Neurology',
#  'Emergency Medicine',
#  'Dermatology',
#  'Nephrology',
#  'Pediatric Medicine',
#  'Pulmonary Disease',
#  'Otolaryngology',
#  'Plastic and Reconstructive Surgery',
#  'Psychologist, Clinical',
#  'Cardiology',
#  'Ambulance Service Provider',
#  'Ophthalmology',
#  'Interventional Cardiology',
#  'Gastroenterology',
#  'Hospitalist',
#  'Audiologist',
#  'Geriatric Medicine',
#  'Neurosurgery',
#  'Interventional Radiology',
#  'Critical Care (Intensivists)',
#  'Podiatry',
#  'Hematology-Oncology',
#  'Pharmacy',
#  'Ambulatory Surgical Center',
#  'Certified Clinical Nurse Specialist',
#  'Medical Oncology',
#  'Nuclear Medicine',
#  'Occupational Therapist in Private Practice',
#  'Thoracic Surgery',
#  'Allergy/ Immunology',
#  'Certified Nurse Midwife',
#  'Pain Management',
#  'Sports Medicine',
#  'Hand Surgery',
#  'Hospice and Palliative Care',
#  'Independent Diagnostic Testing Facility (IDTF)',
#  'Speech Language Pathologist',
#  'Clinical Laboratory',
#  'Advanced Heart Failure and Transplant Cardiology',
#  'Osteopathic Manipulative Medicine',
#  'Registered Dietitian or Nutrition Professional',
#  'Vascular Surgery',
#  'Anesthesiology Assistant',
#  'Clinical Cardiac Electrophysiology',
#  'Addiction Medicine',
#  'Oral Surgery (Dentist only)',
#  'Undefined Physician type',
#  'Hematology',
#  'Maxillofacial Surgery',
#  'Portable X-Ray Supplier',
#  'Colorectal Surgery (Proctology)',
#  'Mammography Center',
#  'Surgical Oncology',
#  'Gynecological Oncology',
#  'Interventional Pain Management',
#  'Preventive Medicine',
#  'All Other Suppliers',
#  'Hematopoietic Cell Transplantation and Cellular Therapy',
#  'Public Health or Welfare Agency',
#  'Sleep Medicine',
#  'Neuropsychiatry',
#  'Peripheral Vascular Disease',
#  'Clinic or Group Practice',
#  'Radiation Therapy Center',
#  'Geriatric Psychiatry',
#  'Dentist',
#  'Slide Preparation Facility',
#  'Medical Genetics and Genomics',
#  'Medical Toxicology',
#  'Unknown Supplier/Provider Specialty',
#  'Intensive Cardiac Rehabilitation',
#  'Medicare Diabetes Preventive Program',
#  'Undersea and Hyperbaric Medicine']

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',
                         'Multispecialty Clinic/Group Practice',
                           'Public Health Welfare Agency', 'Preventive Medicine']

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry','Clinical Psychologist','Psychologist (billing independently)',
                       ]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type of the Provider"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 59888

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Street Address 2 of the Provider                                                          object
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Number of Beneficiaries Age Less 65                                                      float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Submitted Charge Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Provider RUCA                                                                            float64
# Zip Code of the Provider                                                                  object
# City of the Provider                                                                      object
# Street Address 1 of the Provider                                                          object
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# State Code of the Provider                                                                object
# Country Code of the Provider                                                              object
# Average Age of Beneficiaries                                                              object
# Provider Type of the Provider                                                             object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Medicare Participation Indicator                                                          object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Drug Suppress Indicator                                                                             602
# Medical Suppress Indicator                                                                          602
# Number of Beneficiaries With Race Not Elsewhere Classified                                        10062
# Number of Hispanic Beneficiaries                                                                  11129
# Number of Asian Pacific Islander Beneficiaries                                                    12283
# Number of Beneficiaries Age 75 to 84                                                              12666
# Number of Black or African American Beneficiaries                                                 13104
# Number of American Indian/Alaska Native Beneficiaries                                             16865
# Percent (%) of Beneficiaries Identified With Asthma                                               17985
# Percent (%) of Beneficiaries Identified With Cancer                                               18952
# Number of Beneficiaries Age Greater 84                                                            19151
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         19512
# Number of Beneficiaries Age 65 to 74                                                              19919
# Street Address 2 of the Provider                                                                  21215
# Percent (%) of Beneficiaries Identified With Heart Failure                                        22667
# Number of Non-Hispanic White Beneficiaries                                                        22909
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                23375
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  23775
# Number of Beneficiaries Age Less 65                                                               23805
# Percent (%) of Beneficiaries Identified With Stroke                                               25914
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               26129
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      26586
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               27522
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      27845
# Number of Beneficiaries With Medicare Only Entitlement                                            27845
# Percent (%) of Beneficiaries Identified With Diabetes                                             29191
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            31265
# Number of Male Beneficiaries                                                                      31852
# Number of Female Beneficiaries                                                                    31852
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                35257
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       39022
# Middle Initial of the Provider                                                                    40796
# Percent (%) of Beneficiaries Identified With Hypertension                                         42263
# Percent (%) of Beneficiaries Identified With Depression                                           52051
# Credentials of the Provider                                                                       56579
# Total Medical Medicare Standardized Payment Amount                                                59286
# Total Medical Medicare Payment Amount                                                             59286
# Total Medical Submitted Charge Amount                                                             59286
# Number of Medicare Beneficiaries With Medical Services                                            59286
# Number of Medical Services                                                                        59286
# Number of HCPCS Associated With Medical Services                                                  59286
# Total Drug Medicare Standardized Payment Amount                                                   59286
# Total Drug Medicare Payment Amount                                                                59286
# Total Drug Medicare Allowed Amount                                                                59286
# Total Drug Submitted Charge Amount                                                                59286
# Number of Drug Services                                                                           59286
# Number of HCPCS Associated With Drug Services                                                     59286
# Total Medical Medicare Allowed Amount                                                             59286
# Number of Medicare Beneficiaries With Drug Services                                               59286
# Provider RUCA                                                                                     59824
# Zip Code of the Provider                                                                          59880
# City of the Provider                                                                              59881
# Street Address 1 of the Provider                                                                  59881
# National Provider Identifier                                                                      59888
# Total Medicare Standardized Payment Amount                                                        59888
# Last Name/Organization Name of the Provider                                                       59888
# First Name of the Provider                                                                        59888
# Gender of the Provider                                                                            59888
# Entity Type of the Provider                                                                       59888
# State Code of the Provider                                                                        59888
# Country Code of the Provider                                                                      59888
# Average Age of Beneficiaries                                                                      59888
# Provider Type of the Provider                                                                     59888
# Number of HCPCS                                                                                   59888
# Number of Services                                                                                59888
# Number of Medicare Beneficiaries                                                                  59888
# Total Submitted Charge Amount                                                                     59888
# Total Medicare Allowed Amount                                                                     59888
# Total Medicare Payment Amount                                                                     59888
# Medicare Participation Indicator                                                                  59888
# Average HCC Risk Score of Beneficiaries                                                           59888
#
#                                                                                         unique values  \
# Drug Suppress Indicator                                                                             1
# Medical Suppress Indicator                                                                          1
# Number of Beneficiaries With Race Not Elsewhere Classified                                         51
# Number of Hispanic Beneficiaries                                                                  240
# Number of Asian Pacific Islander Beneficiaries                                                    100
# Number of Beneficiaries Age 75 to 84                                                              341
# Number of Black or African American Beneficiaries                                                 289
# Number of American Indian/Alaska Native Beneficiaries                                              43
# Percent (%) of Beneficiaries Identified With Asthma                                                51
# Percent (%) of Beneficiaries Identified With Cancer                                                75
# Number of Beneficiaries Age Greater 84                                                            353
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          55
# Number of Beneficiaries Age 65 to 74                                                              337
# Street Address 2 of the Provider                                                                 7390
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Number of Non-Hispanic White Beneficiaries                                                        758
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   55
# Number of Beneficiaries Age Less 65                                                               469
# Percent (%) of Beneficiaries Identified With Stroke                                                75
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       73
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      658
# Number of Beneficiaries With Medicare Only Entitlement                                            542
# Percent (%) of Beneficiaries Identified With Diabetes                                              68
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Number of Male Beneficiaries                                                                      477
# Number of Female Beneficiaries                                                                    615
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        64
# Middle Initial of the Provider                                                                     29
# Percent (%) of Beneficiaries Identified With Hypertension                                          61
# Percent (%) of Beneficiaries Identified With Depression                                            65
# Credentials of the Provider                                                                      2493
# Total Medical Medicare Standardized Payment Amount                                              58941
# Total Medical Medicare Payment Amount                                                           58892
# Total Medical Submitted Charge Amount                                                           44095
# Number of Medicare Beneficiaries With Medical Services                                            907
# Number of Medical Services                                                                       3396
# Number of HCPCS Associated With Medical Services                                                   52
# Total Drug Medicare Standardized Payment Amount                                                   117
# Total Drug Medicare Payment Amount                                                                117
# Total Drug Medicare Allowed Amount                                                                117
# Total Drug Submitted Charge Amount                                                                117
# Number of Drug Services                                                                           107
# Number of HCPCS Associated With Drug Services                                                      11
# Total Medical Medicare Allowed Amount                                                           58965
# Number of Medicare Beneficiaries With Drug Services                                                46
# Provider RUCA                                                                                      21
# Zip Code of the Provider                                                                        12961
# City of the Provider                                                                             4830
# Street Address 1 of the Provider                                                                36891
# National Provider Identifier                                                                    59888
# Total Medicare Standardized Payment Amount                                                      59536
# Last Name/Organization Name of the Provider                                                     30930
# First Name of the Provider                                                                       9699
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# State Code of the Provider                                                                         57
# Country Code of the Provider                                                                        8
# Average Age of Beneficiaries                                                                       71
# Provider Type of the Provider                                                                       5
# Number of HCPCS                                                                                    54
# Number of Services                                                                               3471
# Number of Medicare Beneficiaries                                                                  915
# Total Submitted Charge Amount                                                                   44639
# Total Medicare Allowed Amount                                                                   59564
# Total Medicare Payment Amount                                                                   59489
# Medicare Participation Indicator                                                                    2
# Average HCC Risk Score of Beneficiaries                                                         19177
#
#                                                                                         null values
# Drug Suppress Indicator                                                                       59286
# Medical Suppress Indicator                                                                    59286
# Number of Beneficiaries With Race Not Elsewhere Classified                                    49826
# Number of Hispanic Beneficiaries                                                              48759
# Number of Asian Pacific Islander Beneficiaries                                                47605
# Number of Beneficiaries Age 75 to 84                                                          47222
# Number of Black or African American Beneficiaries                                             46784
# Number of American Indian/Alaska Native Beneficiaries                                         43023
# Percent (%) of Beneficiaries Identified With Asthma                                           41903
# Percent (%) of Beneficiaries Identified With Cancer                                           40936
# Number of Beneficiaries Age Greater 84                                                        40737
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     40376
# Number of Beneficiaries Age 65 to 74                                                          39969
# Street Address 2 of the Provider                                                              38673
# Percent (%) of Beneficiaries Identified With Heart Failure                                    37221
# Number of Non-Hispanic White Beneficiaries                                                    36979
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            36513
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              36113
# Number of Beneficiaries Age Less 65                                                           36083
# Percent (%) of Beneficiaries Identified With Stroke                                           33974
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           33759
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  33302
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           32366
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  32043
# Number of Beneficiaries With Medicare Only Entitlement                                        32043
# Percent (%) of Beneficiaries Identified With Diabetes                                         30697
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        28623
# Number of Male Beneficiaries                                                                  28036
# Number of Female Beneficiaries                                                                28036
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            24631
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   20866
# Middle Initial of the Provider                                                                19092
# Percent (%) of Beneficiaries Identified With Hypertension                                     17625
# Percent (%) of Beneficiaries Identified With Depression                                        7837
# Credentials of the Provider                                                                    3309
# Total Medical Medicare Standardized Payment Amount                                              602
# Total Medical Medicare Payment Amount                                                           602
# Total Medical Submitted Charge Amount                                                           602
# Number of Medicare Beneficiaries With Medical Services                                          602
# Number of Medical Services                                                                      602
# Number of HCPCS Associated With Medical Services                                                602
# Total Drug Medicare Standardized Payment Amount                                                 602
# Total Drug Medicare Payment Amount                                                              602
# Total Drug Medicare Allowed Amount                                                              602
# Total Drug Submitted Charge Amount                                                              602
# Number of Drug Services                                                                         602
# Number of HCPCS Associated With Drug Services                                                   602
# Total Medical Medicare Allowed Amount                                                           602
# Number of Medicare Beneficiaries With Drug Services                                             602
# Provider RUCA                                                                                    64
# Zip Code of the Provider                                                                          8
# City of the Provider                                                                              7
# Street Address 1 of the Provider                                                                  7
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# State Code of the Provider                                                                        0
# Country Code of the Provider                                                                      0
# Average Age of Beneficiaries                                                                      0
# Provider Type of the Provider                                                                     0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Medicare Participation Indicator                                                                  0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
print(mental_med['Number of Black or African American Beneficiaries'].notnull().sum())
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]
# Out:
# 13104

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Medicare Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 13104

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 5514

# %% [markdown]
# In previous years, some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Medicare Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 0

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Medicare Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 10586

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 5316

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 13104

# %%
black_medicare[age_cols[:-1]].isnull().any(axis=1).sum()
# Out:
# 10586

# %%
black_medicare[age_cols].head(3)
# Out:
#      Number of Beneficiaries Age Less 65  \
# 29                                   NaN
# 638                                  NaN
# 648                                 37.0
#
#      Number of Beneficiaries Age 65 to 74  \
# 29                                    NaN
# 638                                  12.0
# 648                                  12.0
#
#      Number of Beneficiaries Age 75 to 84  \
# 29                                    NaN
# 638                                   NaN
# 648                                   0.0
#
#      Number of Beneficiaries Age Greater 84 Number of Medicare Beneficiaries
# 29                                      0.0                               11
# 638                                     0.0                               24
# 648                                     0.0                               49

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (13104, 13104)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (5514, 5514)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# Street Address 2 of the Provider                                                          object
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Male Beneficiaries                                                             float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charge Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Total Drug Submitted Charge Amount                                                       float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of HCPCS Associated With Medical Services                                         float64
# Provider RUCA                                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# Street Address 1 of the Provider                                                          object
# City of the Provider                                                                      object
# Zip Code of the Provider                                                                  object
# State Code of the Provider                                                                object
# Country Code of the Provider                                                              object
# Provider Type of the Provider                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Average Age of Beneficiaries                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          225
# Drug Suppress Indicator                                                                             225
# Street Address 2 of the Provider                                                                   4791
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5394
# Percent (%) of Beneficiaries Identified With Cancer                                                5427
# Percent (%) of Beneficiaries Identified With Asthma                                                6262
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6383
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6416
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6733
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6776
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6820
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       6960
# Number of Beneficiaries With Medicare Only Entitlement                                             6960
# Number of Male Beneficiaries                                                                       6968
# Number of Female Beneficiaries                                                                     6968
# Percent (%) of Beneficiaries Identified With Diabetes                                              6981
# Percent (%) of Beneficiaries Identified With Stroke                                                7041
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 7217
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7419
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7815
# Percent (%) of Beneficiaries Identified With Hypertension                                          8244
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8424
# Middle Initial of the Provider                                                                     8818
# Percent (%) of Beneficiaries Identified With Depression                                           10236
# Credentials of the Provider                                                                       12432
# Total Medical Medicare Standardized Payment Amount                                                12879
# Total Medical Medicare Payment Amount                                                             12879
# Total Medical Medicare Allowed Amount                                                             12879
# Total Medical Submitted Charge Amount                                                             12879
# Number of Medicare Beneficiaries With Medical Services                                            12879
# Number of Medical Services                                                                        12879
# Total Drug Submitted Charge Amount                                                                12879
# Total Drug Medicare Standardized Payment Amount                                                   12879
# Total Drug Medicare Payment Amount                                                                12879
# Total Drug Medicare Allowed Amount                                                                12879
# Number of Medicare Beneficiaries With Drug Services                                               12879
# Number of Drug Services                                                                           12879
# Number of HCPCS Associated With Drug Services                                                     12879
# Number of HCPCS Associated With Medical Services                                                  12879
# Provider RUCA                                                                                     13095
# Number of Black or African American Beneficiaries                                                 13104
# National Provider Identifier                                                                      13104
# Total Medicare Standardized Payment Amount                                                        13104
# Last Name/Organization Name of the Provider                                                       13104
# First Name of the Provider                                                                        13104
# Gender of the Provider                                                                            13104
# Entity Type of the Provider                                                                       13104
# Street Address 1 of the Provider                                                                  13104
# City of the Provider                                                                              13104
# Zip Code of the Provider                                                                          13104
# State Code of the Provider                                                                        13104
# Country Code of the Provider                                                                      13104
# Provider Type of the Provider                                                                     13104
# Medicare Participation Indicator                                                                  13104
# Number of HCPCS                                                                                   13104
# Number of Services                                                                                13104
# Number of Medicare Beneficiaries                                                                  13104
# Total Submitted Charge Amount                                                                     13104
# Total Medicare Allowed Amount                                                                     13104
# Total Medicare Payment Amount                                                                     13104
# Average Age of Beneficiaries                                                                      13104
# Average HCC Risk Score of Beneficiaries                                                           13104
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# Street Address 2 of the Provider                                                                 2304
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          41
# Percent (%) of Beneficiaries Identified With Cancer                                                45
# Percent (%) of Beneficiaries Identified With Asthma                                                44
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   45
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                72
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                68
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      640
# Number of Beneficiaries With Medicare Only Entitlement                                            508
# Number of Male Beneficiaries                                                                      469
# Number of Female Beneficiaries                                                                    598
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Percent (%) of Beneficiaries Identified With Stroke                                                68
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       73
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        62
# Percent (%) of Beneficiaries Identified With Hypertension                                          55
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Middle Initial of the Provider                                                                     26
# Percent (%) of Beneficiaries Identified With Depression                                            60
# Credentials of the Provider                                                                       776
# Total Medical Medicare Standardized Payment Amount                                              12862
# Total Medical Medicare Payment Amount                                                           12863
# Total Medical Medicare Allowed Amount                                                           12867
# Total Medical Submitted Charge Amount                                                           11543
# Number of Medicare Beneficiaries With Medical Services                                            882
# Number of Medical Services                                                                       2611
# Total Drug Submitted Charge Amount                                                                 76
# Total Drug Medicare Standardized Payment Amount                                                    76
# Total Drug Medicare Payment Amount                                                                 76
# Total Drug Medicare Allowed Amount                                                                 76
# Number of Medicare Beneficiaries With Drug Services                                                37
# Number of Drug Services                                                                            72
# Number of HCPCS Associated With Drug Services                                                      11
# Number of HCPCS Associated With Medical Services                                                   44
# Provider RUCA                                                                                      19
# Number of Black or African American Beneficiaries                                                 289
# National Provider Identifier                                                                    13104
# Total Medicare Standardized Payment Amount                                                      13086
# Last Name/Organization Name of the Provider                                                      9013
# First Name of the Provider                                                                       3832
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# Street Address 1 of the Provider                                                                10590
# City of the Provider                                                                             2845
# Zip Code of the Provider                                                                         6292
# State Code of the Provider                                                                         54
# Country Code of the Provider                                                                        2
# Provider Type of the Provider                                                                       5
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    47
# Number of Services                                                                               2673
# Number of Medicare Beneficiaries                                                                  890
# Total Submitted Charge Amount                                                                   11764
# Total Medicare Allowed Amount                                                                   13092
# Total Medicare Payment Amount                                                                   13086
# Average Age of Beneficiaries                                                                       65
# Average HCC Risk Score of Beneficiaries                                                          9444
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    12879
# Drug Suppress Indicator                                                                       12879
# Street Address 2 of the Provider                                                               8313
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      7710
# Percent (%) of Beneficiaries Identified With Cancer                                            7677
# Percent (%) of Beneficiaries Identified With Asthma                                            6842
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6721
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6688
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             6371
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6328
# Percent (%) of Beneficiaries Identified With Heart Failure                                     6284
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   6144
# Number of Beneficiaries With Medicare Only Entitlement                                         6144
# Number of Male Beneficiaries                                                                   6136
# Number of Female Beneficiaries                                                                 6136
# Percent (%) of Beneficiaries Identified With Diabetes                                          6123
# Percent (%) of Beneficiaries Identified With Stroke                                            6063
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5887
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5685
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    5289
# Percent (%) of Beneficiaries Identified With Hypertension                                      4860
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4680
# Middle Initial of the Provider                                                                 4286
# Percent (%) of Beneficiaries Identified With Depression                                        2868
# Credentials of the Provider                                                                     672
# Total Medical Medicare Standardized Payment Amount                                              225
# Total Medical Medicare Payment Amount                                                           225
# Total Medical Medicare Allowed Amount                                                           225
# Total Medical Submitted Charge Amount                                                           225
# Number of Medicare Beneficiaries With Medical Services                                          225
# Number of Medical Services                                                                      225
# Total Drug Submitted Charge Amount                                                              225
# Total Drug Medicare Standardized Payment Amount                                                 225
# Total Drug Medicare Payment Amount                                                              225
# Total Drug Medicare Allowed Amount                                                              225
# Number of Medicare Beneficiaries With Drug Services                                             225
# Number of Drug Services                                                                         225
# Number of HCPCS Associated With Drug Services                                                   225
# Number of HCPCS Associated With Medical Services                                                225
# Provider RUCA                                                                                     9
# Number of Black or African American Beneficiaries                                                 0
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# Street Address 1 of the Provider                                                                  0
# City of the Provider                                                                              0
# Zip Code of the Provider                                                                          0
# State Code of the Provider                                                                        0
# Country Code of the Provider                                                                      0
# Provider Type of the Provider                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Average Age of Beneficiaries                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries','Number of Medicare Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 6968
# Has nulls: 6136

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Medicare Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 6968
# Don't sum 0

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# Street Address 2 of the Provider                                                          object
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Medical Submitted Charge Amount                                                    float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Medical Medicare Standardized Payment Amount                                       float64
# Provider RUCA                                                                            float64
# Number of Black or African American Beneficiaries                                        float64
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# Street Address 1 of the Provider                                                          object
# City of the Provider                                                                      object
# Zip Code of the Provider                                                                  object
# State Code of the Provider                                                                object
# Country Code of the Provider                                                              object
# Provider Type of the Provider                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Average Age of Beneficiaries                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          225
# Drug Suppress Indicator                                                                             225
# Street Address 2 of the Provider                                                                   4791
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5394
# Percent (%) of Beneficiaries Identified With Cancer                                                5427
# Percent (%) of Beneficiaries Identified With Asthma                                                6262
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6383
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6416
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6733
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6776
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6820
# Number of Beneficiaries With Medicare Only Entitlement                                             6960
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       6960
# Percent (%) of Beneficiaries Identified With Diabetes                                              6981
# Percent (%) of Beneficiaries Identified With Stroke                                                7041
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 7217
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7419
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7815
# Percent (%) of Beneficiaries Identified With Hypertension                                          8244
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8424
# Middle Initial of the Provider                                                                     8818
# Percent (%) of Beneficiaries Identified With Depression                                           10236
# Credentials of the Provider                                                                       12432
# Total Medical Medicare Allowed Amount                                                             12879
# Number of Medicare Beneficiaries With Medical Services                                            12879
# Number of Medical Services                                                                        12879
# Number of HCPCS Associated With Medical Services                                                  12879
# Total Drug Medicare Standardized Payment Amount                                                   12879
# Total Medical Submitted Charge Amount                                                             12879
# Total Drug Medicare Payment Amount                                                                12879
# Total Drug Submitted Charge Amount                                                                12879
# Number of Medicare Beneficiaries With Drug Services                                               12879
# Number of Drug Services                                                                           12879
# Number of HCPCS Associated With Drug Services                                                     12879
# Total Medical Medicare Payment Amount                                                             12879
# Total Drug Medicare Allowed Amount                                                                12879
# Total Medical Medicare Standardized Payment Amount                                                12879
# Provider RUCA                                                                                     13095
# Number of Black or African American Beneficiaries                                                 13104
# National Provider Identifier                                                                      13104
# Total Medicare Standardized Payment Amount                                                        13104
# Last Name/Organization Name of the Provider                                                       13104
# First Name of the Provider                                                                        13104
# Gender of the Provider                                                                            13104
# Entity Type of the Provider                                                                       13104
# Street Address 1 of the Provider                                                                  13104
# City of the Provider                                                                              13104
# Zip Code of the Provider                                                                          13104
# State Code of the Provider                                                                        13104
# Country Code of the Provider                                                                      13104
# Provider Type of the Provider                                                                     13104
# Medicare Participation Indicator                                                                  13104
# Number of HCPCS                                                                                   13104
# Number of Services                                                                                13104
# Number of Medicare Beneficiaries                                                                  13104
# Total Submitted Charge Amount                                                                     13104
# Total Medicare Allowed Amount                                                                     13104
# Total Medicare Payment Amount                                                                     13104
# Average Age of Beneficiaries                                                                      13104
# Average HCC Risk Score of Beneficiaries                                                           13104
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# Street Address 2 of the Provider                                                                 2304
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          41
# Percent (%) of Beneficiaries Identified With Cancer                                                45
# Percent (%) of Beneficiaries Identified With Asthma                                                44
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   45
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                72
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                68
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Number of Beneficiaries With Medicare Only Entitlement                                            508
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      640
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Percent (%) of Beneficiaries Identified With Stroke                                                68
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       73
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        62
# Percent (%) of Beneficiaries Identified With Hypertension                                          55
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Middle Initial of the Provider                                                                     26
# Percent (%) of Beneficiaries Identified With Depression                                            60
# Credentials of the Provider                                                                       776
# Total Medical Medicare Allowed Amount                                                           12867
# Number of Medicare Beneficiaries With Medical Services                                            882
# Number of Medical Services                                                                       2611
# Number of HCPCS Associated With Medical Services                                                   44
# Total Drug Medicare Standardized Payment Amount                                                    76
# Total Medical Submitted Charge Amount                                                           11543
# Total Drug Medicare Payment Amount                                                                 76
# Total Drug Submitted Charge Amount                                                                 76
# Number of Medicare Beneficiaries With Drug Services                                                37
# Number of Drug Services                                                                            72
# Number of HCPCS Associated With Drug Services                                                      11
# Total Medical Medicare Payment Amount                                                           12863
# Total Drug Medicare Allowed Amount                                                                 76
# Total Medical Medicare Standardized Payment Amount                                              12862
# Provider RUCA                                                                                      19
# Number of Black or African American Beneficiaries                                                 289
# National Provider Identifier                                                                    13104
# Total Medicare Standardized Payment Amount                                                      13086
# Last Name/Organization Name of the Provider                                                      9013
# First Name of the Provider                                                                       3832
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# Street Address 1 of the Provider                                                                10590
# City of the Provider                                                                             2845
# Zip Code of the Provider                                                                         6292
# State Code of the Provider                                                                         54
# Country Code of the Provider                                                                        2
# Provider Type of the Provider                                                                       5
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    47
# Number of Services                                                                               2673
# Number of Medicare Beneficiaries                                                                  890
# Total Submitted Charge Amount                                                                   11764
# Total Medicare Allowed Amount                                                                   13092
# Total Medicare Payment Amount                                                                   13086
# Average Age of Beneficiaries                                                                       65
# Average HCC Risk Score of Beneficiaries                                                          9444
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    12879
# Drug Suppress Indicator                                                                       12879
# Street Address 2 of the Provider                                                               8313
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      7710
# Percent (%) of Beneficiaries Identified With Cancer                                            7677
# Percent (%) of Beneficiaries Identified With Asthma                                            6842
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6721
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6688
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             6371
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6328
# Percent (%) of Beneficiaries Identified With Heart Failure                                     6284
# Number of Beneficiaries With Medicare Only Entitlement                                         6144
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   6144
# Percent (%) of Beneficiaries Identified With Diabetes                                          6123
# Percent (%) of Beneficiaries Identified With Stroke                                            6063
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5887
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5685
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    5289
# Percent (%) of Beneficiaries Identified With Hypertension                                      4860
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4680
# Middle Initial of the Provider                                                                 4286
# Percent (%) of Beneficiaries Identified With Depression                                        2868
# Credentials of the Provider                                                                     672
# Total Medical Medicare Allowed Amount                                                           225
# Number of Medicare Beneficiaries With Medical Services                                          225
# Number of Medical Services                                                                      225
# Number of HCPCS Associated With Medical Services                                                225
# Total Drug Medicare Standardized Payment Amount                                                 225
# Total Medical Submitted Charge Amount                                                           225
# Total Drug Medicare Payment Amount                                                              225
# Total Drug Submitted Charge Amount                                                              225
# Number of Medicare Beneficiaries With Drug Services                                             225
# Number of Drug Services                                                                         225
# Number of HCPCS Associated With Drug Services                                                   225
# Total Medical Medicare Payment Amount                                                           225
# Total Drug Medicare Allowed Amount                                                              225
# Total Medical Medicare Standardized Payment Amount                                              225
# Provider RUCA                                                                                     9
# Number of Black or African American Beneficiaries                                                 0
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# Street Address 1 of the Provider                                                                  0
# City of the Provider                                                                              0
# Zip Code of the Provider                                                                          0
# State Code of the Provider                                                                        0
# Country Code of the Provider                                                                      0
# Provider Type of the Provider                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Average Age of Beneficiaries                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
     'National Provider Identifier', #keeping this as unique ID for each provider
    'Provider Type of the Provider',
     'Number of Medicare Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'City of the Provider', 
 'State Code of the Provider',
 'Zip Code of the Provider',
    'Average HCC Risk Score of Beneficiaries'
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
 'Country Code of the Provider',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Number of Beneficiaries With Medicare Only Entitlement',
#  'Total Drug Medicare Allowed Amount',
#  'Total Drug Medicare Payment Amount',
#  'Gender of the Provider',
#  'Number of HCPCS Associated With Drug Services',
#  'Last Name/Organization Name of the Provider',
#  'Number of HCPCS',
#  'Street Address 1 of the Provider',
#  'Middle Initial of the Provider',
#  'Total Medical Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Percent (%) of Beneficiaries Identified With Asthma',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Number of Medicare Beneficiaries With Drug Services',
#  'Number of HCPCS Associated With Medical Services',
#  'Percent (%) of Beneficiaries Identified With Heart Failure',
#  'Street Address 2 of the Provider',
#  'Medicare Participation Indicator',
#  'Number of Medical Services',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#  'Number of Drug Services',
#  'Total Medical Medicare Standardized Payment Amount',
#  'Total Medical Medicare Allowed Amount',
#  'Number of Services',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'Total Medicare Allowed Amount',
#  'Total Drug Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Diabetes',
#  'Total Medicare Standardized Payment Amount',
#  'First Name of the Provider',
#  'Drug Suppress Indicator',
#  'Total Medical Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Stroke',
#  'Total Submitted Charge Amount',
#  'Number of Medicare Beneficiaries With Medical Services',
#  'Entity Type of the Provider',
#  'Medical Suppress Indicator',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Percent (%) of Beneficiaries Identified With Cancer',
#  'Credentials of the Provider',
#  'Provider RUCA',
#  'Percent (%) of Beneficiaries Identified With Hypertension',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#  'Total Drug Medicare Standardized Payment Amount']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape, all_medicare.shape
# Out:
# ((13104, 13), (5514, 18))

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders':
                    'percent_with_psychosis'}

                
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %%
all_medicare.columns, black_medicare.columns
# Out:
# (Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_white', 'num_black', 'num_asian_pac_isl', 'num_hispanic',
#         'num_nat_amer', 'num_race_unknown', 'percent_with_depression',
#         'percent_with_psychosis', 'avg_hcc_risk_score'],
#        dtype='object'),
#  Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_black', 'percent_with_depression', 'percent_with_psychosis',
#         'avg_hcc_risk_score'],
#        dtype='object'))

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#Some years' DFs have country values that are not 'US' listed in Country

# %%
black_medicare.country.unique()
# Out:
# array(['US', 'NL'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# Some zip codes are integers, others strings, others objects

# %%
black_medicare.full_zip.apply(lambda x: type(x)).unique()
# Out:
# array([<class 'float'>, <class 'str'>, <class 'int'>], dtype=object)

# %% [markdown]
# Turning floats to integers and then to strings

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int').astype('str')

# %% [markdown]
# Next I have to convert the Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 5    11017
# 4     1974
# 3      112
# Name: full_zip, dtype: int64

# %% [markdown]
# ####  This is noteworthy: there are no longer 9-digit-zip codes recorded with each record, only 5-digit zips.
# #### For the sake of consistency with previous years, I'll turn these to 9-digit codes, with extension 0000. And have a separate 5-digit-zip column.

# %% [markdown]
# I want to check the 3-digit zip codes, this looks fishy. Further research shows that zip codes in PR and VI start with 00.

# %%
black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) ==3
                ].state.value_counts()
# Out:
# PR    111
# VI      1
# Name: state, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 993     3110
# 2458    4619
# 2479    4106
# 3947    4495
# 4527    6001
# Name: full_zip, dtype: object

# %%
# adding leading zeros to the VERY short zip codes less to make them 5 digits.
# then I can add an "extension" to make them 9 digits.

idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 5    11017
# 9     2086
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ]['full_zip'].head()
# Out:
# 29      48060
# 638     31602
# 648     70791
# 870     87102
# 1078    76424
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# Series([], Name: full_zip, dtype: object)

# %%
# These are 5 digit zip codes that are missing leading zeros, plus a 4 digit extension. 
# I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    13103
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 5096

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    13103
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.

all_medicare.full_zip = all_medicare.full_zip.astype('int').astype('str')

idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5 digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    13103
# Name: full_zip, dtype: int64
# 5    13103
# Name: five_dig_zip, dtype: int64
# 9    5513
# Name: full_zip, dtype: int64
# 5    5513
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13103 entries, 29 to 1121194
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      13103 non-null  object
#  1   city                     13103 non-null  object
#  2   full_zip                 13103 non-null  object
#  3   state                    13103 non-null  object
#  4   country                  13103 non-null  object
#  5   provider_type            13103 non-null  object
#  6   total_beneficiaries      13103 non-null  object
#  7   total_medicare_payment   13103 non-null  float64
#  8   avg_beneficiary_age      13103 non-null  object
#  9   num_black                13103 non-null  float64
#  10  percent_with_depression  10235 non-null  float64
#  11  percent_with_psychosis   8423 non-null   float64
#  12  avg_hcc_risk_score       13103 non-null  float64
#  13  five_dig_zip             13103 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 2.1+ MB

# %% [markdown]
# #### This is noteworthy:
# #### For 2018 (as well as 2017), the number of rows with information for percent_with_depression is ALMOST complete!
# #### This is good news for data collection, and may be a good reason to use a dataframe that includes this col.

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5513 entries, 638 to 1119385
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      5513 non-null   object
#  1   city                     5513 non-null   object
#  2   full_zip                 5513 non-null   object
#  3   state                    5513 non-null   object
#  4   country                  5513 non-null   object
#  5   provider_type            5513 non-null   object
#  6   total_beneficiaries      5513 non-null   object
#  7   total_medicare_payment   5513 non-null   float64
#  8   avg_beneficiary_age      5513 non-null   object
#  9   num_white                5513 non-null   float64
#  10  num_black                5513 non-null   float64
#  11  num_asian_pac_isl        5513 non-null   float64
#  12  num_hispanic             5513 non-null   float64
#  13  num_nat_amer             5513 non-null   float64
#  14  num_race_unknown         5513 non-null   float64
#  15  percent_with_depression  3886 non-null   float64
#  16  percent_with_psychosis   2200 non-null   float64
#  17  avg_hcc_risk_score       5513 non-null   float64
#  18  five_dig_zip             5513 non-null   object
# dtypes: float64(10), object(9)
# memory usage: 1021.4+ KB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../../data/raw/2018acs.csv')

# %%
census.head()
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   87537  2014-01-01       2510         856      1283        1227
# 1   87017  2014-01-01        346         112       150         196
# 2   87528  2014-01-01       3505         727      1758        1747
# 3   87533  2014-01-01        133          58        49          84
# 4   87511  2014-01-01       2896         787      1177        1719
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  ...  \
# 0        42.1            58           75             87  ...
# 1        50.9             0            0             12  ...
# 2        27.9           260          194            159  ...
# 3        25.8             0           12              8  ...
# 4        36.0           142           63             44  ...
#
#    management_business_sci_arts_employed  sales_office_employed  \
# 0                                    NaN                    NaN
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                                    NaN                    NaN
#
#    in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0               304               171                 80        593
# 1                 0                27                 15         96
# 2               293               266                298       1237
# 3                24                 8                  7         58
# 4               263               107                163       1008
#
#    in_undergrad_college  speak_only_english_at_home  speak_spanish_at_home  \
# 0                    20                         NaN                    NaN
# 1                    40                         NaN                    NaN
# 2                   138                         NaN                    NaN
# 3                     3                         NaN                    NaN
# 4                   279                         NaN                    NaN
#
#    speak_spanish_at_home_low_english
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 240 columns]

# %%
# dropping do_date columns, which gives info on how numbers for this year were calculated
# but isn't useful for my investigation.

census.drop(columns=['do_date'], inplace=True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# speak_spanish_at_home_low_english                             float64
# speak_only_english_at_home                                    float64
# pop_divorced                                                  float64
# pop_widowed                                                   float64
# pop_separated                                                 float64
# pop_now_married                                               float64
# pop_never_married                                             float64
# pop_15_and_over                                               float64
# pop_5_years_over                                              float64
# speak_spanish_at_home                                         float64
# aggregate_travel_time_to_work                                 float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# median_income                                                 float64
# gini_index                                                    float64
# median_year_structure_built                                   float64
# income_per_capita                                             float64
# median_age                                                    float64
# population_1_year_and_over                                    float64
# high_school_including_ged                                     float64
# bachelors_degree_2                                            float64
# graduate_professional_degree                                  float64
# some_college_and_associates_degree                            float64
# different_house_year_ago_different_city                       float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_same_city                            float64
#
#                                                              non-null values  \
# speak_spanish_at_home_low_english                                          0
# speak_only_english_at_home                                                 0
# pop_divorced                                                               0
# pop_widowed                                                                0
# pop_separated                                                              0
# pop_now_married                                                            0
# pop_never_married                                                          0
# pop_15_and_over                                                            0
# pop_5_years_over                                                           0
# speak_spanish_at_home                                                      0
# aggregate_travel_time_to_work                                          20065
# median_rent                                                            26961
# renter_occupied_housing_units_paying_cash_median_gross_rent            27148
# percent_income_spent_on_rent                                           27524
# owner_occupied_housing_units_lower_value_quartile                      30154
# owner_occupied_housing_units_median_value                              30648
# owner_occupied_housing_units_upper_value_quartile                      30653
# median_income                                                          30891
# gini_index                                                             32172
# median_year_structure_built                                            32192
# income_per_capita                                                      32456
# median_age                                                             32556
# population_1_year_and_over                                             32954
# high_school_including_ged                                              32954
# bachelors_degree_2                                                     32954
# graduate_professional_degree                                           32954
# some_college_and_associates_degree                                     32954
# different_house_year_ago_different_city                                32954
# less_than_high_school_graduate                                         32954
# different_house_year_ago_same_city                                     32954
#
#                                                              unique values  \
# speak_spanish_at_home_low_english                                        0
# speak_only_english_at_home                                               0
# pop_divorced                                                             0
# pop_widowed                                                              0
# pop_separated                                                            0
# pop_now_married                                                          0
# pop_never_married                                                        0
# pop_15_and_over                                                          0
# pop_5_years_over                                                         0
# speak_spanish_at_home                                                    0
# aggregate_travel_time_to_work                                        17095
# median_rent                                                           2045
# renter_occupied_housing_units_paying_cash_median_gross_rent           2074
# percent_income_spent_on_rent                                           401
# owner_occupied_housing_units_lower_value_quartile                     4545
# owner_occupied_housing_units_median_value                             5485
# owner_occupied_housing_units_upper_value_quartile                     6611
# median_income                                                        19795
# gini_index                                                            4197
# median_year_structure_built                                             77
# income_per_capita                                                    21269
# median_age                                                             670
# population_1_year_and_over                                           15390
# high_school_including_ged                                             7198
# bachelors_degree_2                                                    6216
# graduate_professional_degree                                          4752
# some_college_and_associates_degree                                    7662
# different_house_year_ago_different_city                               4954
# less_than_high_school_graduate                                        4478
# different_house_year_ago_same_city                                    3486
#
#                                                              null values
# speak_spanish_at_home_low_english                                  33120
# speak_only_english_at_home                                         33120
# pop_divorced                                                       33120
# pop_widowed                                                        33120
# pop_separated                                                      33120
# pop_now_married                                                    33120
# pop_never_married                                                  33120
# pop_15_and_over                                                    33120
# pop_5_years_over                                                   33120
# speak_spanish_at_home                                              33120
# aggregate_travel_time_to_work                                      13055
# median_rent                                                         6159
# renter_occupied_housing_units_paying_cash_median_gross_rent         5972
# percent_income_spent_on_rent                                        5596
# owner_occupied_housing_units_lower_value_quartile                   2966
# owner_occupied_housing_units_median_value                           2472
# owner_occupied_housing_units_upper_value_quartile                   2467
# median_income                                                       2229
# gini_index                                                           948
# median_year_structure_built                                          928
# income_per_capita                                                    664
# median_age                                                           564
# population_1_year_and_over                                           166
# high_school_including_ged                                            166
# bachelors_degree_2                                                   166
# graduate_professional_degree                                         166
# some_college_and_associates_degree                                   166
# different_house_year_ago_different_city                              166
# less_than_high_school_graduate                                       166
# different_house_year_ago_same_city                                   166

# %% [markdown]
# Deleting columns with ZERO nonnull values. Weirdly these columns have info for all rows in the previous years.

# %%
allnull = list(info[info['non-null values']==0].index)
allnull
# Out:
# ['pop_5_years_over',
#  'pop_15_and_over',
#  'pop_never_married',
#  'pop_now_married',
#  'pop_separated',
#  'pop_widowed',
#  'pop_divorced',
#  'speak_only_english_at_home',
#  'speak_spanish_at_home',
#  'speak_spanish_at_home_low_english']

# %%
census.drop(columns = allnull, inplace = True)

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['23298', '71130', '48824', '11249', '27599', '03756', '20042', '94039',
#        '22908', '30031', '80437', '05302', '59402', '02178', '92369', '27699',
#        '35294', '90509', '28286', '29151', '65102', '44195', '55903', '78764',
#        '06030', '18934', '00977', '40536', '20883', '60567', '01936', '61637',
#        '21022', '47547', '92093', '29425', '06102', '75033', '00919', '06349',
#        '00908', '84132', '16544', '95671', '00820', '66160', '00963', '26506',
#        '46138', '00726', '24739', '84143', '92357', '20060', '65212', '98431',
#        '94143', '11571', '37684', '32163', '14642', '06504', '54305', '94141',
#        '14702', '01805', '21150', '38157', '58122', '06904', '10184', '35249',
#        '77555', '85220', '19450', '92161', '45408', '77204', '87131', '00792',
#        '02479', '27157', '29240', '01655', '32610', '92415', '21287', '27833',
#        '27710', '12511', '68198'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi      city   full_zip state country  \
# five_dig_zip
# 23298         1740376318  RICHMOND  232980000    VA      US
# 23298         1003951765  RICHMOND  232980000    VA      US
# 23298         1891193934  RICHMOND  232980000    VA      US
# 23298         1902205404  RICHMOND  232980000    VA      US
# 23298         1124109210  RICHMOND  232980000    VA      US
# ...                  ...       ...        ...   ...     ...
# 68198         1629382148     OMAHA  681980000    NE      US
# 68198         1710141288     OMAHA  681980000    NE      US
# 68198         1720039639     OMAHA  681980000    NE      US
# 68198         1952396434     OMAHA  681980000    NE      US
# 68198         1962694190     OMAHA  681980000    NE      US
#
#                                 provider_type total_beneficiaries  \
# five_dig_zip
# 23298         Licensed Clinical Social Worker                  39
# 23298                  Psychologist, Clinical                  53
# 23298                  Psychologist, Clinical                  38
# 23298                  Psychologist, Clinical                  33
# 23298                              Psychiatry                  60
# ...                                       ...                 ...
# 68198                              Psychiatry                 126
# 68198                              Psychiatry                 493
# 68198                              Psychiatry                 228
# 68198                              Psychiatry                 165
# 68198                              Psychiatry                 132
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 23298                       27053.32                  55       25.0
# 23298                        8280.89                  52       28.0
# 23298                       13608.33                  55       19.0
# 23298                        7931.33                  52       20.0
# 23298                        9465.52                  55       31.0
# ...                              ...                 ...        ...
# 68198                       18963.69                  46       30.0
# 68198                      126849.81                  56       11.0
# 68198                       32130.35                  59       23.0
# 68198                       20080.64                  52       22.0
# 68198                       22992.59                  47       21.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 23298                     1.4016
# 23298                     5.0138
# 23298                     2.0305
# 23298                     1.5347
# 23298                     1.7464
# ...                          ...
# 68198                     1.0877
# 68198                     1.2102
# 68198                     2.7361
# 68198                     1.5533
# 68198                     1.5036
#
# [238 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 5005
# 5005

# %% [markdown]
# Dropping those same zip codes from the Census DF.

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %% [markdown]
# Reviewing Null Values

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# median_rent                                                   float64
# percent_income_spent_on_rent                                  float64
# bachelors_degree_2                                            float64
# some_college_and_associates_degree                            float64
# high_school_including_ged                                     float64
# less_than_high_school_graduate                                float64
# population_1_year_and_over                                    float64
# different_house_year_ago_different_city                       float64
# different_house_year_ago_same_city                            float64
# graduate_professional_degree                                  float64
# not_us_citizen_pop                                            float64
# median_income                                                 float64
# gini_index                                                    float64
# median_year_structure_built                                   float64
# income_per_capita                                             float64
# median_age                                                    float64
# income_30000_34999                                            float64
# commuters_16_over                                             float64
# income_less_10000                                             float64
# pop_determined_poverty_status                                 float64
# income_10000_14999                                            float64
# income_15000_19999                                            float64
# income_20000_24999                                            float64
# income_200000_or_more                                         float64
# income_150000_199999                                          float64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           4756
# owner_occupied_housing_units_lower_value_quartile                       4939
# owner_occupied_housing_units_median_value                               4943
# owner_occupied_housing_units_upper_value_quartile                       4945
# renter_occupied_housing_units_paying_cash_median_gross_rent             4949
# median_rent                                                             4949
# percent_income_spent_on_rent                                            4953
# bachelors_degree_2                                                      4960
# some_college_and_associates_degree                                      4960
# high_school_including_ged                                               4960
# less_than_high_school_graduate                                          4960
# population_1_year_and_over                                              4960
# different_house_year_ago_different_city                                 4960
# different_house_year_ago_same_city                                      4960
# graduate_professional_degree                                            4960
# not_us_citizen_pop                                                      4961
# median_income                                                           4964
# gini_index                                                              4967
# median_year_structure_built                                             4968
# income_per_capita                                                       4990
# median_age                                                              4992
# income_30000_34999                                                      5004
# commuters_16_over                                                       5004
# income_less_10000                                                       5004
# pop_determined_poverty_status                                           5004
# income_10000_14999                                                      5004
# income_15000_19999                                                      5004
# income_20000_24999                                                      5004
# income_200000_or_more                                                   5004
# income_150000_199999                                                    5004
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         4682
# owner_occupied_housing_units_lower_value_quartile                     2808
# owner_occupied_housing_units_median_value                             3158
# owner_occupied_housing_units_upper_value_quartile                     3413
# renter_occupied_housing_units_paying_cash_median_gross_rent           1514
# median_rent                                                           1526
# percent_income_spent_on_rent                                           300
# bachelors_degree_2                                                    3849
# some_college_and_associates_degree                                    3993
# high_school_including_ged                                             3916
# less_than_high_school_graduate                                        2967
# population_1_year_and_over                                            4727
# different_house_year_ago_different_city                               3344
# different_house_year_ago_same_city                                    2567
# graduate_professional_degree                                          3447
# not_us_citizen_pop                                                    2802
# median_income                                                         4808
# gini_index                                                            1885
# median_year_structure_built                                             74
# income_per_capita                                                     4705
# median_age                                                             411
# income_30000_34999                                                    1247
# commuters_16_over                                                     4541
# income_less_10000                                                     1735
# pop_determined_poverty_status                                         4741
# income_10000_14999                                                    1333
# income_15000_19999                                                    1298
# income_20000_24999                                                    1300
# income_200000_or_more                                                 2038
# income_150000_199999                                                  1789
#
#                                                              null values
# aggregate_travel_time_to_work                                        249
# owner_occupied_housing_units_lower_value_quartile                     66
# owner_occupied_housing_units_median_value                             62
# owner_occupied_housing_units_upper_value_quartile                     60
# renter_occupied_housing_units_paying_cash_median_gross_rent           56
# median_rent                                                           56
# percent_income_spent_on_rent                                          52
# bachelors_degree_2                                                    45
# some_college_and_associates_degree                                    45
# high_school_including_ged                                             45
# less_than_high_school_graduate                                        45
# population_1_year_and_over                                            45
# different_house_year_ago_different_city                               45
# different_house_year_ago_same_city                                    45
# graduate_professional_degree                                          45
# not_us_citizen_pop                                                    44
# median_income                                                         41
# gini_index                                                            38
# median_year_structure_built                                           37
# income_per_capita                                                     15
# median_age                                                            13
# income_30000_34999                                                     1
# commuters_16_over                                                      1
# income_less_10000                                                      1
# pop_determined_poverty_status                                          1
# income_10000_14999                                                     1
# income_15000_19999                                                     1
# income_20000_24999                                                     1
# income_200000_or_more                                                  1
# income_150000_199999                                                   1

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls.
#
# This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (56, 56)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 4949 4949
# 3185 4949
# 3126 4949

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(10)
# Out:
#                                         data type  non-null values  \
# population_1_year_and_over                float64             4904
# less_than_high_school_graduate            float64             4904
# some_college_and_associates_degree        float64             4904
# graduate_professional_degree              float64             4904
# high_school_including_ged                 float64             4904
# different_house_year_ago_same_city        float64             4904
# bachelors_degree_2                        float64             4904
# different_house_year_ago_different_city   float64             4904
# not_us_citizen_pop                        float64             4905
# median_income                             float64             4946
#
#                                          unique values  null values
# population_1_year_and_over                        4683           45
# less_than_high_school_graduate                    2961           45
# some_college_and_associates_degree                3967           45
# graduate_professional_degree                      3437           45
# high_school_including_ged                         3888           45
# different_house_year_ago_same_city                2567           45
# bachelors_degree_2                                3826           45
# different_house_year_ago_different_city           3323           45
# not_us_citizen_pop                                2802           44
# median_income                                     4797            3

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (45, 45)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# deleting rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#               data type  non-null values  unique values  null values
# median_income   float64             4902           4755            2

# %% [markdown]
# ##### Median_income
#
# Just like median_rent, this column seems important and I'd like to keep it. Dropping zip codes that have nulls in this column.

# %%
mask = census.median_income.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (2, 2)

# %%
black_medicare[
    black_medicare.five_dig_zip.isin(
        census[census.median_income.isnull()].geo_id
    )
]
# Out:
#                 npi              city   full_zip state country  \
# 256650   1225436884         MARLINTON  248540000    WV      US
# 1044071  1932134459  JEFFERSON VALLEY  105350000    NY      US
#
#                            provider_type total_beneficiaries  \
# 256650   Licensed Clinical Social Worker                  27
# 1044071           Psychologist, Clinical                  14
#
#          total_medicare_payment avg_beneficiary_age  num_black  \
# 256650                  6417.64                  54        0.0
# 1044071                19883.39                  67        0.0
#
#          avg_hcc_risk_score five_dig_zip
# 256650               1.3765        24854
# 1044071              0.7798        10535

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)

#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((12595, 12), (6914, 14), (5309, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    4902
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [59]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../../data/processed/2018black_medicare_census.csv')

#saving all races medicare df merged
disorders_merged.to_csv('../../data/processed/2018black_medicare_with_disorders_census.csv')

#saving black_medicare with disorder values merged
all_merged.to_csv('../../data/processed/2018all_races_medicare_census.csv')
