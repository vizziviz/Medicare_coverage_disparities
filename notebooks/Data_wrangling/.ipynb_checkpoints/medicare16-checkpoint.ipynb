# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2016.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1053958, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        D.O.                      M
# 4                        M.D.                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
# 2                           I       4126 N HOLLAND SYLVANIA RD
# 3                           I                  100 HOSPITAL RD
# 4                           I                 11100 EUCLID AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
# 2                        SUITE 220               TOLEDO  ...
# 3                              NaN           BROOKVILLE  ...
# 4                              NaN            CLEVELAND  ...
#
#   Percent (%) of Beneficiaries Identified With Depression  \
# 0                                                    42.0
# 1                                                    13.0
# 2                                                    50.0
# 3                                                    47.0
# 4                                                    28.0
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                                  53.0
# 1                                                  21.0
# 2                                                  37.0
# 3                                                  40.0
# 4                                                  27.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                                        67.0
# 1                                                        46.0
# 2                                                        53.0
# 3                                                        69.0
# 4                                                        41.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                                      75.0
# 1                                                      54.0
# 2                                                      73.0
# 3                                                      75.0
# 4                                                      52.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                                                53.0
# 1                                                                26.0
# 2                                                                37.0
# 3                                                                64.0
# 4                                                                21.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                                       12.0
# 1                                                        9.0
# 2                                                        8.0
# 3                                                       15.0
# 4                                                        NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                                                                49.0
# 1                                                                                38.0
# 2                                                                                75.0
# 3                                                                                43.0
# 4                                                                                46.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                                                     9.0
# 1                                                                                     1.0
# 2                                                                                     6.0
# 3                                                                                    12.0
# 4                                                                                     NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                                 13.0
# 1                                                  3.0
# 2                                                  5.0
# 3                                                 14.0
# 4                                                  0.0
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.0239
# 1                                   1.0925
# 2                                   1.5809
# 3                                   2.0000
# 4                                   0.9540
#
# [5 rows x 70 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries\t',
#        'Number of Non-Hispanic White Beneficiaries\t',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# National Provider Identifier                                                               int64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Standardized Payment Amount                                               float64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charge Amount                                                            float64
# Number of Medicare Beneficiaries                                                           int64
# Number of Services                                                                       float64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type of the Provider                                                             object
# Country Code of the Provider                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
# Entity Type of the Provider                                                               object
# State Code of the Provider                                                                object
# Zip Code of the Provider                                                                  object
# City of the Provider                                                                      object
# Street Address 1 of the Provider                                                          object
# Last Name/Organization Name of the Provider                                               object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Gender of the Provider                                                                    object
# First Name of the Provider                                                                object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Submitted Charge Amount                                                    float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Number of Drug Services                                                                  float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries\t                                                           float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Number of Non-Hispanic White Beneficiaries\t                                             float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Number of Beneficiaries Age Less 65                                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Street Address 2 of the Provider                                                          object
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
#
#                                                                                         non-null values  \
# National Provider Identifier                                                                    1053958
# Average Age of Beneficiaries                                                                    1053958
# Total Medicare Standardized Payment Amount                                                      1053958
# Total Medicare Payment Amount                                                                   1053958
# Total Medicare Allowed Amount                                                                   1053958
# Total Submitted Charge Amount                                                                   1053958
# Number of Medicare Beneficiaries                                                                1053958
# Number of Services                                                                              1053958
# Number of HCPCS                                                                                 1053958
# Medicare Participation Indicator                                                                1053958
# Provider Type of the Provider                                                                   1053958
# Country Code of the Provider                                                                    1053958
# Average HCC Risk Score of Beneficiaries                                                         1053958
# Entity Type of the Provider                                                                     1053958
# State Code of the Provider                                                                      1053958
# Zip Code of the Provider                                                                        1053957
# City of the Provider                                                                            1053957
# Street Address 1 of the Provider                                                                1053957
# Last Name/Organization Name of the Provider                                                     1053938
# Percent (%) of Beneficiaries Identified With Hypertension                                        998630
# Gender of the Provider                                                                           991362
# First Name of the Provider                                                                       991350
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                      972206
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis               952710
# Credentials of the Provider                                                                      950388
# Total Medical Medicare Standardized Payment Amount                                               944587
# Total Medical Medicare Payment Amount                                                            944587
# Total Medical Medicare Allowed Amount                                                            944587
# Number of Medicare Beneficiaries With Medical Services                                           944587
# Number of Medical Services                                                                       944587
# Number of HCPCS Associated With Medical Services                                                 944587
# Total Medical Submitted Charge Amount                                                            944587
# Total Drug Medicare Standardized Payment Amount                                                  944587
# Number of Drug Services                                                                          944587
# Number of Medicare Beneficiaries With Drug Services                                              944587
# Total Drug Submitted Charge Amount                                                               944587
# Number of HCPCS Associated With Drug Services                                                    944587
# Total Drug Medicare Payment Amount                                                               944587
# Total Drug Medicare Allowed Amount                                                               944587
# Number of Female Beneficiaries                                                                   939127
# Number of Male Beneficiaries\t                                                                   939127
# Percent (%) of Beneficiaries Identified With Diabetes                                            904809
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              895875
# Number of Beneficiaries Age 65 to 74                                                             888346
# Percent (%) of Beneficiaries Identified With Depression                                          887371
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              879680
# Percent (%) of Beneficiaries Identified With Asthma                                              815002
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     792145
# Number of Beneficiaries With Medicare Only Entitlement                                           792145
# Percent (%) of Beneficiaries Identified With Heart Failure                                       789045
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               772260
# Number of Beneficiaries Age 75 to 84                                                             752164
# Middle Initial of the Provider                                                                   717380
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 713521
# Number of Non-Hispanic White Beneficiaries\t                                                     709170
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     707582
# Percent (%) of Beneficiaries Identified With Cancer                                              706923
# Number of Beneficiaries Age Less 65                                                              693992
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        656229
# Number of Beneficiaries Age Greater 84                                                           628371
# Percent (%) of Beneficiaries Identified With Stroke                                              577085
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           506929
# Street Address 2 of the Provider                                                                 414480
# Number of Black or African American Beneficiaries                                                362465
# Number of American Indian/Alaska Native Beneficiaries                                            313814
# Number of Hispanic Beneficiaries                                                                 282218
# Number of Asian Pacific Islander Beneficiaries                                                   186022
# Number of Beneficiaries With Race Not Elsewhere Classified                                       162371
# Medical Suppress Indicator                                                                       109371
# Drug Suppress Indicator                                                                          109371
#
#                                                                                         unique values  \
# National Provider Identifier                                                                  1053958
# Average Age of Beneficiaries                                                                       87
# Total Medicare Standardized Payment Amount                                                     997273
# Total Medicare Payment Amount                                                                  996932
# Total Medicare Allowed Amount                                                                 1009801
# Total Submitted Charge Amount                                                                  717858
# Number of Medicare Beneficiaries                                                                 6961
# Number of Services                                                                              40831
# Number of HCPCS                                                                                   478
# Medicare Participation Indicator                                                                    2
# Provider Type of the Provider                                                                      91
# Country Code of the Provider                                                                       22
# Average HCC Risk Score of Beneficiaries                                                         45220
# Entity Type of the Provider                                                                         2
# State Code of the Provider                                                                         61
# Zip Code of the Provider                                                                       348521
# City of the Provider                                                                            13004
# Street Address 1 of the Provider                                                               358093
# Last Name/Organization Name of the Provider                                                    259125
# Percent (%) of Beneficiaries Identified With Hypertension                                          66
# Gender of the Provider                                                                              2
# First Name of the Provider                                                                      66445
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        71
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 72
# Credentials of the Provider                                                                     16260
# Total Medical Medicare Standardized Payment Amount                                             870192
# Total Medical Medicare Payment Amount                                                          890784
# Total Medical Medicare Allowed Amount                                                          902031
# Number of Medicare Beneficiaries With Medical Services                                           6889
# Number of Medical Services                                                                      26162
# Number of HCPCS Associated With Medical Services                                                  476
# Total Medical Submitted Charge Amount                                                          636202
# Total Drug Medicare Standardized Payment Amount                                                234359
# Number of Drug Services                                                                         23905
# Number of Medicare Beneficiaries With Drug Services                                              1166
# Total Drug Submitted Charge Amount                                                             156336
# Number of HCPCS Associated With Drug Services                                                     115
# Total Drug Medicare Payment Amount                                                             234269
# Total Drug Medicare Allowed Amount                                                             237060
# Number of Female Beneficiaries                                                                   4870
# Number of Male Beneficiaries\t                                                                   3683
# Percent (%) of Beneficiaries Identified With Diabetes                                              74
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Number of Beneficiaries Age 65 to 74                                                             3524
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                73
# Percent (%) of Beneficiaries Identified With Asthma                                                75
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     3069
# Number of Beneficiaries With Medicare Only Entitlement                                           5709
# Percent (%) of Beneficiaries Identified With Heart Failure                                         76
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 76
# Number of Beneficiaries Age 75 to 84                                                             2901
# Middle Initial of the Provider                                                                     32
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Number of Non-Hispanic White Beneficiaries\t                                                     6156
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Number of Beneficiaries Age Less 65                                                              2104
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          76
# Number of Beneficiaries Age Greater 84                                                           2155
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# Street Address 2 of the Provider                                                                73911
# Number of Black or African American Beneficiaries                                                2077
# Number of American Indian/Alaska Native Beneficiaries                                             514
# Number of Hispanic Beneficiaries                                                                 1625
# Number of Asian Pacific Islander Beneficiaries                                                   1091
# Number of Beneficiaries With Race Not Elsewhere Classified                                        574
# Medical Suppress Indicator                                                                          2
# Drug Suppress Indicator                                                                             2
#
#                                                                                         null values
# National Provider Identifier                                                                      0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charge Amount                                                                     0
# Number of Medicare Beneficiaries                                                                  0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type of the Provider                                                                     0
# Country Code of the Provider                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0
# Entity Type of the Provider                                                                       0
# State Code of the Provider                                                                        0
# Zip Code of the Provider                                                                          1
# City of the Provider                                                                              1
# Street Address 1 of the Provider                                                                  1
# Last Name/Organization Name of the Provider                                                      20
# Percent (%) of Beneficiaries Identified With Hypertension                                     55328
# Gender of the Provider                                                                        62596
# First Name of the Provider                                                                    62608
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   81752
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis           101248
# Credentials of the Provider                                                                  103570
# Total Medical Medicare Standardized Payment Amount                                           109371
# Total Medical Medicare Payment Amount                                                        109371
# Total Medical Medicare Allowed Amount                                                        109371
# Number of Medicare Beneficiaries With Medical Services                                       109371
# Number of Medical Services                                                                   109371
# Number of HCPCS Associated With Medical Services                                             109371
# Total Medical Submitted Charge Amount                                                        109371
# Total Drug Medicare Standardized Payment Amount                                              109371
# Number of Drug Services                                                                      109371
# Number of Medicare Beneficiaries With Drug Services                                          109371
# Total Drug Submitted Charge Amount                                                           109371
# Number of HCPCS Associated With Drug Services                                                109371
# Total Drug Medicare Payment Amount                                                           109371
# Total Drug Medicare Allowed Amount                                                           109371
# Number of Female Beneficiaries                                                               114831
# Number of Male Beneficiaries\t                                                               114831
# Percent (%) of Beneficiaries Identified With Diabetes                                        149149
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                          158083
# Number of Beneficiaries Age 65 to 74                                                         165612
# Percent (%) of Beneficiaries Identified With Depression                                      166587
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                          174278
# Percent (%) of Beneficiaries Identified With Asthma                                          238956
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                 261813
# Number of Beneficiaries With Medicare Only Entitlement                                       261813
# Percent (%) of Beneficiaries Identified With Heart Failure                                   264913
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease           281698
# Number of Beneficiaries Age 75 to 84                                                         301794
# Middle Initial of the Provider                                                               336578
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                             340437
# Number of Non-Hispanic White Beneficiaries\t                                                 344788
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                 346376
# Percent (%) of Beneficiaries Identified With Cancer                                          347035
# Number of Beneficiaries Age Less 65                                                          359966
# Percent (%) of Beneficiaries Identified With Osteoporosis                                    397729
# Number of Beneficiaries Age Greater 84                                                       425587
# Percent (%) of Beneficiaries Identified With Stroke                                          476873
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders       547029
# Street Address 2 of the Provider                                                             639478
# Number of Black or African American Beneficiaries                                            691493
# Number of American Indian/Alaska Native Beneficiaries                                        740144
# Number of Hispanic Beneficiaries                                                             771740
# Number of Asian Pacific Islander Beneficiaries                                               867936
# Number of Beneficiaries With Race Not Elsewhere Classified                                   891587
# Medical Suppress Indicator                                                                   944587
# Drug Suppress Indicator                                                                      944587

# %% [markdown]
# Looking at Row where Zip Code is Null

# %%
med.loc[med['Zip Code of the Provider'].isnull()]
# Out:
#         National Provider Identifier  \
# 621060                    1588870349
#
#        Last Name/Organization Name of the Provider First Name of the Provider  \
# 621060                                      WIXSON                     SANDRA
#
#        Middle Initial of the Provider Credentials of the Provider  \
# 621060                              J                       PH.D.
#
#        Gender of the Provider Entity Type of the Provider  \
# 621060                      F                           I
#
#        Street Address 1 of the Provider Street Address 2 of the Provider  \
# 621060            ROTUNDA 8, CASA # 163                            ULLOA
#
#        City of the Provider  ...  \
# 621060                ULLOA  ...
#
#        Percent (%) of Beneficiaries Identified With Depression  \
# 621060                                                    75.0
#
#        Percent (%) of Beneficiaries Identified With Diabetes  \
# 621060                                                   NaN
#
#        Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 621060                                                         NaN
#
#        Percent (%) of Beneficiaries Identified With Hypertension  \
# 621060                                                       NaN
#
#        Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 621060                                                                 NaN
#
#         Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 621060                                                        0.0
#
#         Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 621060                                                                                 NaN
#
#         Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 621060                                                                                     NaN
#
#         Percent (%) of Beneficiaries Identified With Stroke  \
# 621060                                                  0.0
#
#         Average HCC Risk Score of Beneficiaries
# 621060                                   0.7541
#
# [1 rows x 70 columns]

# %% [markdown]
# Dropping this Column

# %%
idx = med.loc[med['Zip Code of the Provider'].isnull()].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Looking at Nulls Again

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})
info[info['null values']==0]
# Out:
#                                            data type  non-null values  \
# National Provider Identifier                   int64          1053957
# Entity Type of the Provider                   object          1053957
# Zip Code of the Provider                      object          1053957
# State Code of the Provider                    object          1053957
# Country Code of the Provider                  object          1053957
# Provider Type of the Provider                 object          1053957
# Medicare Participation Indicator              object          1053957
# Number of HCPCS                                int64          1053957
# Number of Services                           float64          1053957
# Number of Medicare Beneficiaries               int64          1053957
# Total Submitted Charge Amount                float64          1053957
# Total Medicare Allowed Amount                float64          1053957
# Total Medicare Payment Amount                float64          1053957
# Total Medicare Standardized Payment Amount   float64          1053957
# Average Age of Beneficiaries                   int64          1053957
# Average HCC Risk Score of Beneficiaries      float64          1053957
#
#                                             unique values  null values
# National Provider Identifier                      1053957            0
# Entity Type of the Provider                             2            0
# Zip Code of the Provider                           348521            0
# State Code of the Provider                             61            0
# Country Code of the Provider                           21            0
# Provider Type of the Provider                          91            0
# Medicare Participation Indicator                        2            0
# Number of HCPCS                                       478            0
# Number of Services                                  40831            0
# Number of Medicare Beneficiaries                     6961            0
# Total Submitted Charge Amount                      717858            0
# Total Medicare Allowed Amount                     1009801            0
# Total Medicare Payment Amount                      996931            0
# Total Medicare Standardized Payment Amount         997272            0
# Average Age of Beneficiaries                           87            0
# Average HCC Risk Score of Beneficiaries             45220            0

# %% [markdown]
# Dropping Rest of Cols that have null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (1053957, 70)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (1053957, 16)

# %%
med.columns
# Out:
# Index(['National Provider Identifier', 'Entity Type of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                 'Total Medicare Standardized Payment Amount':'total_medicare_standardized_payment',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'NPPES Provider Street Address 1':'address',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charge Amount':'total_submitted_charges',
                 'Entity Type of the Provider':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['MD', 'IL', 'OH', 'PA', 'CO', 'FL', 'OK', 'CA', 'TX', 'OR', 'KY',
#        'SC', 'NM', 'MO', 'NY', 'MI', 'GA', 'NJ', 'LA', 'TN', 'MA', 'WA',
#        'NH', 'MN', 'ME', 'CT', 'DC', 'NC', 'NV', 'HI', 'MS', 'IA', 'VA',
#        'ND', 'IN', 'NE', 'AZ', 'AL', 'PR', 'WY', 'DE', 'KS', 'RI', 'WI',
#        'ID', 'AR', 'MT', 'WV', 'VT', 'AE', 'UT', 'SD', 'AK', 'GU', 'VI',
#        'MP', 'AA', 'AP', 'XX', 'AS'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code   full_zip state country  \
# 26931   1023150414           I      21287    MP      US
# 65870   1063459428           I  969501908    MP      US
# 129511  1124064274           I      96950    MP      US
# 165093  1154508067           I      96950    MP      US
# 193555  1184653172           I      96950    MP      US
#
#                                  provider_type  \
# 26931                           Anesthesiology
# 65870                        Internal Medicine
# 129511                      Emergency Medicine
# 165093  Physical Therapist in Private Practice
# 193555                         Family Practice
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 26931                                 Y               63               275.0
# 65870                                 Y               13              1213.0
# 129511                                Y               14               144.0
# 165093                                Y                9               994.0
# 193555                                Y               30              2503.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 26931                   166                456517.50               61053.59
# 65870                   256                 95650.84               91769.72
# 129511                  105                 94570.00               13616.12
# 165093                   32                 39054.65               23502.60
# 193555                  288                266180.30              256621.83
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 26931                 47269.90                             43310.90
# 65870                 55463.61                             54287.37
# 129511                10626.40                             10786.31
# 165093                17013.80                             16594.53
# 193555               189043.13                            194132.73
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 26931                    69              1.5363
# 65870                    71              0.8058
# 129511                   69              1.5904
# 165093                   69              1.1351
# 193555                   67              2.2882

# %%
#this line was accidentally mislabeled with state "MP" instead of state "MD" in the Med DFs from most years
med.loc[med.npi == 1023150414, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
#make all zips ints first
med.full_zip = med.full_zip.apply(lambda x: str(x).replace('-',''))
med.full_zip = med.full_zip.apply(lambda x: str(x).replace(' ',''))
med.full_zip = med.full_zip.apply(lambda x: int(float(x)))

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    861738
# 8     88751
# 5     84463
# 4     13001
# 7      3249
# 3      2677
# 2         2
# 1         2
# Name: full_zip, dtype: int64

# %%
med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2]
# Out:
#                npi entity_code  full_zip state country  \
# 117534  1114060506           I         0    MA      US
# 336458  1316958416           I         0    XX      US
# 387803  1366672248           I        96    PR      US
# 702226  1669551479           I        80    PR      US
#
#                                         provider_type  \
# 117534                             Emergency Medicine
# 336458  Certified Registered Nurse Anesthetist (CRNA)
# 387803                                      Neurology
# 702226                                        Urology
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 117534                                Y               29              1620.0
# 336458                                Y               11                23.0
# 387803                                Y                6                79.0
# 702226                                Y               16               235.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 117534                 1005                649012.00              176630.75
# 336458                   23                 24500.00                5036.75
# 387803                   30                 10378.03               10374.11
# 702226                   90                 22137.31               19982.78
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 117534               136228.96                            136338.08
# 336458                 3948.81                              4000.35
# 387803                 7680.96                              9775.23
# 702226                13786.57                             16535.27
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 117534                   72              2.2092
# 336458                   74              1.0163
# 387803                   71              1.5167
# 702226                   75              1.4090

# %%
idx = med[
    med.full_zip.apply(lambda x: len(str(x))) <= 2].index[:2]
med.drop(index = idx, inplace = True)

# %%
med[
    (med.full_zip.apply(lambda x: 5 < len(str(x)) < 9))]
# Out:
#                 npi entity_code  full_zip state country  \
# 33       1003002072           I  86903701    NJ      US
# 37       1003002312           I  21690917    MA      US
# 52       1003003088           I  88241524    NJ      US
# 59       1003004185           I  38017128    NH      US
# 69       1003005059           O  67905055    CT      US
# ...             ...         ...       ...   ...     ...
# 1053894  1992995880           I  21485100    MA      US
# 1053895  1992995989           I  21901845    MA      US
# 1053919  1992997050           I  67083104    CT      US
# 1053929  1992997423           I  21391047    MA      US
# 1053941  1992998553           I  40059449    ME      US
#
#                                   provider_type  \
# 33                                      Urology
# 37                                 Rheumatology
# 52       Physical Therapist in Private Practice
# 59                          Physician Assistant
# 69                 Mass Immunizer Roster Biller
# ...                                         ...
# 1053894         Licensed Clinical Social Worker
# 1053895                             Audiologist
# 1053919            Oral Surgery (Dentists only)
# 1053929                     Physician Assistant
# 1053941                 Obstetrics & Gynecology
#
#         medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 33                                     Y               97              5397.0
# 37                                     Y               48             68454.0
# 52                                     Y                6              3816.0
# 59                                     Y               19               532.0
# 69                                     Y                4               462.0
# ...                                  ...              ...                 ...
# 1053894                                Y                3                51.0
# 1053895                                Y                8               222.0
# 1053919                                Y                8                18.0
# 1053929                                Y               10                42.0
# 1053941                                Y               19               186.0
#
#          total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 33                       863               2649008.12              471727.69
# 37                       539               3511735.00             1630065.44
# 52                       149                225285.00              112507.36
# 59                       389                530705.00               50911.28
# 69                       230                 15148.16               15079.46
# ...                      ...                      ...                    ...
# 1053894                   11                  6330.00                3435.76
# 1053895                  153                 19016.00                8109.63
# 1053919                   17                  4482.47                4033.44
# 1053929                   40                 13050.00                2989.98
# 1053941                   87                 22907.00               13365.46
#
#          total_medicare_payment  total_medicare_standardized_payment  \
# 33                    362839.69                            344220.76
# 37                   1258525.52                           1241484.97
# 52                     85006.09                             83189.26
# 59                     38832.40                             38817.76
# 69                     14778.45                             14205.60
# ...                         ...                                  ...
# 1053894                 2351.91                              2843.06
# 1053895                 6155.87                              5779.54
# 1053919                 3162.22                              3336.03
# 1053929                 2257.16                              2161.13
# 1053941                10119.88                             10293.87
#
#          avg_beneficiary_age  avg_hcc_risk_score
# 33                        71              1.9637
# 37                        73              1.3336
# 52                        74              1.1450
# 59                        70              1.7557
# 69                        79              0.9572
# ...                      ...                 ...
# 1053894                   52              1.0852
# 1053895                   78              1.2640
# 1053919                   75              1.2654
# 1053929                   70              2.1799
# 1053941                   66              1.0285
#
# [92000 rows x 16 columns]

# %% [markdown]
# My assumption with these is that they are missing the leading zeros for the 5 digit zip code, but they have all 4 digits of the zip extension. Checking several of these by looking up the NPI and matching zip confirms this assumption.

# %%
def make_five_digit_zip(df, zipcol):
    #make all entries integers (because some are floats)
    df[zipcol].apply(lambda x: int(x))
    
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# Checking DF zips:

# %%
med[(med.full_zip.str.startswith('00')) & (~med.state.str.contains('PR|VI|XX', regex=True))]
# Out:
#                 npi entity_code full_zip state country  \
# 25983    1023108586           I    00802    VT      US
# 221590   1205990884           I    00683    RI      US
# 408461   1386790707           I    00802    VA      US
# 547641   1518971001           I    00115    MA      US
# 702250   1669552170           I    00873    NJ      US
# 719568   1689617326           I    00824    NJ      US
# 797308   1750491288           I    00617    IL      US
# 1004664  1952378127           I    00648    CT      US
#
#                                          provider_type  \
# 25983                                        Pathology
# 221590                                  Anesthesiology
# 408461                                  Anesthesiology
# 547641             Cardiovascular Disease (Cardiology)
# 702250                                    Chiropractic
# 719568   Certified Registered Nurse Anesthetist (CRNA)
# 797308                                        Podiatry
# 1004664                                    Dermatology
#
#         medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 25983                                  Y               11               683.0
# 221590                                 Y               37               237.0
# 408461                                 Y               53               401.0
# 547641                                 Y               18              1146.0
# 702250                                 Y                1               328.0
# 719568                                 Y               57               418.0
# 797308                                 Y               35              1523.0
# 1004664                                Y               38              7364.0
#
#          total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 25983                    371                 45629.28               24574.92
# 221590                   186                 88898.34               87078.71
# 408461                   350                330499.49               44318.10
# 547641                   449                400855.00              113279.26
# 702250                    34                 16355.00               14461.52
# 719568                   399                628156.40               39645.47
# 797308                   761                173468.00              104936.60
# 1004664                  906                800138.00              361081.73
#
#          total_medicare_payment  total_medicare_standardized_payment  \
# 25983                  19037.23                             22544.29
# 221590                 67818.22                             76041.68
# 408461                 33983.41                             36746.46
# 547641                 87566.13                             86489.62
# 702250                 11205.56                             10464.56
# 719568                 30738.88                             29751.19
# 797308                 78585.88                             73964.72
# 1004664               261317.95                            240076.38
#
#          avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 25983                     72              1.1374                 1.84
# 221590                    71              2.9610                 1.27
# 408461                    72              1.0163                 1.15
# 547641                    76              2.4175                 2.55
# 702250                    72              1.1898                 9.65
# 719568                    71              1.6582                 1.05
# 797308                    73              1.8951                 2.00
# 1004664                   74              1.0818                 8.13
#
#          allowed_payment_per_capita  medicare_payment_per_capita  \
# 25983                         66.24                        51.31
# 221590                       468.17                       364.61
# 408461                       126.62                        97.10
# 547641                       252.29                       195.02
# 702250                       425.34                       329.58
# 719568                        99.36                        77.04
# 797308                       137.89                       103.27
# 1004664                      398.54                       288.43
#
#          submitted_charges_per_capita
# 25983                          122.99
# 221590                         477.95
# 408461                         944.28
# 547641                         892.77
# 702250                         481.03
# 719568                        1574.33
# 797308                         227.95
# 1004664                        883.15

# %%
idx = med[(med.full_zip.str.startswith('00')) & (~med.state.str.contains('PR|VI|XX', regex=True))].index
df = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2016.csv")
df.loc[idx, 'Zip Code of the Provider']]
# Out:
#         Zip Code of the Provider
# 25983                      00802
# 221590                       683
# 408461                       802
# 547641                       115
# 702250                   8732600
# 719568                       824
# 797308                       617
# 1004664                      648

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country        provider_type  \
# 0  1003000126           I    21502    MD      US    Internal Medicine
# 1  1003006586           I    20832    MD      US    Internal Medicine
# 2  1003006800           I    21202    MD      US  Physician Assistant
# 3  1003007816           I    20910    MD      US        Ophthalmology
# 4  1003007824           I    21201    MD      US    Internal Medicine
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               23              1477.0
# 1                                Y               14              1583.0
# 2                                Y               16                81.0
# 3                                Y               35              2767.0
# 4                                Y               21               181.0
#
#    total_beneficiaries  ...  total_medicare_standardized_payment  \
# 0                  518  ...                            126129.38
# 1                  579  ...                            115349.97
# 2                   69  ...                              7630.64
# 3                  665  ...                            195641.00
# 4                   72  ...                              7943.64
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   75              2.0239                 2.85
# 1                   80              2.3114                 2.73
# 2                   70              1.0178                 1.17
# 3                   79              1.3003                 4.16
# 4                   64              1.5482                 2.51
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                      308.80                       240.92
# 1                      283.82                       217.84
# 2                      193.25                       151.51
# 3                      453.27                       328.98
# 4                      153.66                       119.33
#
#    submitted_charges_per_capita  State Code  Region        Division
# 0                       1441.18          MD   South  South Atlantic
# 1                        523.66          MD   South  South Atlantic
# 2                        529.81          MD   South  South Atlantic
# 3                        792.66          MD   South  South Atlantic
# 4                        230.89          MD   South  South Atlantic
#
# [5 rows x 23 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1047652 entries, 0 to 1047651
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   npi                                  1047652 non-null  int64
#  1   entity_code                          1047652 non-null  object
#  2   full_zip                             1047652 non-null  object
#  3   state                                1047652 non-null  object
#  4   country                              1047652 non-null  object
#  5   provider_type                        1047652 non-null  object
#  6   medicare_participation_indicator     1047652 non-null  object
#  7   number_of_hcpcs                      1047652 non-null  int64
#  8   number_of_services                   1047652 non-null  float64
#  9   total_beneficiaries                  1047652 non-null  int64
#  10  total_submitted_charges              1047652 non-null  float64
#  11  total_allowed_payment                1047652 non-null  float64
#  12  total_medicare_payment               1047652 non-null  float64
#  13  total_medicare_standardized_payment  1047652 non-null  float64
#  14  avg_beneficiary_age                  1047652 non-null  int64
#  15  avg_hcc_risk_score                   1047652 non-null  float64
#  16  services_per_capita                  1047652 non-null  float64
#  17  allowed_payment_per_capita           1047652 non-null  float64
#  18  medicare_payment_per_capita          1047652 non-null  float64
#  19  submitted_charges_per_capita         1047652 non-null  float64
#  20  region                               1047652 non-null  object
#  21  subregion                            1047652 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 183.8+ MB

# %%
med.to_csv('../../data/processed/final2016MEDICARE.csv')
