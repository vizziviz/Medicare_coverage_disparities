# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2018.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1121462, 71)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        D.O.                      M
# 4                        M.D.                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
# 2                           I       4126 N HOLLAND SYLVANIA RD
# 3                           I                  100 HOSPITAL RD
# 4                           I                 11100 EUCLID AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
# 2                        SUITE 220               TOLEDO  ...
# 3                              NaN           BROOKVILLE  ...
# 4                              NaN            CLEVELAND  ...
#
#   Percent (%) of Beneficiaries Identified With Depression  \
# 0                                               47.0
# 1                                               15.0
# 2                                               44.0
# 3                                               53.0
# 4                                               23.0
#
#    Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                               53.0
# 1                                               20.0
# 2                                               31.0
# 3                                               39.0
# 4                                               23.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               75.0
# 1                                               51.0
# 2                                               51.0
# 3                                               67.0
# 4                                               49.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               53.0
# 2                                               68.0
# 3                                               75.0
# 4                                               56.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               55.0
# 1                                               27.0
# 2                                               35.0
# 3                                               57.0
# 4                                               21.0
#
#   Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                               11.0
# 1                                               10.0
# 2                                                5.0
# 3                                               21.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               56.0
# 1                                               39.0
# 2                                               75.0
# 3                                               46.0
# 4                                               41.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                9.0
# 1                                                1.0
# 2                                                6.0
# 3                                               15.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               11.0
# 1                                                3.0
# 2                                                5.0
# 3                                                9.0
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.2948
# 1                                   1.0899
# 2                                   1.7085
# 3                                   2.1838
# 4                                   1.0221
#
# [5 rows x 71 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'Provider RUCA',
#        'State Code of the Provider', 'Country Code of the Provider',
#        'Provider Type of the Provider', 'Medicare Participation Indicator',
#        'Number of HCPCS', 'Number of Services',
#        'Number of Medicare Beneficiaries', 'Total Submitted Charge Amount',
#        'Total Medicare Allowed Amount', 'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %% [markdown]
# # Making a main Medicare DF to merge with Census DF, so I can aggregate by Zipcodes.

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})

# %%
info.sort_values('null values')
# Out:
#                                                                                        data type  \
# National Provider Identifier                                                               int64
# Average Age of Beneficiaries                                                               int64
# Total Medicare Standardized Payment Amount                                               float64
# Total Medicare Payment Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Submitted Charge Amount                                                            float64
# Number of Medicare Beneficiaries                                                           int64
# Number of Services                                                                       float64
# Number of HCPCS                                                                            int64
# Medicare Participation Indicator                                                          object
# Provider Type of the Provider                                                             object
# Country Code of the Provider                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
# Entity Type of the Provider                                                               object
# State Code of the Provider                                                                object
# Last Name/Organization Name of the Provider                                               object
# Zip Code of the Provider                                                                  object
# City of the Provider                                                                      object
# Street Address 1 of the Provider                                                          object
# Provider RUCA                                                                            float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Gender of the Provider                                                                    object
# First Name of the Provider                                                                object
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Submitted Charge Amount                                                    float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries                                                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Number of Non-Hispanic White Beneficiaries                                               float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Middle Initial of the Provider                                                            object
# Number of Beneficiaries Age Less 65                                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Number of Black or African American Beneficiaries                                        float64
# Street Address 2 of the Provider                                                          object
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
#
#                                                                                         non-null values  \
# National Provider Identifier                                                                    1121462
# Average Age of Beneficiaries                                                                    1121462
# Total Medicare Standardized Payment Amount                                                      1121462
# Total Medicare Payment Amount                                                                   1121462
# Total Medicare Allowed Amount                                                                   1121462
# Total Submitted Charge Amount                                                                   1121462
# Number of Medicare Beneficiaries                                                                1121462
# Number of Services                                                                              1121462
# Number of HCPCS                                                                                 1121462
# Medicare Participation Indicator                                                                1121462
# Provider Type of the Provider                                                                   1121462
# Country Code of the Provider                                                                    1121462
# Average HCC Risk Score of Beneficiaries                                                         1121462
# Entity Type of the Provider                                                                     1121462
# State Code of the Provider                                                                      1121462
# Last Name/Organization Name of the Provider                                                     1121439
# Zip Code of the Provider                                                                        1121293
# City of the Provider                                                                            1121293
# Street Address 1 of the Provider                                                                1121292
# Provider RUCA                                                                                   1120404
# Percent (%) of Beneficiaries Identified With Hypertension                                       1062111
# Gender of the Provider                                                                          1060686
# First Name of the Provider                                                                      1060673
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                     1039728
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis              1015903
# Credentials of the Provider                                                                     1006536
# Total Medical Medicare Standardized Payment Amount                                              1002595
# Total Medical Medicare Payment Amount                                                           1002595
# Total Medical Medicare Allowed Amount                                                           1002595
# Number of Medicare Beneficiaries With Medical Services                                          1002595
# Number of Medical Services                                                                      1002595
# Number of HCPCS Associated With Medical Services                                                1002595
# Total Medical Submitted Charge Amount                                                           1002595
# Total Drug Medicare Standardized Payment Amount                                                 1002595
# Total Drug Medicare Payment Amount                                                              1002595
# Total Drug Medicare Allowed Amount                                                              1002595
# Total Drug Submitted Charge Amount                                                              1002595
# Number of Medicare Beneficiaries With Drug Services                                             1002595
# Number of Drug Services                                                                         1002595
# Number of HCPCS Associated With Drug Services                                                   1002595
# Number of Female Beneficiaries                                                                   996295
# Number of Male Beneficiaries                                                                     996295
# Percent (%) of Beneficiaries Identified With Diabetes                                            960528
# Percent (%) of Beneficiaries Identified With Depression                                          960385
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                              954298
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                              951753
# Number of Beneficiaries Age 65 to 74                                                             944174
# Percent (%) of Beneficiaries Identified With Heart Failure                                       844347
# Number of Beneficiaries With Medicare Only Entitlement                                           833663
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     833663
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease               819035
# Number of Beneficiaries Age 75 to 84                                                             799801
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                 765640
# Number of Non-Hispanic White Beneficiaries                                                       760574
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                     759087
# Percent (%) of Beneficiaries Identified With Cancer                                              756606
# Middle Initial of the Provider                                                                   744948
# Number of Beneficiaries Age Less 65                                                              710320
# Percent (%) of Beneficiaries Identified With Osteoporosis                                        706791
# Percent (%) of Beneficiaries Identified With Asthma                                              684714
# Number of Beneficiaries Age Greater 84                                                           650811
# Percent (%) of Beneficiaries Identified With Stroke                                              610204
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders           507566
# Number of Black or African American Beneficiaries                                                382843
# Street Address 2 of the Provider                                                                 371373
# Number of American Indian/Alaska Native Beneficiaries                                            345363
# Number of Hispanic Beneficiaries                                                                 299698
# Number of Asian Pacific Islander Beneficiaries                                                   200675
# Number of Beneficiaries With Race Not Elsewhere Classified                                       188034
# Medical Suppress Indicator                                                                       118867
# Drug Suppress Indicator                                                                          118867
#
#                                                                                         unique values  \
# National Provider Identifier                                                                  1121462
# Average Age of Beneficiaries                                                                       89
# Total Medicare Standardized Payment Amount                                                    1056107
# Total Medicare Payment Amount                                                                 1054824
# Total Medicare Allowed Amount                                                                 1070721
# Total Submitted Charge Amount                                                                  752385
# Number of Medicare Beneficiaries                                                                 6999
# Number of Services                                                                              40638
# Number of HCPCS                                                                                   477
# Medicare Participation Indicator                                                                    2
# Provider Type of the Provider                                                                      99
# Country Code of the Provider                                                                       28
# Average HCC Risk Score of Beneficiaries                                                         47042
# Entity Type of the Provider                                                                         2
# State Code of the Provider                                                                         61
# Last Name/Organization Name of the Provider                                                    271603
# Zip Code of the Provider                                                                        34626
# City of the Provider                                                                            13025
# Street Address 1 of the Provider                                                               387588
# Provider RUCA                                                                                      22
# Percent (%) of Beneficiaries Identified With Hypertension                                          65
# Gender of the Provider                                                                              2
# First Name of the Provider                                                                      71576
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        70
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 72
# Credentials of the Provider                                                                     17438
# Total Medical Medicare Standardized Payment Amount                                             939090
# Total Medical Medicare Payment Amount                                                          945769
# Total Medical Medicare Allowed Amount                                                          959195
# Number of Medicare Beneficiaries With Medical Services                                           6906
# Number of Medical Services                                                                      25519
# Number of HCPCS Associated With Medical Services                                                  469
# Total Medical Submitted Charge Amount                                                          669449
# Total Drug Medicare Standardized Payment Amount                                                238916
# Total Drug Medicare Payment Amount                                                             238606
# Total Drug Medicare Allowed Amount                                                             241929
# Total Drug Submitted Charge Amount                                                             158168
# Number of Medicare Beneficiaries With Drug Services                                              1206
# Number of Drug Services                                                                         24641
# Number of HCPCS Associated With Drug Services                                                     127
# Number of Female Beneficiaries                                                                   4850
# Number of Male Beneficiaries                                                                     3712
# Percent (%) of Beneficiaries Identified With Diabetes                                              73
# Percent (%) of Beneficiaries Identified With Depression                                            75
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                73
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                73
# Number of Beneficiaries Age 65 to 74                                                             3600
# Percent (%) of Beneficiaries Identified With Heart Failure                                         76
# Number of Beneficiaries With Medicare Only Entitlement                                           5791
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                     2979
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 75
# Number of Beneficiaries Age 75 to 84                                                             2987
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   76
# Number of Non-Hispanic White Beneficiaries                                                       6151
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       76
# Percent (%) of Beneficiaries Identified With Cancer                                                76
# Middle Initial of the Provider                                                                     32
# Number of Beneficiaries Age Less 65                                                              1967
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          76
# Percent (%) of Beneficiaries Identified With Asthma                                                76
# Number of Beneficiaries Age Greater 84                                                           2145
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             76
# Number of Black or African American Beneficiaries                                                1981
# Street Address 2 of the Provider                                                                70381
# Number of American Indian/Alaska Native Beneficiaries                                             537
# Number of Hispanic Beneficiaries                                                                 1575
# Number of Asian Pacific Islander Beneficiaries                                                   1099
# Number of Beneficiaries With Race Not Elsewhere Classified                                        616
# Medical Suppress Indicator                                                                          2
# Drug Suppress Indicator                                                                             2
#
#                                                                                         null values
# National Provider Identifier                                                                      0
# Average Age of Beneficiaries                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Total Medicare Payment Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Submitted Charge Amount                                                                     0
# Number of Medicare Beneficiaries                                                                  0
# Number of Services                                                                                0
# Number of HCPCS                                                                                   0
# Medicare Participation Indicator                                                                  0
# Provider Type of the Provider                                                                     0
# Country Code of the Provider                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0
# Entity Type of the Provider                                                                       0
# State Code of the Provider                                                                        0
# Last Name/Organization Name of the Provider                                                      23
# Zip Code of the Provider                                                                        169
# City of the Provider                                                                            169
# Street Address 1 of the Provider                                                                170
# Provider RUCA                                                                                  1058
# Percent (%) of Beneficiaries Identified With Hypertension                                     59351
# Gender of the Provider                                                                        60776
# First Name of the Provider                                                                    60789
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   81734
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis           105559
# Credentials of the Provider                                                                  114926
# Total Medical Medicare Standardized Payment Amount                                           118867
# Total Medical Medicare Payment Amount                                                        118867
# Total Medical Medicare Allowed Amount                                                        118867
# Number of Medicare Beneficiaries With Medical Services                                       118867
# Number of Medical Services                                                                   118867
# Number of HCPCS Associated With Medical Services                                             118867
# Total Medical Submitted Charge Amount                                                        118867
# Total Drug Medicare Standardized Payment Amount                                              118867
# Total Drug Medicare Payment Amount                                                           118867
# Total Drug Medicare Allowed Amount                                                           118867
# Total Drug Submitted Charge Amount                                                           118867
# Number of Medicare Beneficiaries With Drug Services                                          118867
# Number of Drug Services                                                                      118867
# Number of HCPCS Associated With Drug Services                                                118867
# Number of Female Beneficiaries                                                               125167
# Number of Male Beneficiaries                                                                 125167
# Percent (%) of Beneficiaries Identified With Diabetes                                        160934
# Percent (%) of Beneficiaries Identified With Depression                                      161077
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                          167164
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                          169709
# Number of Beneficiaries Age 65 to 74                                                         177288
# Percent (%) of Beneficiaries Identified With Heart Failure                                   277115
# Number of Beneficiaries With Medicare Only Entitlement                                       287799
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                 287799
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease           302427
# Number of Beneficiaries Age 75 to 84                                                         321661
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                             355822
# Number of Non-Hispanic White Beneficiaries                                                   360888
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                 362375
# Percent (%) of Beneficiaries Identified With Cancer                                          364856
# Middle Initial of the Provider                                                               376514
# Number of Beneficiaries Age Less 65                                                          411142
# Percent (%) of Beneficiaries Identified With Osteoporosis                                    414671
# Percent (%) of Beneficiaries Identified With Asthma                                          436748
# Number of Beneficiaries Age Greater 84                                                       470651
# Percent (%) of Beneficiaries Identified With Stroke                                          511258
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders       613896
# Number of Black or African American Beneficiaries                                            738619
# Street Address 2 of the Provider                                                             750089
# Number of American Indian/Alaska Native Beneficiaries                                        776099
# Number of Hispanic Beneficiaries                                                             821764
# Number of Asian Pacific Islander Beneficiaries                                               920787
# Number of Beneficiaries With Race Not Elsewhere Classified                                   933428
# Medical Suppress Indicator                                                                  1002595
# Drug Suppress Indicator                                                                     1002595

# %% [markdown]
# Looking at Rows where Zip Code is Null

# %%
med.loc[med['Zip Code of the Provider'].isnull()]
# Out:
#          National Provider Identifier  \
# 611                        1003036997
# 3192                       1003200445
# 6459                       1003834623
# 15457                      1013228261
# 17227                      1013356013
# ...                               ...
# 1085132                    1962757740
# 1096413                    1972817260
# 1101069                    1982606943
# 1113199                    1992236194
# 1118691                    1992849137
#
#         Last Name/Organization Name of the Provider  \
# 611                                            WISE
# 3192                                           CHOI
# 6459                                      STREUTKER
# 15457                                         JAKOI
# 17227                                          WOOD
# ...                                             ...
# 1085132                                     JOHNSON
# 1096413                                     AFRIYIE
# 1101069                                      GIBSON
# 1113199                                      MAHLUM
# 1118691                                      HEFELE
#
#         First Name of the Provider Middle Initial of the Provider  \
# 611                    CHRISTOPHER                              L
# 3192                       MAY YEE                            NaN
# 6459                       ANTHONY                              D
# 15457                        ANDRE                              M
# 17227                       ANGELA                              D
# ...                            ...                            ...
# 1085132                   DANIELLE                              L
# 1096413                       PIUS                              O
# 1101069                    JEFFREY                              B
# 1113199                      ERICA                              L
# 1118691                    KIRSTEN                              G
#
#         Credentials of the Provider Gender of the Provider  \
# 611                            M.D.                      M
# 3192                           M.D.                      F
# 6459                           M.D.                      M
# 15457                          M.D.                      M
# 17227                         FNP-C                      F
# ...                             ...                    ...
# 1085132                        P.A.                      F
# 1096413                        PA-C                      M
# 1101069                          MD                      M
# 1113199                        PA-C                      F
# 1118691                          MD                      F
#
#         Entity Type of the Provider Street Address 1 of the Provider  \
# 611                               I                              NaN
# 3192                              I                              NaN
# 6459                              I                              NaN
# 15457                             I                              NaN
# 17227                             I                              NaN
# ...                             ...                              ...
# 1085132                           I                              NaN
# 1096413                           I                              NaN
# 1101069                           I                              NaN
# 1113199                           I                              NaN
# 1118691                           I                              NaN
#
#         Street Address 2 of the Provider City of the Provider  ...  \
# 611                                  NaN                  NaN  ...
# 3192                                 NaN                  NaN  ...
# 6459                                 NaN                  NaN  ...
# 15457                                NaN                  NaN  ...
# 17227                                NaN                  NaN  ...
# ...                                  ...                  ...  ...
# 1085132                              NaN                  NaN  ...
# 1096413                              NaN                  NaN  ...
# 1101069                              NaN                  NaN  ...
# 1113199                              NaN                  NaN  ...
# 1118691                              NaN                  NaN  ...
#
#         Percent (%) of Beneficiaries Identified With Depression  \
# 611                                                        40.0
# 3192                                                       46.0
# 6459                                                        NaN
# 15457                                                      36.0
# 17227                                                      30.0
# ...                                                         ...
# 1085132                                                    22.0
# 1096413                                                    25.0
# 1101069                                                    30.0
# 1113199                                                    37.0
# 1118691                                                    25.0
#
#          Percent (%) of Beneficiaries Identified With Diabetes  \
# 611                                                       33.0
# 3192                                                      56.0
# 6459                                                       NaN
# 15457                                                     40.0
# 17227                                                     21.0
# ...                                                        ...
# 1085132                                                   24.0
# 1096413                                                   31.0
# 1101069                                                   43.0
# 1113199                                                   30.0
# 1118691                                                   31.0
#
#         Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 611                                                            60.0
# 3192                                                           61.0
# 6459                                                           50.0
# 15457                                                          61.0
# 17227                                                          53.0
# ...                                                             ...
# 1085132                                                        65.0
# 1096413                                                        55.0
# 1101069                                                        75.0
# 1113199                                                        36.0
# 1118691                                                        53.0
#
#         Percent (%) of Beneficiaries Identified With Hypertension  \
# 611                                                          75.0
# 3192                                                         75.0
# 6459                                                         38.0
# 15457                                                        75.0
# 17227                                                        60.0
# ...                                                           ...
# 1085132                                                      73.0
# 1096413                                                      66.0
# 1101069                                                      75.0
# 1113199                                                      51.0
# 1118691                                                      66.0
#
#         Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 611                                                                    34.0
# 3192                                                                   40.0
# 6459                                                                    NaN
# 15457                                                                  34.0
# 17227                                                                  36.0
# ...                                                                     ...
# 1085132                                                                33.0
# 1096413                                                                29.0
# 1101069                                                                71.0
# 1113199                                                                22.0
# 1118691                                                                25.0
#
#         Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 611                                                          21.0
# 3192                                                          NaN
# 6459                                                          NaN
# 15457                                                        14.0
# 17227                                                         NaN
# ...                                                           ...
# 1085132                                                       7.0
# 1096413                                                      10.0
# 1101069                                                       NaN
# 1113199                                                       NaN
# 1118691                                                      17.0
#
#          Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 611                                                                                    60.0
# 3192                                                                                   44.0
# 6459                                                                                    NaN
# 15457                                                                                  75.0
# 17227                                                                                  44.0
# ...                                                                                     ...
# 1085132                                                                                75.0
# 1096413                                                                                52.0
# 1101069                                                                                48.0
# 1113199                                                                                28.0
# 1118691                                                                                49.0
#
#          Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 611                                                                                         5.0
# 3192                                                                                        NaN
# 6459                                                                                        0.0
# 15457                                                                                       NaN
# 17227                                                                                       0.0
# ...                                                                                         ...
# 1085132                                                                                     NaN
# 1096413                                                                                     NaN
# 1101069                                                                                     NaN
# 1113199                                                                                     NaN
# 1118691                                                                                     NaN
#
#          Percent (%) of Beneficiaries Identified With Stroke  \
# 611                                                      7.0
# 3192                                                     NaN
# 6459                                                     NaN
# 15457                                                    3.0
# 17227                                                    NaN
# ...                                                      ...
# 1085132                                                  NaN
# 1096413                                                  6.0
# 1101069                                                  NaN
# 1113199                                                  NaN
# 1118691                                                  NaN
#
#          Average HCC Risk Score of Beneficiaries
# 611                                       1.7297
# 3192                                      3.8569
# 6459                                      0.7183
# 15457                                     1.5050
# 17227                                     0.8809
# ...                                          ...
# 1085132                                   0.9101
# 1096413                                   1.0992
# 1101069                                   1.6427
# 1113199                                   0.9594
# 1118691                                   1.2667
#
# [169 rows x 71 columns]

# %% [markdown]
# Dropping these Rows. This will put my data off a little after aggregating, but it shouldn't change too much, considering I have over 1 million providers.

# %%
idx = med.loc[med['Zip Code of the Provider'].isnull()].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Looking at Nulls Again

# %%
info = pd.DataFrame(index=med.columns.values,
                    data={'data type': med.dtypes, \
                          'non-null values': med.notnull().sum(),
                          'unique values': med.nunique(), \
                          'null values': med.isnull().sum()})
info[info['null values']==0]
# Out:
#                                            data type  non-null values  \
# National Provider Identifier                   int64          1121293
# Entity Type of the Provider                   object          1121293
# Zip Code of the Provider                      object          1121293
# State Code of the Provider                    object          1121293
# Country Code of the Provider                  object          1121293
# Provider Type of the Provider                 object          1121293
# Medicare Participation Indicator              object          1121293
# Number of HCPCS                                int64          1121293
# Number of Services                           float64          1121293
# Number of Medicare Beneficiaries               int64          1121293
# Total Submitted Charge Amount                float64          1121293
# Total Medicare Allowed Amount                float64          1121293
# Total Medicare Payment Amount                float64          1121293
# Total Medicare Standardized Payment Amount   float64          1121293
# Average Age of Beneficiaries                   int64          1121293
# Average HCC Risk Score of Beneficiaries      float64          1121293
#
#                                             unique values  null values
# National Provider Identifier                      1121293            0
# Entity Type of the Provider                             2            0
# Zip Code of the Provider                            34626            0
# State Code of the Provider                             61            0
# Country Code of the Provider                           27            0
# Provider Type of the Provider                          99            0
# Medicare Participation Indicator                        2            0
# Number of HCPCS                                       477            0
# Number of Services                                  40635            0
# Number of Medicare Beneficiaries                     6999            0
# Total Submitted Charge Amount                      752290            0
# Total Medicare Allowed Amount                     1070562            0
# Total Medicare Payment Amount                     1054677            0
# Total Medicare Standardized Payment Amount        1055959            0
# Average Age of Beneficiaries                           89            0
# Average HCC Risk Score of Beneficiaries             47041            0

# %% [markdown]
# Dropping Rest of Cols that have null values. The Census DF I wil merge with has many, many columns.

# %%
med.shape
# Out:
# (1121293, 71)

# %%
cols = info[info['null values']>0].index
med.drop(columns = cols, inplace = True)
med.shape
# Out:
# (1121293, 16)

# %%
med.columns
# Out:
# Index(['National Provider Identifier', 'Entity Type of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                 'Total Medicare Standardized Payment Amount':'total_medicare_standardized_payment',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
    'Number of Services':'number_of_services',
        'Total Medicare Allowed Amount':'total_allowed_payment',
                 'Total Submitted Charge Amount':'total_submitted_charges',
                 'Entity Type of the Provider':'entity_code',
                 'Medicare Participation Indicator':'medicare_participation_indicator',
                 'Number of HCPCS':'number_of_hcpcs'
                }

med.rename(columns = new_name_dict, inplace = True)

# %%
med.columns
# Out:
# Index(['npi', 'entity_code', 'full_zip', 'state', 'country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score'],
#       dtype='object')

# %%
idx = med[med.country != 'US'].index
med.drop(index = idx, inplace=True)

# %%
med.state.unique()
# Out:
# array(['MD', 'IL', 'OH', 'PA', 'CO', 'FL', 'OK', 'CA', 'TX', 'MN', 'KY',
#        'SC', 'ME', 'MO', 'NY', 'CT', 'NJ', 'MI', 'LA', 'TN', 'MA', 'OR',
#        'AR', 'WA', 'NH', 'DC', 'GA', 'NC', 'NV', 'HI', 'MS', 'IA', 'VA',
#        'ND', 'IN', 'NE', 'AZ', 'AL', 'PR', 'WI', 'DE', 'KS', 'RI', 'ID',
#        'NM', 'MT', 'WV', 'VT', 'AE', 'UT', 'WY', 'SD', 'AK', 'VI', 'GU',
#        'MP', 'AP', 'XX', 'AA', 'AS'], dtype=object)

# %% [markdown]
# States include American forces Air force (AA), American forces in Europe (AE), American Somoa (AS), Virgin Islands (VI), Guam(GU), Armed Forces Pacific (AP)

# %%
med[
    med.state == 'MP'
].head()
# Out:
#                npi entity_code full_zip state country  \
# 27830   1023150414           I    21287    MP      US
# 52729   1043498892           I    96950    MP      US
# 69713   1063459428           I    96950    MP      US
# 174447  1154508067           I    96950    MP      US
# 202380  1184028177           I    96950    MP      US
#
#                                  provider_type  \
# 27830                           Anesthesiology
# 52729                       Emergency Medicine
# 69713                        Internal Medicine
# 174447  Physical Therapist in Private Practice
# 202380                       Internal Medicine
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 27830                                 Y               62               241.0
# 52729                                 Y                4                38.0
# 69713                                 Y                9              1203.0
# 174447                                Y               11              2457.0
# 202380                                Y               11               960.0
#
#         total_beneficiaries  total_submitted_charges  total_allowed_payment  \
# 27830                   181                290352.00               57506.03
# 52729                    29                  4231.00                2093.22
# 69713                   284                138273.47              132084.26
# 174447                   48                 72811.94               61542.44
# 202380                  342                187948.00               84578.92
#
#         total_medicare_payment  total_medicare_standardized_payment  \
# 27830                 44577.95                             41535.80
# 52729                  1608.20                              1608.20
# 69713                 69878.64                             72799.86
# 174447                46496.15                             44478.15
# 202380                65092.09                             61859.72
#
#         avg_beneficiary_age  avg_hcc_risk_score
# 27830                    74              1.7252
# 52729                    69              2.7469
# 69713                    72              0.7965
# 174447                   71              0.7446
# 202380                   76              3.0450

# %%
#this line was accidentally mislabeled with state "MP" instead of state "MD" in the Med DFs from most years
med.loc[med.npi == 1023150414, 'state'] = 'MD'

# %% [markdown]
# # Making all zips 5 digits

# %%
med.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 7    626092
# 5    405073
# 6     65850
# 4     22976
# 3      1214
# Name: full_zip, dtype: int64

# %%
def make_five_digit_zip(df, zipcol):
    #adding leading zeros if zip if less than 5 digits
    idx = df[df[zipcol].apply(lambda x: len(str(x)) < 5)].index
    df.loc[idx,zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(5))
    
    #adding leading zeros if zip is between 5 and 9 digits
    idx = df[df[zipcol].apply(lambda x: 5 < len(str(x)) < 9)].index
    df.loc[idx, zipcol] = df.loc[idx, zipcol].apply(lambda x: str(x).zfill(9))
    
    #make 9-digit zip into 5-digit zip
    five_digit_series = df[zipcol].astype('str').apply(lambda x: x[:5])
    
    return five_digit_series

# %%
med['full_zip'] = make_five_digit_zip(med, 'full_zip')

# %%
med['services_per_capita'] =  round(med.number_of_services  / med.total_beneficiaries, 2)
med['allowed_payment_per_capita']= round(med.total_allowed_payment  / med.total_beneficiaries, 2)
med['medicare_payment_per_capita']=  round(med.total_medicare_payment / med.total_beneficiaries, 2)
med['submitted_charges_per_capita']= round(med.total_submitted_charges / med.total_beneficiaries, 2)

# %% [markdown]
# ##### Adding Regions

# %%
regions = pd.read_csv('../../data/interim/state_and_regions.csv', index_col=0)

# %%
regions.head()
# Out:
#   State Code Region            Division
# 0         AK   West             Pacific
# 1         AL  South  East South Central
# 2         AR  South  West South Central
# 3         AZ   West            Mountain
# 4         CA   West             Pacific

# %%
med = pd.merge(med, regions, left_on='state',right_on='State Code')
checkpoint7 = med.copy()
med.head()
# Out:
#           npi entity_code full_zip state country        provider_type  \
# 0  1003000126           I    00215    MD      US    Internal Medicine
# 1  1003006586           I    00208    MD      US    Internal Medicine
# 2  1003006800           I    00212    MD      US  Physician Assistant
# 3  1003007816           I    00209    MD      US        Ophthalmology
# 4  1003007824           I    00212    MD      US    Internal Medicine
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               19              1218.0
# 1                                Y               16              1293.0
# 2                                Y                4                58.0
# 3                                Y               30              3417.0
# 4                                Y               22               262.0
#
#    total_beneficiaries  ...  total_medicare_standardized_payment  \
# 0                  445  ...                            103527.31
# 1                  546  ...                            103628.02
# 2                   12  ...                               638.98
# 3                  791  ...                            228089.32
# 4                   72  ...                             15533.39
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   76              2.2948                 2.74
# 1                   80              2.1736                 2.37
# 2                   65              0.8597                 4.83
# 3                   79              1.2159                 4.32
# 4                   68              3.0926                 3.64
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                      295.09                       230.35
# 1                      266.49                       207.08
# 2                       97.10                        51.64
# 3                      458.31                       327.41
# 4                      316.98                       220.59
#
#    submitted_charges_per_capita  State Code  Region        Division
# 0                       1556.49          MD   South  South Atlantic
# 1                        485.81          MD   South  South Atlantic
# 2                        227.37          MD   South  South Atlantic
# 3                        819.25          MD   South  South Atlantic
# 4                        489.58          MD   South  South Atlantic
#
# [5 rows x 23 columns]

# %%
med.drop(columns = 'State Code', inplace=True)
med.rename(columns = {'Region':'region', 'Division':'subregion'}, inplace=True)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1115370 entries, 0 to 1115369
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   npi                                  1115370 non-null  int64
#  1   entity_code                          1115370 non-null  object
#  2   full_zip                             1115370 non-null  object
#  3   state                                1115370 non-null  object
#  4   country                              1115370 non-null  object
#  5   provider_type                        1115370 non-null  object
#  6   medicare_participation_indicator     1115370 non-null  object
#  7   number_of_hcpcs                      1115370 non-null  int64
#  8   number_of_services                   1115370 non-null  float64
#  9   total_beneficiaries                  1115370 non-null  int64
#  10  total_submitted_charges              1115370 non-null  float64
#  11  total_allowed_payment                1115370 non-null  float64
#  12  total_medicare_payment               1115370 non-null  float64
#  13  total_medicare_standardized_payment  1115370 non-null  float64
#  14  avg_beneficiary_age                  1115370 non-null  int64
#  15  avg_hcc_risk_score                   1115370 non-null  float64
#  16  services_per_capita                  1115370 non-null  float64
#  17  allowed_payment_per_capita           1115370 non-null  float64
#  18  medicare_payment_per_capita          1115370 non-null  float64
#  19  submitted_charges_per_capita         1115370 non-null  float64
#  20  region                               1115370 non-null  object
#  21  subregion                            1115370 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 195.7+ MB

# %%
med.to_csv('../../data/processed/final2018MEDICARE.csv')
