# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/processed/final2012MEDICARE.csv", index_col=0)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 919021 entries, 0 to 919020
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               919021 non-null  int64
#  1   entity_code                       919021 non-null  object
#  2   full_zip                          919021 non-null  int64
#  3   state                             919021 non-null  object
#  4   country                           919021 non-null  object
#  5   provider_type                     919021 non-null  object
#  6   medicare_participation_indicator  919021 non-null  object
#  7   number_of_hcpcs                   919021 non-null  int64
#  8   number_of_services                919021 non-null  int64
#  9   total_beneficiaries               919021 non-null  int64
#  10  total_submitted_charges           919021 non-null  float64
#  11  total_allowed_payment             919021 non-null  float64
#  12  total_medicare_payment            919021 non-null  float64
#  13  avg_beneficiary_age               919021 non-null  int64
#  14  avg_hcc_risk_score                919021 non-null  float64
#  15  services_per_capita               919021 non-null  float64
#  16  allowed_payment_per_capita        919021 non-null  float64
#  17  medicare_payment_per_capita       919021 non-null  float64
#  18  submitted_charges_per_capita      919021 non-null  float64
#  19  region                            919021 non-null  object
#  20  subregion                         919021 non-null  object
#  21  doctor_category                   919021 non-null  object
# dtypes: float64(8), int64(6), object(8)
# memory usage: 161.3+ MB

# %%
med.full_zip = med.full_zip.apply(lambda x: str(x).zfill(5))
med.npi = med.npi.astype('str')

# %%
med.head()
# Out:
#           npi entity_code full_zip state country               provider_type  \
# 0  1003000126           I    21502    MD      US           Internal Medicine
# 1  1003004482           O    21204    MD      US  Ambulatory Surgical Center
# 2  1003006586           I    20852    MD      US           Internal Medicine
# 3  1003006800           I    21202    MD      US         Physician Assistant
# 4  1003007816           I    20910    MD      US               Ophthalmology
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               16                1243
# 1                                Y               37                1054
# 2                                Y               30                1426
# 3                                Y               10                  88
# 4                                Y               29                1059
#
#    total_beneficiaries  ...  total_medicare_payment  avg_beneficiary_age  \
# 0                  581  ...                90965.51                   76
# 1                  610  ...               653050.74                   75
# 2                  390  ...               101517.88                   80
# 3                   82  ...                14493.58                   72
# 4                  419  ...                97218.06                   82
#
#    avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 0              2.2264                 2.14                      196.14
# 1              1.2309                 1.73                     1374.22
# 2              2.9636                 3.66                      327.00
# 3              0.9648                 1.07                      220.93
# 4              1.3969                 2.53                      299.55
#
#    medicare_payment_per_capita  submitted_charges_per_capita  region  \
# 0                       156.57                        288.37   South
# 1                      1070.57                       3059.21   South
# 2                       260.30                        408.53   South
# 3                       176.75                       1494.89   South
# 4                       232.02                        445.32   South
#
#         subregion               doctor_category
# 0  South Atlantic  General Medicine Pracitioner
# 1  South Atlantic           Surgery Specialists
# 2  South Atlantic  General Medicine Pracitioner
# 3  South Atlantic  General Medicine Pracitioner
# 4  South Atlantic           Surgery Specialists
#
# [5 rows x 22 columns]

# %% [markdown]
# Checkpoint 1

# %%
checkpoint1 = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
census = pd.read_csv('../../data/raw/2012census.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   91046                   116                 13
# 1   20317                   232                  0
# 2   95915                    31                 17
# 3   14881                   100                  0
# 4   71345                    52                 26
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1987.0                         0
# 1                       1949.0                         0
# 2                       1939.0                         0
# 3                       1986.0                         0
# 4                       1970.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                   117                      0                     12
# 1                   139                     40                     24
# 2                    17                     20                      0
# 3                     0                     68                      0
# 4                    78                      0                      0
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                      0  ...
# 1                      0                     14  ...
# 2                      0                      0  ...
# 3                      0                     16  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          11                      0
# 1                         348                      0
# 2                          59                      0
# 3                         100                      0
# 4                         113                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              141                 11
# 1                                  0              348                 55
# 2                                  0               48                 17
# 3                                  0              100                 17
# 4                                  0              113                 28
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0               25              0            0             0  20082012
# 1               84             14           87            79  20082012
# 2                0              0            0            31  20082012
# 3                0              0           83             0  20082012
# 4                1             28           56             0  20082012
#
# [5 rows x 252 columns]

# %% [markdown]
# checkpoint2

# %%
checkpoint2 = census.copy()

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# median_rent                                                   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# gini_index                                                    float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          19643
# renter_occupied_housing_units_paying_cash_median_gross_rent            28629
# median_rent                                                            28638
# percent_income_spent_on_rent                                           29152
# owner_occupied_housing_units_upper_value_quartile                      31921
# owner_occupied_housing_units_lower_value_quartile                      31921
# owner_occupied_housing_units_median_value                              31921
# gini_index                                                             32241
# median_income                                                          32251
# median_year_structure_built                                            32409
# income_per_capita                                                      32548
# median_age                                                             32721
# some_college_and_associates_degree                                     32989
# not_us_citizen_pop                                                     32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# less_than_high_school_graduate                                         32989
# different_house_year_ago_different_city                                32989
# graduate_professional_degree                                           32989
# bachelors_degree_2                                                     32989
# high_school_including_ged                                              32989
# commuters_drove_alone                                                  33120
# commuters_by_carpool                                                   33120
# commuters_by_subway_or_elevated                                        33120
# employed_finance_insurance_real_estate                                 33120
# employed_arts_entertainment_recreation_accommodation_food              33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# employed_information                                                   33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16605
# renter_occupied_housing_units_paying_cash_median_gross_rent           1657
# median_rent                                                           1669
# percent_income_spent_on_rent                                           401
# owner_occupied_housing_units_upper_value_quartile                     6057
# owner_occupied_housing_units_lower_value_quartile                     4215
# owner_occupied_housing_units_median_value                             5125
# gini_index                                                            4141
# median_income                                                        20047
# median_year_structure_built                                             69
# income_per_capita                                                    20115
# median_age                                                             676
# some_college_and_associates_degree                                    7360
# not_us_citizen_pop                                                    4159
# different_house_year_ago_same_city                                    3681
# population_1_year_and_over                                           15192
# less_than_high_school_graduate                                        4695
# different_house_year_ago_different_city                               4801
# graduate_professional_degree                                          4274
# bachelors_degree_2                                                    5711
# high_school_including_ged                                             7087
# commuters_drove_alone                                                 9950
# commuters_by_carpool                                                  2888
# commuters_by_subway_or_elevated                                        854
# employed_finance_insurance_real_estate                                2375
# employed_arts_entertainment_recreation_accommodation_food             2841
# employed_construction                                                 2092
# employed_education_health_social                                      5165
# commuters_by_car_truck_van                                           10544
# employed_information                                                  1083
#
#                                                              null values
# aggregate_travel_time_to_work                                      13477
# renter_occupied_housing_units_paying_cash_median_gross_rent         4491
# median_rent                                                         4482
# percent_income_spent_on_rent                                        3968
# owner_occupied_housing_units_upper_value_quartile                   1199
# owner_occupied_housing_units_lower_value_quartile                   1199
# owner_occupied_housing_units_median_value                           1199
# gini_index                                                           879
# median_income                                                        869
# median_year_structure_built                                          711
# income_per_capita                                                    572
# median_age                                                           399
# some_college_and_associates_degree                                   131
# not_us_citizen_pop                                                   131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# less_than_high_school_graduate                                       131
# different_house_year_ago_different_city                              131
# graduate_professional_degree                                         131
# bachelors_degree_2                                                   131
# high_school_including_ged                                            131
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))

# %%
med[med.full_zip.isin(census.geo_id)].shape, med[~med.full_zip.isin(census.geo_id)].shape
# Out:
# ((893865, 22), (25156, 22))

# %%
pd.options.display.max_rows = 120
med[
    ~med.full_zip.isin(census.geo_id)].head()
# Out:
#            npi entity_code full_zip state country  \
# 9   1003031642           I    21287    MD      US
# 13  1003066549           I    21287    MD      US
# 19  1003080797           I    21287    MD      US
# 29  1003121096           I    20892    MD      US
# 54  1003821521           I    21287    MD      US
#
#                    provider_type medicare_participation_indicator  \
# 9                           CRNA                                Y
# 13           Physician Assistant                                Y
# 19                     Pathology                                Y
# 29  Critical Care (Intensivists)                                Y
# 54                 Ophthalmology                                Y
#
#     number_of_hcpcs  number_of_services  total_beneficiaries  ...  \
# 9                11                 129                  128  ...
# 13               19                 273                  228  ...
# 19               11                 944                  282  ...
# 29                9                  50                   35  ...
# 54               23                 899                  251  ...
#
#     total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score  \
# 9                 16155.22                   69              1.6325
# 13                24870.71                   65              2.1453
# 19                36469.10                   70              1.4237
# 29                 5493.73                   78              2.3124
# 54               104822.22                   73              1.1481
#
#     services_per_capita  allowed_payment_per_capita  \
# 9                  1.01                      165.20
# 13                 1.20                      138.48
# 19                 3.35                      165.35
# 29                 1.43                      200.68
# 54                 3.58                      561.76
#
#     medicare_payment_per_capita  submitted_charges_per_capita  region  \
# 9                        126.21                        695.80   South
# 13                       109.08                        908.55   South
# 19                       129.32                        540.03   South
# 29                       156.96                        729.66   South
# 54                       417.62                       1239.03   South
#
#          subregion               doctor_category
# 9   South Atlantic             Other Specialists
# 13  South Atlantic  General Medicine Pracitioner
# 19  South Atlantic           Medical Specialists
# 29  South Atlantic           Surgery Specialists
# 54  South Atlantic           Surgery Specialists
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### Many are PO Boxes. Some are hospitals with their own zip codes. I want to drop these rows from Med, looking at how much of my data this will remove:

# %%
print(' Total providers in Med df:',med.shape[0],
     '\n Total beneficiaries in Med df:', med.total_beneficiaries.sum(),
     '\n Total providers whose zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].shape[0],
     '\n Total beneficiaries in Med in zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum(),
     '\n Percent providers with missing zips of all providers:',
                          round(med[~med.full_zip.isin(census.geo_id)].shape[0] \
                          / med.shape[0] * 100, 2),  '%',
     '\n Percent beneficiaries in missing zips of all beneficiaries:',
                          round(med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum() \
                          / med.total_beneficiaries.sum() * 100,2),  '%')
# Out:
#  Total providers in Med df: 919021
#  Total beneficiaries in Med df: 354214946
#  Total providers whose zips not in Census: 25156
#  Total beneficiaries in Med in zips not in Census: 8588112
#  Percent providers with missing zips of all providers: 2.74 %
#  Percent beneficiaries in missing zips of all beneficiaries: 2.42 %

# %%
idx = med[~med['full_zip'].isin(census.geo_id)].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Dropping Rows from Census that don't appear in Medicare DF

# %%
print(census.shape)
idx = census[~census.geo_id.isin(med.full_zip)].index
census.drop(index = idx, inplace = True)
print(census.shape)
# Out:
# (33120, 252)
# (19277, 252)

# %%
med.full_zip.nunique()
# Out:
# 19277

# %% [markdown]
# Examining Nulls

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# median_rent                                                   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# gini_index                                                    float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          16029
# renter_occupied_housing_units_paying_cash_median_gross_rent            18800
# median_rent                                                            18805
# percent_income_spent_on_rent                                           18836
# owner_occupied_housing_units_upper_value_quartile                      18950
# owner_occupied_housing_units_lower_value_quartile                      18950
# owner_occupied_housing_units_median_value                              18950
# gini_index                                                             19074
# median_income                                                          19075
# median_year_structure_built                                            19078
# income_per_capita                                                      19204
# median_age                                                             19220
# some_college_and_associates_degree                                     19275
# not_us_citizen_pop                                                     19275
# different_house_year_ago_same_city                                     19275
# population_1_year_and_over                                             19275
# less_than_high_school_graduate                                         19275
# different_house_year_ago_different_city                                19275
# graduate_professional_degree                                           19275
# bachelors_degree_2                                                     19275
# high_school_including_ged                                              19275
# commuters_drove_alone                                                  19277
# commuters_by_carpool                                                   19277
# commuters_by_subway_or_elevated                                        19277
# employed_finance_insurance_real_estate                                 19277
# employed_arts_entertainment_recreation_accommodation_food              19277
# employed_construction                                                  19277
# employed_education_health_social                                       19277
# commuters_by_car_truck_van                                             19277
# employed_information                                                   19277
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        14432
# renter_occupied_housing_units_paying_cash_median_gross_rent           1572
# median_rent                                                           1614
# percent_income_spent_on_rent                                           391
# owner_occupied_housing_units_upper_value_quartile                     5367
# owner_occupied_housing_units_lower_value_quartile                     3949
# owner_occupied_housing_units_median_value                             4695
# gini_index                                                            2892
# median_income                                                        15472
# median_year_structure_built                                             68
# income_per_capita                                                    14302
# median_age                                                             513
# some_college_and_associates_degree                                    7341
# not_us_citizen_pop                                                    4151
# different_house_year_ago_same_city                                    3677
# population_1_year_and_over                                           14234
# less_than_high_school_graduate                                        4681
# different_house_year_ago_different_city                               4789
# graduate_professional_degree                                          4274
# bachelors_degree_2                                                    5709
# high_school_including_ged                                             7065
# commuters_drove_alone                                                 9813
# commuters_by_carpool                                                  2876
# commuters_by_subway_or_elevated                                        848
# employed_finance_insurance_real_estate                                2370
# employed_arts_entertainment_recreation_accommodation_food             2836
# employed_construction                                                 2087
# employed_education_health_social                                      5145
# commuters_by_car_truck_van                                           10383
# employed_information                                                  1081
#
#                                                              null values
# aggregate_travel_time_to_work                                       3248
# renter_occupied_housing_units_paying_cash_median_gross_rent          477
# median_rent                                                          472
# percent_income_spent_on_rent                                         441
# owner_occupied_housing_units_upper_value_quartile                    327
# owner_occupied_housing_units_lower_value_quartile                    327
# owner_occupied_housing_units_median_value                            327
# gini_index                                                           203
# median_income                                                        202
# median_year_structure_built                                          199
# income_per_capita                                                     73
# median_age                                                            57
# some_college_and_associates_degree                                     2
# not_us_citizen_pop                                                     2
# different_house_year_ago_same_city                                     2
# population_1_year_and_over                                             2
# less_than_high_school_graduate                                         2
# different_house_year_ago_different_city                                2
# graduate_professional_degree                                           2
# bachelors_degree_2                                                     2
# high_school_including_ged                                              2
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Some of these columns are irrelevant or are redundant.

# %%
#there are other cols that speak to Commute to work
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# median_rent                                                 float64
# percent_income_spent_on_rent                                float64
# gini_index                                                  float64
# median_income                                               float64
# income_per_capita                                           float64
# median_age                                                  float64
# less_than_high_school_graduate                              float64
# different_house_year_ago_same_city                          float64
# different_house_year_ago_different_city                     float64
# not_us_citizen_pop                                          float64
# bachelors_degree_2                                          float64
# high_school_including_ged                                   float64
# population_1_year_and_over                                  float64
# some_college_and_associates_degree                          float64
# graduate_professional_degree                                float64
# civilian_labor_force                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# black_including_hispanic                                      int64
# white_including_hispanic                                      int64
# female_85_and_over                                            int64
# employed_agriculture_forestry_fishing_hunting_mining          int64
# employed_arts_entertainment_recreation_accommodation_food     int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# commuters_by_carpool                                          int64
# employed_information                                          int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
#
#                                                            non-null values  \
# median_rent                                                          18805
# percent_income_spent_on_rent                                         18836
# gini_index                                                           19074
# median_income                                                        19075
# income_per_capita                                                    19204
# median_age                                                           19220
# less_than_high_school_graduate                                       19275
# different_house_year_ago_same_city                                   19275
# different_house_year_ago_different_city                              19275
# not_us_citizen_pop                                                   19275
# bachelors_degree_2                                                   19275
# high_school_including_ged                                            19275
# population_1_year_and_over                                           19275
# some_college_and_associates_degree                                   19275
# graduate_professional_degree                                         19275
# civilian_labor_force                                                 19277
# commuters_by_subway_or_elevated                                      19277
# commuters_drove_alone                                                19277
# black_including_hispanic                                             19277
# white_including_hispanic                                             19277
# female_85_and_over                                                   19277
# employed_agriculture_forestry_fishing_hunting_mining                 19277
# employed_arts_entertainment_recreation_accommodation_food            19277
# employed_construction                                                19277
# employed_education_health_social                                     19277
# employed_finance_insurance_real_estate                               19277
# commuters_by_carpool                                                 19277
# employed_information                                                 19277
# employed_other_services_not_public_admin                             19277
# employed_public_administration                                       19277
#
#                                                            unique values  \
# median_rent                                                         1614
# percent_income_spent_on_rent                                         391
# gini_index                                                          2892
# median_income                                                      15472
# income_per_capita                                                  14302
# median_age                                                           513
# less_than_high_school_graduate                                      4681
# different_house_year_ago_same_city                                  3677
# different_house_year_ago_different_city                             4789
# not_us_citizen_pop                                                  4151
# bachelors_degree_2                                                  5709
# high_school_including_ged                                           7065
# population_1_year_and_over                                         14234
# some_college_and_associates_degree                                  7341
# graduate_professional_degree                                        4274
# civilian_labor_force                                               11595
# commuters_by_subway_or_elevated                                      848
# commuters_drove_alone                                               9813
# black_including_hispanic                                            5224
# white_including_hispanic                                           13345
# female_85_and_over                                                  1062
# employed_agriculture_forestry_fishing_hunting_mining                 959
# employed_arts_entertainment_recreation_accommodation_food           2836
# employed_construction                                               2087
# employed_education_health_social                                    5145
# employed_finance_insurance_real_estate                              2370
# commuters_by_carpool                                                2876
# employed_information                                                1081
# employed_other_services_not_public_admin                            1722
# employed_public_administration                                      1844
#
#                                                            null values
# median_rent                                                        472
# percent_income_spent_on_rent                                       441
# gini_index                                                         203
# median_income                                                      202
# income_per_capita                                                   73
# median_age                                                          57
# less_than_high_school_graduate                                       2
# different_house_year_ago_same_city                                   2
# different_house_year_ago_different_city                              2
# not_us_citizen_pop                                                   2
# bachelors_degree_2                                                   2
# high_school_including_ged                                            2
# population_1_year_and_over                                           2
# some_college_and_associates_degree                                   2
# graduate_professional_degree                                         2
# civilian_labor_force                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# black_including_hispanic                                             0
# white_including_hispanic                                             0
# female_85_and_over                                                   0
# employed_agriculture_forestry_fishing_hunting_mining                 0
# employed_arts_entertainment_recreation_accommodation_food            0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# commuters_by_carpool                                                 0
# employed_information                                                 0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0

# %%
# Let's look at the rows with 2 nulls
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
med[med.full_zip.isin(null_zips)]
# Out:
#                npi entity_code full_zip state country          provider_type  \
# 48357   1750491288           I    00617    IL      US               Podiatry
# 446885  1477551984           I    00960    OR      US  Obstetrics/Gynecology
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 48357                                 Y               51                2573
# 446885                                Y                3                  40
#
#         total_beneficiaries  ...  total_medicare_payment  avg_beneficiary_age  \
# 48357                  1131  ...               148671.75                   72
# 446885                   24  ...                 1405.50                   71
#
#         avg_hcc_risk_score  services_per_capita  allowed_payment_per_capita  \
# 48357               1.7435                 2.27                      171.03
# 446885              1.3889                 1.67                       88.87
#
#         medicare_payment_per_capita  submitted_charges_per_capita   region  \
# 48357                        131.45                        274.12  Midwest
# 446885                        58.56                         89.67     West
#
#                  subregion               doctor_category
# 48357   East North Central           Medical Specialists
# 446885             Pacific  General Medicine Pracitioner
#
# [2 rows x 22 columns]

# %%
# The first row is a typo in Full_zip, should be 60617
med.loc[
    med[med.npi == '1750491288'].index, 'full_zip'] = '60617'

# The second row is actually from PR not OR, dropping this from Med.
med.drop(index = med[med.npi=='1477551984'].index, inplace = True)

# %%
census = census[census.graduate_professional_degree.notnull()]

# %% [markdown]
# ##### REEXAMINING CENSUS NULLS

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# median_rent                                                 float64
# percent_income_spent_on_rent                                float64
# gini_index                                                  float64
# median_income                                               float64
# income_per_capita                                           float64
# median_age                                                  float64
# employed_transportation_warehousing_utilities                 int64
# bachelors_degree_or_higher_25_64                              int64
# children                                                      int64
# graduate_professional_degree                                float64
# four_more_cars                                                int64
# children_in_single_female_hh                                  int64
# commuters_by_bus                                              int64
# commuters_by_car_truck_van                                    int64
# commuters_by_carpool                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# different_house_year_ago_different_city                     float64
# employed_wholesale_trade                                      int64
# different_house_year_ago_same_city                          float64
# employed_arts_entertainment_recreation_accommodation_food     int64
# female_female_households                                      int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# employed_information                                          int64
# employed_manufacturing                                        int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
# employed_retail_trade                                         int64
#
#                                                            non-null values  \
# median_rent                                                          18804
# percent_income_spent_on_rent                                         18835
# gini_index                                                           19073
# median_income                                                        19074
# income_per_capita                                                    19202
# median_age                                                           19218
# employed_transportation_warehousing_utilities                        19275
# bachelors_degree_or_higher_25_64                                     19275
# children                                                             19275
# graduate_professional_degree                                         19275
# four_more_cars                                                       19275
# children_in_single_female_hh                                         19275
# commuters_by_bus                                                     19275
# commuters_by_car_truck_van                                           19275
# commuters_by_carpool                                                 19275
# commuters_by_subway_or_elevated                                      19275
# commuters_drove_alone                                                19275
# different_house_year_ago_different_city                              19275
# employed_wholesale_trade                                             19275
# different_house_year_ago_same_city                                   19275
# employed_arts_entertainment_recreation_accommodation_food            19275
# female_female_households                                             19275
# employed_construction                                                19275
# employed_education_health_social                                     19275
# employed_finance_insurance_real_estate                               19275
# employed_information                                                 19275
# employed_manufacturing                                               19275
# employed_other_services_not_public_admin                             19275
# employed_public_administration                                       19275
# employed_retail_trade                                                19275
#
#                                                            unique values  \
# median_rent                                                         1614
# percent_income_spent_on_rent                                         391
# gini_index                                                          2891
# median_income                                                      15471
# income_per_capita                                                  14300
# median_age                                                           513
# employed_transportation_warehousing_utilities                       1789
# bachelors_degree_or_higher_25_64                                    6675
# children                                                            8255
# graduate_professional_degree                                        4274
# four_more_cars                                                      1561
# children_in_single_female_hh                                        3789
# commuters_by_bus                                                    1621
# commuters_by_car_truck_van                                         10382
# commuters_by_carpool                                                2876
# commuters_by_subway_or_elevated                                      848
# commuters_drove_alone                                               9813
# different_house_year_ago_different_city                             4789
# employed_wholesale_trade                                            1187
# different_house_year_ago_same_city                                  3677
# employed_arts_entertainment_recreation_accommodation_food           2836
# female_female_households                                             212
# employed_construction                                               2087
# employed_education_health_social                                    5145
# employed_finance_insurance_real_estate                              2370
# employed_information                                                1081
# employed_manufacturing                                              3053
# employed_other_services_not_public_admin                            1722
# employed_public_administration                                      1844
# employed_retail_trade                                               3191
#
#                                                            null values
# median_rent                                                        471
# percent_income_spent_on_rent                                       440
# gini_index                                                         202
# median_income                                                      201
# income_per_capita                                                   73
# median_age                                                          57
# employed_transportation_warehousing_utilities                        0
# bachelors_degree_or_higher_25_64                                     0
# children                                                             0
# graduate_professional_degree                                         0
# four_more_cars                                                       0
# children_in_single_female_hh                                         0
# commuters_by_bus                                                     0
# commuters_by_car_truck_van                                           0
# commuters_by_carpool                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# different_house_year_ago_different_city                              0
# employed_wholesale_trade                                             0
# different_house_year_ago_same_city                                   0
# employed_arts_entertainment_recreation_accommodation_food            0
# female_female_households                                             0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# employed_information                                                 0
# employed_manufacturing                                               0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0
# employed_retail_trade                                                0

# %%
census.columns[census.columns.str.contains('_rent$|^rent_|_rent_', regex=True)]
# Out:
# Index(['rent_burden_not_computed', 'rent_over_50_percent',
#        'rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'rent_under_10_percent',
#        'vacant_housing_units_for_rent', 'median_rent',
#        'percent_income_spent_on_rent'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('income')]
# Out:
# Index(['median_income', 'income_per_capita', 'percent_income_spent_on_rent',
#        'income_less_10000', 'income_10000_14999', 'income_15000_19999',
#        'income_20000_24999', 'income_25000_29999', 'income_30000_34999',
#        'income_35000_39999', 'income_40000_44999', 'income_45000_49999',
#        'income_50000_59999', 'income_60000_74999', 'income_75000_99999',
#        'income_100000_124999', 'income_125000_149999', 'income_150000_199999',
#        'income_200000_or_more', 'households_retirement_income'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('_to_')]
# Out:
# Index(['rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'dwellings_3_to_4_units',
#        'dwellings_5_to_9_units', 'dwellings_10_to_19_units',
#        'dwellings_20_to_49_units', 'housing_built_2000_to_2004', 'male_5_to_9',
#        'male_10_to_14', 'male_15_to_17', 'male_18_to_19', 'male_22_to_24',
#        'male_25_to_29', 'male_30_to_34', 'male_35_to_39', 'male_40_to_44',
#        'male_45_to_49', 'male_50_to_54', 'male_55_to_59', 'male_65_to_66',
#        'male_67_to_69', 'male_70_to_74', 'male_75_to_79', 'male_80_to_84',
#        'female_5_to_9', 'female_10_to_14', 'female_15_to_17',
#        'female_18_to_19', 'female_22_to_24', 'female_25_to_29',
#        'female_30_to_34', 'female_35_to_39', 'female_40_to_44',
#        'female_45_to_49', 'female_50_to_54', 'female_55_to_59',
#        'female_60_to_61', 'female_62_to_64', 'female_65_to_66',
#        'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
#        'female_80_to_84', 'in_grades_1_to_4', 'in_grades_5_to_8',
#        'in_grades_9_to_12', 'male_45_to_64', 'walked_to_work'],
#       dtype='object')

# %%
info[info['null values']>0].index
# Out:
# Index(['median_age', 'median_income', 'income_per_capita', 'median_rent',
#        'percent_income_spent_on_rent', 'gini_index'],
#       dtype='object')

# %% [markdown]
# While these factors are probably very relevant to the number of providers in a zip code, the health risk score, and the use of different providers, it seems there are other features in Census DF that may also address income, rent, and age.

# %%
#dropping these cols with nulls
cols = info[info['null values']>0].index
census.drop(columns = cols, inplace=True)

# %% [markdown]
# # Checking Data Types

# %% [markdown]
# All columns in Census besides Geo_id should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
#   geo_id
# 5  79916

# %% [markdown]
# There's a column called do_date that includes the years used to make the estimate Census measures. I'm going to keep that last four digits which represent the year being estimated.

# %%
census.do_date = census.do_date.apply(lambda x: str(x)[-4:])
census.do_date = pd.to_datetime(census.do_date, format='%Y')
census.do_date
# Out:
# 5       2012-01-01
# 11      2012-01-01
# 20      2012-01-01
# 44      2012-01-01
# 71      2012-01-01
#            ...
# 33115   2012-01-01
# 33116   2012-01-01
# 33117   2012-01-01
# 33118   2012-01-01
# 33119   2012-01-01
# Name: do_date, Length: 19275, dtype: datetime64[ns]

# %%
med.to_csv('../../data/processed/final2012MEDICARE.csv')
census.to_csv('../../data/processed/final2012CENSUS.csv')
