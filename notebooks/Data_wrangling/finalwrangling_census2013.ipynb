# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/processed/final2013MEDICARE.csv", index_col=0)

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949955 entries, 0 to 949954
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   npi                               949955 non-null  int64
#  1   entity_code                       949955 non-null  object
#  2   full_zip                          949955 non-null  int64
#  3   state                             949955 non-null  object
#  4   country                           949955 non-null  object
#  5   provider_type                     949955 non-null  object
#  6   medicare_participation_indicator  949955 non-null  object
#  7   number_of_hcpcs                   949955 non-null  int64
#  8   number_of_services                949955 non-null  int64
#  9   total_beneficiaries               949955 non-null  int64
#  10  total_submitted_charges           949955 non-null  float64
#  11  total_allowed_payment             949955 non-null  float64
#  12  total_medicare_payment            949955 non-null  float64
#  13  avg_beneficiary_age               949955 non-null  int64
#  14  avg_hcc_risk_score                949955 non-null  float64
#  15  services_per_capita               949955 non-null  float64
#  16  allowed_payment_per_capita        949955 non-null  float64
#  17  medicare_payment_per_capita       949955 non-null  float64
#  18  submitted_charges_per_capita      949955 non-null  float64
#  19  region                            949955 non-null  object
#  20  subregion                         949955 non-null  object
# dtypes: float64(8), int64(6), object(7)
# memory usage: 159.4+ MB

# %%
med.full_zip = med.full_zip.apply(lambda x: str(x).zfill(5))
med.npi = med.npi.astype('str')

# %%
med.head()
# Out:
#           npi entity_code full_zip state country           provider_type  \
# 0  1003183823           I    48235    MI      US     Physician Assistant
# 1  1023192564           I    49770    MI      US        General Practice
# 2  1073556320           I    48503    MI      US  Occupational therapist
# 3  1083919666           I    48237    MI      US      Nurse Practitioner
# 4  1144322173           I    48439    MI      US     Physician Assistant
#
#   medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 0                                Y               14                  46
# 1                                Y               18                 135
# 2                                Y                2                  13
# 3                                Y                9                  30
# 4                                Y                7                  36
#
#    total_beneficiaries  ...  total_allowed_payment  total_medicare_payment  \
# 0                   26  ...                2320.28                 1721.94
# 1                   41  ...                7435.61                 3899.56
# 2                   12  ...                 846.68                  667.53
# 3                   21  ...                1570.54                 1231.86
# 4                   26  ...                1812.43                 1422.64
#
#    avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 0                   60              1.3464                 1.77
# 1                   74              1.0309                 3.29
# 2                   61              1.5304                 1.08
# 3                   70              0.8738                 1.43
# 4                   68              1.2295                 1.38
#
#    allowed_payment_per_capita  medicare_payment_per_capita  \
# 0                       89.24                        66.23
# 1                      181.36                        95.11
# 2                       70.56                        55.63
# 3                       74.79                        58.66
# 4                       69.71                        54.72
#
#    submitted_charges_per_capita   region           subregion
# 0                        155.46  Midwest  East North Central
# 1                        229.24  Midwest  East North Central
# 2                        325.86  Midwest  East North Central
# 3                         76.66  Midwest  East North Central
# 4                        145.00  Midwest  East North Central
#
# [5 rows x 21 columns]

# %% [markdown]
# Checkpoint 1

# %%
checkpoint1 = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %%
census = pd.read_csv('../../data/raw/2013acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   91046                   118                 29
# 1   79916                     0                 62
# 2   14881                    71                  0
# 3   20317                   246                  0
# 4   28424                    10                 21
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1987.0                         0
# 1                       1998.0                        41
# 2                       1987.0                         0
# 3                       1951.0                         0
# 4                       2002.0                         0
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                   135                      0                     12
# 1                     0                     21                      0
# 2                     0                     18                      0
# 3                   117                     33                     20
# 4                    13                      0                      6
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                      0  ...
# 1                      0                      0  ...
# 2                      0                     19  ...
# 3                      0                     11  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          23                      0
# 1                        2201                    445
# 2                          71                      0
# 3                         355                      0
# 4                          55                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              176                 10
# 1                                 97             2850               2081
# 2                                  0               71                 18
# 3                                  0              355                 54
# 4                                  0               51                 21
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0               58              0           13             0  20092013
# 1              643             13            0           113  20092013
# 2                0              0           36            17  20092013
# 3               80             13           94            91  20092013
# 4               10              6            9             5  20092013
#
# [5 rows x 252 columns]

# %% [markdown]
# checkpoint2

# %%
checkpoint2 = census.copy()

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          19753
# percent_income_spent_on_rent                                           27449
# median_rent                                                            27491
# renter_occupied_housing_units_paying_cash_median_gross_rent            27503
# owner_occupied_housing_units_upper_value_quartile                      31573
# owner_occupied_housing_units_lower_value_quartile                      31573
# owner_occupied_housing_units_median_value                              31573
# median_income                                                          31985
# median_year_structure_built                                            32172
# gini_index                                                             32242
# income_per_capita                                                      32546
# median_age                                                             32589
# some_college_and_associates_degree                                     32989
# not_us_citizen_pop                                                     32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# less_than_high_school_graduate                                         32989
# different_house_year_ago_different_city                                32989
# graduate_professional_degree                                           32989
# bachelors_degree_2                                                     32989
# high_school_including_ged                                              32989
# commuters_drove_alone                                                  33120
# commuters_by_carpool                                                   33120
# commuters_by_subway_or_elevated                                        33120
# employed_finance_insurance_real_estate                                 33120
# employed_arts_entertainment_recreation_accommodation_food              33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# employed_information                                                   33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16691
# percent_income_spent_on_rent                                           400
# median_rent                                                           1695
# renter_occupied_housing_units_paying_cash_median_gross_rent           1686
# owner_occupied_housing_units_upper_value_quartile                     5923
# owner_occupied_housing_units_lower_value_quartile                     4094
# owner_occupied_housing_units_median_value                             5011
# median_income                                                        19918
# median_year_structure_built                                             70
# gini_index                                                            4143
# income_per_capita                                                    20158
# median_age                                                             665
# some_college_and_associates_degree                                    7383
# not_us_citizen_pop                                                    4223
# different_house_year_ago_same_city                                    3689
# population_1_year_and_over                                           15236
# less_than_high_school_graduate                                        4657
# different_house_year_ago_different_city                               4809
# graduate_professional_degree                                          4310
# bachelors_degree_2                                                    5797
# high_school_including_ged                                             7096
# commuters_drove_alone                                                10035
# commuters_by_carpool                                                  2846
# commuters_by_subway_or_elevated                                        874
# employed_finance_insurance_real_estate                                2361
# employed_arts_entertainment_recreation_accommodation_food             2871
# employed_construction                                                 2049
# employed_education_health_social                                      5174
# commuters_by_car_truck_van                                           10583
# employed_information                                                  1064
#
#                                                              null values
# aggregate_travel_time_to_work                                      13367
# percent_income_spent_on_rent                                        5671
# median_rent                                                         5629
# renter_occupied_housing_units_paying_cash_median_gross_rent         5617
# owner_occupied_housing_units_upper_value_quartile                   1547
# owner_occupied_housing_units_lower_value_quartile                   1547
# owner_occupied_housing_units_median_value                           1547
# median_income                                                       1135
# median_year_structure_built                                          948
# gini_index                                                           878
# income_per_capita                                                    574
# median_age                                                           531
# some_college_and_associates_degree                                   131
# not_us_citizen_pop                                                   131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# less_than_high_school_graduate                                       131
# different_house_year_ago_different_city                              131
# graduate_professional_degree                                         131
# bachelors_degree_2                                                   131
# high_school_including_ged                                            131
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Looking to see if any Medicare zip codes are missing from Census DF

# %%
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))

# %%
med[med.full_zip.isin(census.geo_id)].shape, med[~med.full_zip.isin(census.geo_id)].shape
# Out:
# ((923247, 21), (26708, 21))

# %%
pd.options.display.max_rows = 120
med[
    ~med.full_zip.isin(census.geo_id)].head()
# Out:
#             npi entity_code full_zip state country        provider_type  \
# 61   1003041971           I    48909    MI      US   Emergency Medicine
# 75   1003066218           I    48106    MI      US   Nurse Practitioner
# 160  1003816513           I    46509    MI      US  Physician Assistant
# 186  1003832908           I    49016    MI      US  Physician Assistant
# 419  1013007749           I    48670    MI      US                 CRNA
#
#     medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 61                                 Y               28                 418
# 75                                 Y                4                 966
# 160                                Y               42                 411
# 186                                Y               20                 102
# 419                                Y               55                 231
#
#      total_beneficiaries  ...  total_allowed_payment  total_medicare_payment  \
# 61                   376  ...               50603.61                38933.63
# 75                   276  ...               63881.60                50079.50
# 160                   68  ...               12813.07                 8754.69
# 186                   98  ...                3840.33                 3014.67
# 419                  227  ...               29635.60                22984.88
#
#      avg_beneficiary_age  avg_hcc_risk_score  services_per_capita  \
# 61                    70              2.0197                 1.11
# 75                    78              2.6862                 3.50
# 160                   67              0.8630                 6.04
# 186                   69              1.8044                 1.04
# 419                   71              1.3190                 1.02
#
#      allowed_payment_per_capita  medicare_payment_per_capita  \
# 61                       134.58                       103.55
# 75                       231.46                       181.45
# 160                      188.43                       128.75
# 186                       39.19                        30.76
# 419                      130.55                       101.25
#
#      submitted_charges_per_capita   region           subregion
# 61                         468.02  Midwest  East North Central
# 75                         478.77  Midwest  East North Central
# 160                        351.37  Midwest  East North Central
# 186                        190.02  Midwest  East North Central
# 419                        687.35  Midwest  East North Central
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Many are PO Boxes. Some are hospitals with their own zip codes. I want to drop these rows from Med, looking at how much of my data this will remove:

# %%
print(' Total providers in Med df:',med.shape[0],
     '\n Total beneficiaries in Med df:', med.total_beneficiaries.sum(),
     '\n Total providers whose zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].shape[0],
     '\n Total beneficiaries in Med in zips not in Census:', 
                          med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum(),
     '\n Percent providers with missing zips of all providers:',
                          round(med[~med.full_zip.isin(census.geo_id)].shape[0] \
                          / med.shape[0] * 100, 2),  '%',
     '\n Percent beneficiaries in missing zips of all beneficiaries:',
                          round(med[~med.full_zip.isin(census.geo_id)].total_beneficiaries.sum() \
                          / med.total_beneficiaries.sum() * 100,2),  '%')
# Out:
#  Total providers in Med df: 949955
#  Total beneficiaries in Med df: 358965885
#  Total providers whose zips not in Census: 26708
#  Total beneficiaries in Med in zips not in Census: 9114405
#  Percent providers with missing zips of all providers: 2.81 %
#  Percent beneficiaries in missing zips of all beneficiaries: 2.54 %

# %%
idx = med[~med['full_zip'].isin(census.geo_id)].index
med.drop(index = idx, inplace=True)

# %% [markdown]
# Dropping Rows from Census that don't appear in Medicare DF

# %%
print(census.shape)
idx = census[~census.geo_id.isin(med.full_zip)].index
census.drop(index = idx, inplace = True)
print(census.shape)
# Out:
# (33120, 252)
# (19324, 252)

# %%
med.full_zip.nunique()
# Out:
# 19324

# %% [markdown]
# Examining Nulls

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# some_college_and_associates_degree                            float64
# not_us_citizen_pop                                            float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_different_city                       float64
# graduate_professional_degree                                  float64
# bachelors_degree_2                                            float64
# high_school_including_ged                                     float64
# commuters_drove_alone                                           int64
# commuters_by_carpool                                            int64
# commuters_by_subway_or_elevated                                 int64
# employed_finance_insurance_real_estate                          int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# employed_information                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          16099
# percent_income_spent_on_rent                                           18711
# median_rent                                                            18716
# renter_occupied_housing_units_paying_cash_median_gross_rent            18717
# owner_occupied_housing_units_upper_value_quartile                      18963
# owner_occupied_housing_units_lower_value_quartile                      18963
# owner_occupied_housing_units_median_value                              18963
# median_income                                                          19101
# median_year_structure_built                                            19102
# gini_index                                                             19123
# income_per_capita                                                      19254
# median_age                                                             19257
# some_college_and_associates_degree                                     19323
# not_us_citizen_pop                                                     19323
# different_house_year_ago_same_city                                     19323
# population_1_year_and_over                                             19323
# less_than_high_school_graduate                                         19323
# different_house_year_ago_different_city                                19323
# graduate_professional_degree                                           19323
# bachelors_degree_2                                                     19323
# high_school_including_ged                                              19323
# commuters_drove_alone                                                  19324
# commuters_by_carpool                                                   19324
# commuters_by_subway_or_elevated                                        19324
# employed_finance_insurance_real_estate                                 19324
# employed_arts_entertainment_recreation_accommodation_food              19324
# employed_construction                                                  19324
# employed_education_health_social                                       19324
# commuters_by_car_truck_van                                             19324
# employed_information                                                   19324
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        14479
# percent_income_spent_on_rent                                           388
# median_rent                                                           1636
# renter_occupied_housing_units_paying_cash_median_gross_rent           1608
# owner_occupied_housing_units_upper_value_quartile                     5289
# owner_occupied_housing_units_lower_value_quartile                     3866
# owner_occupied_housing_units_median_value                             4588
# median_income                                                        15492
# median_year_structure_built                                             69
# gini_index                                                            2870
# income_per_capita                                                    14347
# median_age                                                             517
# some_college_and_associates_degree                                    7360
# not_us_citizen_pop                                                    4207
# different_house_year_ago_same_city                                    3684
# population_1_year_and_over                                           14270
# less_than_high_school_graduate                                        4644
# different_house_year_ago_different_city                               4800
# graduate_professional_degree                                          4310
# bachelors_degree_2                                                    5796
# high_school_including_ged                                             7071
# commuters_drove_alone                                                 9905
# commuters_by_carpool                                                  2837
# commuters_by_subway_or_elevated                                        868
# employed_finance_insurance_real_estate                                2356
# employed_arts_entertainment_recreation_accommodation_food             2866
# employed_construction                                                 2043
# employed_education_health_social                                      5162
# commuters_by_car_truck_van                                           10424
# employed_information                                                  1062
#
#                                                              null values
# aggregate_travel_time_to_work                                       3225
# percent_income_spent_on_rent                                         613
# median_rent                                                          608
# renter_occupied_housing_units_paying_cash_median_gross_rent          607
# owner_occupied_housing_units_upper_value_quartile                    361
# owner_occupied_housing_units_lower_value_quartile                    361
# owner_occupied_housing_units_median_value                            361
# median_income                                                        223
# median_year_structure_built                                          222
# gini_index                                                           201
# income_per_capita                                                     70
# median_age                                                            67
# some_college_and_associates_degree                                     1
# not_us_citizen_pop                                                     1
# different_house_year_ago_same_city                                     1
# population_1_year_and_over                                             1
# less_than_high_school_graduate                                         1
# different_house_year_ago_different_city                                1
# graduate_professional_degree                                           1
# bachelors_degree_2                                                     1
# high_school_including_ged                                              1
# commuters_drove_alone                                                  0
# commuters_by_carpool                                                   0
# commuters_by_subway_or_elevated                                        0
# employed_finance_insurance_real_estate                                 0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# employed_information                                                   0

# %% [markdown]
# Some of these columns are irrelevant or are redundant.

# %%
#there are other cols that speak to Commute to work
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# percent_income_spent_on_rent                                float64
# median_rent                                                 float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# less_than_high_school_graduate                              float64
# different_house_year_ago_same_city                          float64
# different_house_year_ago_different_city                     float64
# not_us_citizen_pop                                          float64
# bachelors_degree_2                                          float64
# high_school_including_ged                                   float64
# population_1_year_and_over                                  float64
# some_college_and_associates_degree                          float64
# graduate_professional_degree                                float64
# civilian_labor_force                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# black_including_hispanic                                      int64
# white_including_hispanic                                      int64
# female_85_and_over                                            int64
# employed_agriculture_forestry_fishing_hunting_mining          int64
# employed_arts_entertainment_recreation_accommodation_food     int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# commuters_by_carpool                                          int64
# employed_information                                          int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
#
#                                                            non-null values  \
# percent_income_spent_on_rent                                         18711
# median_rent                                                          18716
# median_income                                                        19101
# gini_index                                                           19123
# income_per_capita                                                    19254
# median_age                                                           19257
# less_than_high_school_graduate                                       19323
# different_house_year_ago_same_city                                   19323
# different_house_year_ago_different_city                              19323
# not_us_citizen_pop                                                   19323
# bachelors_degree_2                                                   19323
# high_school_including_ged                                            19323
# population_1_year_and_over                                           19323
# some_college_and_associates_degree                                   19323
# graduate_professional_degree                                         19323
# civilian_labor_force                                                 19324
# commuters_by_subway_or_elevated                                      19324
# commuters_drove_alone                                                19324
# black_including_hispanic                                             19324
# white_including_hispanic                                             19324
# female_85_and_over                                                   19324
# employed_agriculture_forestry_fishing_hunting_mining                 19324
# employed_arts_entertainment_recreation_accommodation_food            19324
# employed_construction                                                19324
# employed_education_health_social                                     19324
# employed_finance_insurance_real_estate                               19324
# commuters_by_carpool                                                 19324
# employed_information                                                 19324
# employed_other_services_not_public_admin                             19324
# employed_public_administration                                       19324
#
#                                                            unique values  \
# percent_income_spent_on_rent                                         388
# median_rent                                                         1636
# median_income                                                      15492
# gini_index                                                          2870
# income_per_capita                                                  14347
# median_age                                                           517
# less_than_high_school_graduate                                      4644
# different_house_year_ago_same_city                                  3684
# different_house_year_ago_different_city                             4800
# not_us_citizen_pop                                                  4207
# bachelors_degree_2                                                  5796
# high_school_including_ged                                           7071
# population_1_year_and_over                                         14270
# some_college_and_associates_degree                                  7360
# graduate_professional_degree                                        4310
# civilian_labor_force                                               11597
# commuters_by_subway_or_elevated                                      868
# commuters_drove_alone                                               9905
# black_including_hispanic                                            5253
# white_including_hispanic                                           13331
# female_85_and_over                                                  1074
# employed_agriculture_forestry_fishing_hunting_mining                 963
# employed_arts_entertainment_recreation_accommodation_food           2866
# employed_construction                                               2043
# employed_education_health_social                                    5162
# employed_finance_insurance_real_estate                              2356
# commuters_by_carpool                                                2837
# employed_information                                                1062
# employed_other_services_not_public_admin                            1734
# employed_public_administration                                      1849
#
#                                                            null values
# percent_income_spent_on_rent                                       613
# median_rent                                                        608
# median_income                                                      223
# gini_index                                                         201
# income_per_capita                                                   70
# median_age                                                          67
# less_than_high_school_graduate                                       1
# different_house_year_ago_same_city                                   1
# different_house_year_ago_different_city                              1
# not_us_citizen_pop                                                   1
# bachelors_degree_2                                                   1
# high_school_including_ged                                            1
# population_1_year_and_over                                           1
# some_college_and_associates_degree                                   1
# graduate_professional_degree                                         1
# civilian_labor_force                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# black_including_hispanic                                             0
# white_including_hispanic                                             0
# female_85_and_over                                                   0
# employed_agriculture_forestry_fishing_hunting_mining                 0
# employed_arts_entertainment_recreation_accommodation_food            0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# commuters_by_carpool                                                 0
# employed_information                                                 0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0

# %%
# Let's look at the rows with 1 nulls
null_zips = census[census.graduate_professional_degree.isnull()].geo_id
med[med.full_zip.isin(null_zips)]
# Out:
#                npi entity_code full_zip state country provider_type  \
# 520890  1750491288           I    00617    IL      US      Podiatry
#
#        medicare_participation_indicator  number_of_hcpcs  number_of_services  \
# 520890                                Y               49                2998
#
#         total_beneficiaries  ...  total_allowed_payment  \
# 520890                 1213  ...              211016.48
#
#         total_medicare_payment  avg_beneficiary_age  avg_hcc_risk_score  \
# 520890               157829.73                   72              1.5817
#
#         services_per_capita  allowed_payment_per_capita  \
# 520890                 2.47                      173.96
#
#         medicare_payment_per_capita  submitted_charges_per_capita   region  \
# 520890                       130.12                         292.4  Midwest
#
#                  subregion
# 520890  East North Central
#
# [1 rows x 21 columns]

# %%
# The row has a typo in Full_zip, should be 60617
med.loc[
    med[med.npi == '1750491288'].index, 'full_zip'] = '60617'

# %%
census = census[census.graduate_professional_degree.notnull()]

# %% [markdown]
# ##### REEXAMINING CENSUS NULLS

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                           data type  \
# percent_income_spent_on_rent                                float64
# median_rent                                                 float64
# median_income                                               float64
# gini_index                                                  float64
# income_per_capita                                           float64
# median_age                                                  float64
# employed_transportation_warehousing_utilities                 int64
# bachelors_degree_or_higher_25_64                              int64
# children                                                      int64
# graduate_professional_degree                                float64
# four_more_cars                                                int64
# children_in_single_female_hh                                  int64
# commuters_by_bus                                              int64
# commuters_by_car_truck_van                                    int64
# commuters_by_carpool                                          int64
# commuters_by_subway_or_elevated                               int64
# commuters_drove_alone                                         int64
# different_house_year_ago_different_city                     float64
# employed_wholesale_trade                                      int64
# different_house_year_ago_same_city                          float64
# employed_arts_entertainment_recreation_accommodation_food     int64
# female_female_households                                      int64
# employed_construction                                         int64
# employed_education_health_social                              int64
# employed_finance_insurance_real_estate                        int64
# employed_information                                          int64
# employed_manufacturing                                        int64
# employed_other_services_not_public_admin                      int64
# employed_public_administration                                int64
# employed_retail_trade                                         int64
#
#                                                            non-null values  \
# percent_income_spent_on_rent                                         18710
# median_rent                                                          18715
# median_income                                                        19100
# gini_index                                                           19122
# income_per_capita                                                    19253
# median_age                                                           19256
# employed_transportation_warehousing_utilities                        19323
# bachelors_degree_or_higher_25_64                                     19323
# children                                                             19323
# graduate_professional_degree                                         19323
# four_more_cars                                                       19323
# children_in_single_female_hh                                         19323
# commuters_by_bus                                                     19323
# commuters_by_car_truck_van                                           19323
# commuters_by_carpool                                                 19323
# commuters_by_subway_or_elevated                                      19323
# commuters_drove_alone                                                19323
# different_house_year_ago_different_city                              19323
# employed_wholesale_trade                                             19323
# different_house_year_ago_same_city                                   19323
# employed_arts_entertainment_recreation_accommodation_food            19323
# female_female_households                                             19323
# employed_construction                                                19323
# employed_education_health_social                                     19323
# employed_finance_insurance_real_estate                               19323
# employed_information                                                 19323
# employed_manufacturing                                               19323
# employed_other_services_not_public_admin                             19323
# employed_public_administration                                       19323
# employed_retail_trade                                                19323
#
#                                                            unique values  \
# percent_income_spent_on_rent                                         388
# median_rent                                                         1636
# median_income                                                      15491
# gini_index                                                          2870
# income_per_capita                                                  14346
# median_age                                                           517
# employed_transportation_warehousing_utilities                       1784
# bachelors_degree_or_higher_25_64                                    6736
# children                                                            8181
# graduate_professional_degree                                        4310
# four_more_cars                                                      1578
# children_in_single_female_hh                                        3794
# commuters_by_bus                                                    1616
# commuters_by_car_truck_van                                         10424
# commuters_by_carpool                                                2837
# commuters_by_subway_or_elevated                                      868
# commuters_drove_alone                                               9905
# different_house_year_ago_different_city                             4800
# employed_wholesale_trade                                            1171
# different_house_year_ago_same_city                                  3684
# employed_arts_entertainment_recreation_accommodation_food           2866
# female_female_households                                             205
# employed_construction                                               2043
# employed_education_health_social                                    5162
# employed_finance_insurance_real_estate                              2356
# employed_information                                                1062
# employed_manufacturing                                              3007
# employed_other_services_not_public_admin                            1734
# employed_public_administration                                      1849
# employed_retail_trade                                               3194
#
#                                                            null values
# percent_income_spent_on_rent                                       613
# median_rent                                                        608
# median_income                                                      223
# gini_index                                                         201
# income_per_capita                                                   70
# median_age                                                          67
# employed_transportation_warehousing_utilities                        0
# bachelors_degree_or_higher_25_64                                     0
# children                                                             0
# graduate_professional_degree                                         0
# four_more_cars                                                       0
# children_in_single_female_hh                                         0
# commuters_by_bus                                                     0
# commuters_by_car_truck_van                                           0
# commuters_by_carpool                                                 0
# commuters_by_subway_or_elevated                                      0
# commuters_drove_alone                                                0
# different_house_year_ago_different_city                              0
# employed_wholesale_trade                                             0
# different_house_year_ago_same_city                                   0
# employed_arts_entertainment_recreation_accommodation_food            0
# female_female_households                                             0
# employed_construction                                                0
# employed_education_health_social                                     0
# employed_finance_insurance_real_estate                               0
# employed_information                                                 0
# employed_manufacturing                                               0
# employed_other_services_not_public_admin                             0
# employed_public_administration                                       0
# employed_retail_trade                                                0

# %% [markdown]
# The remaining columns with nulls are important, but I know that other columns in the DF, have some information related to rent, income, and age.

# %%
census.columns[census.columns.str.contains('_rent$|^rent_|_rent_', regex=True)]
# Out:
# Index(['rent_burden_not_computed', 'rent_over_50_percent',
#        'rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'rent_under_10_percent',
#        'vacant_housing_units_for_rent', 'median_rent',
#        'percent_income_spent_on_rent'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('income')]
# Out:
# Index(['median_income', 'income_per_capita', 'percent_income_spent_on_rent',
#        'income_less_10000', 'income_10000_14999', 'income_15000_19999',
#        'income_20000_24999', 'income_25000_29999', 'income_30000_34999',
#        'income_35000_39999', 'income_40000_44999', 'income_45000_49999',
#        'income_50000_59999', 'income_60000_74999', 'income_75000_99999',
#        'income_100000_124999', 'income_125000_149999', 'income_150000_199999',
#        'income_200000_or_more', 'households_retirement_income'],
#       dtype='object')

# %%
census.columns[census.columns.str.contains('_to_')]
# Out:
# Index(['rent_40_to_50_percent', 'rent_35_to_40_percent',
#        'rent_30_to_35_percent', 'rent_25_to_30_percent',
#        'rent_20_to_25_percent', 'rent_15_to_20_percent',
#        'rent_10_to_15_percent', 'dwellings_3_to_4_units',
#        'dwellings_5_to_9_units', 'dwellings_10_to_19_units',
#        'dwellings_20_to_49_units', 'housing_built_2000_to_2004', 'male_5_to_9',
#        'male_10_to_14', 'male_15_to_17', 'male_18_to_19', 'male_22_to_24',
#        'male_25_to_29', 'male_30_to_34', 'male_35_to_39', 'male_40_to_44',
#        'male_45_to_49', 'male_50_to_54', 'male_55_to_59', 'male_65_to_66',
#        'male_67_to_69', 'male_70_to_74', 'male_75_to_79', 'male_80_to_84',
#        'female_5_to_9', 'female_10_to_14', 'female_15_to_17',
#        'female_18_to_19', 'female_22_to_24', 'female_25_to_29',
#        'female_30_to_34', 'female_35_to_39', 'female_40_to_44',
#        'female_45_to_49', 'female_50_to_54', 'female_55_to_59',
#        'female_60_to_61', 'female_62_to_64', 'female_65_to_66',
#        'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
#        'female_80_to_84', 'in_grades_1_to_4', 'in_grades_5_to_8',
#        'in_grades_9_to_12', 'male_45_to_64', 'walked_to_work'],
#       dtype='object')

# %%
info[info['null values']>0].index
# Out:
# Index(['median_age', 'median_income', 'income_per_capita', 'median_rent',
#        'percent_income_spent_on_rent', 'gini_index'],
#       dtype='object')

# %% [markdown]
# While these factors are probably very relevant to the number of providers in a zip code, the health risk score, and the use of different providers, it seems there are other features in Census DF that may also address income, rent, and age.

# %%
#dropping these cols with nulls
cols = info[info['null values']>0].index
census.drop(columns = cols, inplace=True)

# %% [markdown]
# # Checking Data Types

# %% [markdown]
# All columns in Census besides Geo_id should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
#   geo_id
# 1  79916

# %% [markdown]
# There's a column called do_date that includes the years used to make the estimate Census measures. I'm going to keep that last four digits which represent the year being estimated.

# %%
census.do_date = census.do_date.apply(lambda x: str(x)[-4:])
census.do_date = pd.to_datetime(census.do_date, format='%Y')
census.do_date
# Out:
# 1       2013-01-01
# 7       2013-01-01
# 50      2013-01-01
# 70      2013-01-01
# 77      2013-01-01
#            ...
# 33115   2013-01-01
# 33116   2013-01-01
# 33117   2013-01-01
# 33118   2013-01-01
# 33119   2013-01-01
# Name: do_date, Length: 19323, dtype: datetime64[ns]

# %%
census.isnull().sum().sort_values()
# Out:
# geo_id                          0
# children                        0
# children_in_single_female_hh    0
# commuters_by_bus                0
# commuters_by_car_truck_van      0
#                                ..
# male_21                         0
# male_22_to_24                   0
# male_25_to_29                   0
# pop_divorced                    0
# do_date                         0
# Length: 240, dtype: int64

# %%
med.to_csv('../../data/processed/final2013MEDICARE.csv')
census.to_csv('../../data/processed/final2013CENSUS.csv')
