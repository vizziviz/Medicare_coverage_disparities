# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2014.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (986677, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1659374411                                        MAHR
# 1                    1073738571                                        GIBB
# 2                    1619972387                                        DEEM
# 3                    1265649073                                      GAMBLE
# 4                    1366640377                                       DIRKS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                       TODD                              A
# 1                      JOYCE                              E
# 2                     ROBERT                              B
# 3                      SARAH                              M
# 4                    ZACHARY                              B
#
#   Credentials of the Provider Gender of the Provider  \
# 0                          MD                      M
# 1                        CRNP                      F
# 2                        M.D.                      M
# 3                          DO                      F
# 4                        O.D.                      M
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                   1836 SOUTH AVE
# 1                           I                215 ALLEGHENY AVE
# 2                           I                 1549 S JEFFERSON
# 3                           I                 222 RAILROAD AVE
# 4                           I                   320 SUNRISE DR
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN            LA CROSSE  ...
# 1                              NaN              OAKMONT  ...
# 2                              NaN           MONTICELLO  ...
# 3                          SUITE B            GREENWICH  ...
# 4                              NaN          SAINT PETER  ...
#
#   Percent (%) of Beneficiaries Identified With Depression   \
# 0                                                NaN
# 1                                               37.0
# 2                                                NaN
# 3                                                NaN
# 4                                               22.0
#
#   Percent (%) of Beneficiaries Identified With Diabetes   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               26.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               32.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension   \
# 0                                                NaN
# 1                                               57.0
# 2                                                NaN
# 3                                                NaN
# 4                                               34.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               12.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis   \
# 0                                                NaN
# 1                                               37.0
# 2                                                NaN
# 3                                                NaN
# 4                                               17.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.0
# 4                                               27.0
#
#    Percent (%) of Beneficiaries Identified With Stroke   \
# 0                                                0.0
# 1                                                NaN
# 2                                                0.0
# 3                                                0.0
# 4                                                NaN
#
#    Average HCC Risk Score of Beneficiaries
# 0                                    1.1238
# 1                                    0.9576
# 2                                    0.6467
# 3                                    0.9607
# 4                                    0.9950
#
# [5 rows x 70 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount ',
#        'Total Drug Medicare Payment Amount ',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#        'Percent (%) of Beneficiaries Identified With Asthma ',
#        'Percent (%) of Beneficiaries Identified With Cancer ',
#        'Percent (%) of Beneficiaries Identified With Heart Failure ',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Diabetes ',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#        'Percent (%) of Beneficiaries Identified With Hypertension ',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Percent (%) of Beneficiaries Identified With Stroke ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
med['Provider Type of the Provider'].unique()
# Out:
# array(['Allergy/Immunology', 'Nurse Practitioner', 'Family Practice',
#        'Internal Medicine', 'Optometry', 'Physician Assistant',
#        'Psychiatry', 'Orthopedic Surgery', 'Obstetrics/Gynecology',
#        'Pediatric Medicine', 'Urology', 'Radiation Oncology',
#        'Physical Therapist', 'Podiatry', 'Dermatology',
#        'Emergency Medicine', 'General Practice', 'Neurology',
#        'General Surgery', 'Rheumatology', 'Chiropractic',
#        'Otolaryngology', 'Infectious Disease', 'Endocrinology',
#        'Centralized Flu', 'Ophthalmology', 'Anesthesiology', 'Cardiology',
#        'Maxillofacial Surgery', 'Hematology/Oncology',
#        'Diagnostic Radiology', 'Gastroenterology', 'CRNA',
#        'Plastic and Reconstructive Surgery',
#        'Physical Medicine and Rehabilitation', 'Sports Medicine',
#        'Licensed Clinical Social Worker', 'Pathology',
#        'Mass Immunization Roster Biller', 'Addiction Medicine',
#        'Pain Management', 'Independent Diagnostic Testing Facility',
#        'Clinical Psychologist', 'Certified Nurse Midwife',
#        'Pulmonary Disease', 'Gynecological/Oncology', 'Vascular Surgery',
#        'Certified Clinical Nurse Specialist',
#        'Audiologist (billing independently)', 'Preventive Medicine',
#        'Nephrology', 'Occupational therapist', 'All Other Suppliers',
#        'Neurosurgery', 'Public Health Welfare Agency',
#        'Ambulatory Surgical Center', 'Medical Oncology',
#        'Ambulance Service Supplier', 'Speech Language Pathologist',
#        'Oral Surgery (dentists only)', 'Nuclear Medicine',
#        'Registered Dietician/Nutrition Professional',
#        'Osteopathic Manipulative Medicine', 'Surgical Oncology',
#        'Thoracic Surgery', 'Clinical Laboratory',
#        'Critical Care (Intensivists)', 'Unknown Physician Specialty Code',
#        'Cardiac Electrophysiology', 'Geriatric Medicine', 'Hand Surgery',
#        'Multispecialty Clinic/Group Practice', 'Cardiac Surgery',
#        'Anesthesiologist Assistants', 'Interventional Radiology',
#        'Psychologist (billing independently)',
#        'Interventional Pain Management', 'Hospice and Palliative Care',
#        'Hematology', 'Sleep Medicine',
#        'Colorectal Surgery (formerly proctology)', 'Geriatric Psychiatry',
#        'Peripheral Vascular Disease', 'Portable X-ray', 'Neuropsychiatry',
#        'Radiation Therapy', 'Mammographic Screening Center',
#        'Slide Preparation Facility', 'Unknown Supplier/Provider',
#        'Pharmacy', 'Interventional Cardiology'], dtype=object)

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',
                         'Multispecialty Clinic/Group Practice',
                           'Public Health Welfare Agency', 'Preventive Medicine']

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry','Clinical Psychologist','Psychologist (billing independently)',
                       ]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type of the Provider"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 54294

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
# Number of Beneficiaries With Race Not Elsewhere Classified                                float64
# Number of Hispanic Beneficiaries                                                          float64
# Number of Asian Pacific Islander Beneficiaries                                            float64
# Number of Beneficiaries Age 75 to 84                                                      float64
# Number of Black or African American Beneficiaries                                         float64
# Number of American Indian/Alaska Native Beneficiaries                                     float64
# Number of Beneficiaries Age Greater 84                                                    float64
# Number of Beneficiaries Age 65 to 74                                                      float64
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Number of Non-Hispanic White Beneficiaries                                                float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Number of Beneficiaries Age Less 65                                                       float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Number of Male Beneficiaries                                                              float64
# Number of Female Beneficiaries                                                            float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Submitted Charge Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Total Medical Medicare Payment Amount                                                     float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Gender of the Provider                                                                     object
# First Name of the Provider                                                                 object
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Medical Suppress Indicator                                                                           785
# Drug Suppress Indicator                                                                              785
# Number of Beneficiaries With Race Not Elsewhere Classified                                         10052
# Number of Hispanic Beneficiaries                                                                   10607
# Number of Asian Pacific Islander Beneficiaries                                                     11370
# Number of Beneficiaries Age 75 to 84                                                               12555
# Number of Black or African American Beneficiaries                                                  12699
# Number of American Indian/Alaska Native Beneficiaries                                              14917
# Number of Beneficiaries Age Greater 84                                                             17393
# Number of Beneficiaries Age 65 to 74                                                               17467
# Percent (%) of Beneficiaries Identified With Cancer                                                18900
# Percent (%) of Beneficiaries Identified With Asthma                                                19174
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          19785
# Percent (%) of Beneficiaries Identified With Heart Failure                                         22156
# Street Address 2 of the Provider                                                                   22258
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                22469
# Number of Non-Hispanic White Beneficiaries                                                         22545
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 22749
# Number of Beneficiaries Age Less 65                                                                23415
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   23536
# Percent (%) of Beneficiaries Identified With Stroke                                                24415
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                25251
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       25587
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       27037
# Number of Beneficiaries With Medicare Only Entitlement                                             27037
# Percent (%) of Beneficiaries Identified With Diabetes                                              28265
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             29875
# Number of Male Beneficiaries                                                                       30908
# Number of Female Beneficiaries                                                                     30908
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 31368
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        35630
# Percent (%) of Beneficiaries Identified With Hypertension                                          38517
# Middle Initial of the Provider                                                                     38925
# Percent (%) of Beneficiaries Identified With Depression                                            46049
# Credentials of the Provider                                                                        52221
# Total Medical Medicare Standardized Payment Amount                                                 53509
# Total Medical Submitted Charge Amount                                                              53509
# Total Medical Medicare Allowed Amount                                                              53509
# Number of Medicare Beneficiaries With Medical Services                                             53509
# Number of Medical Services                                                                         53509
# Number of HCPCS Associated With Medical Services                                                   53509
# Total Drug Medicare Standardized Payment Amount                                                    53509
# Total Drug Medicare Payment Amount                                                                 53509
# Total Drug Medicare Allowed Amount                                                                 53509
# Total Drug Submitted Charge Amount                                                                 53509
# Number of Drug Services                                                                            53509
# Number of HCPCS Associated With Drug Services                                                      53509
# Total Medical Medicare Payment Amount                                                              53509
# Number of Medicare Beneficiaries With Drug Services                                                53509
# Gender of the Provider                                                                             54292
# First Name of the Provider                                                                         54292
# National Provider Identifier                                                                       54294
# Total Medicare Standardized Payment Amount                                                         54294
# Last Name/Organization Name of the Provider                                                        54294
# Entity Type of the Provider                                                                        54294
# Street Address 1 of the Provider                                                                   54294
# City of the Provider                                                                               54294
# Zip Code of the Provider                                                                           54294
# State Code of the Provider                                                                         54294
# Country Code of the Provider                                                                       54294
# Provider Type of the Provider                                                                      54294
# Medicare Participation Indicator                                                                   54294
# Number of HCPCS                                                                                    54294
# Number of Services                                                                                 54294
# Number of Medicare Beneficiaries                                                                   54294
# Total Submitted Charge Amount                                                                      54294
# Total Medicare Allowed Amount                                                                      54294
# Total Medicare Payment Amount                                                                      54294
# Average Age of Beneficiaries                                                                       54294
# Average HCC Risk Score of Beneficiaries                                                            54294
#
#                                                                                          unique values  \
# Medical Suppress Indicator                                                                           2
# Drug Suppress Indicator                                                                              2
# Number of Beneficiaries With Race Not Elsewhere Classified                                          37
# Number of Hispanic Beneficiaries                                                                   282
# Number of Asian Pacific Islander Beneficiaries                                                     111
# Number of Beneficiaries Age 75 to 84                                                               370
# Number of Black or African American Beneficiaries                                                  344
# Number of American Indian/Alaska Native Beneficiaries                                               56
# Number of Beneficiaries Age Greater 84                                                             409
# Number of Beneficiaries Age 65 to 74                                                               329
# Percent (%) of Beneficiaries Identified With Cancer                                                 72
# Percent (%) of Beneficiaries Identified With Asthma                                                 53
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           53
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Street Address 2 of the Provider                                                                  7592
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 72
# Number of Non-Hispanic White Beneficiaries                                                         846
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  73
# Number of Beneficiaries Age Less 65                                                                571
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    57
# Percent (%) of Beneficiaries Identified With Stroke                                                 76
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        75
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       756
# Number of Beneficiaries With Medicare Only Entitlement                                             556
# Percent (%) of Beneficiaries Identified With Diabetes                                               68
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Number of Male Beneficiaries                                                                       531
# Number of Female Beneficiaries                                                                     686
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  71
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         64
# Percent (%) of Beneficiaries Identified With Hypertension                                           63
# Middle Initial of the Provider                                                                      29
# Percent (%) of Beneficiaries Identified With Depression                                             63
# Credentials of the Provider                                                                       2149
# Total Medical Medicare Standardized Payment Amount                                               53186
# Total Medical Submitted Charge Amount                                                            40777
# Total Medical Medicare Allowed Amount                                                            53263
# Number of Medicare Beneficiaries With Medical Services                                            1002
# Number of Medical Services                                                                        3747
# Number of HCPCS Associated With Medical Services                                                    60
# Total Drug Medicare Standardized Payment Amount                                                    261
# Total Drug Medicare Payment Amount                                                                 261
# Total Drug Medicare Allowed Amount                                                                 262
# Total Drug Submitted Charge Amount                                                                 262
# Number of Drug Services                                                                            243
# Number of HCPCS Associated With Drug Services                                                       16
# Total Medical Medicare Payment Amount                                                            53190
# Number of Medicare Beneficiaries With Drug Services                                                 73
# Gender of the Provider                                                                               2
# First Name of the Provider                                                                        8833
# National Provider Identifier                                                                     54294
# Total Medicare Standardized Payment Amount                                                       53968
# Last Name/Organization Name of the Provider                                                      28794
# Entity Type of the Provider                                                                          2
# Street Address 1 of the Provider                                                                 31956
# City of the Provider                                                                              4607
# Zip Code of the Provider                                                                         33747
# State Code of the Provider                                                                          55
# Country Code of the Provider                                                                         4
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     68
# Number of Services                                                                                3916
# Number of Medicare Beneficiaries                                                                  1020
# Total Submitted Charge Amount                                                                    41516
# Total Medicare Allowed Amount                                                                    54047
# Total Medicare Payment Amount                                                                    53967
# Average Age of Beneficiaries                                                                        69
# Average HCC Risk Score of Beneficiaries                                                          17401
#
#                                                                                          null values
# Medical Suppress Indicator                                                                     53509
# Drug Suppress Indicator                                                                        53509
# Number of Beneficiaries With Race Not Elsewhere Classified                                     44242
# Number of Hispanic Beneficiaries                                                               43687
# Number of Asian Pacific Islander Beneficiaries                                                 42924
# Number of Beneficiaries Age 75 to 84                                                           41739
# Number of Black or African American Beneficiaries                                              41595
# Number of American Indian/Alaska Native Beneficiaries                                          39377
# Number of Beneficiaries Age Greater 84                                                         36901
# Number of Beneficiaries Age 65 to 74                                                           36827
# Percent (%) of Beneficiaries Identified With Cancer                                            35394
# Percent (%) of Beneficiaries Identified With Asthma                                            35120
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      34509
# Percent (%) of Beneficiaries Identified With Heart Failure                                     32138
# Street Address 2 of the Provider                                                               32036
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            31825
# Number of Non-Hispanic White Beneficiaries                                                     31749
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             31545
# Number of Beneficiaries Age Less 65                                                            30879
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               30758
# Percent (%) of Beneficiaries Identified With Stroke                                            29879
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            29043
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   28707
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   27257
# Number of Beneficiaries With Medicare Only Entitlement                                         27257
# Percent (%) of Beneficiaries Identified With Diabetes                                          26029
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         24419
# Number of Male Beneficiaries                                                                   23386
# Number of Female Beneficiaries                                                                 23386
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             22926
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    18664
# Percent (%) of Beneficiaries Identified With Hypertension                                      15777
# Middle Initial of the Provider                                                                 15369
# Percent (%) of Beneficiaries Identified With Depression                                         8245
# Credentials of the Provider                                                                     2073
# Total Medical Medicare Standardized Payment Amount                                               785
# Total Medical Submitted Charge Amount                                                            785
# Total Medical Medicare Allowed Amount                                                            785
# Number of Medicare Beneficiaries With Medical Services                                           785
# Number of Medical Services                                                                       785
# Number of HCPCS Associated With Medical Services                                                 785
# Total Drug Medicare Standardized Payment Amount                                                  785
# Total Drug Medicare Payment Amount                                                               785
# Total Drug Medicare Allowed Amount                                                               785
# Total Drug Submitted Charge Amount                                                               785
# Number of Drug Services                                                                          785
# Number of HCPCS Associated With Drug Services                                                    785
# Total Medical Medicare Payment Amount                                                            785
# Number of Medicare Beneficiaries With Drug Services                                              785
# Gender of the Provider                                                                             2
# First Name of the Provider                                                                         2
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
print(mental_med['Number of Black or African American Beneficiaries'].notnull().sum())
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]
# Out:
# 12699

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Medicare Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 12699

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 5654

# %% [markdown]
# Some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Medicare Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 0

# %%
#Let's look at rows where all info is present but not all bins equal the total.

mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']
][race_cols]
# Out:
# Empty DataFrame
# Columns: [Number of American Indian/Alaska Native Beneficiaries, Number of Asian Pacific Islander Beneficiaries, Number of Non-Hispanic White Beneficiaries, Number of Hispanic Beneficiaries, Number of Beneficiaries With Race Not Elsewhere Classified, Number of Black or African American Beneficiaries, Number of Medicare Beneficiaries]
# Index: []

# %%
#index of rows where sums don't equal total
idx = mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']
].index

#sums of races that are off
sums_of_races = mental_med.loc[idx][race_cols[:-1]].sum(axis=1)

#values to replace 'Number with Race Not Classified' (Total+'Number Not Classfd'-sums)
new_values = mental_med.loc[idx, 
        'Number of Beneficiaries With Race Not Elsewhere Classified'] + \
        mental_med.loc[idx]['Number of Medicare Beneficiaries'] - \
        sums_of_races

#actually replacing those values
mental_med.loc[idx, 
            'Number of Beneficiaries With Race Not Elsewhere Classified'] = new_values

# %%
#checking my work
(mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']).sum()
# Out:
# 0

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Medicare Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 9923

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 5431

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 12699

# %%
black_medicare[age_cols[:-1]].isnull().any(axis=1).sum()
# Out:
# 9923

# %%
black_medicare[age_cols].head(3)
# Out:
#      Number of Beneficiaries Age Less 65  \
# 684                                  NaN
# 892                                  NaN
# 895                                  NaN
#
#      Number of Beneficiaries Age 65 to 74  \
# 684                                   NaN
# 892                                   NaN
# 895                                   NaN
#
#      Number of Beneficiaries Age 75 to 84  \
# 684                                   NaN
# 892                                   NaN
# 895                                   NaN
#
#      Number of Beneficiaries Age Greater 84 Number of Medicare Beneficiaries
# 684                                     0.0                               11
# 892                                     NaN                               23
# 895                                     NaN                               21

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (12699, 12699)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (5654, 5654)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Medical Suppress Indicator                                                                 object
# Drug Suppress Indicator                                                                    object
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Number of Male Beneficiaries                                                              float64
# Number of Female Beneficiaries                                                            float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Medicare Standardized Payment Amount                                        float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Medical Medicare Allowed Amount                                                     float64
# Total Medical Submitted Charge Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Allowed Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Black or African American Beneficiaries                                         float64
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# First Name of the Provider                                                                 object
# Gender of the Provider                                                                     object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Medical Suppress Indicator                                                                           281
# Drug Suppress Indicator                                                                              281
# Street Address 2 of the Provider                                                                    5317
# Percent (%) of Beneficiaries Identified With Cancer                                                 5446
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           5566
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    6411
# Percent (%) of Beneficiaries Identified With Asthma                                                 6465
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 6521
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 6577
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  6682
# Percent (%) of Beneficiaries Identified With Heart Failure                                          6704
# Percent (%) of Beneficiaries Identified With Stroke                                                 6801
# Number of Beneficiaries With Medicare Only Entitlement                                              6958
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                        6958
# Percent (%) of Beneficiaries Identified With Diabetes                                               6994
# Number of Male Beneficiaries                                                                        7058
# Number of Female Beneficiaries                                                                      7058
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  7087
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        7365
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         7788
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              8160
# Percent (%) of Beneficiaries Identified With Hypertension                                           8287
# Middle Initial of the Provider                                                                      8891
# Percent (%) of Beneficiaries Identified With Depression                                             9725
# Credentials of the Provider                                                                        12229
# Total Medical Medicare Standardized Payment Amount                                                 12418
# Total Medical Medicare Payment Amount                                                              12418
# Total Medical Medicare Allowed Amount                                                              12418
# Total Medical Submitted Charge Amount                                                              12418
# Number of Medicare Beneficiaries With Medical Services                                             12418
# Number of Medical Services                                                                         12418
# Total Drug Medicare Payment Amount                                                                 12418
# Total Drug Medicare Standardized Payment Amount                                                    12418
# Total Drug Medicare Allowed Amount                                                                 12418
# Number of Medicare Beneficiaries With Drug Services                                                12418
# Number of Drug Services                                                                            12418
# Number of HCPCS Associated With Drug Services                                                      12418
# Number of HCPCS Associated With Medical Services                                                   12418
# Total Drug Submitted Charge Amount                                                                 12418
# Number of Black or African American Beneficiaries                                                  12699
# National Provider Identifier                                                                       12699
# Total Medicare Standardized Payment Amount                                                         12699
# Last Name/Organization Name of the Provider                                                        12699
# First Name of the Provider                                                                         12699
# Gender of the Provider                                                                             12699
# Entity Type of the Provider                                                                        12699
# Street Address 1 of the Provider                                                                   12699
# City of the Provider                                                                               12699
# Zip Code of the Provider                                                                           12699
# State Code of the Provider                                                                         12699
# Country Code of the Provider                                                                       12699
# Provider Type of the Provider                                                                      12699
# Medicare Participation Indicator                                                                   12699
# Number of HCPCS                                                                                    12699
# Number of Services                                                                                 12699
# Number of Medicare Beneficiaries                                                                   12699
# Total Submitted Charge Amount                                                                      12699
# Total Medicare Allowed Amount                                                                      12699
# Total Medicare Payment Amount                                                                      12699
# Average Age of Beneficiaries                                                                       12699
# Average HCC Risk Score of Beneficiaries                                                            12699
#
#                                                                                          unique values  \
# Medical Suppress Indicator                                                                           1
# Drug Suppress Indicator                                                                              1
# Street Address 2 of the Provider                                                                  2490
# Percent (%) of Beneficiaries Identified With Cancer                                                 40
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           43
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    48
# Percent (%) of Beneficiaries Identified With Asthma                                                 47
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 70
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  71
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Percent (%) of Beneficiaries Identified With Stroke                                                 65
# Number of Beneficiaries With Medicare Only Entitlement                                             534
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       717
# Percent (%) of Beneficiaries Identified With Diabetes                                               65
# Number of Male Beneficiaries                                                                       522
# Number of Female Beneficiaries                                                                     655
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  70
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Percent (%) of Beneficiaries Identified With Hypertension                                           59
# Middle Initial of the Provider                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                             62
# Credentials of the Provider                                                                        742
# Total Medical Medicare Standardized Payment Amount                                               12406
# Total Medical Medicare Payment Amount                                                            12400
# Total Medical Medicare Allowed Amount                                                            12403
# Total Medical Submitted Charge Amount                                                            11276
# Number of Medicare Beneficiaries With Medical Services                                             956
# Number of Medical Services                                                                        2830
# Total Drug Medicare Payment Amount                                                                 161
# Total Drug Medicare Standardized Payment Amount                                                    161
# Total Drug Medicare Allowed Amount                                                                 162
# Number of Medicare Beneficiaries With Drug Services                                                 64
# Number of Drug Services                                                                            153
# Number of HCPCS Associated With Drug Services                                                       14
# Number of HCPCS Associated With Medical Services                                                    52
# Total Drug Submitted Charge Amount                                                                 162
# Number of Black or African American Beneficiaries                                                  344
# National Provider Identifier                                                                     12699
# Total Medicare Standardized Payment Amount                                                       12687
# Last Name/Organization Name of the Provider                                                       8885
# First Name of the Provider                                                                        3674
# Gender of the Provider                                                                               2
# Entity Type of the Provider                                                                          1
# Street Address 1 of the Provider                                                                  9959
# City of the Provider                                                                              2761
# Zip Code of the Provider                                                                         10326
# State Code of the Provider                                                                          54
# Country Code of the Provider                                                                         2
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     56
# Number of Services                                                                                2932
# Number of Medicare Beneficiaries                                                                   977
# Total Submitted Charge Amount                                                                    11559
# Total Medicare Allowed Amount                                                                    12684
# Total Medicare Payment Amount                                                                    12681
# Average Age of Beneficiaries                                                                        62
# Average HCC Risk Score of Beneficiaries                                                           8853
#
#                                                                                          null values
# Medical Suppress Indicator                                                                     12418
# Drug Suppress Indicator                                                                        12418
# Street Address 2 of the Provider                                                                7382
# Percent (%) of Beneficiaries Identified With Cancer                                             7253
# Percent (%) of Beneficiaries Identified With Osteoporosis                                       7133
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                6288
# Percent (%) of Beneficiaries Identified With Asthma                                             6234
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                             6178
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                             6122
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease              6017
# Percent (%) of Beneficiaries Identified With Heart Failure                                      5995
# Percent (%) of Beneficiaries Identified With Stroke                                             5898
# Number of Beneficiaries With Medicare Only Entitlement                                          5741
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                    5741
# Percent (%) of Beneficiaries Identified With Diabetes                                           5705
# Number of Male Beneficiaries                                                                    5641
# Number of Female Beneficiaries                                                                  5641
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis              5612
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                    5334
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                     4911
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders          4539
# Percent (%) of Beneficiaries Identified With Hypertension                                       4412
# Middle Initial of the Provider                                                                  3808
# Percent (%) of Beneficiaries Identified With Depression                                         2974
# Credentials of the Provider                                                                      470
# Total Medical Medicare Standardized Payment Amount                                               281
# Total Medical Medicare Payment Amount                                                            281
# Total Medical Medicare Allowed Amount                                                            281
# Total Medical Submitted Charge Amount                                                            281
# Number of Medicare Beneficiaries With Medical Services                                           281
# Number of Medical Services                                                                       281
# Total Drug Medicare Payment Amount                                                               281
# Total Drug Medicare Standardized Payment Amount                                                  281
# Total Drug Medicare Allowed Amount                                                               281
# Number of Medicare Beneficiaries With Drug Services                                              281
# Number of Drug Services                                                                          281
# Number of HCPCS Associated With Drug Services                                                    281
# Number of HCPCS Associated With Medical Services                                                 281
# Total Drug Submitted Charge Amount                                                               281
# Number of Black or African American Beneficiaries                                                  0
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# First Name of the Provider                                                                         0
# Gender of the Provider                                                                             0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries','Number of Medicare Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 7058
# Has nulls: 5641

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Medicare Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 7058
# Don't sum 0

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                         data type  \
# Drug Suppress Indicator                                                                    object
# Medical Suppress Indicator                                                                 object
# Street Address 2 of the Provider                                                           object
# Percent (%) of Beneficiaries Identified With Cancer                                       float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                 float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                          float64
# Percent (%) of Beneficiaries Identified With Asthma                                       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                       float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                       float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease        float64
# Percent (%) of Beneficiaries Identified With Heart Failure                                float64
# Percent (%) of Beneficiaries Identified With Stroke                                       float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                              float64
# Number of Beneficiaries With Medicare Only Entitlement                                    float64
# Percent (%) of Beneficiaries Identified With Diabetes                                     float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis        float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia              float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                               float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders    float64
# Percent (%) of Beneficiaries Identified With Hypertension                                 float64
# Middle Initial of the Provider                                                             object
# Percent (%) of Beneficiaries Identified With Depression                                   float64
# Credentials of the Provider                                                                object
# Total Medical Medicare Allowed Amount                                                     float64
# Total Medical Submitted Charge Amount                                                     float64
# Number of Medicare Beneficiaries With Medical Services                                    float64
# Number of Medical Services                                                                float64
# Number of HCPCS Associated With Medical Services                                          float64
# Total Drug Medicare Standardized Payment Amount                                           float64
# Total Drug Medicare Allowed Amount                                                        float64
# Total Drug Submitted Charge Amount                                                        float64
# Number of Medicare Beneficiaries With Drug Services                                       float64
# Number of Drug Services                                                                   float64
# Number of HCPCS Associated With Drug Services                                             float64
# Total Medical Medicare Payment Amount                                                     float64
# Total Drug Medicare Payment Amount                                                        float64
# Total Medical Medicare Standardized Payment Amount                                        float64
# Number of Black or African American Beneficiaries                                         float64
# National Provider Identifier                                                               object
# Total Medicare Standardized Payment Amount                                                float64
# Last Name/Organization Name of the Provider                                                object
# First Name of the Provider                                                                 object
# Gender of the Provider                                                                     object
# Entity Type of the Provider                                                                object
# Street Address 1 of the Provider                                                           object
# City of the Provider                                                                       object
# Zip Code of the Provider                                                                   object
# State Code of the Provider                                                                 object
# Country Code of the Provider                                                               object
# Provider Type of the Provider                                                              object
# Medicare Participation Indicator                                                           object
# Number of HCPCS                                                                            object
# Number of Services                                                                        float64
# Number of Medicare Beneficiaries                                                           object
# Total Submitted Charge Amount                                                             float64
# Total Medicare Allowed Amount                                                             float64
# Total Medicare Payment Amount                                                             float64
# Average Age of Beneficiaries                                                               object
# Average HCC Risk Score of Beneficiaries                                                   float64
#
#                                                                                          non-null values  \
# Drug Suppress Indicator                                                                              281
# Medical Suppress Indicator                                                                           281
# Street Address 2 of the Provider                                                                    5317
# Percent (%) of Beneficiaries Identified With Cancer                                                 5446
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           5566
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    6411
# Percent (%) of Beneficiaries Identified With Asthma                                                 6465
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 6521
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 6577
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  6682
# Percent (%) of Beneficiaries Identified With Heart Failure                                          6704
# Percent (%) of Beneficiaries Identified With Stroke                                                 6801
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                        6958
# Number of Beneficiaries With Medicare Only Entitlement                                              6958
# Percent (%) of Beneficiaries Identified With Diabetes                                               6994
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  7087
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        7365
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         7788
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              8160
# Percent (%) of Beneficiaries Identified With Hypertension                                           8287
# Middle Initial of the Provider                                                                      8891
# Percent (%) of Beneficiaries Identified With Depression                                             9725
# Credentials of the Provider                                                                        12229
# Total Medical Medicare Allowed Amount                                                              12418
# Total Medical Submitted Charge Amount                                                              12418
# Number of Medicare Beneficiaries With Medical Services                                             12418
# Number of Medical Services                                                                         12418
# Number of HCPCS Associated With Medical Services                                                   12418
# Total Drug Medicare Standardized Payment Amount                                                    12418
# Total Drug Medicare Allowed Amount                                                                 12418
# Total Drug Submitted Charge Amount                                                                 12418
# Number of Medicare Beneficiaries With Drug Services                                                12418
# Number of Drug Services                                                                            12418
# Number of HCPCS Associated With Drug Services                                                      12418
# Total Medical Medicare Payment Amount                                                              12418
# Total Drug Medicare Payment Amount                                                                 12418
# Total Medical Medicare Standardized Payment Amount                                                 12418
# Number of Black or African American Beneficiaries                                                  12699
# National Provider Identifier                                                                       12699
# Total Medicare Standardized Payment Amount                                                         12699
# Last Name/Organization Name of the Provider                                                        12699
# First Name of the Provider                                                                         12699
# Gender of the Provider                                                                             12699
# Entity Type of the Provider                                                                        12699
# Street Address 1 of the Provider                                                                   12699
# City of the Provider                                                                               12699
# Zip Code of the Provider                                                                           12699
# State Code of the Provider                                                                         12699
# Country Code of the Provider                                                                       12699
# Provider Type of the Provider                                                                      12699
# Medicare Participation Indicator                                                                   12699
# Number of HCPCS                                                                                    12699
# Number of Services                                                                                 12699
# Number of Medicare Beneficiaries                                                                   12699
# Total Submitted Charge Amount                                                                      12699
# Total Medicare Allowed Amount                                                                      12699
# Total Medicare Payment Amount                                                                      12699
# Average Age of Beneficiaries                                                                       12699
# Average HCC Risk Score of Beneficiaries                                                            12699
#
#                                                                                          unique values  \
# Drug Suppress Indicator                                                                              1
# Medical Suppress Indicator                                                                           1
# Street Address 2 of the Provider                                                                  2490
# Percent (%) of Beneficiaries Identified With Cancer                                                 40
# Percent (%) of Beneficiaries Identified With Osteoporosis                                           43
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                    48
# Percent (%) of Beneficiaries Identified With Asthma                                                 47
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                 70
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                 73
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                  71
# Percent (%) of Beneficiaries Identified With Heart Failure                                          74
# Percent (%) of Beneficiaries Identified With Stroke                                                 65
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       717
# Number of Beneficiaries With Medicare Only Entitlement                                             534
# Percent (%) of Beneficiaries Identified With Diabetes                                               65
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                  70
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                        74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                         64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders              75
# Percent (%) of Beneficiaries Identified With Hypertension                                           59
# Middle Initial of the Provider                                                                      28
# Percent (%) of Beneficiaries Identified With Depression                                             62
# Credentials of the Provider                                                                        742
# Total Medical Medicare Allowed Amount                                                            12403
# Total Medical Submitted Charge Amount                                                            11276
# Number of Medicare Beneficiaries With Medical Services                                             956
# Number of Medical Services                                                                        2830
# Number of HCPCS Associated With Medical Services                                                    52
# Total Drug Medicare Standardized Payment Amount                                                    161
# Total Drug Medicare Allowed Amount                                                                 162
# Total Drug Submitted Charge Amount                                                                 162
# Number of Medicare Beneficiaries With Drug Services                                                 64
# Number of Drug Services                                                                            153
# Number of HCPCS Associated With Drug Services                                                       14
# Total Medical Medicare Payment Amount                                                            12400
# Total Drug Medicare Payment Amount                                                                 161
# Total Medical Medicare Standardized Payment Amount                                               12406
# Number of Black or African American Beneficiaries                                                  344
# National Provider Identifier                                                                     12699
# Total Medicare Standardized Payment Amount                                                       12687
# Last Name/Organization Name of the Provider                                                       8885
# First Name of the Provider                                                                        3674
# Gender of the Provider                                                                               2
# Entity Type of the Provider                                                                          1
# Street Address 1 of the Provider                                                                  9959
# City of the Provider                                                                              2761
# Zip Code of the Provider                                                                         10326
# State Code of the Provider                                                                          54
# Country Code of the Provider                                                                         2
# Provider Type of the Provider                                                                        6
# Medicare Participation Indicator                                                                     2
# Number of HCPCS                                                                                     56
# Number of Services                                                                                2932
# Number of Medicare Beneficiaries                                                                   977
# Total Submitted Charge Amount                                                                    11559
# Total Medicare Allowed Amount                                                                    12684
# Total Medicare Payment Amount                                                                    12681
# Average Age of Beneficiaries                                                                        62
# Average HCC Risk Score of Beneficiaries                                                           8853
#
#                                                                                          null values
# Drug Suppress Indicator                                                                        12418
# Medical Suppress Indicator                                                                     12418
# Street Address 2 of the Provider                                                                7382
# Percent (%) of Beneficiaries Identified With Cancer                                             7253
# Percent (%) of Beneficiaries Identified With Osteoporosis                                       7133
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                6288
# Percent (%) of Beneficiaries Identified With Asthma                                             6234
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                             6178
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                             6122
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease              6017
# Percent (%) of Beneficiaries Identified With Heart Failure                                      5995
# Percent (%) of Beneficiaries Identified With Stroke                                             5898
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                    5741
# Number of Beneficiaries With Medicare Only Entitlement                                          5741
# Percent (%) of Beneficiaries Identified With Diabetes                                           5705
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis              5612
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                    5334
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                     4911
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders          4539
# Percent (%) of Beneficiaries Identified With Hypertension                                       4412
# Middle Initial of the Provider                                                                  3808
# Percent (%) of Beneficiaries Identified With Depression                                         2974
# Credentials of the Provider                                                                      470
# Total Medical Medicare Allowed Amount                                                            281
# Total Medical Submitted Charge Amount                                                            281
# Number of Medicare Beneficiaries With Medical Services                                           281
# Number of Medical Services                                                                       281
# Number of HCPCS Associated With Medical Services                                                 281
# Total Drug Medicare Standardized Payment Amount                                                  281
# Total Drug Medicare Allowed Amount                                                               281
# Total Drug Submitted Charge Amount                                                               281
# Number of Medicare Beneficiaries With Drug Services                                              281
# Number of Drug Services                                                                          281
# Number of HCPCS Associated With Drug Services                                                    281
# Total Medical Medicare Payment Amount                                                            281
# Total Drug Medicare Payment Amount                                                               281
# Total Medical Medicare Standardized Payment Amount                                               281
# Number of Black or African American Beneficiaries                                                  0
# National Provider Identifier                                                                       0
# Total Medicare Standardized Payment Amount                                                         0
# Last Name/Organization Name of the Provider                                                        0
# First Name of the Provider                                                                         0
# Gender of the Provider                                                                             0
# Entity Type of the Provider                                                                        0
# Street Address 1 of the Provider                                                                   0
# City of the Provider                                                                               0
# Zip Code of the Provider                                                                           0
# State Code of the Provider                                                                         0
# Country Code of the Provider                                                                       0
# Provider Type of the Provider                                                                      0
# Medicare Participation Indicator                                                                   0
# Number of HCPCS                                                                                    0
# Number of Services                                                                                 0
# Number of Medicare Beneficiaries                                                                   0
# Total Submitted Charge Amount                                                                      0
# Total Medicare Allowed Amount                                                                      0
# Total Medicare Payment Amount                                                                      0
# Average Age of Beneficiaries                                                                       0
# Average HCC Risk Score of Beneficiaries                                                            0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
     'National Provider Identifier', #keeping this as unique ID for each provider
    'Provider Type of the Provider',
     'Number of Medicare Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'City of the Provider', 
 'State Code of the Provider',
 'Zip Code of the Provider',
    'Average HCC Risk Score of Beneficiaries '
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression ', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
 'Country Code of the Provider',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Middle Initial of the Provider',
#  'Percent (%) of Beneficiaries Identified With Hypertension ',
#  'Total Medical Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Diabetes ',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease ',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Number of Services',
#  'Street Address 1 of the Provider',
#  'Number of Drug Services',
#  'Street Address 2 of the Provider',
#  'Total Submitted Charge Amount',
#  'Entity Type of the Provider',
#  'Number of Medical Services',
#  'Credentials of the Provider',
#  'First Name of the Provider',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'Number of Beneficiaries With Medicare Only Entitlement',
#  'Total Drug Medicare Standardized Payment Amount',
#  'Medical Suppress Indicator',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis ',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia ',
#  'Total Medicare Standardized Payment Amount',
#  'Total Medical Medicare Standardized Payment Amount',
#  'Number of HCPCS Associated With Medical Services',
#  'Percent (%) of Beneficiaries Identified With Cancer ',
#  'Total Drug Medicare Payment Amount ',
#  'Percent (%) of Beneficiaries Identified With Stroke ',
#  'Number of HCPCS Associated With Drug Services',
#  'Gender of the Provider',
#  'Total Drug Medicare Allowed Amount ',
#  'Medicare Participation Indicator',
#  'Percent (%) of Beneficiaries Identified With Asthma ',
#  'Percent (%) of Beneficiaries Identified With Heart Failure ',
#  'Number of Medicare Beneficiaries With Drug Services',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Number of Medicare Beneficiaries With Medical Services',
#  'Total Medical Medicare Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia ',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis ',
#  'Total Drug Submitted Charge Amount',
#  'Total Medical Medicare Allowed Amount',
#  'Last Name/Organization Name of the Provider',
#  'Number of HCPCS',
#  'Total Medicare Allowed Amount',
#  'Drug Suppress Indicator']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression ',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ',
#        'Average HCC Risk Score of Beneficiaries '],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape, all_medicare.shape
# Out:
# ((12699, 13), (5654, 18))

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries ':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression ':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders ':
                    'percent_with_psychosis'}

                
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %%
all_medicare.columns, black_medicare.columns
# Out:
# (Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_white', 'num_black', 'num_asian_pac_isl', 'num_hispanic',
#         'num_nat_amer', 'num_race_unknown', 'percent_with_depression',
#         'percent_with_psychosis', 'avg_hcc_risk_score'],
#        dtype='object'),
#  Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_black', 'percent_with_depression', 'percent_with_psychosis',
#         'avg_hcc_risk_score'],
#        dtype='object'))

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#Some years' DFs have country values that are not 'US' listed in Country

# %%
black_medicare.country.unique()
# Out:
# array(['US', 'DE'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# How many unique 5-digit zip codes are there in this df? There are 33,000 zip codes on Census df.

# %% [markdown]
# First I have to convert the NPPES Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9652
# 8    1342
# 5    1311
# 4     285
# 3      60
# 7      48
# Name: full_zip, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 2023     4856
# 3479     3038
# 5032     2343
# 10722     962
# 29206    6708
# Name: full_zip, dtype: object

# %%
#adding leading zeros to the five digit zip code
idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9997
# 8    1342
# 5    1311
# 7      48
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ].head()['full_zip']
# Out:
# 2403     10459
# 4170     44122
# 13822    70403
# 15224    98372
# 15802    40324
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# 442901    9616910
# 6474      6740084
# 15275     9182600
# 64616     7391400
# 68914     6749670
# Name: full_zip, dtype: object

# %%
#I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    12698
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 4937

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    12698
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.
idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    12698
# Name: full_zip, dtype: int64
# 5    12698
# Name: five_dig_zip, dtype: int64
# 9    5653
# Name: full_zip, dtype: int64
# 5    5653
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12698 entries, 684 to 978108
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      12698 non-null  object
#  1   city                     12698 non-null  object
#  2   full_zip                 12698 non-null  object
#  3   state                    12698 non-null  object
#  4   country                  12698 non-null  object
#  5   provider_type            12698 non-null  object
#  6   total_beneficiaries      12698 non-null  object
#  7   total_medicare_payment   12698 non-null  float64
#  8   avg_beneficiary_age      12698 non-null  object
#  9   num_black                12698 non-null  float64
#  10  percent_with_depression  9725 non-null   float64
#  11  percent_with_psychosis   8160 non-null   float64
#  12  avg_hcc_risk_score       12698 non-null  float64
#  13  five_dig_zip             12698 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 2.1+ MB

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5653 entries, 684 to 978108
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      5653 non-null   object
#  1   city                     5653 non-null   object
#  2   full_zip                 5653 non-null   object
#  3   state                    5653 non-null   object
#  4   country                  5653 non-null   object
#  5   provider_type            5653 non-null   object
#  6   total_beneficiaries      5653 non-null   object
#  7   total_medicare_payment   5653 non-null   float64
#  8   avg_beneficiary_age      5653 non-null   object
#  9   num_white                5653 non-null   float64
#  10  num_black                5653 non-null   float64
#  11  num_asian_pac_isl        5653 non-null   float64
#  12  num_hispanic             5653 non-null   float64
#  13  num_nat_amer             5653 non-null   float64
#  14  num_race_unknown         5653 non-null   object
#  15  percent_with_depression  3653 non-null   float64
#  16  percent_with_psychosis   2041 non-null   float64
#  17  avg_hcc_risk_score       5653 non-null   float64
#  18  five_dig_zip             5653 non-null   object
# dtypes: float64(9), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../../data/raw/2014acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   20899                   131                  0
# 1   70803                   102                  0
# 2   40041                   142                  0
# 3   95646                    23                  0
# 4   61112                   100                  0
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       1985.0                         0
# 1                       1996.0                        27
# 2                       1939.0                         0
# 3                       1991.0                         5
# 4                       2001.0                         9
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                    39                      8                     41
# 1                    44                      0                      0
# 2                    44                     66                      0
# 3                    12                      0                      0
# 4                    56                      9                      0
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  \
# 0                      0                     34  ...
# 1                      0                     11  ...
# 2                     11                     10  ...
# 3                      0                      0  ...
# 4                      0                      0  ...
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                          32                      8
# 1                         955                     31
# 2                         277                      0
# 3                          77                     16
# 4                         100                      0
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                  0              131                 17
# 1                                  4             1010               1005
# 2                                  0              277                 40
# 3                                 10               98                 87
# 4                                  0              100                 10
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced   do_date
# 0                9             24            0            23  20102014
# 1                5              0            0             0  20102014
# 2               10              0          196            24  20102014
# 3                8              0            0             3  20102014
# 4                0              0           81             9  20102014
#
# [5 rows x 252 columns]

# %%
# dropping do_date columns, which gives info on how numbers for this year were calculated
# but isn't useful for my investigation.

census.drop(columns=['do_date'], inplace=True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# bachelors_degree_2                                            float64
# different_house_year_ago_same_city                            float64
# different_house_year_ago_different_city                       float64
# population_1_year_and_over                                    float64
# not_us_citizen_pop                                            float64
# less_than_high_school_graduate                                float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# some_college_and_associates_degree                            float64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# commuters_by_subway_or_elevated                                 int64
# commuters_by_carpool                                            int64
# commuters_drove_alone                                           int64
# employed_finance_insurance_real_estate                          int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# commuters_by_car_truck_van                                      int64
# female_75_to_79                                                 int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                          20157
# percent_income_spent_on_rent                                           27690
# median_rent                                                            27725
# renter_occupied_housing_units_paying_cash_median_gross_rent            27738
# owner_occupied_housing_units_median_value                              31607
# owner_occupied_housing_units_upper_value_quartile                      31607
# owner_occupied_housing_units_lower_value_quartile                      31607
# median_income                                                          32008
# median_year_structure_built                                            32204
# gini_index                                                             32255
# income_per_capita                                                      32571
# median_age                                                             32614
# bachelors_degree_2                                                     32989
# different_house_year_ago_same_city                                     32989
# different_house_year_ago_different_city                                32989
# population_1_year_and_over                                             32989
# not_us_citizen_pop                                                     32989
# less_than_high_school_graduate                                         32989
# high_school_including_ged                                              32989
# graduate_professional_degree                                           32989
# some_college_and_associates_degree                                     32989
# employed_agriculture_forestry_fishing_hunting_mining                   33120
# commuters_by_subway_or_elevated                                        33120
# commuters_by_carpool                                                   33120
# commuters_drove_alone                                                  33120
# employed_finance_insurance_real_estate                                 33120
# employed_construction                                                  33120
# employed_education_health_social                                       33120
# commuters_by_car_truck_van                                             33120
# female_75_to_79                                                        33120
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                        16959
# percent_income_spent_on_rent                                           399
# median_rent                                                           1703
# renter_occupied_housing_units_paying_cash_median_gross_rent           1678
# owner_occupied_housing_units_median_value                             4992
# owner_occupied_housing_units_upper_value_quartile                     5870
# owner_occupied_housing_units_lower_value_quartile                     4091
# median_income                                                        19805
# median_year_structure_built                                             71
# gini_index                                                            4097
# income_per_capita                                                    20265
# median_age                                                             652
# bachelors_degree_2                                                    5885
# different_house_year_ago_same_city                                    3668
# different_house_year_ago_different_city                               4819
# population_1_year_and_over                                           15365
# not_us_citizen_pop                                                    4186
# less_than_high_school_graduate                                        4646
# high_school_including_ged                                             7137
# graduate_professional_degree                                          4404
# some_college_and_associates_degree                                    7440
# employed_agriculture_forestry_fishing_hunting_mining                  1007
# commuters_by_subway_or_elevated                                        880
# commuters_by_carpool                                                  2874
# commuters_drove_alone                                                10011
# employed_finance_insurance_real_estate                                2361
# employed_construction                                                 2051
# employed_education_health_social                                      5226
# commuters_by_car_truck_van                                           10614
# female_75_to_79                                                       1078
#
#                                                              null values
# aggregate_travel_time_to_work                                      12963
# percent_income_spent_on_rent                                        5430
# median_rent                                                         5395
# renter_occupied_housing_units_paying_cash_median_gross_rent         5382
# owner_occupied_housing_units_median_value                           1513
# owner_occupied_housing_units_upper_value_quartile                   1513
# owner_occupied_housing_units_lower_value_quartile                   1513
# median_income                                                       1112
# median_year_structure_built                                          916
# gini_index                                                           865
# income_per_capita                                                    549
# median_age                                                           506
# bachelors_degree_2                                                   131
# different_house_year_ago_same_city                                   131
# different_house_year_ago_different_city                              131
# population_1_year_and_over                                           131
# not_us_citizen_pop                                                   131
# less_than_high_school_graduate                                       131
# high_school_including_ged                                            131
# graduate_professional_degree                                         131
# some_college_and_associates_degree                                   131
# employed_agriculture_forestry_fishing_hunting_mining                   0
# commuters_by_subway_or_elevated                                        0
# commuters_by_carpool                                                   0
# commuters_drove_alone                                                  0
# employed_finance_insurance_real_estate                                 0
# employed_construction                                                  0
# employed_education_health_social                                       0
# commuters_by_car_truck_van                                             0
# female_75_to_79                                                        0

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['84603', '27710', '77555', '07962', '60567', '77805', '11571', '94143',
#        '20453', '65102', '06349', '21287', '92161', '32163', '01655', '29151',
#        '19849', '95671', '58122', '21285', '06030', '20060', '45408', '92369',
#        '84132', '44195', '92093', '23298', '85378', '37232', '05047', '29425',
#        '92357', '29240', '10155', '21041', '00732', '00963', '85220', '03756',
#        '66160', '27599', '08101', '18341', '24114', '05302', '31099', '20042',
#        '00801', '84143', '00792', '87131', '24402', '35294', '35249', '08754',
#        '29220', '19718', '85219', '48824', '21302', '26507', '92415', '00802',
#        '40536', '22908', '28286', '04402', '13925', '92697', '32610', '68198',
#        '00908', '14642', '90509', '65211', '94141', '00726', '10982', '06102',
#        '23287', '00919', '01202', '00000', '04333'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi        city   full_zip state country  \
# five_dig_zip
# 84603         1902099385       PROVO  846030000    UT      US
# 27710         1679731616      DURHAM  277104000    NC      US
# 27710         1194965822      DURHAM  277100001    NC      US
# 27710         1417381203      DURHAM  277104000    NC      US
# 77555         1548587868   GALVESTON  775555302    TX      US
# ...                  ...         ...        ...   ...     ...
# 00919         1285605980    SAN JUAN  009190144    PR      US
# 00919         1023089836    SAN JUAN  009190000    PR      US
# 01202         1528164845  PITTSFIELD  012020000    MA      US
# 00000         1033456587     BAYAMON  000000959    PR      US
# 04333         1013987403     AUGUSTA  043330001    ME      US
#
#                       provider_type total_beneficiaries  \
# five_dig_zip
# 84603                    Psychiatry                  17
# 27710                    Psychiatry                 506
# 27710         Clinical Psychologist                  11
# 27710         Clinical Psychologist                  11
# 77555                    Psychiatry                 121
# ...                             ...                 ...
# 00919                    Psychiatry                  19
# 00919                    Psychiatry                  26
# 01202                    Psychiatry                 479
# 00000         Clinical Psychologist                  12
# 04333         Clinical Psychologist                  12
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 84603                        3853.43                  59        0.0
# 27710                       49867.36                  63      321.0
# 27710                        6764.06                  73        0.0
# 27710                        5182.88                  66        0.0
# 77555                       11366.48                  52       26.0
# ...                              ...                 ...        ...
# 00919                        2913.27                  64        0.0
# 00919                        6606.72                  68        0.0
# 01202                       91904.96                  53       13.0
# 00000                        3261.77                  87        0.0
# 04333                        8447.58                  44        0.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 84603                     1.5653
# 27710                     1.7275
# 27710                     0.9475
# 27710                     1.0004
# 77555                     1.3451
# ...                          ...
# 00919                     1.1424
# 00919                     1.0222
# 01202                     1.1779
# 00000                     1.3891
# 04333                     0.9209
#
# [206 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 4852
# 4852

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# owner_occupied_housing_units_median_value                     float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_lower_value_quartile             float64
# graduate_professional_degree                                  float64
# high_school_including_ged                                     float64
# less_than_high_school_graduate                                float64
# different_house_year_ago_same_city                            float64
# different_house_year_ago_different_city                       float64
# not_us_citizen_pop                                            float64
# bachelors_degree_2                                            float64
# population_1_year_and_over                                    float64
# some_college_and_associates_degree                            float64
# percent_income_spent_on_rent                                  float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# gini_index                                                    float64
# median_year_structure_built                                   float64
# median_income                                                 float64
# median_age                                                    float64
# income_per_capita                                             float64
# civilian_labor_force                                            int64
# asian_including_hispanic                                        int64
# amerindian_including_hispanic                                   int64
# employed_agriculture_forestry_fishing_hunting_mining            int64
# employed_arts_entertainment_recreation_accommodation_food       int64
# employed_construction                                           int64
# employed_education_health_social                                int64
# employed_finance_insurance_real_estate                          int64
# black_including_hispanic                                        int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           4613
# owner_occupied_housing_units_median_value                               4793
# owner_occupied_housing_units_upper_value_quartile                       4793
# owner_occupied_housing_units_lower_value_quartile                       4793
# graduate_professional_degree                                            4802
# high_school_including_ged                                               4802
# less_than_high_school_graduate                                          4802
# different_house_year_ago_same_city                                      4802
# different_house_year_ago_different_city                                 4802
# not_us_citizen_pop                                                      4802
# bachelors_degree_2                                                      4802
# population_1_year_and_over                                              4802
# some_college_and_associates_degree                                      4802
# percent_income_spent_on_rent                                            4805
# median_rent                                                             4805
# renter_occupied_housing_units_paying_cash_median_gross_rent             4805
# gini_index                                                              4819
# median_year_structure_built                                             4819
# median_income                                                           4819
# median_age                                                              4841
# income_per_capita                                                       4841
# civilian_labor_force                                                    4852
# asian_including_hispanic                                                4852
# amerindian_including_hispanic                                           4852
# employed_agriculture_forestry_fishing_hunting_mining                    4852
# employed_arts_entertainment_recreation_accommodation_food               4852
# employed_construction                                                   4852
# employed_education_health_social                                        4852
# employed_finance_insurance_real_estate                                  4852
# black_including_hispanic                                                4852
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         4535
# owner_occupied_housing_units_median_value                             2860
# owner_occupied_housing_units_upper_value_quartile                     3036
# owner_occupied_housing_units_lower_value_quartile                     2591
# graduate_professional_degree                                          3197
# high_school_including_ged                                             3783
# less_than_high_school_graduate                                        3042
# different_house_year_ago_same_city                                    2663
# different_house_year_ago_different_city                               3234
# not_us_citizen_pop                                                    2724
# bachelors_degree_2                                                    3646
# population_1_year_and_over                                            4605
# some_college_and_associates_degree                                    3871
# percent_income_spent_on_rent                                           324
# median_rent                                                           1302
# renter_occupied_housing_units_paying_cash_median_gross_rent           1272
# gini_index                                                            1894
# median_year_structure_built                                             69
# median_income                                                         4651
# median_age                                                             397
# income_per_capita                                                     4543
# civilian_labor_force                                                  4450
# asian_including_hispanic                                              2323
# amerindian_including_hispanic                                          693
# employed_agriculture_forestry_fishing_hunting_mining                   602
# employed_arts_entertainment_recreation_accommodation_food             2392
# employed_construction                                                 1634
# employed_education_health_social                                      3427
# employed_finance_insurance_real_estate                                1996
# black_including_hispanic                                              3061
#
#                                                              null values
# aggregate_travel_time_to_work                                        239
# owner_occupied_housing_units_median_value                             59
# owner_occupied_housing_units_upper_value_quartile                     59
# owner_occupied_housing_units_lower_value_quartile                     59
# graduate_professional_degree                                          50
# high_school_including_ged                                             50
# less_than_high_school_graduate                                        50
# different_house_year_ago_same_city                                    50
# different_house_year_ago_different_city                               50
# not_us_citizen_pop                                                    50
# bachelors_degree_2                                                    50
# population_1_year_and_over                                            50
# some_college_and_associates_degree                                    50
# percent_income_spent_on_rent                                          47
# median_rent                                                           47
# renter_occupied_housing_units_paying_cash_median_gross_rent           47
# gini_index                                                            33
# median_year_structure_built                                           33
# median_income                                                         33
# median_age                                                            11
# income_per_capita                                                     11
# civilian_labor_force                                                   0
# asian_including_hispanic                                               0
# amerindian_including_hispanic                                          0
# employed_agriculture_forestry_fishing_hunting_mining                   0
# employed_arts_entertainment_recreation_accommodation_food              0
# employed_construction                                                  0
# employed_education_health_social                                       0
# employed_finance_insurance_real_estate                                 0
# black_including_hispanic                                               0

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls. This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (47, 47)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 4805 4805
# 3052 4805
# 3081 4805

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(5)
# Out:
#                                         data type  non-null values  \
# graduate_professional_degree              float64             4756
# not_us_citizen_pop                        float64             4756
# less_than_high_school_graduate            float64             4756
# different_house_year_ago_different_city   float64             4756
# some_college_and_associates_degree        float64             4756
#
#                                          unique values  null values
# graduate_professional_degree                      3190           49
# not_us_citizen_pop                                2724           49
# less_than_high_school_graduate                    3037           49
# different_house_year_ago_different_city           3224           49
# some_college_and_associates_degree                3847           49

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (49, 49)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#        data type  non-null values  unique values  null values
# geo_id    object             4756           4756            0

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((12223, 12), (6713, 14), (5415, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    4756
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [12]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'num_race_unknown',
#        'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../../data/processed/2014black_medicare_census.csv')

#saving all races medicare df merged
disorders_merged.to_csv('../../data/processed/2014black_medicare_with_disorders_census.csv')

#saving black_medicare with disorder values merged
all_merged.to_csv('../../data/processed/2014all_races_medicare_census.csv')
