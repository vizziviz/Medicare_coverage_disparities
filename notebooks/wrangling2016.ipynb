# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/capstone2/notebooks'

# %% [markdown]
# # Uploading Data

# %%
med = pd.read_csv("../data/raw/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2016.csv")
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
med.shape
# Out:
# (1053958, 70)

# %%
med.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        D.O.                      M
# 4                        M.D.                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
# 2                           I       4126 N HOLLAND SYLVANIA RD
# 3                           I                  100 HOSPITAL RD
# 4                           I                 11100 EUCLID AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
# 2                        SUITE 220               TOLEDO  ...
# 3                              NaN           BROOKVILLE  ...
# 4                              NaN            CLEVELAND  ...
#
#   Percent (%) of Beneficiaries Identified With Depression  \
# 0                                               42.0
# 1                                               13.0
# 2                                               50.0
# 3                                               47.0
# 4                                               28.0
#
#   Percent (%) of Beneficiaries Identified With Diabetes  \
# 0                                               53.0
# 1                                               21.0
# 2                                               37.0
# 3                                               40.0
# 4                                               27.0
#
#   Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               67.0
# 1                                               46.0
# 2                                               53.0
# 3                                               69.0
# 4                                               41.0
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               54.0
# 2                                               73.0
# 3                                               75.0
# 4                                               52.0
#
#   Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               53.0
# 1                                               26.0
# 2                                               37.0
# 3                                               64.0
# 4                                               21.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                               12.0
# 1                                                9.0
# 2                                                8.0
# 3                                               15.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               49.0
# 1                                               38.0
# 2                                               75.0
# 3                                               43.0
# 4                                               46.0
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                9.0
# 1                                                1.0
# 2                                                6.0
# 3                                               12.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               13.0
# 1                                                3.0
# 2                                                5.0
# 3                                               14.0
# 4                                                0.0
#
#    Average HCC Risk Score of Beneficiaries
# 0                                   2.0239
# 1                                   1.0925
# 2                                   1.5809
# 3                                   2.0000
# 4                                   0.9540
#
# [5 rows x 70 columns]

# %% [markdown]
# CHECKPOINT, SAVING ORIGINAL DF

# %%
original_df = med.copy()

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# I ONLY WANT TO LOOK AT MENTAL HEALTH PROVIDERS SO I WILL FILTER THE DF FOR THOSE PROVIDER AND THEN EXAMINE THE NULL VALUES

# %%
med.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
#        'Number of Medicare Beneficiaries With Drug Services',
#        'Total Drug Submitted Charge Amount',
#        'Total Drug Medicare Allowed Amount',
#        'Total Drug Medicare Payment Amount',
#        'Total Drug Medicare Standardized Payment Amount',
#        'Medical Suppress Indicator',
#        'Number of HCPCS Associated With Medical Services',
#        'Number of Medical Services',
#        'Number of Medicare Beneficiaries With Medical Services',
#        'Total Medical Submitted Charge Amount',
#        'Total Medical Medicare Allowed Amount',
#        'Total Medical Medicare Payment Amount',
#        'Total Medical Medicare Standardized Payment Amount',
#        'Average Age of Beneficiaries', 'Number of Beneficiaries Age Less 65',
#        'Number of Beneficiaries Age 65 to 74',
#        'Number of Beneficiaries Age 75 to 84',
#        'Number of Beneficiaries Age Greater 84',
#        'Number of Female Beneficiaries', 'Number of Male Beneficiaries\t',
#        'Number of Non-Hispanic White Beneficiaries\t',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Number of Beneficiaries With Medicare Only Entitlement',
#        'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#        'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#        'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#        'Percent (%) of Beneficiaries Identified With Asthma',
#        'Percent (%) of Beneficiaries Identified With Cancer',
#        'Percent (%) of Beneficiaries Identified With Heart Failure',
#        'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#        'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Diabetes',
#        'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#        'Percent (%) of Beneficiaries Identified With Hypertension',
#        'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#        'Percent (%) of Beneficiaries Identified With Osteoporosis',
#        'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Percent (%) of Beneficiaries Identified With Stroke',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
list(med['Provider Type of the Provider'].unique())
# Out:
# ['Internal Medicine',
#  'Pathology',
#  'Anesthesiology',
#  'Family Practice',
#  'Obstetrics & Gynecology',
#  'General Surgery',
#  'Urology',
#  'Cardiac Surgery',
#  'Physician Assistant',
#  'Physical Therapist in Private Practice',
#  'Dermatology',
#  'Certified Registered Nurse Anesthetist (CRNA)',
#  'Mass Immunizer Roster Biller',
#  'Physical Medicine and Rehabilitation',
#  'Radiation Oncology',
#  'Infectious Disease',
#  'Orthopedic Surgery',
#  'Licensed Clinical Social Worker',
#  'Certified Clinical Nurse Specialist',
#  'Endocrinology',
#  'Chiropractic',
#  'Diagnostic Radiology',
#  'Centralized Flu',
#  'Rheumatology',
#  'General Practice',
#  'Neurology',
#  'Emergency Medicine',
#  'Nephrology',
#  'Hand Surgery',
#  'Ophthalmology',
#  'Nurse Practitioner',
#  'Pulmonary Disease',
#  'Otolaryngology',
#  'Plastic and Reconstructive Surgery',
#  'Psychologist, Clinical',
#  'Cardiovascular Disease (Cardiology)',
#  'Ambulance Service Provider',
#  'Osteopathic Manipulative Medicine',
#  'Psychiatry',
#  'Interventional Cardiology',
#  'Audiologist',
#  'Geriatric Medicine',
#  'Neurosurgery',
#  'Gastroenterology',
#  'Thoracic Surgery',
#  'Critical Care (Intensivists)',
#  'Pain Management',
#  'Podiatry',
#  'Optometry',
#  'Hematology-Oncology',
#  'All Other Suppliers',
#  'Ambulatory Surgical Center',
#  'Medical Oncology',
#  'Nuclear Medicine',
#  'Allergy/ Immunology',
#  'Certified Nurse Midwife',
#  'Pediatric Medicine',
#  'Sports Medicine',
#  'Occupational Therapist in Private Practice',
#  'Hospice and Palliative Care',
#  'Independent Diagnostic Testing Facility (IDTF)',
#  'Clinical Laboratory',
#  'Registered Dietitian or Nutrition Professional',
#  'Vascular Surgery',
#  'Interventional Radiology',
#  'Clinical Cardiatric Electrophysiology',
#  'Anesthesiology Assistant',
#  'Oral Surgery (Dentists only)',
#  'Hematology',
#  'Maxillofacial Surgery',
#  'Speech Language Pathologist',
#  'Portable X-Ray Supplier',
#  'Colorectal Surgery (Proctology)',
#  'Geriatric Psychiatry',
#  'Mammography Center',
#  'Surgical Oncology',
#  'Preventive Medicine',
#  'Interventional Pain Management',
#  'Clinic or Group Practice',
#  'Public Health or Welfare Agency',
#  'Sleep Medicine',
#  'Slide Preparation Facility',
#  'Neuropsychiatry',
#  'Peripheral Vascular Disease',
#  'Gynecological Oncology',
#  'Undefined Physician type',
#  'Addiction Medicine',
#  'Radiation Therapy Center',
#  'Unknown Supplier/Provider Specialty',
#  'Hospitalist',
#  'Dentist']

# %%
maybe_mental_providers = ['Clinic or Group Practice','Preventive Medicine',
                           'All Other Suppliers','Addiction Medicine',
                          'Occupational Therapist in Private Practice',
                         'Multispecialty Clinic/Group Practice',
                           'Public Health Welfare Agency', 'Preventive Medicine']

# %%
def_mental_providers = ['Licensed Clinical Social Worker','Psychologist, Clinical',
                        'Geriatric Psychiatry','Neuropsychiatry',
                       'Psychiatry','Clinical Psychologist','Psychologist (billing independently)',
                       ]

# %% [markdown]
# # Filtering Out Non-Mental Health Providers

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)

# %%
mental_med = pd.DataFrame(data = {}, columns = med.columns)
for i in def_mental_providers:
    mental_med = pd.concat([mental_med, med[med["Provider Type of the Provider"]==i]])

# %%
mental_med.duplicated().sum()
# Out:
# 0

# %%
len(mental_med)
# Out:
# 57552

# %% [markdown]
# ##### Checkpoint 1

# %%
checkpoint1_df = mental_med.copy()

# %% [markdown]
# # Checking Missing Data

# %%
info = pd.DataFrame(index=mental_med.columns.values,
                    data={'data type': mental_med.dtypes, \
                          'non-null values': mental_med.notnull().sum(),
                          'unique values': mental_med.nunique(), \
                          'null values': mental_med.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# Number of Beneficiaries With Race Not Elsewhere Classified                               float64
# Number of Hispanic Beneficiaries                                                         float64
# Number of Asian Pacific Islander Beneficiaries                                           float64
# Number of Beneficiaries Age 75 to 84                                                     float64
# Number of Black or African American Beneficiaries                                        float64
# Number of American Indian/Alaska Native Beneficiaries                                    float64
# Number of Beneficiaries Age Greater 84                                                   float64
# Number of Beneficiaries Age 65 to 74                                                     float64
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Street Address 2 of the Provider                                                          object
# Number of Non-Hispanic White Beneficiaries\t                                             float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Number of Beneficiaries Age Less 65                                                      float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Number of Female Beneficiaries                                                           float64
# Number of Male Beneficiaries\t                                                           float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Submitted Charge Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Payment Amount                                                    float64
# Number of Drug Services                                                                  float64
# Zip Code of the Provider                                                                  object
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# Street Address 1 of the Provider                                                          object
# City of the Provider                                                                      object
# State Code of the Provider                                                                object
# Average Age of Beneficiaries                                                              object
# Country Code of the Provider                                                              object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Provider Type of the Provider                                                             object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          690
# Drug Suppress Indicator                                                                             690
# Number of Beneficiaries With Race Not Elsewhere Classified                                        10131
# Number of Hispanic Beneficiaries                                                                  10924
# Number of Asian Pacific Islander Beneficiaries                                                    11858
# Number of Beneficiaries Age 75 to 84                                                              12583
# Number of Black or African American Beneficiaries                                                 13121
# Number of American Indian/Alaska Native Beneficiaries                                             16140
# Number of Beneficiaries Age Greater 84                                                            18251
# Number of Beneficiaries Age 65 to 74                                                              18870
# Percent (%) of Beneficiaries Identified With Cancer                                               19233
# Percent (%) of Beneficiaries Identified With Osteoporosis                                         19910
# Percent (%) of Beneficiaries Identified With Heart Failure                                        22741
# Street Address 2 of the Provider                                                                  23159
# Number of Non-Hispanic White Beneficiaries\t                                                      23240
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                23392
# Number of Beneficiaries Age Less 65                                                               23845
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                  23893
# Percent (%) of Beneficiaries Identified With Asthma                                               25393
# Percent (%) of Beneficiaries Identified With Stroke                                               25467
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                               25812
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                               26105
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                      26176
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      27796
# Number of Beneficiaries With Medicare Only Entitlement                                            27796
# Percent (%) of Beneficiaries Identified With Diabetes                                             29088
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders            30821
# Number of Female Beneficiaries                                                                    31845
# Number of Male Beneficiaries\t                                                                    31845
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                34220
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                       36967
# Middle Initial of the Provider                                                                    40263
# Percent (%) of Beneficiaries Identified With Hypertension                                         41009
# Percent (%) of Beneficiaries Identified With Depression                                           48887
# Credentials of the Provider                                                                       54882
# Total Medical Medicare Standardized Payment Amount                                                56862
# Total Medical Submitted Charge Amount                                                             56862
# Total Medical Medicare Allowed Amount                                                             56862
# Number of Medicare Beneficiaries With Medical Services                                            56862
# Number of Medical Services                                                                        56862
# Number of HCPCS Associated With Medical Services                                                  56862
# Total Drug Medicare Standardized Payment Amount                                                   56862
# Total Drug Medicare Payment Amount                                                                56862
# Total Drug Medicare Allowed Amount                                                                56862
# Total Drug Submitted Charge Amount                                                                56862
# Number of Medicare Beneficiaries With Drug Services                                               56862
# Number of HCPCS Associated With Drug Services                                                     56862
# Total Medical Medicare Payment Amount                                                             56862
# Number of Drug Services                                                                           56862
# Zip Code of the Provider                                                                          57551
# National Provider Identifier                                                                      57552
# Total Medicare Standardized Payment Amount                                                        57552
# Last Name/Organization Name of the Provider                                                       57552
# First Name of the Provider                                                                        57552
# Gender of the Provider                                                                            57552
# Entity Type of the Provider                                                                       57552
# Street Address 1 of the Provider                                                                  57552
# City of the Provider                                                                              57552
# State Code of the Provider                                                                        57552
# Average Age of Beneficiaries                                                                      57552
# Country Code of the Provider                                                                      57552
# Medicare Participation Indicator                                                                  57552
# Number of HCPCS                                                                                   57552
# Number of Services                                                                                57552
# Number of Medicare Beneficiaries                                                                  57552
# Total Submitted Charge Amount                                                                     57552
# Total Medicare Allowed Amount                                                                     57552
# Total Medicare Payment Amount                                                                     57552
# Provider Type of the Provider                                                                     57552
# Average HCC Risk Score of Beneficiaries                                                           57552
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          2
# Drug Suppress Indicator                                                                             1
# Number of Beneficiaries With Race Not Elsewhere Classified                                         45
# Number of Hispanic Beneficiaries                                                                  263
# Number of Asian Pacific Islander Beneficiaries                                                    104
# Number of Beneficiaries Age 75 to 84                                                              347
# Number of Black or African American Beneficiaries                                                 306
# Number of American Indian/Alaska Native Beneficiaries                                              53
# Number of Beneficiaries Age Greater 84                                                            377
# Number of Beneficiaries Age 65 to 74                                                              343
# Percent (%) of Beneficiaries Identified With Cancer                                                70
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          52
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Street Address 2 of the Provider                                                                 7828
# Number of Non-Hispanic White Beneficiaries\t                                                      797
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 74
# Number of Beneficiaries Age Less 65                                                               524
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   56
# Percent (%) of Beneficiaries Identified With Asthma                                                72
# Percent (%) of Beneficiaries Identified With Stroke                                                76
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       74
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      701
# Number of Beneficiaries With Medicare Only Entitlement                                            549
# Percent (%) of Beneficiaries Identified With Diabetes                                              69
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Number of Female Beneficiaries                                                                    656
# Number of Male Beneficiaries\t                                                                    504
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        65
# Middle Initial of the Provider                                                                     29
# Percent (%) of Beneficiaries Identified With Hypertension                                          63
# Percent (%) of Beneficiaries Identified With Depression                                            64
# Credentials of the Provider                                                                      2313
# Total Medical Medicare Standardized Payment Amount                                              56507
# Total Medical Submitted Charge Amount                                                           42808
# Total Medical Medicare Allowed Amount                                                           56588
# Number of Medicare Beneficiaries With Medical Services                                            952
# Number of Medical Services                                                                       3580
# Number of HCPCS Associated With Medical Services                                                   56
# Total Drug Medicare Standardized Payment Amount                                                   166
# Total Drug Medicare Payment Amount                                                                166
# Total Drug Medicare Allowed Amount                                                                166
# Total Drug Submitted Charge Amount                                                                166
# Number of Medicare Beneficiaries With Drug Services                                                63
# Number of HCPCS Associated With Drug Services                                                      14
# Total Medical Medicare Payment Amount                                                           56499
# Number of Drug Services                                                                           150
# Zip Code of the Provider                                                                        36105
# National Provider Identifier                                                                    57552
# Total Medicare Standardized Payment Amount                                                      57188
# Last Name/Organization Name of the Provider                                                     30157
# First Name of the Provider                                                                       9341
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# Street Address 1 of the Provider                                                                34409
# City of the Provider                                                                             4759
# State Code of the Provider                                                                         56
# Average Age of Beneficiaries                                                                       71
# Country Code of the Provider                                                                        8
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    62
# Number of Services                                                                               3679
# Number of Medicare Beneficiaries                                                                  959
# Total Submitted Charge Amount                                                                   43448
# Total Medicare Allowed Amount                                                                   57271
# Total Medicare Payment Amount                                                                   57188
# Provider Type of the Provider                                                                       5
# Average HCC Risk Score of Beneficiaries                                                         18602
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    56862
# Drug Suppress Indicator                                                                       56862
# Number of Beneficiaries With Race Not Elsewhere Classified                                    47421
# Number of Hispanic Beneficiaries                                                              46628
# Number of Asian Pacific Islander Beneficiaries                                                45694
# Number of Beneficiaries Age 75 to 84                                                          44969
# Number of Black or African American Beneficiaries                                             44431
# Number of American Indian/Alaska Native Beneficiaries                                         41412
# Number of Beneficiaries Age Greater 84                                                        39301
# Number of Beneficiaries Age 65 to 74                                                          38682
# Percent (%) of Beneficiaries Identified With Cancer                                           38319
# Percent (%) of Beneficiaries Identified With Osteoporosis                                     37642
# Percent (%) of Beneficiaries Identified With Heart Failure                                    34811
# Street Address 2 of the Provider                                                              34393
# Number of Non-Hispanic White Beneficiaries\t                                                  34312
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease            34160
# Number of Beneficiaries Age Less 65                                                           33707
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                              33659
# Percent (%) of Beneficiaries Identified With Asthma                                           32159
# Percent (%) of Beneficiaries Identified With Stroke                                           32085
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                           31740
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                           31447
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                  31376
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                  29756
# Number of Beneficiaries With Medicare Only Entitlement                                        29756
# Percent (%) of Beneficiaries Identified With Diabetes                                         28464
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders        26731
# Number of Female Beneficiaries                                                                25707
# Number of Male Beneficiaries\t                                                                25707
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis            23332
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                   20585
# Middle Initial of the Provider                                                                17289
# Percent (%) of Beneficiaries Identified With Hypertension                                     16543
# Percent (%) of Beneficiaries Identified With Depression                                        8665
# Credentials of the Provider                                                                    2670
# Total Medical Medicare Standardized Payment Amount                                              690
# Total Medical Submitted Charge Amount                                                           690
# Total Medical Medicare Allowed Amount                                                           690
# Number of Medicare Beneficiaries With Medical Services                                          690
# Number of Medical Services                                                                      690
# Number of HCPCS Associated With Medical Services                                                690
# Total Drug Medicare Standardized Payment Amount                                                 690
# Total Drug Medicare Payment Amount                                                              690
# Total Drug Medicare Allowed Amount                                                              690
# Total Drug Submitted Charge Amount                                                              690
# Number of Medicare Beneficiaries With Drug Services                                             690
# Number of HCPCS Associated With Drug Services                                                   690
# Total Medical Medicare Payment Amount                                                           690
# Number of Drug Services                                                                         690
# Zip Code of the Provider                                                                          1
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# Street Address 1 of the Provider                                                                  0
# City of the Provider                                                                              0
# State Code of the Provider                                                                        0
# Average Age of Beneficiaries                                                                      0
# Country Code of the Provider                                                                      0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Provider Type of the Provider                                                                     0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ####  The number of black patients seen is the focus of my study, so I don't want to impute these values especially without a strong reason to support my imputation.

# %% [markdown]
# #### Dropping NaN Values for Number of Black Beneficiaries

# %%
print(mental_med['Number of Black or African American Beneficiaries'].notnull().sum())
mental_med = mental_med[mental_med['Number of Black or African American Beneficiaries'].notnull()]
# Out:
# 13121

# %% [markdown]
# ## I want to see how many rows have info for all races. And how many rows have info for at least Black beneficiaries.

# %%
race_cols = [
    'Number of American Indian/Alaska Native Beneficiaries',
    'Number of Asian Pacific Islander Beneficiaries',
    'Number of Non-Hispanic White Beneficiaries\t',
    'Number of Hispanic Beneficiaries',
    'Number of Beneficiaries With Race Not Elsewhere Classified',
    'Number of Black or African American Beneficiaries',
    'Number of Medicare Beneficiaries'
     ]

# %% [markdown]
# All rows with info for Black beneficiaries

# %%
mental_med['Number of Black or African American Beneficiaries'].notnull().sum()
# Out:
# 13121

# %% [markdown]
# All row with info for All Races beneficiaries, useful if I want to compare/contrast

# %%
#here '[:-1]' excludes both 'Total Number of Unique Ben' from sums

all_races_idx = mental_med[
                    mental_med[race_cols[:-1]].notnull().all(axis=1)
                            ][race_cols].index

mental_med.loc[all_races_idx].shape[0]
# Out:
# 5747

# %% [markdown]
# Some of these 'all races' rows don't actually sum up to the total

# %%
mask = mental_med[race_cols[:-1]].sum(axis=1) != \
        mental_med['Number of Medicare Beneficiaries']

len(mental_med.loc[all_races_idx][mask])
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 0

# %%
#Let's look at rows where all info is present but not all bins equal the total.

mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']
][race_cols]
# Out:
# Empty DataFrame
# Columns: [Number of American Indian/Alaska Native Beneficiaries, Number of Asian Pacific Islander Beneficiaries, Number of Non-Hispanic White Beneficiaries	, Number of Hispanic Beneficiaries, Number of Beneficiaries With Race Not Elsewhere Classified, Number of Black or African American Beneficiaries, Number of Medicare Beneficiaries]
# Index: []

# %%
#index of rows where sums don't equal total
idx = mental_med.loc[all_races_idx][
    mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']
].index

#sums of races that are off
sums_of_races = mental_med.loc[idx][race_cols[:-1]].sum(axis=1)

#values to replace 'Number with Race Not Classified' (Total+'Number Not Classfd'-sums)
new_values = mental_med.loc[idx, 
        'Number of Beneficiaries With Race Not Elsewhere Classified'] + \
        mental_med.loc[idx]['Number of Medicare Beneficiaries'] - \
        sums_of_races

#actually replacing those values
mental_med.loc[idx, 
            'Number of Beneficiaries With Race Not Elsewhere Classified'] = new_values

# %%
#checking my work
(mental_med.loc[all_races_idx][race_cols[:-1]].sum(axis=1) != \
    mental_med.loc[all_races_idx]['Number of Medicare Beneficiaries']).sum()
# Out:
# 0

# %% [markdown]
# ### I'm going to save two different dataframes, one that has info for ALL races (with all race columns) and one that has info for Black patients (but other columns dropped)

# %%
all_medicare = \
    mental_med.loc[all_races_idx]

idx_black_nonnull = \
    mental_med[
    mental_med['Number of Black or African American Beneficiaries'].notnull()
            ].index

black_medicare = \
    mental_med.loc[idx_black_nonnull].drop(columns = race_cols[:-2])
# adding [:-2] to race_cols lets the DF keep 'Black Beneficiaries' (2nd to last col) and 
# Total 'Unique Beneficiaries' (last col)

# %% [markdown]
# Checkpoint 2 Race

# %%
checkpoint2a = all_medicare.copy()
checkpoint2b = black_medicare.copy()

# %% [markdown]
# ## Age

# %%
age_cols = [
    'Number of Beneficiaries Age Less 65',
    'Number of Beneficiaries Age 65 to 74',
    'Number of Beneficiaries Age 75 to 84',
    'Number of Beneficiaries Age Greater 84',
    'Number of Medicare Beneficiaries'
]

# %% [markdown]
# #### How many rows have age bins that don't add up to total beneficiaries?

# %%
(black_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != black_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 10416

# %%
(all_medicare[age_cols[:-1]].fillna(0).sum(axis=1) \
 != all_medicare['Number of Medicare Beneficiaries']).sum()
# Out:
# 5523

# %% [markdown]
# #### How many rows have age bins that have at least 1 null value?

# %%
len(black_medicare)
# Out:
# 13121

# %%
black_medicare[age_cols[:-1]].isnull().any(axis=1).sum()
# Out:
# 10416

# %%
black_medicare[age_cols].head(3)
# Out:
#      Number of Beneficiaries Age Less 65  \
# 28                                   NaN
# 220                                  NaN
# 464                                  NaN
#
#      Number of Beneficiaries Age 65 to 74  \
# 28                                    NaN
# 220                                   NaN
# 464                                   NaN
#
#      Number of Beneficiaries Age 75 to 84  \
# 28                                    NaN
# 220                                   NaN
# 464                                   NaN
#
#      Number of Beneficiaries Age Greater 84 Number of Medicare Beneficiaries
# 28                                      0.0                               11
# 220                                     NaN                               14
# 464                                     NaN                               39

# %% [markdown]
# #### Because so many rows have at least ONE bin with NaN, it will be hard to be confident about comparing ages of patients. BUT there is an Average Age of Beneficiaries column, let's see have many rows are non-null.

# %%
len(black_medicare), black_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (13121, 13121)

# %%
len(all_medicare), all_medicare['Average Age of Beneficiaries'].notnull().sum()
# Out:
# (5747, 5747)

# %% [markdown]
# #### Zero null values. This will do, for some perspective on age, even though the bins would be more useful and specific.

# %%
black_medicare.drop(columns = age_cols[:-1], inplace=True)
all_medicare.drop(columns = age_cols[:-1], inplace=True)

# %% [markdown]
# Checkpoint 3 Age

# %%
checkpoint3 = black_medicare.copy()
checkpoint3b = all_medicare.copy()

# %% [markdown]
# #### Examining Null Values

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Medical Suppress Indicator                                                                object
# Drug Suppress Indicator                                                                   object
# Street Address 2 of the Provider                                                          object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Number of Male Beneficiaries\t                                                           float64
# Number of Female Beneficiaries                                                           float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Medicare Standardized Payment Amount                                       float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Medical Submitted Charge Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Allowed Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Black or African American Beneficiaries                                        float64
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# Street Address 1 of the Provider                                                          object
# City of the Provider                                                                      object
# Zip Code of the Provider                                                                  object
# State Code of the Provider                                                                object
# Country Code of the Provider                                                              object
# Provider Type of the Provider                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Average Age of Beneficiaries                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Medical Suppress Indicator                                                                          263
# Drug Suppress Indicator                                                                             263
# Street Address 2 of the Provider                                                                   5427
# Percent (%) of Beneficiaries Identified With Cancer                                                5600
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5660
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6500
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6576
# Percent (%) of Beneficiaries Identified With Asthma                                                6671
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6754
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6845
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6914
# Number of Beneficiaries With Medicare Only Entitlement                                             7086
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       7086
# Percent (%) of Beneficiaries Identified With Diabetes                                              7088
# Percent (%) of Beneficiaries Identified With Stroke                                                7122
# Number of Male Beneficiaries\t                                                                     7146
# Number of Female Beneficiaries                                                                     7146
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 7357
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7437
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7785
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8295
# Percent (%) of Beneficiaries Identified With Hypertension                                          8404
# Middle Initial of the Provider                                                                     9000
# Percent (%) of Beneficiaries Identified With Depression                                            9955
# Credentials of the Provider                                                                       12512
# Total Medical Medicare Standardized Payment Amount                                                12858
# Total Medical Medicare Payment Amount                                                             12858
# Total Medical Medicare Allowed Amount                                                             12858
# Total Medical Submitted Charge Amount                                                             12858
# Number of Medicare Beneficiaries With Medical Services                                            12858
# Number of Medical Services                                                                        12858
# Total Drug Medicare Payment Amount                                                                12858
# Total Drug Medicare Standardized Payment Amount                                                   12858
# Total Drug Medicare Allowed Amount                                                                12858
# Number of Medicare Beneficiaries With Drug Services                                               12858
# Number of Drug Services                                                                           12858
# Number of HCPCS Associated With Drug Services                                                     12858
# Number of HCPCS Associated With Medical Services                                                  12858
# Total Drug Submitted Charge Amount                                                                12858
# Number of Black or African American Beneficiaries                                                 13121
# National Provider Identifier                                                                      13121
# Total Medicare Standardized Payment Amount                                                        13121
# Last Name/Organization Name of the Provider                                                       13121
# First Name of the Provider                                                                        13121
# Gender of the Provider                                                                            13121
# Entity Type of the Provider                                                                       13121
# Street Address 1 of the Provider                                                                  13121
# City of the Provider                                                                              13121
# Zip Code of the Provider                                                                          13121
# State Code of the Provider                                                                        13121
# Country Code of the Provider                                                                      13121
# Provider Type of the Provider                                                                     13121
# Medicare Participation Indicator                                                                  13121
# Number of HCPCS                                                                                   13121
# Number of Services                                                                                13121
# Number of Medicare Beneficiaries                                                                  13121
# Total Submitted Charge Amount                                                                     13121
# Total Medicare Allowed Amount                                                                     13121
# Total Medicare Payment Amount                                                                     13121
# Average Age of Beneficiaries                                                                      13121
# Average HCC Risk Score of Beneficiaries                                                           13121
#
#                                                                                         unique values  \
# Medical Suppress Indicator                                                                          1
# Drug Suppress Indicator                                                                             1
# Street Address 2 of the Provider                                                                 2568
# Percent (%) of Beneficiaries Identified With Cancer                                                43
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          42
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   44
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Percent (%) of Beneficiaries Identified With Asthma                                                69
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 69
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Number of Beneficiaries With Medicare Only Entitlement                                            515
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      677
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Percent (%) of Beneficiaries Identified With Stroke                                                68
# Number of Male Beneficiaries\t                                                                    497
# Number of Female Beneficiaries                                                                    631
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        65
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Percent (%) of Beneficiaries Identified With Hypertension                                          57
# Middle Initial of the Provider                                                                     26
# Percent (%) of Beneficiaries Identified With Depression                                            63
# Credentials of the Provider                                                                       753
# Total Medical Medicare Standardized Payment Amount                                              12840
# Total Medical Medicare Payment Amount                                                           12843
# Total Medical Medicare Allowed Amount                                                           12844
# Total Medical Submitted Charge Amount                                                           11634
# Number of Medicare Beneficiaries With Medical Services                                            912
# Number of Medical Services                                                                       2704
# Total Drug Medicare Payment Amount                                                                112
# Total Drug Medicare Standardized Payment Amount                                                   112
# Total Drug Medicare Allowed Amount                                                                112
# Number of Medicare Beneficiaries With Drug Services                                                53
# Number of Drug Services                                                                           109
# Number of HCPCS Associated With Drug Services                                                      12
# Number of HCPCS Associated With Medical Services                                                   46
# Total Drug Submitted Charge Amount                                                                112
# Number of Black or African American Beneficiaries                                                 306
# National Provider Identifier                                                                    13121
# Total Medicare Standardized Payment Amount                                                      13102
# Last Name/Organization Name of the Provider                                                      9130
# First Name of the Provider                                                                       3809
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# Street Address 1 of the Provider                                                                10404
# City of the Provider                                                                             2870
# Zip Code of the Provider                                                                        10760
# State Code of the Provider                                                                         55
# Country Code of the Provider                                                                        1
# Provider Type of the Provider                                                                       5
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    53
# Number of Services                                                                               2785
# Number of Medicare Beneficiaries                                                                  918
# Total Submitted Charge Amount                                                                   11894
# Total Medicare Allowed Amount                                                                   13107
# Total Medicare Payment Amount                                                                   13106
# Average Age of Beneficiaries                                                                       63
# Average HCC Risk Score of Beneficiaries                                                          9246
#
#                                                                                         null values
# Medical Suppress Indicator                                                                    12858
# Drug Suppress Indicator                                                                       12858
# Street Address 2 of the Provider                                                               7694
# Percent (%) of Beneficiaries Identified With Cancer                                            7521
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      7461
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6621
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6545
# Percent (%) of Beneficiaries Identified With Asthma                                            6450
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             6367
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6276
# Percent (%) of Beneficiaries Identified With Heart Failure                                     6207
# Number of Beneficiaries With Medicare Only Entitlement                                         6035
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   6035
# Percent (%) of Beneficiaries Identified With Diabetes                                          6033
# Percent (%) of Beneficiaries Identified With Stroke                                            5999
# Number of Male Beneficiaries\t                                                                 5975
# Number of Female Beneficiaries                                                                 5975
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5764
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5684
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    5336
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4826
# Percent (%) of Beneficiaries Identified With Hypertension                                      4717
# Middle Initial of the Provider                                                                 4121
# Percent (%) of Beneficiaries Identified With Depression                                        3166
# Credentials of the Provider                                                                     609
# Total Medical Medicare Standardized Payment Amount                                              263
# Total Medical Medicare Payment Amount                                                           263
# Total Medical Medicare Allowed Amount                                                           263
# Total Medical Submitted Charge Amount                                                           263
# Number of Medicare Beneficiaries With Medical Services                                          263
# Number of Medical Services                                                                      263
# Total Drug Medicare Payment Amount                                                              263
# Total Drug Medicare Standardized Payment Amount                                                 263
# Total Drug Medicare Allowed Amount                                                              263
# Number of Medicare Beneficiaries With Drug Services                                             263
# Number of Drug Services                                                                         263
# Number of HCPCS Associated With Drug Services                                                   263
# Number of HCPCS Associated With Medical Services                                                263
# Total Drug Submitted Charge Amount                                                              263
# Number of Black or African American Beneficiaries                                                 0
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# Street Address 1 of the Provider                                                                  0
# City of the Provider                                                                              0
# Zip Code of the Provider                                                                          0
# State Code of the Provider                                                                        0
# Country Code of the Provider                                                                      0
# Provider Type of the Provider                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Average Age of Beneficiaries                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# ## GENDER

# %%
gender_cols = [
    'Number of Female Beneficiaries', 'Number of Male Beneficiaries\t','Number of Medicare Beneficiaries'
]

# %% [markdown]
# Number of Rows with No Null Values for gender

# %%
print('No nulls:', black_medicare[gender_cols[:-1]].notnull().all(axis=1).sum())
print('Has nulls:', black_medicare[gender_cols[:-1]].isnull().any(axis=1).sum())
# Out:
# No nulls: 7146
# Has nulls: 5975

# %% [markdown]
# Rows whose gender values add up correctly to total beneficaries

# %%
nonnull_rows = black_medicare[gender_cols[:-1]].notnull().all(axis=1)

mask = black_medicare.loc[nonnull_rows][gender_cols[:-1]].sum(axis=1) == \
                        black_medicare.loc[nonnull_rows,'Number of Medicare Beneficiaries']

print('Do sum:', len(black_medicare.loc[nonnull_rows][mask]))
print("Don't sum", len(black_medicare.loc[nonnull_rows][~mask]))
# Out:
# Do sum: 7146
# Don't sum 0

# %% [markdown]
# #### Although sex disparity in health access is interesting, I will exclude these columns to keep my focus on the number of Black patients and not have to reduce my data any more.

# %%
black_medicare.drop(columns = gender_cols[:-1], inplace=True)
all_medicare.drop(columns = gender_cols[:-1], inplace=True)

# %% [markdown]
# Gender Checkpoint 4

# %%
checkpoint4 = black_medicare.copy()
checkpoint4b = all_medicare.copy()

# %%
info = pd.DataFrame(index=black_medicare.columns.values,
                    data={'data type': black_medicare.dtypes, \
                          'non-null values': black_medicare.notnull().sum(),
                          'unique values': black_medicare.nunique(), \
                          'null values': black_medicare.isnull().sum()})
info.sort_values('non-null values')
# Out:
#                                                                                        data type  \
# Drug Suppress Indicator                                                                   object
# Medical Suppress Indicator                                                                object
# Street Address 2 of the Provider                                                          object
# Percent (%) of Beneficiaries Identified With Cancer                                      float64
# Percent (%) of Beneficiaries Identified With Osteoporosis                                float64
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                         float64
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                      float64
# Percent (%) of Beneficiaries Identified With Asthma                                      float64
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease       float64
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                      float64
# Percent (%) of Beneficiaries Identified With Heart Failure                               float64
# Number of Beneficiaries With Medicare Only Entitlement                                   float64
# Number of Beneficiaries With Medicare & Medicaid Entitlement                             float64
# Percent (%) of Beneficiaries Identified With Diabetes                                    float64
# Percent (%) of Beneficiaries Identified With Stroke                                      float64
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis       float64
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia             float64
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                              float64
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders   float64
# Percent (%) of Beneficiaries Identified With Hypertension                                float64
# Middle Initial of the Provider                                                            object
# Percent (%) of Beneficiaries Identified With Depression                                  float64
# Credentials of the Provider                                                               object
# Total Medical Submitted Charge Amount                                                    float64
# Number of Medicare Beneficiaries With Medical Services                                   float64
# Number of Medical Services                                                               float64
# Number of HCPCS Associated With Medical Services                                         float64
# Total Medical Medicare Allowed Amount                                                    float64
# Total Drug Medicare Standardized Payment Amount                                          float64
# Total Drug Medicare Allowed Amount                                                       float64
# Total Drug Submitted Charge Amount                                                       float64
# Number of Medicare Beneficiaries With Drug Services                                      float64
# Number of Drug Services                                                                  float64
# Number of HCPCS Associated With Drug Services                                            float64
# Total Medical Medicare Payment Amount                                                    float64
# Total Drug Medicare Payment Amount                                                       float64
# Total Medical Medicare Standardized Payment Amount                                       float64
# Number of Black or African American Beneficiaries                                        float64
# National Provider Identifier                                                              object
# Total Medicare Standardized Payment Amount                                               float64
# Last Name/Organization Name of the Provider                                               object
# First Name of the Provider                                                                object
# Gender of the Provider                                                                    object
# Entity Type of the Provider                                                               object
# Street Address 1 of the Provider                                                          object
# City of the Provider                                                                      object
# Zip Code of the Provider                                                                  object
# State Code of the Provider                                                                object
# Country Code of the Provider                                                              object
# Provider Type of the Provider                                                             object
# Medicare Participation Indicator                                                          object
# Number of HCPCS                                                                           object
# Number of Services                                                                       float64
# Number of Medicare Beneficiaries                                                          object
# Total Submitted Charge Amount                                                            float64
# Total Medicare Allowed Amount                                                            float64
# Total Medicare Payment Amount                                                            float64
# Average Age of Beneficiaries                                                              object
# Average HCC Risk Score of Beneficiaries                                                  float64
#
#                                                                                         non-null values  \
# Drug Suppress Indicator                                                                             263
# Medical Suppress Indicator                                                                          263
# Street Address 2 of the Provider                                                                   5427
# Percent (%) of Beneficiaries Identified With Cancer                                                5600
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          5660
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   6500
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                6576
# Percent (%) of Beneficiaries Identified With Asthma                                                6671
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 6754
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                6845
# Percent (%) of Beneficiaries Identified With Heart Failure                                         6914
# Number of Beneficiaries With Medicare Only Entitlement                                             7086
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                       7086
# Percent (%) of Beneficiaries Identified With Diabetes                                              7088
# Percent (%) of Beneficiaries Identified With Stroke                                                7122
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 7357
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       7437
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        7785
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             8295
# Percent (%) of Beneficiaries Identified With Hypertension                                          8404
# Middle Initial of the Provider                                                                     9000
# Percent (%) of Beneficiaries Identified With Depression                                            9955
# Credentials of the Provider                                                                       12512
# Total Medical Submitted Charge Amount                                                             12858
# Number of Medicare Beneficiaries With Medical Services                                            12858
# Number of Medical Services                                                                        12858
# Number of HCPCS Associated With Medical Services                                                  12858
# Total Medical Medicare Allowed Amount                                                             12858
# Total Drug Medicare Standardized Payment Amount                                                   12858
# Total Drug Medicare Allowed Amount                                                                12858
# Total Drug Submitted Charge Amount                                                                12858
# Number of Medicare Beneficiaries With Drug Services                                               12858
# Number of Drug Services                                                                           12858
# Number of HCPCS Associated With Drug Services                                                     12858
# Total Medical Medicare Payment Amount                                                             12858
# Total Drug Medicare Payment Amount                                                                12858
# Total Medical Medicare Standardized Payment Amount                                                12858
# Number of Black or African American Beneficiaries                                                 13121
# National Provider Identifier                                                                      13121
# Total Medicare Standardized Payment Amount                                                        13121
# Last Name/Organization Name of the Provider                                                       13121
# First Name of the Provider                                                                        13121
# Gender of the Provider                                                                            13121
# Entity Type of the Provider                                                                       13121
# Street Address 1 of the Provider                                                                  13121
# City of the Provider                                                                              13121
# Zip Code of the Provider                                                                          13121
# State Code of the Provider                                                                        13121
# Country Code of the Provider                                                                      13121
# Provider Type of the Provider                                                                     13121
# Medicare Participation Indicator                                                                  13121
# Number of HCPCS                                                                                   13121
# Number of Services                                                                                13121
# Number of Medicare Beneficiaries                                                                  13121
# Total Submitted Charge Amount                                                                     13121
# Total Medicare Allowed Amount                                                                     13121
# Total Medicare Payment Amount                                                                     13121
# Average Age of Beneficiaries                                                                      13121
# Average HCC Risk Score of Beneficiaries                                                           13121
#
#                                                                                         unique values  \
# Drug Suppress Indicator                                                                             1
# Medical Suppress Indicator                                                                          1
# Street Address 2 of the Provider                                                                 2568
# Percent (%) of Beneficiaries Identified With Cancer                                                43
# Percent (%) of Beneficiaries Identified With Osteoporosis                                          42
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                                   44
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                                74
# Percent (%) of Beneficiaries Identified With Asthma                                                69
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease                 69
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                                69
# Percent (%) of Beneficiaries Identified With Heart Failure                                         74
# Number of Beneficiaries With Medicare Only Entitlement                                            515
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                      677
# Percent (%) of Beneficiaries Identified With Diabetes                                              67
# Percent (%) of Beneficiaries Identified With Stroke                                                68
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis                 69
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                       74
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                        65
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders             75
# Percent (%) of Beneficiaries Identified With Hypertension                                          57
# Middle Initial of the Provider                                                                     26
# Percent (%) of Beneficiaries Identified With Depression                                            63
# Credentials of the Provider                                                                       753
# Total Medical Submitted Charge Amount                                                           11634
# Number of Medicare Beneficiaries With Medical Services                                            912
# Number of Medical Services                                                                       2704
# Number of HCPCS Associated With Medical Services                                                   46
# Total Medical Medicare Allowed Amount                                                           12844
# Total Drug Medicare Standardized Payment Amount                                                   112
# Total Drug Medicare Allowed Amount                                                                112
# Total Drug Submitted Charge Amount                                                                112
# Number of Medicare Beneficiaries With Drug Services                                                53
# Number of Drug Services                                                                           109
# Number of HCPCS Associated With Drug Services                                                      12
# Total Medical Medicare Payment Amount                                                           12843
# Total Drug Medicare Payment Amount                                                                112
# Total Medical Medicare Standardized Payment Amount                                              12840
# Number of Black or African American Beneficiaries                                                 306
# National Provider Identifier                                                                    13121
# Total Medicare Standardized Payment Amount                                                      13102
# Last Name/Organization Name of the Provider                                                      9130
# First Name of the Provider                                                                       3809
# Gender of the Provider                                                                              2
# Entity Type of the Provider                                                                         1
# Street Address 1 of the Provider                                                                10404
# City of the Provider                                                                             2870
# Zip Code of the Provider                                                                        10760
# State Code of the Provider                                                                         55
# Country Code of the Provider                                                                        1
# Provider Type of the Provider                                                                       5
# Medicare Participation Indicator                                                                    2
# Number of HCPCS                                                                                    53
# Number of Services                                                                               2785
# Number of Medicare Beneficiaries                                                                  918
# Total Submitted Charge Amount                                                                   11894
# Total Medicare Allowed Amount                                                                   13107
# Total Medicare Payment Amount                                                                   13106
# Average Age of Beneficiaries                                                                       63
# Average HCC Risk Score of Beneficiaries                                                          9246
#
#                                                                                         null values
# Drug Suppress Indicator                                                                       12858
# Medical Suppress Indicator                                                                    12858
# Street Address 2 of the Provider                                                               7694
# Percent (%) of Beneficiaries Identified With Cancer                                            7521
# Percent (%) of Beneficiaries Identified With Osteoporosis                                      7461
# Percent (%) of Beneficiaries Identified With Atrial Fibrillation                               6621
# Percent (%) of Beneficiaries Identified With Ischemic Heart Disease                            6545
# Percent (%) of Beneficiaries Identified With Asthma                                            6450
# Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease             6367
# Percent (%) of Beneficiaries Identified With Chronic Kidney Disease                            6276
# Percent (%) of Beneficiaries Identified With Heart Failure                                     6207
# Number of Beneficiaries With Medicare Only Entitlement                                         6035
# Number of Beneficiaries With Medicare & Medicaid Entitlement                                   6035
# Percent (%) of Beneficiaries Identified With Diabetes                                          6033
# Percent (%) of Beneficiaries Identified With Stroke                                            5999
# Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis             5764
# Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia                   5684
# Percent (%) of Beneficiaries Identified With Hyperlipidemia                                    5336
# Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders         4826
# Percent (%) of Beneficiaries Identified With Hypertension                                      4717
# Middle Initial of the Provider                                                                 4121
# Percent (%) of Beneficiaries Identified With Depression                                        3166
# Credentials of the Provider                                                                     609
# Total Medical Submitted Charge Amount                                                           263
# Number of Medicare Beneficiaries With Medical Services                                          263
# Number of Medical Services                                                                      263
# Number of HCPCS Associated With Medical Services                                                263
# Total Medical Medicare Allowed Amount                                                           263
# Total Drug Medicare Standardized Payment Amount                                                 263
# Total Drug Medicare Allowed Amount                                                              263
# Total Drug Submitted Charge Amount                                                              263
# Number of Medicare Beneficiaries With Drug Services                                             263
# Number of Drug Services                                                                         263
# Number of HCPCS Associated With Drug Services                                                   263
# Total Medical Medicare Payment Amount                                                           263
# Total Drug Medicare Payment Amount                                                              263
# Total Medical Medicare Standardized Payment Amount                                              263
# Number of Black or African American Beneficiaries                                                 0
# National Provider Identifier                                                                      0
# Total Medicare Standardized Payment Amount                                                        0
# Last Name/Organization Name of the Provider                                                       0
# First Name of the Provider                                                                        0
# Gender of the Provider                                                                            0
# Entity Type of the Provider                                                                       0
# Street Address 1 of the Provider                                                                  0
# City of the Provider                                                                              0
# Zip Code of the Provider                                                                          0
# State Code of the Provider                                                                        0
# Country Code of the Provider                                                                      0
# Provider Type of the Provider                                                                     0
# Medicare Participation Indicator                                                                  0
# Number of HCPCS                                                                                   0
# Number of Services                                                                                0
# Number of Medicare Beneficiaries                                                                  0
# Total Submitted Charge Amount                                                                     0
# Total Medicare Allowed Amount                                                                     0
# Total Medicare Payment Amount                                                                     0
# Average Age of Beneficiaries                                                                      0
# Average HCC Risk Score of Beneficiaries                                                           0

# %% [markdown]
# #### DECIDE WHAT ARE MY MOST IMPORTANT COLUMNS:

# %%
#DEFINITELY
def_imp_cols = [
#these cols have ZERO null values and may be relevant so I'll keep them 
     'National Provider Identifier', #keeping this as unique ID for each provider
    'Provider Type of the Provider',
     'Number of Medicare Beneficiaries',
     'Average Age of Beneficiaries',
     'Number of Black or African American Beneficiaries',
    'Total Medicare Payment Amount', 
    'City of the Provider', 
 'State Code of the Provider',
 'Zip Code of the Provider',
    'Average HCC Risk Score of Beneficiaries'
]

#MAYBE: i might want to keep the first two disorder columns for black_medicare
# i def want to keep the race columns for all_medicare
maybe_imp_cols = [
    'Percent (%) of Beneficiaries Identified With Depression', 
    'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
    'Number of American Indian/Alaska Native Beneficiaries',
 'Number of Asian Pacific Islander Beneficiaries',
 'Number of Non-Hispanic White Beneficiaries',
 'Number of Hispanic Beneficiaries', 
    'Number of Beneficiaries With Race Not Elsewhere Classified',
 'Country Code of the Provider',

]

# %%
joined = def_imp_cols + maybe_imp_cols

#NOT important columns
not_imp_cols = list(list(set(black_medicare.columns)-set(joined)))
not_imp_cols
# Out:
# ['Percent (%) of Beneficiaries Identified With Hypertension',
#  'Medical Suppress Indicator',
#  'Number of Medicare Beneficiaries With Medical Services',
#  'Percent (%) of Beneficiaries Identified With Cancer',
#  'Number of Beneficiaries With Medicare & Medicaid Entitlement',
#  'Middle Initial of the Provider',
#  'First Name of the Provider',
#  'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia',
#  'Street Address 2 of the Provider',
#  'Total Medicare Allowed Amount',
#  'Percent (%) of Beneficiaries Identified With Stroke',
#  'Credentials of the Provider',
#  'Street Address 1 of the Provider',
#  'Number of Medical Services',
#  'Percent (%) of Beneficiaries Identified With Heart Failure',
#  'Gender of the Provider',
#  'Number of Services',
#  'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease',
#  'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease',
#  'Number of Beneficiaries With Medicare Only Entitlement',
#  'Total Medical Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease',
#  'Number of HCPCS Associated With Drug Services',
#  'Number of Drug Services',
#  'Total Drug Submitted Charge Amount',
#  'Total Drug Medicare Payment Amount',
#  'Number of Medicare Beneficiaries With Drug Services',
#  'Number of HCPCS Associated With Medical Services',
#  'Total Medical Medicare Payment Amount',
#  'Total Medicare Standardized Payment Amount',
#  'Total Drug Medicare Standardized Payment Amount',
#  'Percent (%) of Beneficiaries Identified With Diabetes',
#  'Total Medical Medicare Allowed Amount',
#  'Total Submitted Charge Amount',
#  'Percent (%) of Beneficiaries Identified With Asthma',
#  'Medicare Participation Indicator',
#  'Total Medical Medicare Standardized Payment Amount',
#  'Entity Type of the Provider',
#  'Percent (%) of Beneficiaries Identified With Atrial Fibrillation',
#  'Drug Suppress Indicator',
#  'Number of HCPCS',
#  'Last Name/Organization Name of the Provider',
#  'Percent (%) of Beneficiaries Identified With Hyperlipidemia',
#  'Percent (%) of Beneficiaries Identified With Osteoporosis',
#  'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis',
#  'Total Drug Medicare Allowed Amount']

# %% [markdown]
# Dropping Less Important Columns

# %%
black_medicare = black_medicare.drop(columns = not_imp_cols)

# %%
black_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Black or African American Beneficiaries',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %%
all_medicare = all_medicare.drop(columns = not_imp_cols)
all_medicare.columns
# Out:
# Index(['National Provider Identifier', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Number of Medicare Beneficiaries', 'Total Medicare Payment Amount',
#        'Average Age of Beneficiaries',
#        'Number of Non-Hispanic White Beneficiaries\t',
#        'Number of Black or African American Beneficiaries',
#        'Number of Asian Pacific Islander Beneficiaries',
#        'Number of Hispanic Beneficiaries',
#        'Number of American Indian/Alaska Native Beneficiaries',
#        'Number of Beneficiaries With Race Not Elsewhere Classified',
#        'Percent (%) of Beneficiaries Identified With Depression',
#        'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders',
#        'Average HCC Risk Score of Beneficiaries'],
#       dtype='object')

# %% [markdown]
# How many rows and columns in this df?

# %%
black_medicare.shape, all_medicare.shape
# Out:
# ((13121, 13), (5747, 18))

# %% [markdown]
# ##### Renaming remaining columns

# %%
new_name_dict = {'National Provider Identifier': 'npi',
                 'City of the Provider': 'city',
                   'Zip Code of the Provider': 'full_zip',
                 'State Code of the Provider': 'state',
                   'Country Code of the Provider': 'country',
                 'Provider Type of the Provider':'provider_type',
                 'Number of Medicare Beneficiaries':'total_beneficiaries',
                'Average Age of Beneficiaries':'avg_beneficiary_age',
                'Total Medicare Payment Amount':'total_medicare_payment',
                'Number of Black or African American Beneficiaries':'num_black',
                'Average HCC Risk Score of Beneficiaries':'avg_hcc_risk_score',
                'Percent (%) of Beneficiaries Identified With Depression':'percent_with_depression',
                'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders':
                    'percent_with_psychosis'}

                
black_medicare.rename(columns = new_name_dict, inplace = True)
all_medicare.rename(columns = new_name_dict, inplace = True)

# %%
extra_name_dict = {'Number of Non-Hispanic White Beneficiaries\t':'num_white',
                  'Number of Asian Pacific Islander Beneficiaries':'num_asian_pac_isl',
       'Number of Hispanic Beneficiaries':'num_hispanic',
       'Number of American Indian/Alaska Native Beneficiaries':'num_nat_amer',
       'Number of Beneficiaries With Race Not Elsewhere Classified':'num_race_unknown',}
all_medicare.rename(columns = extra_name_dict, inplace = True)

# %%
all_medicare.columns, black_medicare.columns
# Out:
# (Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_white', 'num_black', 'num_asian_pac_isl', 'num_hispanic',
#         'num_nat_amer', 'num_race_unknown', 'percent_with_depression',
#         'percent_with_psychosis', 'avg_hcc_risk_score'],
#        dtype='object'),
#  Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#         'total_beneficiaries', 'total_medicare_payment', 'avg_beneficiary_age',
#         'num_black', 'percent_with_depression', 'percent_with_psychosis',
#         'avg_hcc_risk_score'],
#        dtype='object'))

# %% [markdown]
# Dropped Columns Checkpoint

# %%
checkpoint5 = black_medicare.copy()
checkpoint5b = all_medicare.copy()

# %% [markdown]
# ##### Country

# %%
#Some years' DFs have country values that are not 'US' listed in Country

# %%
black_medicare.country.unique()
# Out:
# array(['US'], dtype=object)

# %%
idx = black_medicare[black_medicare.country !='US'].index
black_medicare.drop(index = idx, inplace = True)

idx = all_medicare[all_medicare.country !='US'].index
all_medicare.drop(index = idx, inplace = True)

# %% [markdown]
# ##### Zip Codes

# %% [markdown]
# Some zip codes are integers, others strings, others objects

# %%
black_medicare.full_zip.apply(lambda x: type(x)).unique()
# Out:
# array([<class 'int'>, <class 'str'>, <class 'float'>], dtype=object)

# %% [markdown]
# Turning floats to integers and then to strings

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int').astype('str')

# %% [markdown]
# Next I have to convert the Zip Code to a 9-digit code (with leading zeros) or else I'll incorrectly capture the five digit zip code.

# %%
black_medicare.full_zip.apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    9708
# 8    1754
# 5    1204
# 4     317
# 3      78
# 7      60
# Name: full_zip, dtype: int64

# %% [markdown]
# I want to check the 3-digit zip codes, this looks fishy. Further research shows that zip codes in PR and VI start with 00.

# %%
black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) ==3
                ].state.value_counts()
# Out:
# PR    77
# VI     1
# Name: state, dtype: int64

# %%
# I looked over all zips with 5 or less digits
# It looks like they're 5-dig zips with no zip extensions, some are missing leading zeros

black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
                ].head()['full_zip']
# Out:
# 5321     4002
# 25154    2081
# 26546    6069
# 37579    6810
# 39996    3060
# Name: full_zip, dtype: object

# %%
# adding leading zeros to the VERY short zip codes less to make them 5 digits.
# then I can add an "extension" to make them 9 digits.

idx = black_medicare[
    black_medicare.full_zip.apply(lambda x: len(str(x))) <5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

# %%
#adding trailing zeros to mimic the four digit extension.
#this is probably not necessary but it couldn't hurt.

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    10103
# 8     1754
# 5     1204
# 7       60
# Name: full_zip, dtype: int64

# %%
# These are the 5 digit zips. I'll add trailing zeros here too.
black_medicare[black_medicare['full_zip'
                             ].apply(lambda x: len(str(x))) == 5
                              ]['full_zip'].head()
# Out:
# 654      70791
# 9873     42303
# 14778    72455
# 20393    44012
# 24981    24064
# Name: full_zip, dtype: object

# %%
idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# %%
#Here are the 7 and 8 digit zips
black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 8
].head()['full_zip']
# Out:
# 224074    6789805
# 242072    6789638
# 460057    9797001
# 178331    6925823
# 207765    9183523
# Name: full_zip, dtype: object

# %%
# These are 5 digit zip codes that are missing leading zeros, plus a 4 digit extension. 
# I'll add leading zeros to these

idx = black_medicare[
    black_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
].index

black_medicare.loc[idx,'full_zip'] = \
    black_medicare.loc[idx,'full_zip'].apply(lambda x: str(x).zfill(9))

# %%
black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
# Out:
# 9    13121
# Name: full_zip, dtype: int64

# %%
black_medicare['five_dig_zip'] = \
    black_medicare['full_zip'].astype('str').apply(lambda x: x[:5]
                        )
black_medicare['five_dig_zip'] = \
    black_medicare['five_dig_zip'].apply(lambda x: x.zfill(5))
black_medicare.five_dig_zip.nunique()
# Out:
# 5124

# %%
black_medicare['five_dig_zip'].apply(lambda x: len(x)).value_counts()
# Out:
# 5    13121
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Doing the same for all_medicare

# %%
#add leading zeros to the zip codes with length of 3 or 4 characters.
#then I add trailing zeros to these same zips, so they're 9 characters long.

all_medicare.full_zip = all_medicare.full_zip.astype('int').astype('str')

idx = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) <5
                    ].index

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).zfill(5))

all_medicare.loc[idx,'full_zip'] = \
    all_medicare.loc[idx,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add trailing zeros to the 5 digit zips as well
idx2 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x))) == 5
].index

all_medicare.loc[idx2,'full_zip'] = \
    all_medicare.loc[idx2,'full_zip'
                      ].apply(lambda x: str(x).ljust(9,'0'))

# add leading zeros to the 7 and 8 digit zip codes

idx3 = all_medicare[
    all_medicare['full_zip'].apply(lambda x: len(str(x)))  < 9
                    ].index

all_medicare.loc[idx3,'full_zip'] = \
    all_medicare.loc[idx3,'full_zip'].apply(lambda x: str(x).zfill(9))

#create 5-dig-zips column

all_medicare['five_dig_zip'] = \
    all_medicare['full_zip'
                ].astype('str').apply(lambda x: x[:5]).apply(lambda x: x.zfill(5))

# %%
print(
    black_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    black_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['full_zip'].apply(lambda x: len(str(x))).value_counts()
)
print(
    all_medicare['five_dig_zip'].apply(lambda x: len(str(x))).value_counts()
)
# Out:
# 9    13121
# Name: full_zip, dtype: int64
# 5    13121
# Name: five_dig_zip, dtype: int64
# 9    5747
# Name: full_zip, dtype: int64
# 5    5747
# Name: five_dig_zip, dtype: int64

# %% [markdown]
# Checkpoint 6

# %%
checkpoint6 = black_medicare.copy()
checkpoint6b = all_medicare.copy()

# %%
pd.options.display.max_colwidth = 1000
black_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13121 entries, 28 to 1053424
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      13121 non-null  object
#  1   city                     13121 non-null  object
#  2   full_zip                 13121 non-null  object
#  3   state                    13121 non-null  object
#  4   country                  13121 non-null  object
#  5   provider_type            13121 non-null  object
#  6   total_beneficiaries      13121 non-null  object
#  7   total_medicare_payment   13121 non-null  float64
#  8   avg_beneficiary_age      13121 non-null  object
#  9   num_black                13121 non-null  float64
#  10  percent_with_depression  9955 non-null   float64
#  11  percent_with_psychosis   8295 non-null   float64
#  12  avg_hcc_risk_score       13121 non-null  float64
#  13  five_dig_zip             13121 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 2.1+ MB

# %%
all_medicare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5747 entries, 220 to 1051188
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   npi                      5747 non-null   object
#  1   city                     5747 non-null   object
#  2   full_zip                 5747 non-null   object
#  3   state                    5747 non-null   object
#  4   country                  5747 non-null   object
#  5   provider_type            5747 non-null   object
#  6   total_beneficiaries      5747 non-null   object
#  7   total_medicare_payment   5747 non-null   float64
#  8   avg_beneficiary_age      5747 non-null   object
#  9   num_white                5747 non-null   float64
#  10  num_black                5747 non-null   float64
#  11  num_asian_pac_isl        5747 non-null   float64
#  12  num_hispanic             5747 non-null   float64
#  13  num_nat_amer             5747 non-null   float64
#  14  num_race_unknown         5747 non-null   object
#  15  percent_with_depression  3743 non-null   float64
#  16  percent_with_psychosis   2112 non-null   float64
#  17  avg_hcc_risk_score       5747 non-null   float64
#  18  five_dig_zip             5747 non-null   object
# dtypes: float64(9), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### Mental Disorders
# The only cols left with Nulls are the mental disorder cols.
#
# I want to make a third df with all rows that have these numbers. Then I'll drop these cols from the other two dfs.

# %%
disorder_cols = [
         'percent_with_depression',
        'percent_with_psychosis'
]

black_medicare_with_disorders = \
    black_medicare[black_medicare[disorder_cols].notnull().all(axis=1)]

black_medicare.drop(columns = disorder_cols, inplace=True)
all_medicare.drop(columns = disorder_cols, inplace=True)

# %% [markdown]
# Checkpoint 7

# %%
checkpoint7 = black_medicare.copy()
checkpoint7b= all_medicare.copy()
checkpoint7c = black_medicare_with_disorders.copy()

# %% [markdown]
# # Census DF

# %%
census = pd.read_csv('../data/raw/2016acs.csv')

# %%
census.head()
# Out:
#    geo_id  nonfamily_households  family_households  \
# 0   61112                    95                  0
# 1   33856                   169                 92
# 2   59465                    10                  6
# 3   28424                     8                 12
# 4   63745                     2                  9
#
#    median_year_structure_built  rent_burden_not_computed  \
# 0                       2002.0                         0
# 1                       1966.0                         0
# 2                       1962.0                         0
# 3                       2001.0                         0
# 4                       1965.0                         2
#
#    rent_over_50_percent  rent_40_to_50_percent  rent_35_to_40_percent  \
# 0                    56                     10                      0
# 1                     0                     36                      0
# 2                     0                      0                      5
# 3                     7                      0                      4
# 4                     0                      0                      1
#
#    rent_30_to_35_percent  rent_25_to_30_percent  ...  pop_5_years_over  \
# 0                      0                      0  ...               NaN
# 1                      0                     87  ...               NaN
# 2                      0                      0  ...               NaN
# 3                      0                      0  ...               NaN
# 4                      2                      0  ...               NaN
#
#    speak_only_english_at_home  speak_spanish_at_home  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
#
#    speak_spanish_at_home_low_english  pop_15_and_over  pop_never_married  \
# 0                                NaN              NaN                NaN
# 1                                NaN              NaN                NaN
# 2                                NaN              NaN                NaN
# 3                                NaN              NaN                NaN
# 4                                NaN              NaN                NaN
#
#    pop_now_married  pop_separated  pop_widowed  pop_divorced
# 0              NaN            NaN          NaN           NaN
# 1              NaN            NaN          NaN           NaN
# 2              NaN            NaN          NaN           NaN
# 3              NaN            NaN          NaN           NaN
# 4              NaN            NaN          NaN           NaN
#
# [5 rows x 252 columns]

# %%
# dropping do_date columns, which gives info on how numbers for this year were calculated
# but isn't useful for my investigation.

census.drop(columns=['do_date'], inplace=True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# pop_divorced                                                  float64
# pop_5_years_over                                              float64
# speak_only_english_at_home                                    float64
# speak_spanish_at_home                                         float64
# speak_spanish_at_home_low_english                             float64
# pop_widowed                                                   float64
# pop_never_married                                             float64
# pop_15_and_over                                               float64
# pop_now_married                                               float64
# pop_separated                                                 float64
# aggregate_travel_time_to_work                                 float64
# median_rent                                                   float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# percent_income_spent_on_rent                                  float64
# owner_occupied_housing_units_lower_value_quartile             float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# income_per_capita                                             float64
# median_age                                                    float64
# different_house_year_ago_different_city                       float64
# different_house_year_ago_same_city                            float64
# population_1_year_and_over                                    float64
# less_than_high_school_graduate                                float64
# not_us_citizen_pop                                            float64
# bachelors_degree_2                                            float64
# some_college_and_associates_degree                            float64
# high_school_including_ged                                     float64
#
#                                                              non-null values  \
# pop_divorced                                                               0
# pop_5_years_over                                                           0
# speak_only_english_at_home                                                 0
# speak_spanish_at_home                                                      0
# speak_spanish_at_home_low_english                                          0
# pop_widowed                                                                0
# pop_never_married                                                          0
# pop_15_and_over                                                            0
# pop_now_married                                                            0
# pop_separated                                                              0
# aggregate_travel_time_to_work                                          20339
# median_rent                                                            27217
# renter_occupied_housing_units_paying_cash_median_gross_rent            27373
# percent_income_spent_on_rent                                           27762
# owner_occupied_housing_units_lower_value_quartile                      30173
# owner_occupied_housing_units_upper_value_quartile                      30704
# owner_occupied_housing_units_median_value                              30774
# median_income                                                          31112
# median_year_structure_built                                            32208
# gini_index                                                             32254
# income_per_capita                                                      32515
# median_age                                                             32595
# different_house_year_ago_different_city                                32989
# different_house_year_ago_same_city                                     32989
# population_1_year_and_over                                             32989
# less_than_high_school_graduate                                         32989
# not_us_citizen_pop                                                     32989
# bachelors_degree_2                                                     32989
# some_college_and_associates_degree                                     32989
# high_school_including_ged                                              32989
#
#                                                              unique values  \
# pop_divorced                                                             0
# pop_5_years_over                                                         0
# speak_only_english_at_home                                               0
# speak_spanish_at_home                                                    0
# speak_spanish_at_home_low_english                                        0
# pop_widowed                                                              0
# pop_never_married                                                        0
# pop_15_and_over                                                          0
# pop_now_married                                                          0
# pop_separated                                                            0
# aggregate_travel_time_to_work                                        17086
# median_rent                                                           1899
# renter_occupied_housing_units_paying_cash_median_gross_rent           1948
# percent_income_spent_on_rent                                           399
# owner_occupied_housing_units_lower_value_quartile                     4221
# owner_occupied_housing_units_upper_value_quartile                     6247
# owner_occupied_housing_units_median_value                             5223
# median_income                                                        19533
# median_year_structure_built                                             75
# gini_index                                                            4112
# income_per_capita                                                    20615
# median_age                                                             655
# different_house_year_ago_different_city                               4905
# different_house_year_ago_same_city                                    3588
# population_1_year_and_over                                           15370
# less_than_high_school_graduate                                        4555
# not_us_citizen_pop                                                    4196
# bachelors_degree_2                                                    5991
# some_college_and_associates_degree                                    7533
# high_school_including_ged                                             7195
#
#                                                              null values
# pop_divorced                                                       33120
# pop_5_years_over                                                   33120
# speak_only_english_at_home                                         33120
# speak_spanish_at_home                                              33120
# speak_spanish_at_home_low_english                                  33120
# pop_widowed                                                        33120
# pop_never_married                                                  33120
# pop_15_and_over                                                    33120
# pop_now_married                                                    33120
# pop_separated                                                      33120
# aggregate_travel_time_to_work                                      12781
# median_rent                                                         5903
# renter_occupied_housing_units_paying_cash_median_gross_rent         5747
# percent_income_spent_on_rent                                        5358
# owner_occupied_housing_units_lower_value_quartile                   2947
# owner_occupied_housing_units_upper_value_quartile                   2416
# owner_occupied_housing_units_median_value                           2346
# median_income                                                       2008
# median_year_structure_built                                          912
# gini_index                                                           866
# income_per_capita                                                    605
# median_age                                                           525
# different_house_year_ago_different_city                              131
# different_house_year_ago_same_city                                   131
# population_1_year_and_over                                           131
# less_than_high_school_graduate                                       131
# not_us_citizen_pop                                                   131
# bachelors_degree_2                                                   131
# some_college_and_associates_degree                                   131
# high_school_including_ged                                            131

# %% [markdown]
# Deleting columns with ZERO nonnull values. Weirdly these columns have info for all rows in the previous years.

# %%
allnull = list(info[info['non-null values']==0].index)
allnull
# Out:
# ['pop_5_years_over',
#  'speak_only_english_at_home',
#  'speak_spanish_at_home',
#  'speak_spanish_at_home_low_english',
#  'pop_15_and_over',
#  'pop_never_married',
#  'pop_now_married',
#  'pop_separated',
#  'pop_widowed',
#  'pop_divorced']

# %%
census.drop(columns = allnull, inplace = True)

# %% [markdown]
# Only keep Census zipcodes that appear in the Medicare DF

# %%
medzips = list(black_medicare.five_dig_zip)
census.geo_id = census.geo_id.astype('str').apply(lambda x: x.zfill(5))
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))

# %%
missingzips = list(set(medzips) - commonzips)

# %%
black_medicare.set_index('five_dig_zip').loc[missingzips].index.unique()
# Out:
# Index(['60567', '06030', '66160', '98493', '92415', '11242', '21041', '48824',
#        '79430', '18341', '92697', '20060', '09831', '29220', '77805', '04333',
#        '01655', '68198', '37684', '00919', '65212', '29151', '28286', '03756',
#        '22908', '23298', '84143', '00801', '00792', '35402', '02059', '00963',
#        '14642', '32163', '06904', '94143', '20042', '65102', '02065', '95671',
#        '84132', '45408', '92093', '29425', '65402', '11571', '21501', '86205',
#        '94141', '27157', '27599', '27710', '09104', '08101', '02234', '44195',
#        '06102', '84068', '18711', '21022', '77555', '92161', '92369', '10982',
#        '00726', '01936', '87131', '00908', '84148', '01805', '00977', '07962',
#        '35249', '58107', '40536', '71130', '32610', '23249', '92357', '85220',
#        '38157', '12402', '27699', '05302', '73523', '21287'],
#       dtype='object', name='five_dig_zip')

# %%
pd.options.display.max_rows = 120
black_medicare.set_index('five_dig_zip').loc[missingzips]
# Out:
#                      npi         city   full_zip state country  \
# five_dig_zip
# 60567         1043254840   NAPERVILLE  605670000    IL      US
# 06030         1326479106   FARMINGTON  060300001    CT      US
# 06030         1083807531   FARMINGTON  060300001    CT      US
# 06030         1497916472   FARMINGTON  060300001    CT      US
# 66160         1043305592  KANSAS CITY  661600000    KS      US
# ...                  ...          ...        ...   ...     ...
# 21287         1902860596    BALTIMORE  212870005    MD      US
# 21287         1912942707    BALTIMORE  212870005    MD      US
# 21287         1942238563    BALTIMORE  212870005    MD      US
# 21287         1942265038    BALTIMORE  212870005    MD      US
# 21287         1982650891    BALTIMORE  212870005    MD      US
#
#                                 provider_type total_beneficiaries  \
# five_dig_zip
# 60567                              Psychiatry                 413
# 06030         Licensed Clinical Social Worker                  11
# 06030                              Psychiatry                 375
# 06030                              Psychiatry                 461
# 66160                              Psychiatry                 303
# ...                                       ...                 ...
# 21287                              Psychiatry                 235
# 21287                              Psychiatry                  81
# 21287                              Psychiatry                 226
# 21287                              Psychiatry                 175
# 21287                              Psychiatry                 105
#
#               total_medicare_payment avg_beneficiary_age  num_black  \
# five_dig_zip
# 60567                       96131.28                  74       89.0
# 06030                        2278.05                  46        0.0
# 06030                      269489.26                  56       85.0
# 06030                       93372.33                  82       14.0
# 66160                       34367.18                  59       37.0
# ...                              ...                 ...        ...
# 21287                       75652.79                  56      120.0
# 21287                       33499.92                  53       41.0
# 21287                       58480.23                  76       26.0
# 21287                       12080.87                  46       81.0
# 21287                       22851.23                  53       56.0
#
#               avg_hcc_risk_score
# five_dig_zip
# 60567                     2.6481
# 06030                     1.1025
# 06030                     2.0022
# 06030                     2.4661
# 66160                     2.1183
# ...                          ...
# 21287                     1.3758
# 21287                     1.5535
# 21287                     1.4598
# 21287                     1.5313
# 21287                     1.9078
#
# [204 rows x 11 columns]

# %% [markdown]
# ##### A lot of these are PO Box zip codes. Although I don't want to reduce my DF by any more rows,  I don't feel comfortable changing them to a zip code nearby (e.g. changing 30031 to 30032).
# ##### Dropping them from both Census and Medicare.

# %%
idx = black_medicare[black_medicare['five_dig_zip'].isin(missingzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare['five_dig_zip'].isin(missingzips)].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders['five_dig_zip'].isin(missingzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
medzips = list(black_medicare.five_dig_zip)
censuszips = list(census.geo_id)
commonzips = (set(medzips)).intersection(set(censuszips))
list(set(medzips) - commonzips)
# Out:
# []

# %%
print(black_medicare.five_dig_zip.nunique())
print(census[census.geo_id.isin(commonzips)].shape[0])
# Out:
# 5038
# 5038

# %% [markdown]
# Dropping those same zip codes from the Census DF.

# %%
idx = census[census.geo_id.isin(commonzips)].index
census = census.loc[idx]

# %% [markdown]
# Reviewing Null Values

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(30)
# Out:
#                                                             data type  \
# aggregate_travel_time_to_work                                 float64
# owner_occupied_housing_units_lower_value_quartile             float64
# median_rent                                                   float64
# owner_occupied_housing_units_upper_value_quartile             float64
# owner_occupied_housing_units_median_value                     float64
# renter_occupied_housing_units_paying_cash_median_gross_rent   float64
# less_than_high_school_graduate                                float64
# population_1_year_and_over                                    float64
# bachelors_degree_2                                            float64
# different_house_year_ago_different_city                       float64
# some_college_and_associates_degree                            float64
# different_house_year_ago_same_city                            float64
# high_school_including_ged                                     float64
# graduate_professional_degree                                  float64
# not_us_citizen_pop                                            float64
# percent_income_spent_on_rent                                  float64
# median_income                                                 float64
# median_year_structure_built                                   float64
# gini_index                                                    float64
# median_age                                                    float64
# income_per_capita                                             float64
# white_male_45_54                                                int64
# white_male_55_64                                                int64
# hispanic_male_55_64                                             int64
# bachelors_degree_or_higher_25_64                                int64
# children                                                        int64
# commuters_drove_alone                                           int64
# commuters_by_bus                                                int64
# commuters_by_car_truck_van                                      int64
# commuters_by_carpool                                            int64
#
#                                                              non-null values  \
# aggregate_travel_time_to_work                                           4803
# owner_occupied_housing_units_lower_value_quartile                       4979
# median_rent                                                             4983
# owner_occupied_housing_units_upper_value_quartile                       4986
# owner_occupied_housing_units_median_value                               4987
# renter_occupied_housing_units_paying_cash_median_gross_rent             4988
# less_than_high_school_graduate                                          4992
# population_1_year_and_over                                              4992
# bachelors_degree_2                                                      4992
# different_house_year_ago_different_city                                 4992
# some_college_and_associates_degree                                      4992
# different_house_year_ago_same_city                                      4992
# high_school_including_ged                                               4992
# graduate_professional_degree                                            4992
# not_us_citizen_pop                                                      4992
# percent_income_spent_on_rent                                            4993
# median_income                                                           5004
# median_year_structure_built                                             5007
# gini_index                                                              5008
# median_age                                                              5026
# income_per_capita                                                       5026
# white_male_45_54                                                        5038
# white_male_55_64                                                        5038
# hispanic_male_55_64                                                     5038
# bachelors_degree_or_higher_25_64                                        5038
# children                                                                5038
# commuters_drove_alone                                                   5038
# commuters_by_bus                                                        5038
# commuters_by_car_truck_van                                              5038
# commuters_by_carpool                                                    5038
#
#                                                              unique values  \
# aggregate_travel_time_to_work                                         4714
# owner_occupied_housing_units_lower_value_quartile                     2690
# median_rent                                                           1415
# owner_occupied_housing_units_upper_value_quartile                     3323
# owner_occupied_housing_units_median_value                             3036
# renter_occupied_housing_units_paying_cash_median_gross_rent           1431
# less_than_high_school_graduate                                        3015
# population_1_year_and_over                                            4762
# bachelors_degree_2                                                    3772
# different_house_year_ago_different_city                               3337
# some_college_and_associates_degree                                    3985
# different_house_year_ago_same_city                                    2679
# high_school_including_ged                                             3960
# graduate_professional_degree                                          3309
# not_us_citizen_pop                                                    2806
# percent_income_spent_on_rent                                           309
# median_income                                                         4817
# median_year_structure_built                                             71
# gini_index                                                            1902
# median_age                                                             403
# income_per_capita                                                     4740
# white_male_45_54                                                      2280
# white_male_55_64                                                      2217
# hispanic_male_55_64                                                    798
# bachelors_degree_or_higher_25_64                                      4060
# children                                                              4133
# commuters_drove_alone                                                 4454
# commuters_by_bus                                                      1276
# commuters_by_car_truck_van                                            4466
# commuters_by_carpool                                                  2273
#
#                                                              null values
# aggregate_travel_time_to_work                                        235
# owner_occupied_housing_units_lower_value_quartile                     59
# median_rent                                                           55
# owner_occupied_housing_units_upper_value_quartile                     52
# owner_occupied_housing_units_median_value                             51
# renter_occupied_housing_units_paying_cash_median_gross_rent           50
# less_than_high_school_graduate                                        46
# population_1_year_and_over                                            46
# bachelors_degree_2                                                    46
# different_house_year_ago_different_city                               46
# some_college_and_associates_degree                                    46
# different_house_year_ago_same_city                                    46
# high_school_including_ged                                             46
# graduate_professional_degree                                          46
# not_us_citizen_pop                                                    46
# percent_income_spent_on_rent                                          45
# median_income                                                         34
# median_year_structure_built                                           31
# gini_index                                                            30
# median_age                                                            12
# income_per_capita                                                     12
# white_male_45_54                                                       0
# white_male_55_64                                                       0
# hispanic_male_55_64                                                    0
# bachelors_degree_or_higher_25_64                                       0
# children                                                               0
# commuters_drove_alone                                                  0
# commuters_by_bus                                                       0
# commuters_by_car_truck_van                                             0
# commuters_by_carpool                                                   0

# %% [markdown]
# Some of these columns don't seem as important to determining access to health care, or are redundant with other columns.

# %%
cols_to_drop = ['aggregate_travel_time_to_work','owner_occupied_housing_units_lower_value_quartile',
'owner_occupied_housing_units_median_value','owner_occupied_housing_units_upper_value_quartile',
'renter_occupied_housing_units_paying_cash_median_gross_rent','median_year_structure_built']

census.drop(columns = cols_to_drop, inplace = True)

# %% [markdown]
# #####  Median_rent nulls.
#
# This column is important and I want to keep the information it provides. Dropping rows with zipcodes whose median_rent is null.

# %% [markdown]
# How many rows with Null median_rent and how many of these zips are in Medicare df?

# %%
mask = census.median_rent.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (55, 55)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census
tempzips = list(census[
                census.median_rent.isnull()
                    ].geo_id)

idx = black_medicare[
        black_medicare.five_dig_zip.isin(tempzips)
                    ].index
black_medicare.drop(index = idx, inplace=True)

idx = all_medicare[
        all_medicare.five_dig_zip.isin(tempzips)
                    ].index
all_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[
        black_medicare_with_disorders.five_dig_zip.isin(tempzips)
                    ].index
black_medicare_with_disorders.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[census.median_rent.isnull()].index
census.drop(index = idx, inplace = True)

# %%
print(black_medicare.five_dig_zip.nunique(), census.shape[0])
print(black_medicare_with_disorders.five_dig_zip.nunique(), census.shape[0])
print(all_medicare.five_dig_zip.nunique(), census.shape[0])

#Census has more zipcodes than latter two DFs
#But I'm going to left-merge on Medicare DFs, so it's okay.
# Out:
# 4983 4983
# 3117 4983
# 3190 4983

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(10)
# Out:
#                                         data type  non-null values  \
# not_us_citizen_pop                        float64             4939
# some_college_and_associates_degree        float64             4939
# bachelors_degree_2                        float64             4939
# high_school_including_ged                 float64             4939
# population_1_year_and_over                float64             4939
# graduate_professional_degree              float64             4939
# different_house_year_ago_different_city   float64             4939
# different_house_year_ago_same_city        float64             4939
# less_than_high_school_graduate            float64             4939
# median_income                             float64             4981
#
#                                          unique values  null values
# not_us_citizen_pop                                2805           44
# some_college_and_associates_degree                3953           44
# bachelors_degree_2                                3752           44
# high_school_including_ged                         3936           44
# population_1_year_and_over                        4722           44
# graduate_professional_degree                      3295           44
# different_house_year_ago_different_city           3325           44
# different_house_year_ago_same_city                2676           44
# less_than_high_school_graduate                    3003           44
# median_income                                     4794            2

# %% [markdown]
# #### Removing rows from zipcodes in Census and Medicare that have nulls in high_school_including_ged.
# #### Hopefully this takes care of all the rest of the columns with nulls in Census DF.

# %%
mask = census.high_school_including_ged.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (44, 44)

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)

# %%
info = pd.DataFrame(index=census.columns.values,
                    data={'data type': census.dtypes, \
                          'non-null values': census.notnull().sum(),
                          'unique values': census.nunique(), \
                          'null values': census.isnull().sum()})
info.sort_values('non-null values').head(1)
# Out:
#               data type  non-null values  unique values  null values
# median_income   float64             4937           4751            2

# %% [markdown]
# ##### Median_income
#
# Just like median_rent, this column seems important and I'd like to keep it. Dropping zip codes that have nulls in this column.

# %%
mask = census.median_income.isnull()
census[mask].shape[0], census[mask].geo_id.isin(medzips).sum()
# Out:
# (2, 2)

# %%
black_medicare[
    black_medicare.five_dig_zip.isin(
        census[census.median_income.isnull()].geo_id
    )
]
# Out:
#                npi       city   full_zip state country  \
# 242275  1225436884  MARLINTON  248541142    WV      US
# 203047  1194702100     HARRIS  127420800    NY      US
#
#                           provider_type total_beneficiaries  \
# 242275  Licensed Clinical Social Worker                  15
# 203047                       Psychiatry                 146
#
#         total_medicare_payment avg_beneficiary_age  num_black  \
# 242275                 2754.68                  48        0.0
# 203047                39280.13                  57       17.0
#
#         avg_hcc_risk_score five_dig_zip
# 242275              1.0743        24854
# 203047              1.8675        12742

# %%
#DELETING rows from Medicare with Zips that have nulls in Census

tempzips = list(census[mask].geo_id)

idx = black_medicare[black_medicare.five_dig_zip.isin(tempzips)].index
black_medicare.drop(index = idx, inplace=True)

idx = black_medicare_with_disorders[black_medicare_with_disorders.five_dig_zip.isin(tempzips)].index
black_medicare_with_disorders.drop(index = idx, inplace=True)

idx = all_medicare[all_medicare.five_dig_zip.isin(tempzips)].index
all_medicare.drop(index = idx, inplace=True)

#DELETING rows from Census for these Zips that have nulls
idx = census[mask].index
census.drop(index = idx, inplace = True)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
black_medicare.shape, black_medicare_with_disorders.shape, all_medicare.shape
# Out:
# ((12641, 12), (6777, 14), (5514, 17))

# %% [markdown]
# # Now that Census DF is clean, I can merge with Medicare DFs.

# %%
census['geo_id'] = census['geo_id'].astype('str')

# %%
census.geo_id.apply(lambda x: len(x)).value_counts()
# Out:
# 5    4937
# Name: geo_id, dtype: int64

# %%
census['geo_id'] = census.geo_id.apply(lambda x: x.zfill(5))

# %%
census['geo_id'] = census['geo_id'].astype('int')

# %% [markdown]
# #### Checking data types

# %% [markdown]
# All columns in Census should be 'int' or 'float.' I want to see what is listed as object.

# %%
census.select_dtypes('object').head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [627]

# %% [markdown]
# Checking Medicare DFs

# %%
print(black_medicare.select_dtypes('object').columns)
print(black_medicare_with_disorders.select_dtypes('object').columns)
print(all_medicare.select_dtypes('object').columns)
# Out:
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'five_dig_zip'],
#       dtype='object')
# Index(['npi', 'city', 'full_zip', 'state', 'country', 'provider_type',
#        'total_beneficiaries', 'avg_beneficiary_age', 'num_race_unknown',
#        'five_dig_zip'],
#       dtype='object')

# %%
black_medicare.full_zip = black_medicare.full_zip.astype('int')
black_medicare.total_beneficiaries = black_medicare.total_beneficiaries.astype('int')
black_medicare.avg_beneficiary_age = black_medicare.avg_beneficiary_age.astype('int')
black_medicare.five_dig_zip = black_medicare.five_dig_zip.astype('int')

# %%
black_medicare_with_disorders.full_zip = black_medicare_with_disorders.full_zip.astype('int')
black_medicare_with_disorders.total_beneficiaries = black_medicare_with_disorders.total_beneficiaries.astype('int')
black_medicare_with_disorders.avg_beneficiary_age = black_medicare_with_disorders.avg_beneficiary_age.astype('int')
black_medicare_with_disorders.five_dig_zip = black_medicare_with_disorders.five_dig_zip.astype('int')
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
all_medicare.full_zip = all_medicare.full_zip.astype('int')
all_medicare.total_beneficiaries = all_medicare.total_beneficiaries.astype('int')
all_medicare.avg_beneficiary_age = all_medicare.avg_beneficiary_age.astype('int')
all_medicare.five_dig_zip = all_medicare.five_dig_zip.astype('int')
all_medicare.num_race_unknown = all_medicare.num_race_unknown.astype('int')

# %%
merged = black_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
all_merged = all_medicare.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')
disorders_merged = black_medicare_with_disorders.merge(census, left_on='five_dig_zip', right_on='geo_id', how='left')

# %%
#saving black medicare merged
merged.to_csv('../data/processed/2016black_medicare_census')

#saving all races medicare df merged
disorders_merged.to_csv('../data/processed/2016black_medicare_with_disorders_census')

#saving black_medicare with disorder values merged
all_merged.to_csv('../data/processed/2016all_races_medicare_census')
