# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/models'

# %%
med = pd.read_csv('../data/processed/final2017MEDICARE.csv', index_col=0)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
med['payment_per_service']=med.total_medicare_payment/med.number_of_services
med['percentage_rate'] = med.total_medicare_payment/ med.total_submitted_charges
med['standardized_pay_per_service'] = med['total_medicare_standardized_payment']/med.number_of_services

# %%
df = med.drop(columns = ['npi','country'])

# %%
df.columns
# Out:
# Index(['entity_code', 'full_zip', 'state', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score', 'services_per_capita',
#        'allowed_payment_per_capita', 'medicare_payment_per_capita',
#        'submitted_charges_per_capita', 'region', 'subregion',
#        'payment_per_service', 'percentage_rate', 'standardize_pay_per_service',
#        'standardized_pay_per_service'],
#       dtype='object')

# %%
pd.options.display.max_rows = 100
df['standardized_rate'] = df.total_medicare_standardized_payment/df.total_submitted_charges
df.sort_values(['full_zip','provider_type'])[df.provider_type=='Mass Immunizer Roster Biller'][['full_zip','provider_type','standardized_pay_per_service','standardized_rate']].tail(100)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          full_zip                 provider_type  standardized_pay_per_service  \
# 811708      99163  Mass Immunizer Roster Biller                     44.471154
# 790679      99201  Mass Immunizer Roster Biller                     38.453214
# 804631      99201  Mass Immunizer Roster Biller                     36.426325
# 788520      99202  Mass Immunizer Roster Biller                     46.117709
# 806317      99203  Mass Immunizer Roster Biller                     40.471746
# 791069      99204  Mass Immunizer Roster Biller                     37.987769
# 791083      99204  Mass Immunizer Roster Biller                     29.614655
# 807120      99204  Mass Immunizer Roster Biller                     34.241452
# ...

# %%
df.columns
# Out:
# Index(['entity_code', 'full_zip', 'state', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'total_medicare_standardized_payment', 'avg_beneficiary_age',
#        'avg_hcc_risk_score', 'services_per_capita',
#        'allowed_payment_per_capita', 'medicare_payment_per_capita',
#        'submitted_charges_per_capita', 'region', 'subregion',
#        'payment_per_service', 'percentage_rate',
#        'standardize_pay_per_service'],
#       dtype='object')
