# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/notebooks/Data_wrangling'

# %%
med = pd.read_csv('../../data/processed/final2013MEDICARE.csv', index_col=0)

# %% [markdown]
# MED is the df I will use to merge with Census and aggregate by zip code.
# But I want a DF of providers as well, so I can compare doctors with mostly Black patients to doctors with mostly non-Black patients.

# %%
med['payment_per_service']=med.total_medicare_payment/med.number_of_services
med['percentage_rate'] = med.total_medicare_payment/ med.total_submitted_charges

# %%
df = med.drop(columns = ['npi','full_zip','country'])

# %%
df.columns
# Out:
# Index(['entity_code', 'state', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'number_of_services', 'total_beneficiaries', 'total_submitted_charges',
#        'total_allowed_payment', 'total_medicare_payment',
#        'avg_beneficiary_age', 'avg_hcc_risk_score', 'services_per_capita',
#        'allowed_payment_per_capita', 'medicare_payment_per_capita',
#        'submitted_charges_per_capita', 'region', 'subregion',
#        'payment_per_service', 'percentage_rate'],
#       dtype='object')

# %%
df = pd.get_dummies(df)

# %%
from math import trunc

df['class'] = df.percentage_rate.apply(lambda x: trunc(x*10))

# %%
df['class']
# Out:
# 0         4
# 1         4
# 2         1
# 3         7
# 4         3
#          ..
# 949950    5
# 949951    2
# 949952    5
# 949953    0
# 949954    4
# Name: class, Length: 949955, dtype: int64

# %%
y = df['class']
X = df.drop(columns = ['class','percentage_rate'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size = 0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
ypred = lr.predict(X_test)

# %%
from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(20,20))
plot_confusion_matrix(lr, X_test, y_test, ax=ax)

# %%
(y_test * X_test['total_submitted_charges']).sum() - (ypred /10 * X_test['total_submitted_charges']).sum()
# Out:
# 134048276624.34598

# %%
pd.DataFrame((ypred/10 * X_test['total_submitted_charges'])).describe()
# Out:
#        total_submitted_charges
# count             1.899910e+05
# mean              7.803754e+04
# std               5.235882e+05
# min               0.000000e+00
# 25%               7.279882e+03
# 50%               2.546120e+04
# 75%               7.365802e+04
# max               1.559942e+08

# %%
pd.DataFrame((y_test * X_test['total_submitted_charges'])).describe()
# Out:
#                   0
# count  1.899910e+05
# mean   7.835882e+05
# std    5.822459e+06
# min    0.000000e+00
# 25%    7.189490e+04
# 50%    2.499180e+05
# 75%    7.301069e+05
# max    2.005640e+09

# %%
pd.merge?

# %%
idx = X_test.sort_values('total_medicare_payment', ascending=False).head().index
X_test['ypred'] = ypred / 10
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_test.columns
# Out:
# Index(['number_of_hcpcs', 'number_of_services', 'total_beneficiaries',
#        'total_submitted_charges', 'total_allowed_payment',
#        'total_medicare_payment', 'avg_beneficiary_age', 'avg_hcc_risk_score',
#        'services_per_capita', 'allowed_payment_per_capita',
#        ...
#        'subregion_East South Central', 'subregion_Middle Atlantic',
#        'subregion_Mountain', 'subregion_New England', 'subregion_Pacific',
#        'subregion_South Atlantic', 'subregion_West North Central',
#        'subregion_West South Central', 'class', 'ypred'],
#       dtype='object', length=174)

# %%
X_test['new_payment_per_service'] = X_test.total_submitted_charges * X_test.ypred / X_test.number_of_services
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
idx = X_test.index
providers = med.loc[idx,'provider_type']
X_test['provider_type'] = providers
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # I looked at this DF by ordering by Risk Score, by Comparing Actual Payment to Predicted Pay, and finally, by Ordering by Diff Rate - PredictedRate.
# # Seems highest diffs for for Other Health Services: Mass Immunization and Public Health Welfare Agency.
# # I wonder how the model will do if I take out Other Health Services.

# %%
pd.options.display.max_rows = 100
X_test['diff'] = X_test.percentage_rate - X_test.ypred
X_test[['provider_type','total_medicare_payment','number_of_services','payment_per_service','new_payment_per_service', 'percentage_rate','ypred', 'diff','avg_hcc_risk_score']].sort_values('diff', ascending=False).head(100)
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       provider_type  total_medicare_payment  \
# 743908              Mass Immunization Roster Biller                  570.88
# 267494              Mass Immunization Roster Biller                  875.00
# 617933              Mass Immunization Roster Biller                  274.90
# 858520                 Public Health Welfare Agency                  706.40
# 9863           Multispecialty Clinic/Group Practice                  706.00
# 759809         Multispecialty Clinic/Group Practice                  273.00
# 861036                 Public Health Welfare Agency                  600.44
# 93095               Mass Immunization Roster Biller                  731.75
# 856772                 Public Health Welfare Agency                  459.16
# 924420              Mass Immunization Roster Biller                  510.74
# 861564                 Public Health Welfare Agency                  388.52
# 238685              Mass Immunization Roster Biller                  934.98
# 75446               Mass Immunization Roster Biller                  583.00
# 388371              Mass Immunization Roster Biller                  509.83
# 78447               Mass Immunization Roster Biller                  663.10
# 234930                             General Practice                  711.07
# 24904          Multispecialty Clinic/Group Practice                 2492.00
# 740640              Mass Immunization Roster Biller                 1054.83
# 307603              Mass Immunization Roster Biller                  325.00
# 31630          Multispecialty Clinic/Group Practice                  140.00
# 301691              Mass Immunization Roster Biller                 1628.10
# 602470  Registered Dietician/Nutrition Professional                 1117.83
# 369560                 Public Health Welfare Agency                 1927.57
# 30676               Mass Immunization Roster Biller                  511.36
# 446834              Mass Immunization Roster Biller                  546.63
# 665128              Mass Immunization Roster Biller                 1331.86
# 5630           Multispecialty Clinic/Group Practice                  762.16
# 331978              Mass Immunization Roster Biller                 1420.62
# 662658              Mass Immunization Roster Biller                  901.27
# 664307              Mass Immunization Roster Biller                 1276.37
# 731206  Registered Dietician/Nutrition Professional                  592.95
# 662956              Mass Immunization Roster Biller                 1484.69
# 472434              Mass Immunization Roster Biller                  499.90
# 740145              Mass Immunization Roster Biller                  751.12
# 522769              Mass Immunization Roster Biller                 1149.97
# 686776              Mass Immunization Roster Biller                 1135.47
# 121095              Mass Immunization Roster Biller                  516.24
# 133930              Mass Immunization Roster Biller                 1074.06
# 554799              Mass Immunization Roster Biller                 1311.98
# 220629              Mass Immunization Roster Biller                  742.72
# 443929                  48            12.322917                 8.750000
# 5962                  3734             1.971398                 1.400000
# 891902              114906             1.994468                 1.416432
# 375830                  48            14.250833                10.120833
# 609902                  30            18.229333                12.946500
# 256453                 148            15.214797                10.806014
# 573693                 238            16.952899                12.040618
# 459838                 122            14.778607                10.496500
# 840485                3705             6.848920                 4.865000
# 817190                  36            12.025833                 8.542333
# 336609                1186             2.956189                 2.100000
# 200942                6145           192.623736               136.839235
# 683442                  30            14.780000                10.500000
# 893651                 202             8.941535                 6.352431
# 580072                 146            24.092671                17.117733
# 85929                  142            21.413310                15.214106
# 890906                6168             1.993627                 1.416480
# 7204                 11232             1.970420                 1.400000
# 9060                  2013             1.970412                 1.400000
# 2643                  7411             1.970395                 1.400000
# 897617                  42            17.358095                12.333333
# 21519                 8417             1.970360                 1.400000
# 211927                  98            14.633367                10.397500
# 457344                 109            11.240734                 7.987064
# 923831                 185            20.565459                14.613314
#
#         percentage_rate  ypred      diff  avg_hcc_risk_score
# 743908         1.000000    0.7  0.300000              1.1957
# 267494         1.000000    0.7  0.300000              1.1155
# 617933         1.000000    0.7  0.300000              0.8611
# 858520         1.000000    0.7  0.300000              0.7910
# 9863           1.000000    0.7  0.300000              1.6428
# 759809         1.000000    0.7  0.300000              1.6747
# 861036         1.000000    0.7  0.300000              1.0502
# 93095          1.000000    0.7  0.300000              0.7364
# 856772         1.000000    0.7  0.300000              0.9660
# 924420         1.000000    0.7  0.300000              1.0056
# 861564         1.000000    0.7  0.300000              0.6444
# 238685         1.000000    0.7  0.300000              0.6298
# 75446          1.000000    0.7  0.300000              0.6409
# 388371         1.000000    0.7  0.300000              1.1305
# 78447          1.000000    0.7  0.300000              0.7165
# 234930         1.000000    0.7  0.300000              1.2241
# 24904          1.000000    0.7  0.300000              1.0664
# 740640         1.000000    0.7  0.300000              0.7473
# 307603         1.000000    0.7  0.300000              0.7235
# 31630          1.000000    0.7  0.300000              1.0914
# 301691         0.999448    0.7  0.299448              0.7841
# 602470         0.998937    0.7  0.298937              2.4354
# 369560         0.996990    0.7  0.296990              0.8133
# 30676          0.996531    0.7  0.296531              1.6087
# 446834         0.995919    0.7  0.295919              0.6222
# 665128         0.995634    0.7  0.295634              0.8902
# 5630           0.994987    0.7  0.294987              1.3928
# 331978         0.994832    0.7  0.294832              0.8532
# 662658         0.993869    0.7  0.293869              0.8559
# 664307         0.993501    0.7  0.293501              0.8375
# 731206         0.990959    0.7  0.290959              0.9053
# 662956         0.990011    0.7  0.290011              0.9419
# 472434         0.989901    0.7  0.289901              1.3555
# 740145         0.989879    0.7  0.289879              0.5826
# 522769         0.989877    0.7  0.289877              0.5545
# 686776         0.989404    0.7  0.289404              0.7302
# 121095         0.989193    0.7  0.289193              0.5461
# 133930         0.988805    0.7  0.288805              1.2917
# 554799         0.988190    0.7  0.288190              1.8289
