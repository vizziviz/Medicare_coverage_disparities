# %% [markdown]
# After all, the fundamental reason we build predictive machine learning models is typically to model what would happen under a particular set of circumstances which have either not yet occurred or have occurred but for which we do not know the actual result.
#
# 	Hyperparameter tuning?
# 	Should I do BOTH data_with_paymentcols and data_without_paymentcols?
# 	Look at feature importances:
#         barchart for top x features or all features with coefficient > y.
#         How can I find the p-value for features? Is that only in regression?
# 	Do Ridge Regression and Lasso Regression.
# 		Barchart for top features
# 	Make DataFrame with top features for my model, Lasso Regression, and Ridge Regression (or model and Ridge)
# 	Make inferences:
# 		Does race show up in these features? Where?
# 		How do I interpret differences in RATES distinct from differences in CHARGES? A city doctor should CHARGE more, but should his rate b higher?
#         Or should a rural (lowpop) doctor have higher rates bc he might charge less?
#         Or might city doctors be cheap Public Health providers /Flu shots, thus paid in full?
#
#     Look at extreme mistakes:
#     Providers marked low but actually v high. Providers marked v high but actually low: barcharts of types of providers, racial majority, regions, subregions, histogram of submitted charges OR medicare payments, histogram of payment/service, histogram of payment/person. Boxplots of percent black / white / hispanic / asian for false very-highs and for false-lows

# %% [markdown]
# # Importing Modules and Checking Directory

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
os.getcwd()
# Out:
# '/Users/Livi/Projects/Black_mental_health/models'

# %%
X = pd.read_csv('../data/processed/feature_matrix_scaled_PT.csv', index_col=0)
X.head()
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#    number_of_hcpcs  number_of_services  total_beneficiaries  \
# 0        -0.003948            0.540055             0.851671
# 1        -0.170174            0.576787             1.015528
# 2        -1.402499           -1.478753            -2.032970
# 3         0.447350            1.158778             1.311877
# 4         0.139490           -0.443103            -0.613947
#
#    total_submitted_charges  avg_beneficiary_age  avg_hcc_risk_score  \
# 0                 1.196155             0.998501            1.105662
# 1                 0.573919             2.139463            0.994263
# 2                -2.079729            -1.181247           -1.398919
# 3                 1.152199             1.833739           -0.416924
# 4                -0.657554            -0.706375            1.649911
#
#    submitted_charges_per_person  services_per_person  \
# 0                      0.871076            -0.119979
# 1                     -0.276118            -0.317600
# 2                     -1.041626             0.565058
# 3                      0.242840             0.442297
# 4                     -0.268393             0.241994
#
#    submitted_charges_per_service  total_pop  ...  subregion_Pacific  \
# 0                       1.063762   0.781846  ...          -0.378901
# 1                       0.179416  -0.074416  ...          -0.378901
# 2                      -1.326987  -0.413310  ...          -0.378901
# 3                       0.106138   0.795532  ...          -0.378901
# 4                      -0.223406  -0.679061  ...          -0.378901
#
#    subregion_South Atlantic  subregion_West North Central  \
# 0                  2.036056                     -0.285347
# 1                  2.036056                     -0.285347
# 2                  2.036056                     -0.285347
# 3                  2.036056                     -0.285347
# 4                  2.036056                     -0.285347
#
#    subregion_West South Central  majority_asian  majority_black  \
# 0                     -0.331112         -0.0744       -0.225179
# 1                     -0.331112         -0.0744       -0.225179
# 2                     -0.331112         -0.0744        4.440915
# 3                     -0.331112         -0.0744       -0.225179
# 4                     -0.331112         -0.0744       -0.225179
#
#    majority_hispanic  majority_native_amer  majority_white  no_majority
# 0          -0.234267             -0.033669        0.585053    -0.416918
# 1          -0.234267             -0.033669        0.585053    -0.416918
# 2          -0.234267             -0.033669       -1.709248    -0.416918
# 3          -0.234267             -0.033669       -1.709248     2.398553
# 4          -0.234267             -0.033669       -1.709248     2.398553
#
# [5 rows x 190 columns]

# %%
y = pd.read_csv('../data/processed/target_array.csv', index_col=0)
y.head()
# Out:
# /Users/Livi/opt/anaconda3/envs/springboard/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#   payrate_level
# 0           low
# 1          high
# 2        medium
# 3        medium
# 4          high

# %%
X.shape, y.shape
# Out:
# ((1072142, 190), (1072142, 1))

# %% [markdown]
#     The best performing models in my Preprocessing step were SVM (only when data was scaled) and Logistic Regression (a little better performance also when data was scaled).
#     I'll be including both of these in this Modeling notebook to compare the important features.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X.values[:100000], y.values.ravel()[:100000], test_size = 0.2, random_state=2)

# %%
X_train.shape, y_train.shape
# Out:
# ((80000, 190), (80000,))

# %%
import time
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score, make_scorer, precision_score, recall_score

# %% [markdown]
# SVC

# %% [markdown]
#     from sklearn.svm import SVC
#
#     svc = SVC(kernel='linear')
#     svc.fit(X_train, y_train)

# %% [markdown]
#     ypred_svc = svc.predict(X_test)

# %% [markdown]
#     f1_svc = f1_score(y_test, ypred_svc, average='weighted')
#     recall_svc = recall_score(y_test, ypred_svc, average='weighted')
#     precision_svc = precision_score(y_test, ypred_svc, average='weighted')

# %% [markdown]
# Despite this model performing quickly in my preprocessing. It's quite slow when passing all of my data to it. Here I will do a Random Forest instead, which scored very slightly lower in the CV but trains much faster.

# %%
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

rf = RandomForestClassifier(n_jobs=-1)

start = time.time()

rf.fit(X_train, y_train)

end= time.time()
total = end - start

print("Time:", total/60, "minutes")
# Out:
# Time: 7.308404219150543 minutes

# %%
start = time.time()

ypred_rf = rf.predict(X_test)

end = time.time()
print('Time:',(end-start)/60, 'minutes')
# Out:
# Time: 0.24052363236745197 minutes

# %%
from sklearn.metrics import plot_confusion_matrix

start = time.time()

plt.figure(figsize=(20,20))
plot_confusion_matrix(rf, X_test, y_test, labels=['low','medium','high','very high'])
f1_rf = f1_score(y_test, ypred_rf, average='weighted')

end=time.time()

print('RF F1 Score:', f1_rf)
print('Time:', (end-start)/60, 'minutes')
# Out:
# RF F1 Score: 0.8295080509069066
# Time: 0.361489482720693 minutes

# %%
recall_rf = recall_score(y_test, ypred_lr, average='weighted')
precision_rf = precision_score(y_test, ypred_lr, average='weighted')

print('RF F1 Score:', f1_rf, 'RF Recall Score:', recall_rf, 'RF Precision Score:', precision_rf)
# Out:
# RF F1 Score: 0.8295080509069066 RF Recall Score: 0.7564508531961628 RF Precision Score: 0.7592650742682764

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

start =  time.time()

#using all data since this model is much faster than SVM
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values.ravel(), test_size = 0.2, random_state=2)

lr = LogisticRegression(n_jobs=-1)

lr.fit(X_train, y_train)
end = time.time()

print('Time:', (end-start)/60, 'minutes')
# Out:
# Time: 12.806880935033162 minutes

# %%
start =  time.time()

ypred_lr = lr.predict(X_test)

end = time.time()
print('Time:', (end-start)/60, 'minutes')
# Out:
# Time: 0.04330828189849854 minutes

# %%
f1_lr = f1_score(y_test, ypred_lr, average='weighted')
recall_lr = recall_score(y_test, ypred_lr, average='weighted')
precision_lr = precision_score(y_test, ypred_lr, average='weighted')
print(f1_lr, recall_lr, precision_lr)
# Out:
# 0.7520908088754783 0.7564508531961628 0.7592650742682764

# %%
from sklearn.metrics import plot_confusion_matrix

start = time.time()

plt.figure(figsize=(20,20))

plot_confusion_matrix(lr, X_test, y_test, labels=['low','medium','high','very high'])

end=time.time()
print('Time:', (end-start)/60, 'minutes')
# Out:
# Time: 0.016247367858886717 minutes

# %%
scores = pd.DataFrame({'models':['Random Forest', 'Logistic Regression'],
             'F1 Scores': [f1_rf, f1_lr],
             'Recall Scores': [recall_rf, recall_lr],
             'Precision Scores':[precision_rf, precision_lr]})
scores
# Out:
#                 models  F1 Scores  Recall Scores  Precision Scores
# 0        Random Forest   0.829508       0.756451          0.759265
# 1  Logistic Regression   0.752091       0.756451          0.759265

# %%
import dataframe_image as dfi
dfi.export(scores,"model_metrics.png")

# %%
scores.to_csv('../reports/figures/model_scores.csv')

# %%
[format(i, '8f') for i in rf.feature_importances_]

# %%
rf_imp = pd.DataFrame({'Features': X.columns, 
              'RF Feature Importances': [format(i, '8f') for i in rf.feature_importances_]}
            ).sort_values('RF Feature Importances', ascending=False).head(20)
rf_imp.to_csv('../references/rf_feature_imp.csv')

# %%
rf_imp.head()
# Out:
#                         Features RF Feature Importances
# 8  submitted_charges_per_service               0.166715
# 6   submitted_charges_per_person               0.082571
# 7            services_per_person               0.077495
# 3        total_submitted_charges               0.052601
# 0                number_of_hcpcs               0.043647

# %%
mean_lr_coef = list(lr.coef_.sum(axis=0)/4)

coefficients = pd.DataFrame({'features': X.columns,
             'lr LOW coef': lr.coef_[1],
             'lr MEDIUM coef': lr.coef_[2],
             'lr HIGH coef': lr.coef_[0],
             'lr VERY HIGH coef': lr.coef_[3]})

coefficients.sort_values('lr LOW coef', ascending=False).head(30)
# Out:
#                                               features  lr LOW coef  \
# 3                              total_submitted_charges     3.324239
# 6                         submitted_charges_per_person     1.495213
# 145                  provider_type_Physician Assistant     0.586846
# 93                  provider_type_Diagnostic Radiology     0.538370
# 0                                      number_of_hcpcs     0.520446
# 144  provider_type_Physical Therapist in Private Pr...     0.506127
# 78                           provider_type_Audiologist     0.314265
# 139                            provider_type_Pathology     0.292642
# 129                   provider_type_Nurse Practitioner     0.278650
# 67                                            state_WI     0.228710
# 2                                  total_beneficiaries     0.187439
# 167                              provider_type_Urology     0.178319
# 94                    provider_type_Emergency Medicine     0.172325
# 85                          provider_type_Chiropractic     0.122643
# 131  provider_type_Occupational Therapist in Privat...     0.115851
# 17                                       entity_code_I     0.115160
# 73                   provider_type_Allergy/ Immunology     0.105916
# 74            provider_type_Ambulance Service Provider     0.088624
# 115             provider_type_Interventional Radiology     0.082356
# 88                   provider_type_Clinical Laboratory     0.082284
# 80                            provider_type_Cardiology     0.078924
# 56                                            state_OR     0.075041
# 42                                            state_MN     0.072004
# 12                                 percent_native_amer     0.067533
# 29                                            state_GA     0.066270
# 31                                            state_IA     0.063047
# 182                       subregion_West North Central     0.053577
# 171                                     region_Midwest     0.051142
# 161                      provider_type_Sports Medicine     0.049170
# 118         provider_type_Mass Immunizer Roster Biller     0.048218
#
#      lr MEDIUM coef  lr HIGH coef  lr VERY HIGH coef
# 3         -0.257211     -2.468719          -0.598309
# 6          0.716188     -0.914095          -1.297306
# 145        0.311581     -0.009018          -0.889409
# 93         0.099848     -0.271144          -0.367075
# 0          0.361010     -0.209254          -0.672202
# 144        0.287550     -0.010413          -0.783264
# 78         0.105004     -0.151039          -0.268230
# 139        0.045697     -0.165806          -0.172533
# 129        0.098825     -0.133828          -0.243647
# 67         0.039820     -0.115800          -0.152730
# 2          0.264728     -0.742964           0.290798
# 167        0.183797      0.075661          -0.437777
# 94         0.081155     -0.022107          -0.231373
# 85         0.073688     -0.009800          -0.186531
# 131        0.042724     -0.065130          -0.093445
# 17         0.134546      0.067296          -0.317003
# 73         0.063226     -0.007865          -0.161277
# 74         0.095776     -0.002933          -0.181467
# 115        0.038477     -0.037795          -0.083037
# 88         0.043198     -0.029460          -0.096021
# 80         0.116390      0.014753          -0.210067
# 56         0.081265     -0.073664          -0.082643
# 42         0.047344     -0.046304          -0.073044
# 12         0.030638     -0.001761          -0.096410
# 29         0.032401     -0.043147          -0.055524
# 31         0.038902     -0.021093          -0.080856
# 182        0.039714     -0.023356          -0.069935
# 171        0.012115     -0.011784          -0.051473
# 161        0.050206      0.004451          -0.103828
# 118       -0.226207     -0.186006           0.363995

# %%
mask = coefficients['is LOW coef positive?']==True
coefficients.loc[mask,['features','lr LOW coef', 'is LOW coef positive?']
                             ].sort_values('lr LOW coef', ascending=False).head(20)
# Out:
#                                               features  lr LOW coef  \
# 3                              total_submitted_charges     3.324239
# 6                         submitted_charges_per_person     1.495213
# 145                  provider_type_Physician Assistant     0.586846
# 93                  provider_type_Diagnostic Radiology     0.538370
# 0                                      number_of_hcpcs     0.520446
# 144  provider_type_Physical Therapist in Private Pr...     0.506127
# 78                           provider_type_Audiologist     0.314265
# 139                            provider_type_Pathology     0.292642
# 129                   provider_type_Nurse Practitioner     0.278650
# 67                                            state_WI     0.228710
# 2                                  total_beneficiaries     0.187439
# 167                              provider_type_Urology     0.178319
# 94                    provider_type_Emergency Medicine     0.172325
# 85                          provider_type_Chiropractic     0.122643
# 131  provider_type_Occupational Therapist in Privat...     0.115851
# 17                                       entity_code_I     0.115160
# 73                   provider_type_Allergy/ Immunology     0.105916
# 74            provider_type_Ambulance Service Provider     0.088624
# 115             provider_type_Interventional Radiology     0.082356
# 88                   provider_type_Clinical Laboratory     0.082284
#
#      is LOW coef positive?
# 3                     True
# 6                     True
# 145                   True
# 93                    True
# 0                     True
# 144                   True
# 78                    True
# 139                   True
# 129                   True
# 67                    True
# 2                     True
# 167                   True
# 94                    True
# 85                    True
# 131                   True
# 17                    True
# 73                    True
# 74                    True
# 115                   True
# 88                    True

# %%
mask = coefficients['is LOW coef positive?']==False
coefficients.loc[mask,['features','lr LOW coef', 'is LOW coef positive?']
                             ].sort_values('lr LOW coef', ascending=False).head(20)
# Out:
#                                               features  lr LOW coef  \
# 1                                   number_of_services     3.580007
# 7                                  services_per_person     0.832959
# 75            provider_type_Ambulatory Surgical Center     0.445163
# 4                                  avg_beneficiary_age     0.393966
# 99                       provider_type_General Surgery     0.333476
# 151               provider_type_Psychologist, Clinical     0.311072
# 132                        provider_type_Ophthalmology     0.295610
# 112                    provider_type_Internal Medicine     0.242966
# 84   provider_type_Certified Registered Nurse Anest...     0.229801
# 150                           provider_type_Psychiatry     0.221522
# 146   provider_type_Plastic and Reconstructive Surgery     0.213665
# 116      provider_type_Licensed Clinical Social Worker     0.208267
# 124                           provider_type_Nephrology     0.206399
# 127                         provider_type_Neurosurgery     0.199138
# 81                       provider_type_Centralized Flu     0.186315
# 76                        provider_type_Anesthesiology     0.184557
# 163                     provider_type_Thoracic Surgery     0.184392
# 133                            provider_type_Optometry     0.173207
# 108                          provider_type_Hospitalist     0.158063
# 130              provider_type_Obstetrics & Gynecology     0.157172
#
#      is LOW coef positive?
# 1                    False
# 7                    False
# 75                   False
# 4                    False
# 99                   False
# 151                  False
# 132                  False
# 112                  False
# 84                   False
# 150                  False
# 146                  False
# 116                  False
# 124                  False
# 127                  False
# 81                   False
# 76                   False
# 163                  False
# 133                  False
# 108                  False
# 130                  False

# %%
mask = coefficients['is VERY HIGH coef positive?']==True
coefficients.loc[mask,['features','lr VERY HIGH coef', 'is VERY HIGH coef positive?']
                             ].sort_values('lr VERY HIGH coef', ascending=False).head(20)
# Out:
#                                              features  lr VERY HIGH coef  \
# 8                       submitted_charges_per_service           1.147480
# 7                                 services_per_person           0.865051
# 1                                  number_of_services           0.553773
# 167                             provider_type_Urology           0.437777
# 151              provider_type_Psychologist, Clinical           0.417425
# 4                                 avg_beneficiary_age           0.325893
# 17                                      entity_code_I           0.317003
# 112                   provider_type_Internal Medicine           0.303438
# 116     provider_type_Licensed Clinical Social Worker           0.300799
# 92                          provider_type_Dermatology           0.291099
# 75           provider_type_Ambulatory Surgical Center           0.283365
# 150                          provider_type_Psychiatry           0.248965
# 99                      provider_type_General Surgery           0.230658
# 124                          provider_type_Nephrology           0.228424
# 146  provider_type_Plastic and Reconstructive Surgery           0.218059
# 80                           provider_type_Cardiology           0.210067
# 132                       provider_type_Ophthalmology           0.201068
# 5                                  avg_hcc_risk_score           0.160725
# 163                    provider_type_Thoracic Surgery           0.142019
# 137                      provider_type_Otolaryngology           0.137078
#
#      is VERY HIGH coef positive?
# 8                           True
# 7                           True
# 1                           True
# 167                         True
# 151                         True
# 4                           True
# 17                          True
# 112                         True
# 116                         True
# 92                          True
# 75                          True
# 150                         True
# 99                          True
# 124                         True
# 146                         True
# 80                          True
# 132                         True
# 5                           True
# 163                         True
# 137                         True

# %%
mask = coefficients['is VERY HIGH coef positive?']==False
coefficients.loc[mask,['features','lr VERY HIGH coef', 'is VERY HIGH coef positive?']
                             ].sort_values('lr VERY HIGH coef', ascending=False).head(20)
# Out:
#                                               features  lr VERY HIGH coef  \
# 6                         submitted_charges_per_person           1.297306
# 145                  provider_type_Physician Assistant           0.889409
# 144  provider_type_Physical Therapist in Private Pr...           0.783264
# 84   provider_type_Certified Registered Nurse Anest...           0.678251
# 81                       provider_type_Centralized Flu           0.672853
# 0                                      number_of_hcpcs           0.672202
# 3                              total_submitted_charges           0.598309
# 76                        provider_type_Anesthesiology           0.593573
# 93                  provider_type_Diagnostic Radiology           0.367075
# 118         provider_type_Mass Immunizer Roster Biller           0.363995
# 18                                       entity_code_O           0.317003
# 108                          provider_type_Hospitalist           0.315587
# 2                                  total_beneficiaries           0.290798
# 78                           provider_type_Audiologist           0.268230
# 129                   provider_type_Nurse Practitioner           0.243647
# 94                    provider_type_Emergency Medicine           0.231373
# 85                          provider_type_Chiropractic           0.186531
# 74            provider_type_Ambulance Service Provider           0.181467
# 139                            provider_type_Pathology           0.172533
# 105                  provider_type_Hematology-Oncology           0.163622
#
#      is VERY HIGH coef positive?
# 6                          False
# 145                        False
# 144                        False
# 84                         False
# 81                         False
# 0                          False
# 3                          False
# 76                         False
# 93                         False
# 118                        False
# 18                         False
# 108                        False
# 2                          False
# 78                         False
# 129                        False
# 94                         False
# 85                         False
# 74                         False
# 139                        False
# 105                        False

# %% [markdown]
# Without any hyperparameter tuning my best model was the Logistic Regression with 90%. In another preprocessing notebook, the Logistic Regression model also performed best with addition Medicare-Payment columns (which I left out here because of possible collinearity) at 99%.
#
# Because the ratio of Medicare payment to Submitted charges actually tells whether the client is low rate, medium rate or high rate, I prefer to leave these out. I'm not sure if the models can "figure out" that relationship or not.
#
# My goal is actually to have a pretty good model that has a few mistakes because these mistakes are just as telling as the ability of the model to correctly identify classes.
#
# On that note, I am interested in the F1 Score particularly for the "very high" class and "low" class because I want to know whether the model falsely labels high-rate providers as low or vice versa. That said, maybe I don't want to optimize for "low" class F1 Score but rather the OVERALL F1 score. If a model is generally very accurate but still mislabels some outliers, those outliers may be worth re-examining.
#
# Overall, my modeling notebook will focus most heavily of feature importances and tables that contain the extreme outliers: low rate providers labeled as 'very high' and very high rate providers labeled as very low. I want to see if these providers show a pattern.
#
# If they do seem fishy, a final iteration of modeling may be one that labels these outliers as "wrongly compensated" and trains on the data to look for other potential "wrongly compensated" providers.

# %% [markdown]
# I didn't scale my date before modeling here, both because I may want to say that for the "modeling" stage since my initial performances were good and because the combination of binary and continuous variables may complicate that process.
