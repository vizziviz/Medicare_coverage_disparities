# %%
import pandas as pd

# %%
chunks = pd.read_csv('/home/vizziwo/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2018.csv', chunksize=50000)

# %%
for chunk in chunks:
    df = chunk
    break
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
df.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'Provider RUCA',
#        'State Code of the Provider', 'Country Code of the Provider',
#        'Provider Type of the Provider', 'Medicare Participation Indicator',
#        'Number of HCPCS', 'Number of Services',
#        'Number of Medicare Beneficiaries', 'Total Submitted Charge Amount',
#        'Total Medicare Allowed Amount', 'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
# ...

# %%
df['Provider Type of the Provider'].unique()
# Out:
# array(['Internal Medicine', 'Pathology', 'Anesthesiology',
#        'Family Practice', 'Obstetrics & Gynecology', 'General Surgery',
#        'Urology', 'Cardiac Surgery', 'Physician Assistant',
#        'Licensed Clinical Social Worker',
#        'Physical Therapist in Private Practice',
#        'Certified Registered Nurse Anesthetist (CRNA)', 'Optometry',
#        'Mass Immunizer Roster Biller',
#        'Physical Medicine and Rehabilitation', 'Radiation Oncology',
#        'Infectious Disease', 'Nurse Practitioner', 'Orthopedic Surgery',
#        'Endocrinology', 'Chiropractic', 'Psychiatry',
#        'Diagnostic Radiology', 'Centralized Flu', 'Rheumatology',
#        'General Practice', 'Neurology', 'Emergency Medicine',
#        'Dermatology', 'Nephrology', 'Pediatric Medicine',
#        'Pulmonary Disease', 'Otolaryngology',
#        'Plastic and Reconstructive Surgery', 'Psychologist, Clinical',
#        'Cardiology', 'Ambulance Service Provider', 'Ophthalmology',
# ...

# %%
df[df['Provider Type of the Provider']=='Psychologist, Clinical']
# Out:
#        National Provider Identifier  \
# 72                       1003005430
# 236                      1003013574
# 584                      1003034570
# 619                      1003037441
# 649                      1003039785
# ...                             ...
# 49671                    1043320500
# 49690                    1043321268
# 49736                    1043322829
# 49764                    1043323751
# 49839                    1043326135
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 72                                       BEAUMONT                      LAURA
# 236                                       LADANYE                      KAREN
# 584                                       BURGHER                      PETER
# 619                                        ZAPLAC                      TRUDI
# 649                                         YOUNG                      DAVID
# ...

# %%
df[df['Provider Type of the Provider']=='Psychiatry'].iloc[:, 1:16]
# Out:
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 35                                 CASTRO CORDOBA                  JUAN LUIS
# 90                                       GVOZDJAN                  DRAGOSLAV
# 102                                        HARLOW                    MICHAEL
# 206                                       SOLIMAN                      MAGED
# 212                                            LU                     DUNYUE
# ...                                           ...                        ...
# 49881                                     RASTOGI                    SANTOSH
# 49951                                        FAMY                CHRISTOPHER
# 49957                                       WHITE                   CLARENCE
# 49970                                       BURKY                CHRISTOPHER
# 49971                                      BAYLES                   S. TYLER
#
# ...

# %%
x = 1
for chunk in chunks:
    x += 1
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
x
# Out:
# 23

# %%
23*50000
# Out:
# 1150000

# %%
df['Pct_Black'] = df['Number of Black or African American Beneficiaries'] / df['Number of Medicare Beneficiaries'] * 100

# %%
y = df[(df['Provider Type of the Provider']=='Psychiatry') | (df['Provider Type of the Provider']=='Psychologist, Clinical') | (df['Provider Type of the Provider']=='Licensed Clinical Social Worker')]

# %%
len(y)
# Out:
# 2671

# %%
y.groupby('Zip Code of the Provider').Pct_Black.mean().value_counts().reset_index().sort_values('Pct_Black', ascending=False)
# Out:
#          index  Pct_Black
# 0     0.000000        309
# 1    50.000000          5
# 2    53.125000          2
# 3    25.490196          2
# 4    55.263158          2
# ..         ...        ...
# 93   15.000000          1
# 94   46.000000          1
# 95   40.000000          1
# 96   12.500000          1
# 253  64.876033          1
#
# [254 rows x 2 columns]
