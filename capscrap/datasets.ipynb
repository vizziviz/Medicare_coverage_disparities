# %%
import pandas as pd

# %% [markdown]
# # Zip Code Level Data, for years 2012 through 2018

# %% [markdown]
# ## Medicare Providers and Utilization, mental health

# %%
df1 = pd.read_csv('/home/vizziwo/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2018.csv', chunksize = 50000)
z = 1
for i, chunk in enumerate(df1):
    if i ==0:
        df2 = chunk
    z += 1
print('df size is ', z*50000)
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# df size is  10050000

# %% [markdown]
# Is there a better way to do this?

# %%
df2.head()
# Out:
#    National Provider Identifier  \
# 0                             1
# 1                    1003000126
# 2                    1003000126
# 3                    1003000126
# 4                    1003000126
#
#          Last Name/Organization Name of the Provider  \
# 0  CPT copyright 2017 American Medical Associatio...
# 1                                          ENKESHAFI
# 2                                          ENKESHAFI
# 3                                          ENKESHAFI
# 4                                          ENKESHAFI
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                    ARDALAN                            NaN
# 2                    ARDALAN                            NaN
# 3                    ARDALAN                            NaN
# 4                    ARDALAN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# ...

# %%
df2.columns.unique()
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
df2[(df2['Provider Type']=='Psychiatry') |
   (df2['Provider Type']=='Psychologist, Clinical') |
   (df2['Provider Type']=='Licensed Clinical Social Worker')].head()
# Out:
#      National Provider Identifier Last Name/Organization Name of the Provider  \
# 187                    1003001272                               OCHOA-DURRELL
# 188                    1003001272                               OCHOA-DURRELL
# 270                    1003001819                                      TAVORA
# 323                    1003002106                              CASTRO CORDOBA
# 794                    1003005430                                    BEAUMONT
#
#     First Name of the Provider Middle Initial of the Provider  \
# 187                     DEANNE                              E
# 188                     DEANNE                              E
# 270                       SARA                              M
# 323                  JUAN LUIS                            NaN
# 794                      LAURA                              A
#
#     Credentials of the Provider Gender of the Provider  \
# 187                        LCSW                      F
# ...

# %%
z = df2[(df2['Provider Type']=='Psychiatry') |
   (df2['Provider Type']=='Psychologist, Clinical') |
   (df2['Provider Type']=='Licensed Clinical Social Worker')]
z['HCPCS Description'].unique()
# Out:
# array(['Psychotherapy, 45 minutes', 'Psychotherapy, 60 minutes',
#        'Established patient office or other outpatient visit, typically 15 minutes',
#        'Psychiatric diagnostic evaluation',
#        'Subsequent hospital inpatient care, typically 15 minutes per day',
#        'Subsequent hospital inpatient care, typically 25 minutes per day',
#        'Hospital discharge day management, 30 minutes or less',
#        'Established patient office or other outpatient visit, typically 10 minutes',
#        'Established patient office or other outpatient, visit typically 25 minutes',
#        'Emergency department visit, problem of high severity',
#        'Psychotherapy, 30 minutes',
#        'New patient office or other outpatient visit, typically 20 minutes',
#        'New patient office or other outpatient visit, typically 30 minutes',
#        'Initial hospital inpatient care, typically 30 minutes per day',
# ...

# %%
z.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %% [markdown]
# ## Medicare Providers and Demographics of Beneficiaries, mental health

# %%
chunks = pd.read_csv('/home/vizziwo/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2018.csv', chunksize=50000)
q = 1
for i, chunk in enumerate(chunks):
    if i == 0:
        df3 = chunk
    q+=1
print('df size is ', q*50000, 'rows. This DF is 1/',q,'of the whole dataset.')
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# df size is  1200000 rows. This DF is 1/ 24 of the whole dataset.

# %%
df3.head(2)
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                   2650 RIDGE AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN           CUMBERLAND  ...
# 1                EVANSTON HOSPITAL             EVANSTON  ...
#
# ...

# %%
df3.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'Provider RUCA',
#        'State Code of the Provider', 'Country Code of the Provider',
#        'Provider Type of the Provider', 'Medicare Participation Indicator',
#        'Number of HCPCS', 'Number of Services',
#        'Number of Medicare Beneficiaries', 'Total Submitted Charge Amount',
#        'Total Medicare Allowed Amount', 'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
# ...

# %%
df3[(df3['Provider Type of the Provider']=='Psychiatry') |
   (df3['Provider Type of the Provider']=='Psychologist, Clinical') |
   (df3['Provider Type of the Provider']=='Licensed Clinical Social Worker')].head(2)
# Out:
#     National Provider Identifier Last Name/Organization Name of the Provider  \
# 12                    1003000795                                     O'NEILL
# 19                    1003001272                               OCHOA-DURRELL
#
#    First Name of the Provider Middle Initial of the Provider  \
# 12                    MICHAEL                              J
# 19                     DEANNE                              E
#
#    Credentials of the Provider Gender of the Provider  \
# 12                       LICSW                      M
# 19                        LCSW                      F
#
#    Entity Type of the Provider Street Address 1 of the Provider  \
# 12                           I            1919 UNIVERSITY AVE W
# 19                           I                  125 FRANKLIN ST
#
#    Street Address 2 of the Provider City of the Provider  ...  \
# 12                              NaN           SAINT PAUL  ...
# ...

# %%
df3 = df3[(df3['Provider Type of the Provider']=='Psychiatry') |
   (df3['Provider Type of the Provider']=='Psychologist, Clinical') |
   (df3['Provider Type of the Provider']=='Licensed Clinical Social Worker')]
len(df3)
# Out:
# 2671

# %%
df3['Zip Code of the Provider'].nunique()
# Out:
# 2126

# %%
df3[['Number of Black or African American Beneficiaries', 'Percent (%) of Beneficiaries Identified With Depression',]]
# Out:
#        Number of Black or African American Beneficiaries  \
# 0                                                    NaN
# 1                                                   39.0
# 2                                                   60.0
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49995                                                NaN
# 49996                                                NaN
# 49997                                                NaN
# 49998                                               18.0
# 49999                                                NaN
#
#        Percent (%) of Beneficiaries Identified With Depression
# 0                                                   47.0
# 1                                                   15.0
# 2                                                   44.0
# ...

# %%
df3 = pd.read_csv('/home/vizziwo/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2018.csv')
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df3['Zip Code of the Provider'].nunique()
# Out:
# 34626

# %%
x = df3.groupby(by='Zip Code of the Provider', as_index=False).agg({'Number of Medicare Beneficiaries':'sum',
                                            'Number of Black or African American Beneficiaries':'sum',
                                            'Percent (%) of Beneficiaries Identified With Depression':'mean'})
y = x['Zip Code of the Provider'].unique()
list(y)
# Out:
# [0.0,
#  80.0,
#  96.0,
#  115.0,
#  601.0,
#  602.0,
#  603,
#  604.0,
#  605,
#  610.0,
#  612.0,
#  613.0,
#  614.0,
#  616.0,
#  617,
#  622,
#  623,
#  624.0,
#  627.0,
#  628.0,
#  629.0,
#  631.0,
#  634.0,
#  636.0,
#  637.0,
#  638,
#  641.0,
#  646.0,
#  647,
#  650.0,
#  652.0,
#  653.0,
#  656,
#  659.0,
#  660,
#  662,
#  664.0,
#  667.0,
#  668.0,
#  669.0,
#  670.0,
#  673,
#  674.0,
#  676.0,
#  677.0,
#  678.0,
#  680.0,
#  681,
#  682.0,
#  683.0,
#  685.0,
#  687,
#  688.0,
#  690.0,
#  692.0,
#  693.0,
#  694.0,
#  698.0,
#  703.0,
#  704.0,
#  705.0,
#  707.0,
#  714,
#  715.0,
#  716.0,
#  717.0,
#  718.0,
#  719.0,
#  720.0,
#  721.0,
#  723,
#  725.0,
#  726,
#  727.0,
#  728,
#  729.0,
#  730.0,
#  731,
#  732.0,
#  733.0,
#  734.0,
#  735,
#  736.0,
#  737.0,
#  738.0,
#  739.0,
#  741,
#  745.0,
#  751.0,
#  754.0,
#  757.0,
#  765.0,
#  766.0,
#  767.0,
#  769.0,
#  771.0,
#  772.0,
#  773,
#  777.0,
#  778.0,
#  780.0,
#  782.0,
#  783,
#  784,
#  785.0,
# ...

# %%
df3
# Out:
#          National Provider Identifier  \
# 0                          1003000126
# 1                          1003000134
# 2                          1003000142
# 3                          1003000407
# 4                          1003000423
# ...                               ...
# 1121457                    1992999551
# 1121458                    1992999569
# 1121459                    1992999759
# 1121460                    1992999775
# 1121461                    1992999825
#
#         Last Name/Organization Name of the Provider  \
# 0                                         ENKESHAFI
# 1                                            CIBULL
# 2                                            KHALIL
# 3                                           GIRARDI
# 4                                           VELOTTA
# ...                                             ...
# 1121457                                       MOLAI
# 1121458                                        YUEN
# ...

# %%
df3.groupby(by='Zip Code of the Provider')['Number of Medicare Beneficiaries',
                                            'Number of Black or African American Beneficiaries',
                                            'Percent (%) of Beneficiaries Identified With Depression']
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np
y = list(df3['Zip Code of the Provider'].unique())
list(np.sort(y))
# Out:
# ['0.0',
#  '001',
#  '00601',
#  '00602',
#  '00603',
#  '00604',
#  '00605',
#  '00610',
#  '00611',
#  '00612',
#  '00613',
#  '00614',
#  '00616',
#  '00617',
#  '00623',
#  '00627',
#  '00631',
#  '00637',
#  '00641',
#  '00646',
#  '00647',
#  '00648',
#  '00653',
#  '00656',
#  '00659',
#  '00660',
#  '00662',
#  '00667',
#  '00669',
#  '00674',
#  '00676',
#  '00677',
#  '00678',
#  '00680',
#  '00681',
#  '00682',
#  '00683',
#  '00685',
#  '00687',
#  '00692',
#  '00693',
#  '00694',
#  '00698',
#  '00703',
#  '00705',
#  '00714',
#  '00715',
#  '00716',
#  '00717',
#  '00718',
#  '00719',
#  '00720',
#  '00723',
#  '00725',
#  '00726',
#  '00727',
#  '00728',
#  '00729',
#  '00730',
#  '00731',
#  '00733',
#  '00735',
#  '00736',
#  '00737',
#  '00738',
#  '00739',
#  '00745',
#  '00751',
#  '00754',
#  '00757',
#  '00765',
#  '00766',
#  '00767',
#  '00769',
#  '00771',
#  '00772',
#  '00775',
#  '00777',
#  '00778',
#  '00780',
#  '00782',
#  '00783',
#  '00784',
# ...

# %%
y='0'
y.as
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-1e8409c73f17> in <module>
#       1 y='0'
# ----> 2 y.astype('int')
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
x['Zip Code of the Provider'] = x['Zip Code of the Provider'].astype('int', errors='ignore').apply(lambda x: '{0:0>7}'.format(x)).astype('int', errors='ignore')

# %%
y = x['Zip Code of the Provider'].astype('float', errors='ignore').astype('int', errors='ignore')

# %%
y = y.apply(lambda x: x.replace('x.0'))

# %%
y
# Out:
# 0        00000.0
# 1        00080.0
# 2        00096.0
# 3        00115.0
# 4        00601.0
#           ...
# 34621    00P3E6H
# 34622    00SP606
# 34623    00T2N2T
# 34624    00V5Z0A
# 34625    00V6Y 2
# Name: Zip Code of the Provider, Length: 34626, dtype: object

# %% [markdown]
# ## HPSAs by Zip

# %%
df4 = pd.read_csv('/home/vizziwo/results-20201205-143407.csv')
# Out:
# /opt/miniconda3/envs/cap2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (67,68,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df4.head()
# Out:
#     Source_ID                              Source_Name Status_Code  \
# 0  7549995446  East Ridge Health Systems - Martinsburg           W
# 1  7549995415                Fairmont General Hospital           W
# 2  7389993809          Northwest Human Services Center           W
# 3  7389993808                Family Health Care Center           W
# 4  7389993807          Southeast Human Services Center           W
#
#   Status_Description Type_Code       Type_Desc          Address         City  \
# 0          Withdrawn      OFAC  Other Facility   235 S Water St  Martinsburg
# 1          Withdrawn      OFAC  Other Facility  1325 Locust Ave     Fairmont
# 2          Withdrawn      OFAC  Other Facility    316 2nd Ave W    Williston
# 3          Withdrawn      OFAC  Other Facility              NaN          NaN
# 4          Withdrawn      OFAC  Other Facility    2627 9th St N        Fargo
#
#   State_Abbr Postal_Code  ... Common_State_Name Common_State_FIPS  \
# ...

# %%
df4.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Degree_of_Shortage', 'Designation_Date',
#        'Designation_Last_Update_Date', 'Designation_Pop',
#        'Estimated_Underserved_Pop', 'Estimated_Served_Pop', 'Formal_Ratio',
#        'Total_FTE_Clinicians', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'Provider_Ratio_Goal',
#        'Percent_Pop_Below_Poverty', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Component_State_Abbr', 'Component_Postal_Code',
#        'Component_Designation_Date', 'Component_Designation_Date_String',
#        'Component_Designation_Last_Update_Date', 'Geography_ID', 'CountyFIPS',
# ...

# %%
df4.Postal_Code.nunique()
# Out:
# 2316

# %%
df4.City.nunique()
# Out:
# 1653

# %%
df0 = pd.read_csv('/home/vizziwo/medicaire_hpsa.csv')

# %%
df0.columns
# Out:
# Index(['HPSA Name', 'HPSA ID', 'Designation Type', 'HPSA Discipline Class',
#        'HPSA Score', 'Primary State Abbreviation', 'HPSA Status',
#        'HPSA Designation Date', 'HPSA Designation Last Update Date',
#        'Metropolitan Indicator', 'HPSA Geography Identification Number',
#        'HPSA Degree of Shortage', 'Withdrawn Date', 'HPSA FTE',
#        'HPSA Designation Population', '% of Population Below 100% Poverty',
#        'HPSA Formal Ratio', 'HPSA Population Type', 'Primary HHS Region Name',
#        'Rural Status', 'Longitude', 'Latitude',
#        'BHCMIS Organization Identification Number', 'Break in Designation',
#        'Common County Name', 'Common Postal Code', 'Common Region Name',
#        'Common State Abbreviation', 'Common State County FIPS Code',
#        'Common State FIPS Code', 'Common State Name', 'County Equivalent Name',
#        'County or County Equivalent Federal Information Processing Standard Code',
# ...

# %%
df0['Common Postal Code'].nunique()
# Out:
# 4177

# %%
df0['HPSA Postal Code'].nunique()
# Out:
# 5406

# %% [markdown]
# THIS PROBABLY ISN'T USEFUL

# %% [markdown]
# ## Census Data by Zip Code

# %%
df5 = pd.read_csv('/home/vizziwo/drive_census_zipcode.csv')

# %%
df5.shape
# Out:
# (33120, 240)

# %%
df5.columns
# Out:
# Index(['geo_id', 'do_date', 'total_pop', 'households', 'male_pop',
#        'female_pop', 'median_age', 'male_under_5', 'male_5_to_9',
#        'male_10_to_14',
#        ...
#        'management_business_sci_arts_employed', 'sales_office_employed',
#        'in_grades_1_to_4', 'in_grades_5_to_8', 'in_grades_9_to_12',
#        'in_school', 'in_undergrad_college', 'speak_only_english_at_home',
#        'speak_spanish_at_home', 'speak_spanish_at_home_low_english'],
#       dtype='object', length=240)

# %%
df5.head()
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   87537  2014-01-01       2510         856      1283        1227
# 1   87017  2014-01-01        346         112       150         196
# 2   87528  2014-01-01       3505         727      1758        1747
# 3   87533  2014-01-01        133          58        49          84
# 4   87511  2014-01-01       2896         787      1177        1719
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  ...  \
# 0        42.1            58           75             87  ...
# 1        50.9             0            0             12  ...
# 2        27.9           260          194            159  ...
# 3        25.8             0           12              8  ...
# 4        36.0           142           63             44  ...
#
#    management_business_sci_arts_employed  sales_office_employed  \
# 0                                    NaN                    NaN
# ...

# %%
df5.merge(df3, how='inner', left_on ='geo_id', right_on = 'Zip Code of the Provider')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72e90cc76312> in <module>
# ----> 1 df5.merge(df3, how='inner', left_on ='geo_id', right_on = 'Zip Code of the Provider')
#
# NameError: name 'df5' is not defined

# %% [markdown]
# # County Level Data, for years 2012 through 2018

# %% [markdown]
# ## Prevalence (% of beneficiaries / total population, i think. Or total beneficiaries)

# %%
df = pd.read_csv('/home/vizziwo/mmd_data (5).csv')

# %%
df.head()
# Out:
#    year geography     measure         adjustment      analysis  \
# 0  2018    County  Prevalence  Unsmoothed actual  Base measure
# 1  2018    County  Prevalence  Unsmoothed actual  Base measure
# 2  2018    County  Prevalence  Unsmoothed actual  Base measure
# 3  2018    County  Prevalence  Unsmoothed actual  Base measure
# 4  2018    County  Prevalence  Unsmoothed actual  Base measure
#
#                        domain   condition primary_sex primary_age  \
# 0  Primary chronic conditions  Depression         All         All
# 1  Primary chronic conditions  Depression         All         All
# 2  Primary chronic conditions  Depression         All         All
# 3  Primary chronic conditions  Depression         All         All
# 4  Primary chronic conditions  Depression         All         All
#
#       primary_dual  fips          county    state  urban primary_race  \
# 0  Dual & non-dual  1001  Autauga County  ALABAMA  Urban        Black
# ...

# %%
df.primary_denominator.unique()
# Out:
# array(['500-999', '1,000-4,999', '11-499', '10,000+', '5,000-9,999'],
#       dtype=object)

# %%
df.shape
# Out:
# (2145, 18)

# %% [markdown]
# ##  AVG PRINCIPAL COST (there's another dataset for total cost)

# %%
dg = pd.read_csv('/home/vizziwo/mmd_data (4).csv')

# %%
dg.head()
# Out:
#    year geography                 measure         adjustment      analysis  \
# 0  2018    County  Average principal cost  Unsmoothed actual  Base measure
# 1  2018    County  Average principal cost  Unsmoothed actual  Base measure
# 2  2018    County  Average principal cost  Unsmoothed actual  Base measure
# 3  2018    County  Average principal cost  Unsmoothed actual  Base measure
# 4  2018    County  Average principal cost  Unsmoothed actual  Base measure
#
#                        domain   condition primary_sex primary_age  \
# 0  Primary chronic conditions  Depression         All         All
# 1  Primary chronic conditions  Depression         All         All
# 2  Primary chronic conditions  Depression         All         All
# 3  Primary chronic conditions  Depression         All         All
# 4  Primary chronic conditions  Depression         All         All
#
#       primary_dual  fips          county    state  urban primary_race  \
# ...

# %%
df.shape
# Out:
# (3223, 18)
